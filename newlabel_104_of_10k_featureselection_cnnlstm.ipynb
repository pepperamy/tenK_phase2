# %% [markdown]
# <a href="https://colab.research.google.com/github/pepperamy/tenK_phase2/blob/main/newlabel_104_of_10k_featureselection_cnnlstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # packages

# %%
import pandas as pd
import pickle
import re
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from scipy.optimize import linear_sum_assignment
import time

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import statsmodels.api as sm
import statsmodels.formula.api as smf

import warnings
warnings.filterwarnings('ignore')

from scipy.stats import mstats
import math

from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import KFold,StratifiedKFold

# %%
from keras import regularizers

# %%
from keras import metrics

# %%
from keras import backend as K

# %%
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, precision_recall_curve, classification_report,accuracy_score, auc, roc_curve, roc_auc_score, average_precision_score

# %%
from keras.models import Sequential
from sklearn.metrics import mean_squared_error
from keras.layers import Embedding, Dense, Conv2D, MaxPooling2D, Reshape, Conv1D, MaxPooling1D, ZeroPadding1D,\
Dropout, Activation, Input, Flatten, Concatenate, BatchNormalization, Lambda, LSTM, GRU, Bidirectional,\
ZeroPadding2D
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from keras import regularizers
from keras.models import Model
from keras import optimizers







from keras import models
from keras import layers

# %%
from sklearn.utils import class_weight

# %%
from sklearn import utils

# %%
import random

# %%
from sklearn.svm import LinearSVC,SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score
#from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
from matplotlib.font_manager import FontProperties
from matplotlib import pyplot as plt

# %% [markdown]
# # data prepare

# %%
df = pd.read_csv('data_performance_words_win1_03_new.csv')

# %%
df.shape
# Out:
# (64860, 193)

# %%
sum(df.label)
# Out:
# 487.0

# %%
df.head()
# Out:
#     cik      y1      y2        s1  ...  Risk_3_new  Risk_3_p  Risk_3_u  label_new
# 0  20.0  1995.0  1996.0  0.633505  ...    0.019737  0.000000  0.571429          0
# 1  20.0  1996.0  1997.0  0.803827  ...    0.000000  0.066667  0.800000          0
# 2  20.0  1997.0  1998.0  0.462705  ...    0.004688  0.066667  0.533333          0
# 3  20.0  1998.0  1999.0  0.701689  ...    0.000000  0.090909  0.545455          0
# 4  20.0  1999.0  2000.0  0.823023  ...    0.010870  0.000000  0.764706          0
#
# [5 rows x 193 columns]

# %%
df_fl = df[(df.y2 <= 2015) & (df.y2 >= 1995 ) ]

# %%
df_fl.label.value_counts()
# Out:
# 0.0    61257
# 1.0      487
# Name: label, dtype: int64

# %%
df_fl.shape
# Out:
# (61744, 193)

# %%
selected_new = ['WeakModal','Negative', 'Compare', 'Discrep','Positive',\
         'Achieve',  'Reward', 'StrongModal','Uncertainty', 'Litigious']#[::-1]

v_perf = ['aqi',
 'asset_turnover',
 'depi',
 'gmi',
 #'ig',
 'opm',
 'rg',
 'sg',
 'sgee',
 'ch_rec',
 'ch_inv',
 'soft_asset',
 'ch_cs',
 'ch_roa',
 'issue']

v_1 = ['s1']
v_2 = ['pastavg3','cr3']

# %%
# selected_comb = []
# for s in selected_new:
#   selected_comb.append(s+'_up')
#   selected_comb.append(s+'_down')

# %%
selected_new_all = []
temp = []
for s in selected_new:
    wrd = s.split('_')[0]
    if wrd not in temp:
        #print(s,'\n',temp)
        #selected_new_all.append(wrd+'_3_avg')
        selected_new_all.append(wrd+'_3_p')
        selected_new_all.append(wrd+'_3_n')
        #selected_new_all.append(wrd+'_3_u')
        selected_new_all.append(wrd+'_3_new')
        selected_new_all.append(wrd+'_3_dis')
        temp.append(wrd)
    else: 
        pass

# %%
selected_new_all
# Out:
# ['WeakModal_3_p',
#  'WeakModal_3_n',
#  'WeakModal_3_new',
#  'WeakModal_3_dis',
#  'Negative_3_p',
#  'Negative_3_n',
#  'Negative_3_new',
#  'Negative_3_dis',
#  'Compare_3_p',
#  'Compare_3_n',
#  'Compare_3_new',
#  'Compare_3_dis',
#  'Discrep_3_p',
#  'Discrep_3_n',
#  'Discrep_3_new',
#  'Discrep_3_dis',
#  'Positive_3_p',
#  'Positive_3_n',
#  'Positive_3_new',
#  'Positive_3_dis',
#  'Achieve_3_p',
#  'Achieve_3_n',
#  'Achieve_3_new',
#  'Achieve_3_dis',
#  'Reward_3_p',
#  'Reward_3_n',
#  'Reward_3_new',
#  'Reward_3_dis',
#  'StrongModal_3_p',
#  'StrongModal_3_n',
#  'StrongModal_3_new',
#  'StrongModal_3_dis',
#  'Uncertainty_3_p',
#  'Uncertainty_3_n',
#  'Uncertainty_3_new',
#  'Uncertainty_3_dis',
#  'Litigious_3_p',
#  'Litigious_3_n',
#  'Litigious_3_new',
#  'Litigious_3_dis']

# %%
selected_new_all_sorted = []
selected_new_all_p = []
selected_new_all_n = []
selected_new_all_new = []
selected_new_all_dis = []
for s in selected_new_all:
  if 'new' in s.split('_'):
    selected_new_all_new.append(s)
  elif 'p' in s.split('_'):
    selected_new_all_p.append(s)
  elif 'n' in s.split('_'):
    selected_new_all_n.append(s)
  elif 'dis' in s.split('_'):
    selected_new_all_dis.append(s)

for i, w in enumerate(selected_new_all_p):
  selected_new_all_sorted.append(selected_new_all_p[i])
  selected_new_all_sorted.append(selected_new_all_new[i])
  selected_new_all_sorted.append(selected_new_all_n[i])
  
  selected_new_all_sorted.append(selected_new_all_dis[i])

# %%
selected_new_all_sorted
# Out:
# ['WeakModal_3_p',
#  'WeakModal_3_new',
#  'WeakModal_3_n',
#  'WeakModal_3_dis',
#  'Negative_3_p',
#  'Negative_3_new',
#  'Negative_3_n',
#  'Negative_3_dis',
#  'Compare_3_p',
#  'Compare_3_new',
#  'Compare_3_n',
#  'Compare_3_dis',
#  'Discrep_3_p',
#  'Discrep_3_new',
#  'Discrep_3_n',
#  'Discrep_3_dis',
#  'Positive_3_p',
#  'Positive_3_new',
#  'Positive_3_n',
#  'Positive_3_dis',
#  'Achieve_3_p',
#  'Achieve_3_new',
#  'Achieve_3_n',
#  'Achieve_3_dis',
#  'Reward_3_p',
#  'Reward_3_new',
#  'Reward_3_n',
#  'Reward_3_dis',
#  'StrongModal_3_p',
#  'StrongModal_3_new',
#  'StrongModal_3_n',
#  'StrongModal_3_dis',
#  'Uncertainty_3_p',
#  'Uncertainty_3_new',
#  'Uncertainty_3_n',
#  'Uncertainty_3_dis',
#  'Litigious_3_p',
#  'Litigious_3_new',
#  'Litigious_3_n',
#  'Litigious_3_dis']

# %% [markdown]
# # SVM
# #### variables:
# #### A. Quant. Indicators
# #### B. Overall Similarity+ Word Changes
# #### C. Quant. Indicators + Overall Similarity
# #### D. Quant. Indicators + Overall Similarity + Word Changes

# %%
def svm( data, vs, label = 'label'):
    
    columns_fl = vs[1] #+ [ 'sic_class_x']
    
    data_target = data.loc[:,columns_fl + [label]]
    
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    
    class_report = []
    sum_pred_list = []

    kf = StratifiedKFold(n_splits = 4, shuffle = True)
    c = 0
    data_target = data[columns_fl + [label]]
    data_target = data_target.dropna()
    data_target = data_target.reset_index(drop = True)
    print('dataset: ', data_target.shape, '/n', sum(data_target[label]))
     
    for train_index, test_index in kf.split(data_target[columns_fl],data_target[label]):
        
        c += 1

        train_x = data_target.loc[train_index,columns_fl]
        train_y = data_target.loc[train_index,label]
        test_x = data_target.loc[test_index,columns_fl]
        test_y = data_target.loc[test_index,label] 

        print('iterate_num: ', c, '\n','sum of test_y:', sum(test_y))
    
        svm = LinearSVC(class_weight = "balanced")
        svm.fit(train_x, train_y )
        pickle.dump(svm, open('svm_'+str(vs[0])+ '_'+str(c), 'wb'))
        

        pred = svm.predict(test_x)
        sum_pred_list.append(pred)
        print('sum of pred: ', sum(pred), '\n')
        # c_r = metrics.classification_report(test_y, pred, labels=[0,1], output_dict = True)
        # class_report.append(c_r)
        #print(metrics.classification_report(test_y, pred, labels=[0,1]))
        
        decision_values = svm.decision_function(test_x)
        auc_score = roc_auc_score(test_y, decision_values)
        print(auc_score)
        auc_list.append(auc_score)
        
        fpr, tpr, thresholds = roc_curve(test_y, decision_values)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        
#         mean_tpr = np.mean(tprs, axis=0)
#         mean_auc = auc(mean_fpr, mean_tpr)
        
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    frauds_prec = []
    fradus_recall = []
    for d in class_report:
        frauds_prec.append(d['1']['precision'])
        fradus_recall.append(d['1']['recall'])
    
#     coef_s = 0
#     for i in coef:
#         coef_s += abs(i)
#     coef_avg = coef_s / len(coef)
#     coef_top = pd.DataFrame(coef_avg, index = columns_fl,columns = ['importance'])
#     coef_top = coef_top.sort_values('importance',ascending=False)
#     print(coef_top.iloc[0:10,:])
        
    print('frauds_prec : ', np.mean(frauds_prec))
    print('fradus_recall : ', np.mean(fradus_recall))
    print('\n')
    return np.mean(auc_list),mean_tpr

# %%
df_fl.label_new
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 64795    0
# 64797    0
# 64802    0
# 64803    0
# 64808    0
# Name: label_new, Length: 61744, dtype: int64

# %%
# without timestep
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
mean_tpr_dict_svm = dict()
for fl in vs_fl.items():
#    print(fl)
    svm_model = svm( df_fl, fl,label = 'label_new')
    print(fl)
    print(svm_model[0])
    mean_tpr_dict_svm[fl[0]] = svm_model[1]
    print('============================')
# Out:
# dataset:  (61744, 15) /n 545
# iterate_num:  1
#  sum of test_y: 136
# sum of pred:  3235
#
# 0.6789547289504037
# iterate_num:  2
#  sum of test_y: 136
# sum of pred:  3168
#
# 0.7103787004998077
# iterate_num:  3
#  sum of test_y: 136
# sum of pred:  3497
#
# 0.6522606689734718
# iterate_num:  4
#  sum of test_y: 137
# sum of pred:  3375
#
# 0.653919463272968
# avg_AUC :  0.6738783904241629
# avg_AUC_2 :  0.673978270250812
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6738783904241629
# ============================
# dataset:  (61744, 16) /n 545
# iterate_num:  1
#  sum of test_y: 136
# sum of pred:  3146
#
# 0.7151768550557478
# iterate_num:  2
#  sum of test_y: 136
# sum of pred:  3117
#
# 0.6666589773164168
# iterate_num:  3
#  sum of test_y: 136
# sum of pred:  3008
#
# 0.6944002306805075
# iterate_num:  4
#  sum of test_y: 137
# sum of pred:  3157
#
# 0.654800204011235
# avg_AUC :  0.6827590667659768
# avg_AUC_2 :  0.6827687431420256
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.6827590667659768
# ============================
# dataset:  (61744, 42) /n 545
# iterate_num:  1
#  sum of test_y: 136
# sum of pred:  5874
#
# 0.6267411572472126
# iterate_num:  2
#  sum of test_y: 136
# sum of pred:  5783
#
# 0.6068242983467897
# iterate_num:  3
#  sum of test_y: 136
# sum of pred:  5744
#
# 0.6327465397923876
# iterate_num:  4
#  sum of test_y: 137
# sum of pred:  5694
#
# 0.5899941935997915
# avg_AUC :  0.6140765472465454
# avg_AUC_2 :  0.6141954376309249
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6140765472465454
# ============================
# dataset:  (61744, 56) /n 545
# iterate_num:  1
#  sum of test_y: 136
# sum of pred:  2872
#
# 0.6879488658208383
# iterate_num:  2
#  sum of test_y: 136
# sum of pred:  3190
#
# 0.703172337562476
# iterate_num:  3
#  sum of test_y: 136
# sum of pred:  3274
#
# 0.7198514994232988
# iterate_num:  4
#  sum of test_y: 137
# sum of pred:  3294
#
# 0.7117740150947323
# avg_AUC :  0.7056866794753364
# avg_AUC_2 :  0.7055582255574204
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7056866794753364
# ============================

# %% [markdown]
# # SVM with timestep (flat the T-year data and feed into SVM)
# ##### T =1,2,3
# ##### variables:
# ##### A. Quant. Indicators
# ##### B. Overall Similarity+ Word Changes
# ##### C. Quant. Indicators + Overall Similarity
# ##### D. Quant. Indicators + Overall Similarity + Word Changes

# %%
def svm_2( data, y, vs):
    
    # columns_fl = vs[1] #+ [ 'sic_class_x']
    
    # data_target = data.loc[:,columns_fl + [label]]
    
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    
    class_report = []
    sum_pred_list = []

    kf = StratifiedKFold(n_splits = 4, shuffle = True)
    c = 0
    # data_target = data[columns_fl + [label]]
    # data_target = data_target.dropna()
    # data_target = data_target.reset_index(drop = True)
    # print('dataset: ', data_target.shape, '/n', sum(data_target.label))
     
    for train_index, test_index in kf.split(data, y):
        
        c += 1

        train_x = data[train_index]
        train_y = y[train_index]
        test_x = data[test_index]
        test_y = y[test_index] 

        print('iterate_num: ', c, '\n','sum of train_y:', sum(train_y), 'train_x shape', train_x.shape)
    
        svm = LinearSVC(class_weight = "balanced")
        svm.fit(train_x, train_y )
        pickle.dump(svm, open('svm_'+str(vs)+ '_'+str(c), 'wb'))
        

        pred = svm.predict(test_x)
        sum_pred_list.append(pred)
        print('sum of pred: ', sum(pred), '\n')
        # c_r = metrics.classification_report(test_y, pred, labels=[0,1], output_dict = True)
        # class_report.append(c_r)
        #print(metrics.classification_report(test_y, pred, labels=[0,1]))
        
        decision_values = svm.decision_function(test_x)
        auc_score = roc_auc_score(test_y, decision_values)
        print(auc_score)
        auc_list.append(auc_score)
        
        fpr, tpr, thresholds = roc_curve(test_y, decision_values)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        
#         mean_tpr = np.mean(tprs, axis=0)
#         mean_auc = auc(mean_fpr, mean_tpr)
        
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    frauds_prec = []
    fradus_recall = []
    for d in class_report:
        frauds_prec.append(d['1']['precision'])
        fradus_recall.append(d['1']['recall'])
    
#     coef_s = 0
#     for i in coef:
#         coef_s += abs(i)
#     coef_avg = coef_s / len(coef)
#     coef_top = pd.DataFrame(coef_avg, index = columns_fl,columns = ['importance'])
#     coef_top = coef_top.sort_values('importance',ascending=False)
#     print(coef_top.iloc[0:10,:])
        
    print('frauds_prec : ', np.mean(frauds_prec))
    print('fradus_recall : ', np.mean(fradus_recall))
    print('\n')
    return np.mean(auc_list),mean_tpr

# %%
# Generate the flat structure T-year data  
def shift_data_2(data, step, cols, label):
    A = []
    
    A.append(data[cols].values)
    
    for t in range(1, step):
        d = data.groupby("cik")[cols].shift(t)
        A.append(d.values)
    A = A[::-1]
    A = np.concatenate(A, axis = 1)  # flatten shifted columns
    A = np.concatenate([data[label].values[:,None], A], axis = 1)  # add target


    
    A = A[~np.isnan(A).any(axis=1)]  # drop nan
    

    Y = A[:,0]  # get target
    D = A[:,1:]

    
    print(D.shape, Y.sum())
    # return A_perf, A_words, Y
    return D, Y

# %%
# with timestep = 1
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
mean_tpr_dict_svm = dict()
for fl in vs_fl.items():
    print(fl)
    data, y = shift_data_2(df_fl, 1, fl[1], 'label_new')
    svm_model = svm_2(data, y, fl[0])
    print(fl)
    print(svm_model[0])
    mean_tpr_dict_svm[fl[0]] = svm_model[1]
    print('============================')
# Out:
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# (61744, 14) 545.0
# iterate_num:  1
#  sum of train_y: 409.0 train_x shape (46308, 14)
# sum of pred:  3040.0
#
# 0.6617123221837755
# iterate_num:  2
#  sum of train_y: 409.0 train_x shape (46308, 14)
# sum of pred:  3968.0
#
# 0.634133506343714
# iterate_num:  3
#  sum of train_y: 409.0 train_x shape (46308, 14)
# sum of pred:  3490.0
#
# 0.7088249711649365
# iterate_num:  4
#  sum of train_y: 408.0 train_x shape (46308, 14)
# sum of pred:  3249.0
#
# 0.6897435689465893
# avg_AUC :  0.6736035921597539
# avg_AUC_2 :  0.6734572810544257
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6736035921597539
# ============================
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# (61744, 15) 545.0
# iterate_num:  1
#  sum of train_y: 409.0 train_x shape (46308, 15)
# sum of pred:  3197.0
#
# 0.7073731257208766
# iterate_num:  2
#  sum of train_y: 409.0 train_x shape (46308, 15)
# sum of pred:  3306.0
#
# 0.6641911764705882
# iterate_num:  3
#  sum of train_y: 409.0 train_x shape (46308, 15)
# sum of pred:  3231.0
#
# 0.6276254325259516
# iterate_num:  4
#  sum of train_y: 408.0 train_x shape (46308, 15)
# sum of pred:  2864.0
#
# 0.7105216074902087
# avg_AUC :  0.6774278355519063
# avg_AUC_2 :  0.6775408252772465
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.6774278355519063
# ============================
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# (61744, 41) 545.0
# iterate_num:  1
#  sum of train_y: 409.0 train_x shape (46308, 41)
# sum of pred:  5742.0
#
# 0.6306752210688197
# iterate_num:  2
#  sum of train_y: 409.0 train_x shape (46308, 41)
# sum of pred:  5653.0
#
# 0.5872707612456747
# iterate_num:  3
#  sum of train_y: 409.0 train_x shape (46308, 41)
# sum of pred:  5927.0
#
# 0.6307131872356786
# iterate_num:  4
#  sum of train_y: 408.0 train_x shape (46308, 41)
# sum of pred:  5826.0
#
# 0.594583015062766
# avg_AUC :  0.6108105461532347
# avg_AUC_2 :  0.6107889489571543
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6108105461532347
# ============================
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# (61744, 55) 545.0
# iterate_num:  1
#  sum of train_y: 409.0 train_x shape (46308, 55)
# sum of pred:  3087.0
#
# 0.719331507112649
# iterate_num:  2
#  sum of train_y: 409.0 train_x shape (46308, 55)
# sum of pred:  3314.0
#
# 0.6908217993079585
# iterate_num:  3
#  sum of train_y: 409.0 train_x shape (46308, 55)
# sum of pred:  3013.0
#
# 0.6959573241061131
# iterate_num:  4
#  sum of train_y: 408.0 train_x shape (46308, 55)
# sum of pred:  3108.0
#
# 0.7188070590940774
# avg_AUC :  0.7062294224051995
# avg_AUC_2 :  0.7062603547280447
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7062294224051995
# ============================

# %%
# with timestep = 2
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
mean_tpr_dict_svm = dict()
for fl in vs_fl.items():
    print(fl)
    data, y = shift_data_2(df_fl, 2, fl[1], 'label_new')
    svm_model = svm_2(data, y, fl[0])
    print(fl)
    print(svm_model[0])
    mean_tpr_dict_svm[fl[0]] = svm_model[1]
    print('============================')
# Out:
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# (53600, 28) 463.0
# iterate_num:  1
#  sum of train_y: 348.0 train_x shape (40200, 28)
# sum of pred:  604.0
#
# 0.7031572057403741
# iterate_num:  2
#  sum of train_y: 347.0 train_x shape (40200, 28)
# sum of pred:  758.0
#
# 0.6769960491750512
# iterate_num:  3
#  sum of train_y: 347.0 train_x shape (40200, 28)
# sum of pred:  753.0
#
# 0.6726461182236343
# iterate_num:  4
#  sum of train_y: 347.0 train_x shape (40200, 28)
# sum of pred:  979.0
#
# 0.657243222336438
# avg_AUC :  0.6775106488688744
# avg_AUC_2 :  0.6775104871806521
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6775106488688744
# ============================
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# (53600, 30) 463.0
# iterate_num:  1
#  sum of train_y: 348.0 train_x shape (40200, 30)
# sum of pred:  11788.0
#
# 0.7094991081801967
# iterate_num:  2
#  sum of train_y: 347.0 train_x shape (40200, 30)
# sum of pred:  762.0
#
# 0.7104657923973875
# iterate_num:  3
#  sum of train_y: 347.0 train_x shape (40200, 30)
# sum of pred:  751.0
#
# 0.6781855797485177
# iterate_num:  4
#  sum of train_y: 347.0 train_x shape (40200, 30)
# sum of pred:  697.0
#
# 0.674849313148304
# avg_AUC :  0.6932499483686014
# avg_AUC_2 :  0.6931324110671936
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.6932499483686014
# ============================
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# (53600, 82) 463.0
# iterate_num:  1
#  sum of train_y: 348.0 train_x shape (40200, 82)
# sum of pred:  4785.0
#
# 0.6822123676588503
# iterate_num:  2
#  sum of train_y: 347.0 train_x shape (40200, 82)
# sum of pred:  4415.0
#
# 0.5954220270172051
# iterate_num:  3
#  sum of train_y: 347.0 train_x shape (40200, 82)
# sum of pred:  4459.0
#
# 0.5865450009864084
# iterate_num:  4
#  sum of train_y: 347.0 train_x shape (40200, 82)
# sum of pred:  4750.0
#
# 0.6512780477421632
# avg_AUC :  0.6288643608511567
# avg_AUC_2 :  0.6288757136583224
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6288643608511567
# ============================
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# (53600, 110) 463.0
# iterate_num:  1
#  sum of train_y: 348.0 train_x shape (40200, 110)
# sum of pred:  1082.0
#
# 0.7435545155536647
# iterate_num:  2
#  sum of train_y: 347.0 train_x shape (40200, 110)
# sum of pred:  1260.0
#
# 0.7064072412754778
# iterate_num:  3
#  sum of train_y: 347.0 train_x shape (40200, 110)
# sum of pred:  1093.0
#
# 0.7175023881464868
# iterate_num:  4
#  sum of train_y: 347.0 train_x shape (40200, 110)
# sum of pred:  1292.0
#
# 0.702178015554102
# avg_AUC :  0.7174105401324329
# avg_AUC_2 :  0.7172612557357685
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7174105401324329
# ============================

# %%
# with timestep = 3
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
mean_tpr_dict_svm = dict()
for fl in vs_fl.items():
    print(fl)
    data, y = shift_data_2(df_fl, 3, fl[1], 'label_new')
    svm_model = svm_2(data, y, fl[0])
    print(fl)
    print(svm_model[0])
    mean_tpr_dict_svm[fl[0]] = svm_model[1]
    print('============================')
# Out:
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# (46409, 42) 395.0
# iterate_num:  1
#  sum of train_y: 296.0 train_x shape (34806, 42)
# sum of pred:  257.0
#
# 0.6806679450977087
# iterate_num:  2
#  sum of train_y: 297.0 train_x shape (34807, 42)
# sum of pred:  162.0
#
# 0.6645133192359003
# iterate_num:  3
#  sum of train_y: 296.0 train_x shape (34807, 42)
# sum of pred:  145.0
#
# 0.6804821228015178
# iterate_num:  4
#  sum of train_y: 296.0 train_x shape (34807, 42)
# sum of pred:  209.0
#
# 0.6687399071125055
# avg_AUC :  0.6736008235619081
# avg_AUC_2 :  0.6737143127835769
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6736008235619081
# ============================
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# (46409, 45) 395.0
# iterate_num:  1
#  sum of train_y: 296.0 train_x shape (34806, 45)
# sum of pred:  208.0
#
# 0.6592155912392352
# iterate_num:  2
#  sum of train_y: 297.0 train_x shape (34807, 45)
# sum of pred:  235.0
#
# 0.6663015171298005
# iterate_num:  3
#  sum of train_y: 296.0 train_x shape (34807, 45)
# sum of pred:  243.0
#
# 0.6947419074690222
# iterate_num:  4
#  sum of train_y: 296.0 train_x shape (34807, 45)
# sum of pred:  199.0
#
# 0.7208282073099946
# avg_AUC :  0.6852718057870131
# avg_AUC_2 :  0.6850946071725292
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.6852718057870131
# ============================
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# (46409, 123) 395.0
# iterate_num:  1
#  sum of train_y: 296.0 train_x shape (34806, 123)
# sum of pred:  3601.0
#
# 0.6519234416487545
# iterate_num:  2
#  sum of train_y: 297.0 train_x shape (34807, 123)
# sum of pred:  3628.0
#
# 0.6210688030427749
# iterate_num:  3
#  sum of train_y: 296.0 train_x shape (34807, 123)
# sum of pred:  3460.0
#
# 0.5841857679639129
# iterate_num:  4
#  sum of train_y: 296.0 train_x shape (34807, 123)
# sum of pred:  3659.0
#
# 0.6666122232496222
# avg_AUC :  0.6309475589762661
# avg_AUC_2 :  0.6311353589492117
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6309475589762661
# ============================
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# (46409, 165) 395.0
# iterate_num:  1
#  sum of train_y: 296.0 train_x shape (34806, 165)
# sum of pred:  529.0
#
# 0.7027164903555724
# iterate_num:  2
#  sum of train_y: 297.0 train_x shape (34807, 165)
# sum of pred:  622.0
#
# 0.7276670403905652
# iterate_num:  3
#  sum of train_y: 296.0 train_x shape (34807, 165)
# sum of pred:  477.0
#
# 0.7246199278712535
# iterate_num:  4
#  sum of train_y: 296.0 train_x shape (34807, 165)
# sum of pred:  531.0
#
# 0.7094073834054708
# avg_AUC :  0.7161027105057154
# avg_AUC_2 :  0.7158330886685864
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7161027105057154
# ============================

# %% [markdown]
# # LR
# ##### variables:
# ##### A. Quant. Indicators
# ##### B. Overall Similarity+ Word Changes
# ##### C. Quant. Indicators + Overall Similarity
# ##### D. Quant. Indicators + Overall Similarity + Word Changes

# %%
def lg( data,vs, label = 'label'):
    
    
    columns_fl = vs[1]# + [ 'sic_class_x']
    data_target = data.loc[:,columns_fl + [label]]
    
        
#     train_x, test_x, train_y, test_y = train_test_split(data_x, data_y,test_size=0.2, random_state=19, 
#                                                                         stratify = data_y) 

    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    
    class_report = []
    sum_pred_list = []
    kf = StratifiedKFold(n_splits = 4, shuffle = True)
    c = 0
    data_target = data[columns_fl + [label]]
    data_target = data_target.dropna()
    data_target = data_target.reset_index(drop = True)
    for train_index, test_index in kf.split(data_target[columns_fl],data_target[label]):
        
        c += 1

        train_x = data_target.loc[train_index,columns_fl]
        train_y = data_target.loc[train_index,label]
        test_x = data_target.loc[test_index,columns_fl]
        test_y = data_target.loc[test_index,label] 

        print('iterate_num: ', c, '\n','sum of test_y:', sum(test_y))
    
        lg = LogisticRegression(class_weight = 'balanced')
        lg.fit(train_x, train_y )
        pickle.dump(lg, open('lg_'+str(vs[0])+ '_'+str(c), 'wb'))

        pred = lg.predict(test_x)
        sum_pred_list.append(pred)
        print('sum of pred: ', sum(pred), '\n')
        # c_r = metrics.classification_report(test_y, pred, labels=[0,1], output_dict = True)
        # class_report.append(c_r)
        #print(metrics.classification_report(test_y, pred, labels=[0,1]))
        
        decision_values = lg.predict_proba(test_x)
        auc_score = roc_auc_score(test_y, decision_values[:,1])
        print(auc_score)
        auc_list.append(auc_score)
        fpr, tpr, thresholds = roc_curve(test_y, decision_values[:,1])
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        
        #print('AUC',auc_score)
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    frauds_prec = []
    fradus_recall = []
    for d in class_report:
        frauds_prec.append(d['1']['precision'])
        fradus_recall.append(d['1']['recall'])
        
    print('frauds_prec : ', np.mean(frauds_prec))
    print('fradus_recall : ', np.mean(fradus_recall))
    print('\n')
    return np.mean(auc_list),mean_tpr

# %%
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf+v_1+selected_new_all}
mean_tpr_dict_lg = dict()
for fl in vs_fl.items():
    lg_model = lg( df_fl, fl, label = 'label')
    print(fl)
    print(lg_model[0])
    mean_tpr_dict_lg[fl[0]] = lg_model[1]
    print('============================')
# Out:
# iterate_num:  1
#  sum of test_y: 121.0
# sum of pred:  6100.0
#
# 0.6839575525534033
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  6112.0
#
# 0.6747056695148765
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  6211.0
#
# 0.6752323492700347
# iterate_num:  4
#  sum of test_y: 122.0
# sum of pred:  5919.0
#
# 0.6491301220141433
# avg_AUC :  0.6707564233381145
# avg_AUC_2 :  0.6711430796243152
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6707564233381145
# ============================
# iterate_num:  1
#  sum of test_y: 121.0
# sum of pred:  5770.0
#
# 0.719786953319141
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  5902.0
#
# 0.6674268910693526
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  5686.0
#
# 0.6710371095129924
# iterate_num:  4
#  sum of test_y: 122.0
# sum of pred:  5788.0
#
# 0.6942142302018725
# avg_AUC :  0.6881162960258396
# avg_AUC_2 :  0.6880118246548946
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.6881162960258396
# ============================
# iterate_num:  1
#  sum of test_y: 121.0
# sum of pred:  5688.0
#
# 0.6594598824142052
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  5696.0
#
# 0.610473219619035
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  5620.0
#
# 0.6484139660056051
# iterate_num:  4
#  sum of test_y: 122.0
# sum of pred:  5535.0
#
# 0.6216624881978774
# avg_AUC :  0.6350023890591806
# avg_AUC_2 :  0.6348271360126122
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6350023890591806
# ============================
# iterate_num:  1
#  sum of test_y: 121.0
# sum of pred:  5140.0
#
# 0.7331039897685788
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  4994.0
#
# 0.6827626922327582
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  5223.0
#
# 0.7140974614463996
# iterate_num:  4
#  sum of test_y: 122.0
# sum of pred:  5280.0
#
# 0.7368592330600736
# avg_AUC :  0.7167058441269525
# avg_AUC_2 :  0.7165114086262983
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7167058441269525
# ============================

# %% [markdown]
# # LG with timestepwith timestep (flat the T-year data and feed into LG)
# ##### T=1,2,3
# ##### variables:
# ##### A. Quant. Indicators
# ##### B. Overall Similarity+ Word Changes
# ##### C. Quant. Indicators + Overall Similarity
# ##### D. Quant. Indicators + Overall Similarity + Word Changes

# %%
def lg_2( data, y, vs):
    
    
    # columns_fl = vs[1]# + [ 'sic_class_x']
    # data_target = data.loc[:,columns_fl + [label]]
    
        
#     train_x, test_x, train_y, test_y = train_test_split(data_x, data_y,test_size=0.2, random_state=19, 
#                                                                         stratify = data_y) 

    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    
    class_report = []
    sum_pred_list = []
    kf = StratifiedKFold(n_splits = 4, shuffle = True)
    c = 0
    # data_target = data[columns_fl + [label]]
    # data_target = data_target.dropna()
    # data_target = data_target.reset_index(drop = True)
    for train_index, test_index in kf.split(data, y):
        
        c += 1

        train_x = data[train_index]
        train_y = y[train_index]
        test_x = data[test_index]
        test_y = y[test_index] 

        print('iterate_num: ', c, '\n','sum of test_y:', sum(test_y))
    
        lg = LogisticRegression(class_weight = 'balanced')
        lg.fit(train_x, train_y )
        #pickle.dump(lg, open('lg_'+str(vs[0])+ '_'+str(c), 'wb'))

        pred = lg.predict(test_x)
        sum_pred_list.append(pred)
        print('sum of pred: ', sum(pred), '\n')
        # c_r = metrics.classification_report(test_y, pred, labels=[0,1], output_dict = True)
        # class_report.append(c_r)
        #print(metrics.classification_report(test_y, pred, labels=[0,1]))
        
        decision_values = lg.predict_proba(test_x)
        auc_score = roc_auc_score(test_y, decision_values[:,1])
        print(auc_score)
        auc_list.append(auc_score)
        fpr, tpr, thresholds = roc_curve(test_y, decision_values[:,1])
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        
        #print('AUC',auc_score)
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    frauds_prec = []
    fradus_recall = []
    for d in class_report:
        frauds_prec.append(d['1']['precision'])
        fradus_recall.append(d['1']['recall'])
        
    print('frauds_prec : ', np.mean(frauds_prec))
    print('fradus_recall : ', np.mean(fradus_recall))
    print('\n')
    return np.mean(auc_list),mean_tpr

# %%
# timestep = 1
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
mean_tpr_dict_lg = dict()
for fl in vs_fl.items():
    print(fl)
    data, y = shift_data_2(df_fl, 1, fl[1], 'label')
    lg_model = lg_2(data, y, fl[0])
    print(fl)
    print(lg_model[0])
    mean_tpr_dict_lg[fl[0]] = lg_model[1]
    print('============================')
# Out:
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# (61744, 14) 487.0
# iterate_num:  1
#  sum of test_y: 121.0
# sum of pred:  6174.0
#
# 0.6723840668280165
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  6020.0
#
# 0.6830163977245722
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  6009.0
#
# 0.6697343264600912
# iterate_num:  4
#  sum of test_y: 122.0
# sum of pred:  6006.0
#
# 0.6599441847918008
# avg_AUC :  0.6712697439511202
# avg_AUC_2 :  0.6712836945528992
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6712697439511202
# ============================
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# (61744, 15) 487.0
# iterate_num:  1
#  sum of test_y: 121.0
# sum of pred:  5763.0
#
# 0.6816716717526975
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  5801.0
#
# 0.7164118550046352
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  5614.0
#
# 0.663225228388467
# iterate_num:  4
#  sum of test_y: 122.0
# sum of pred:  5967.0
#
# 0.7163353151621681
# avg_AUC :  0.694411017576992
# avg_AUC_2 :  0.6939880446519112
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.694411017576992
# ============================
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# (61744, 41) 487.0
# iterate_num:  1
#  sum of test_y: 121.0
# sum of pred:  5582.0
#
# 0.62228032259196
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  5576.0
#
# 0.6589968035249005
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  5646.0
#
# 0.670144323098761
# iterate_num:  4
#  sum of test_y: 122.0
# sum of pred:  5721.0
#
# 0.636656803910276
# avg_AUC :  0.6470195632814744
# avg_AUC_2 :  0.6471918411865574
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6470195632814744
# ============================
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# (61744, 55) 487.0
# iterate_num:  1
#  sum of test_y: 121.0
# sum of pred:  5193.0
#
# 0.7196757891442248
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  5212.0
#
# 0.7278521528570236
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  5196.0
#
# 0.715860018797757
# iterate_num:  4
#  sum of test_y: 122.0
# sum of pred:  5016.0
#
# 0.697677256640768
# avg_AUC :  0.7152663043599433
# avg_AUC_2 :  0.7151367351882187
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7152663043599433
# ============================

# %%
# timestep = 2
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
mean_tpr_dict_lg = dict()
for fl in vs_fl.items():
    print(fl)
    data, y = shift_data_2(df_fl, 2, fl[1], 'label')
    lg_model = lg_2(data, y, fl[0])
    print(fl)
    print(lg_model[0])
    mean_tpr_dict_lg[fl[0]] = lg_model[1]
    print('============================')
# Out:
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# (53600, 28) 408.0
# iterate_num:  1
#  sum of test_y: 102.0
# sum of pred:  4924.0
#
# 0.6898206718391973
# iterate_num:  2
#  sum of test_y: 102.0
# sum of pred:  4875.0
#
# 0.6717308219723443
# iterate_num:  3
#  sum of test_y: 102.0
# sum of pred:  5251.0
#
# 0.6746193589482719
# iterate_num:  4
#  sum of test_y: 102.0
# sum of pred:  5180.0
#
# 0.6929296459146148
# avg_AUC :  0.682275124668607
# avg_AUC_2 :  0.6822638146167559
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.682275124668607
# ============================
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# (53600, 30) 408.0
# iterate_num:  1
#  sum of test_y: 102.0
# sum of pred:  4902.0
#
# 0.7313889159213092
# iterate_num:  2
#  sum of test_y: 102.0
# sum of pred:  4625.0
#
# 0.6719593687979026
# iterate_num:  3
#  sum of test_y: 102.0
# sum of pred:  4811.0
#
# 0.7037126325940212
# iterate_num:  4
#  sum of test_y: 102.0
# sum of pred:  4639.0
#
# 0.7016114762945336
# avg_AUC :  0.7021680984019416
# avg_AUC_2 :  0.7019706872648048
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.7021680984019416
# ============================
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# (53600, 82) 408.0
# iterate_num:  1
#  sum of test_y: 102.0
# sum of pred:  4532.0
#
# 0.6428727303825725
# iterate_num:  2
#  sum of test_y: 102.0
# sum of pred:  4446.0
#
# 0.6666275925319745
# iterate_num:  3
#  sum of test_y: 102.0
# sum of pred:  4611.0
#
# 0.6513967897280735
# iterate_num:  4
#  sum of test_y: 102.0
# sum of pred:  4506.0
#
# 0.630147832933745
# avg_AUC :  0.6477612363940913
# avg_AUC_2 :  0.6477767874826698
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6477612363940913
# ============================
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# (53600, 110) 408.0
# iterate_num:  1
#  sum of test_y: 102.0
# sum of pred:  4046.0
#
# 0.7206059292419027
# iterate_num:  2
#  sum of test_y: 102.0
# sum of pred:  4093.0
#
# 0.7316484271554914
# iterate_num:  3
#  sum of test_y: 102.0
# sum of pred:  4001.0
#
# 0.6869719462457866
# iterate_num:  4
#  sum of test_y: 102.0
# sum of pred:  4097.0
#
# 0.7522309119165789
# avg_AUC :  0.7228643036399398
# avg_AUC_2 :  0.7229897009308773
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7228643036399398
# ============================

# %%
# timestep = 3
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
mean_tpr_dict_lg = dict()
for fl in vs_fl.items():
    print(fl)
    data, y = shift_data_2(df_fl, 3, fl[1], 'label')
    lg_model = lg_2(data, y, fl[0])
    print(fl)
    print(lg_model[0])
    mean_tpr_dict_lg[fl[0]] = lg_model[1]
    print('============================')
# Out:
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# (46409, 42) 341.0
# iterate_num:  1
#  sum of test_y: 86.0
# sum of pred:  4539.0
#
# 0.6993170863697951
# iterate_num:  2
#  sum of test_y: 85.0
# sum of pred:  4338.0
#
# 0.6444396774078217
# iterate_num:  3
#  sum of test_y: 85.0
# sum of pred:  4404.0
#
# 0.7032100884115042
# iterate_num:  4
#  sum of test_y: 85.0
# sum of pred:  4325.0
#
# 0.6581901945461696
# avg_AUC :  0.6762892616838226
# avg_AUC_2 :  0.6759458469786787
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6762892616838226
# ============================
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# (46409, 45) 341.0
# iterate_num:  1
#  sum of test_y: 86.0
# sum of pred:  4139.0
#
# 0.7277664362691351
# iterate_num:  2
#  sum of test_y: 85.0
# sum of pred:  4032.0
#
# 0.7092175760640281
# iterate_num:  3
#  sum of test_y: 85.0
# sum of pred:  3955.0
#
# 0.6964558785222869
# iterate_num:  4
#  sum of test_y: 85.0
# sum of pred:  4012.0
#
# 0.6862785958353125
# avg_AUC :  0.7049296216726906
# avg_AUC_2 :  0.7047665436858324
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.7049296216726906
# ============================
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# (46409, 123) 341.0
# iterate_num:  1
#  sum of test_y: 86.0
# sum of pred:  3490.0
#
# 0.6576738935971294
# iterate_num:  2
#  sum of test_y: 85.0
# sum of pred:  3646.0
#
# 0.6859394552298648
# iterate_num:  3
#  sum of test_y: 85.0
# sum of pred:  3562.0
#
# 0.6906608645020915
# iterate_num:  4
#  sum of test_y: 85.0
# sum of pred:  3464.0
#
# 0.6309363651686254
# avg_AUC :  0.6663026446244278
# avg_AUC_2 :  0.665965054097749
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6663026446244278
# ============================
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# (46409, 165) 341.0
# iterate_num:  1
#  sum of test_y: 86.0
# sum of pred:  3284.0
#
# 0.7209766755312168
# iterate_num:  2
#  sum of test_y: 85.0
# sum of pred:  3194.0
#
# 0.7052214373636926
# iterate_num:  3
#  sum of test_y: 85.0
# sum of pred:  3299.0
#
# 0.7032489057097181
# iterate_num:  4
#  sum of test_y: 85.0
# sum of pred:  3188.0
#
# 0.7076087012038471
# avg_AUC :  0.7092639299521186
# avg_AUC_2 :  0.7093033619367408
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7092639299521186
# ============================

# %% [markdown]
# # NN
# ##### T=1
# ##### variables:
# ##### A. Quant. Indicators
# ##### C. Quant. Indicators + Overall Similarity

# %%
def model_M1(n1,n2):
    model_m1 = None
    model_m1 = Sequential(name = 'M1')
    model_m1.add(BatchNormalization())
    model_m1.add(layers.Dense(n1,name = 'layer_1',activation='relu'))
    model_m1.add(layers.Dropout(0.3))
    #model_m1.add(layers.Dense(64,name = 'layer_2'))
    model_m1.add(BatchNormalization())
    model_m1.add(layers.Dense(n2,name = 'layer_2',activation='relu'))
    model_m1.add(layers.Dense(1,activation='sigmoid'))
    
    return model_m1

# %%
def performance_measure(pred_yp, y):
    '''
    Given lists of predicted y probability and x, y, return a dataframe of AR, AUC, Brier, Decile Table
    '''
    
    tenc_dat = pd.DataFrame({'y_true':y,'probability':pred_yp.flatten()})
    tenc_dat.sort_values('probability',axis = 0,ascending=False, inplace = True)
    tenc_dat.index = range(0,len(tenc_dat))
    y = tenc_dat['y_true']
    point = float(len(tenc_dat))/10
    point = int(round(point))
    tenc = []
    for i in range(0,10):
        tenc.append(y[(i*point):((i+1)*point)])
    tenc[9]=tenc[9].append(y[10*point:])
    total = sum(y)
    num_of_bkr = []
    for j in range(0,10):
        num_of_bkr.append(sum(tenc[j]))
    tencile_bkr = np.array(num_of_bkr)
    rate = tencile_bkr.astype(float)/total

    return rate

# %%
class AUCEvaluation(Callback):
    """ Show AUC after interval number of epoches """
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()
        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            logs['auc'] = score
            tencile=performance_measure(y_pred, self.y_val)
            logs['tencile'] = tencile
            print(" epoch:{:d} auc: {:.4f}".format(epoch, score))

# %%
def fit_model( model,x_train, y_train, x_val, y_val, x_test, y_test, model_name, verbose = 0):
    
    history = None
    result = None
    
    model_df = model
    
    #class weight for test 
    class_weights = class_weight.compute_class_weight('balanced',
                              np.unique(y_train),
                              y_train)
    class_weights = {l:c for l,c in zip(np.unique(y_train), class_weights)}
    print('class_weights',class_weights)
    # class weight for val
    val_class_weights = class_weight.compute_class_weight('balanced',
                                np.unique(y_val),
                                y_val)
    val_class_weights = {l:c for l,c in zip(np.unique(y_val), val_class_weights)}
    val_sample_weights = []
    for y in y_val:
        if y == 1:
          val_sample_weights.append(val_class_weights[1])
        else: val_sample_weights.append(val_class_weights[0])
    val_sample_weights = np.asarray(val_sample_weights)
    
    
    auc_eval = AUCEvaluation(validation_data=(x_val, y_val), interval=1)
    earlyStopping = EarlyStopping(monitor='val_my_auc',patience = 3, 
                      verbose =verbose, mode ='max')
    checkpoint = ModelCheckpoint(model_name,monitor='val_my_auc',verbose=verbose,
              save_best_only=True, save_weights_only=True, mode ='max')

    opt = optimizers.RMSprop(lr=0.0005)
    model_df.compile(optimizer= opt,
              loss='binary_crossentropy',
              metrics=['accuracy', metrics.AUC(name='my_auc')])
    
    history = model_df.fit(x_train,
                y_train,
                epochs=30,
                batch_size=512,
                callbacks=[auc_eval, earlyStopping,checkpoint], #checkpoint
                class_weight = class_weights, \
                validation_data=(x_val,y_val,val_sample_weights))
    model_df.summary()
    model_df.load_weights(model_name)
    y_pred = model_df.predict(x_test)
    y_pred_1=np.reshape(y_pred, -1)
    auc_score = roc_auc_score(y_test, y_pred_1)
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_1)
    print("AUC: " ,round(auc_score,4))
        
    return history, auc_score, fpr, tpr, thresholds, [y_test, y_pred_1]

# %%
def cross_val(n1, n2, data,label,columns_fl,model_name):
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    
    kf = StratifiedKFold(n_splits = 4, shuffle = True)
    c = 0
    data_1 = data[columns_fl + [label]]
    data_1 = data_1.dropna()
    data_target = data_1.reset_index(drop = True)
    
    predicted_res =[]
    print('dataset: ', data_target.shape, '/n', sum(data_target[label]))
    
    
    for train_index, test_index in kf.split(data_target[columns_fl],data_target[label]):
        
        c += 1

        train_data = data_target.loc[train_index,columns_fl]
        train_label = data_target.loc[train_index,label]
        test_x = data_target.loc[test_index,columns_fl].to_numpy()
        test_y = data_target.loc[test_index,label] 

        print('iterate_num: ', c, '\n','sum of test_y:', sum(test_y))
        train_x, val_x, train_y, val_y = train_test_split(train_data.to_numpy(), train_label.to_numpy(),test_size=0.2, \
                                  random_state=42, stratify = train_label)
        print('train_x_shape',train_x.shape)
        model = model_M1(n1,n2)
        mod_res = fit_model(model, train_x, train_y, val_x, val_y, test_x, test_y, model_name+'_'+str(c)+'_NN_model')
        auc_list.append(mod_res[1])
        tprs.append(np.interp(mean_fpr, mod_res[2], mod_res[3]))
#         print(type(mod_res[-1]))
#         print(len(mod_res[-1]))
#         print(mod_res[-1])
        temp_pred_res = [mod_res[-1],test_index]
        #print(temp_pred_res)
        predicted_res.append(temp_pred_res)
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    
    return np.mean(auc_list),mean_tpr, predicted_res

# %%
label = 'label_new'
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1 ,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
#
mean_tpr_dict_nn = dict()
pred_res_nn = dict()
for fl in vs_fl.items():
    print(fl[1])
    n1 = len(fl[1])*2
    n2 = len(fl[1])
    #M1 = model_M1(n1,n2)
    NN = cross_val(n1, n2, df_fl, label, fl[1], fl[0])
    print(fl)
    print(NN[0])
    mean_tpr_dict_nn[fl[0]] = NN[1]
    pred_res_nn[fl[0]] = NN[2]
# Out:
# ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue']
# dataset:  (61744, 15) /n 545
# iterate_num:  1
#  sum of test_y: 136
# train_x_shape (37046, 14)
# class_weights {0: 0.5044527356409488, 1: 56.64525993883792}
# Epoch 1/30
# 73/73 [==============================] - 3s 21ms/step - loss: 0.7739 - accuracy: 0.6573 - my_auc: 0.4650 - val_loss: 0.6976 - val_accuracy: 0.1758 - val_my_auc: 0.4911
#  epoch:0 auc: 0.4927
# Epoch 2/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7549 - accuracy: 0.6357 - my_auc: 0.4835 - val_loss: 0.6968 - val_accuracy: 0.3203 - val_my_auc: 0.5181
#  epoch:1 auc: 0.5176
# Epoch 3/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7204 - accuracy: 0.6247 - my_auc: 0.5404 - val_loss: 0.6903 - val_accuracy: 0.4670 - val_my_auc: 0.5529
#  epoch:2 auc: 0.5528
# Epoch 4/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6808 - accuracy: 0.6198 - my_auc: 0.5954 - val_loss: 0.6828 - val_accuracy: 0.5569 - val_my_auc: 0.5820
#  epoch:3 auc: 0.5821
# Epoch 5/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6856 - accuracy: 0.6247 - my_auc: 0.6178 - val_loss: 0.6757 - val_accuracy: 0.5826 - val_my_auc: 0.6041
#  epoch:4 auc: 0.6035
# Epoch 6/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6552 - accuracy: 0.6196 - my_auc: 0.6111 - val_loss: 0.6718 - val_accuracy: 0.6059 - val_my_auc: 0.6173
#  epoch:5 auc: 0.6161
# Epoch 7/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6313 - accuracy: 0.6333 - my_auc: 0.6608 - val_loss: 0.6696 - val_accuracy: 0.6061 - val_my_auc: 0.6257
#  epoch:6 auc: 0.6256
# Epoch 8/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6269 - accuracy: 0.6277 - my_auc: 0.6627 - val_loss: 0.6695 - val_accuracy: 0.6047 - val_my_auc: 0.6265
#  epoch:7 auc: 0.6269
# Epoch 9/30
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6431 - accuracy: 0.6168 - my_auc: 0.6634 - val_loss: 0.6696 - val_accuracy: 0.6124 - val_my_auc: 0.6293
#  epoch:8 auc: 0.6302
# Epoch 10/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6546 - accuracy: 0.6213 - my_auc: 0.6572 - val_loss: 0.6715 - val_accuracy: 0.6256 - val_my_auc: 0.6300
#  epoch:9 auc: 0.6299
# Epoch 11/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6513 - accuracy: 0.6252 - my_auc: 0.6574 - val_loss: 0.6710 - val_accuracy: 0.6299 - val_my_auc: 0.6323
#  epoch:10 auc: 0.6325
# Epoch 12/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6385 - accuracy: 0.6427 - my_auc: 0.6545 - val_loss: 0.6741 - val_accuracy: 0.6373 - val_my_auc: 0.6314
#  epoch:11 auc: 0.6313
# Epoch 13/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6731 - accuracy: 0.6344 - my_auc: 0.6718 - val_loss: 0.6788 - val_accuracy: 0.6386 - val_my_auc: 0.6270
#  epoch:12 auc: 0.6265
# Epoch 14/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6629 - accuracy: 0.6335 - my_auc: 0.6730 - val_loss: 0.6793 - val_accuracy: 0.6462 - val_my_auc: 0.6287
#  epoch:13 auc: 0.6284
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 14)                56
# _________________________________________________________________
# layer_1 (Dense)              (None, 28)                420
# _________________________________________________________________
# dropout (Dropout)            (None, 28)                0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28)                112
# _________________________________________________________________
# layer_2 (Dense)              (None, 14)                406
# _________________________________________________________________
# dense (Dense)                (None, 1)                 15
# =================================================================
# Total params: 1,009
# Trainable params: 925
# Non-trainable params: 84
# _________________________________________________________________
# AUC:  0.6611
# iterate_num:  2
#  sum of test_y: 136
# train_x_shape (37046, 14)
# class_weights {0: 0.5044527356409488, 1: 56.64525993883792}
# Epoch 1/30
# 73/73 [==============================] - 3s 21ms/step - loss: 0.8842 - accuracy: 0.5068 - my_auc: 0.4926 - val_loss: 0.6965 - val_accuracy: 0.2017 - val_my_auc: 0.4949
#  epoch:0 auc: 0.4933
# Epoch 2/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7291 - accuracy: 0.4804 - my_auc: 0.5617 - val_loss: 0.6942 - val_accuracy: 0.1962 - val_my_auc: 0.5433
#  epoch:1 auc: 0.5427
# Epoch 3/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7340 - accuracy: 0.4694 - my_auc: 0.5744 - val_loss: 0.6859 - val_accuracy: 0.2799 - val_my_auc: 0.5752
#  epoch:2 auc: 0.5749
# Epoch 4/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6489 - accuracy: 0.4855 - my_auc: 0.6229 - val_loss: 0.6787 - val_accuracy: 0.3545 - val_my_auc: 0.5897
#  epoch:3 auc: 0.5898
# Epoch 5/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6676 - accuracy: 0.4904 - my_auc: 0.6285 - val_loss: 0.6768 - val_accuracy: 0.4293 - val_my_auc: 0.5987
#  epoch:4 auc: 0.5983
# Epoch 6/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6627 - accuracy: 0.5094 - my_auc: 0.6522 - val_loss: 0.6766 - val_accuracy: 0.5154 - val_my_auc: 0.6041
#  epoch:5 auc: 0.6051
# Epoch 7/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6300 - accuracy: 0.5457 - my_auc: 0.6773 - val_loss: 0.6772 - val_accuracy: 0.5388 - val_my_auc: 0.6139
#  epoch:6 auc: 0.6148
# Epoch 8/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6444 - accuracy: 0.5490 - my_auc: 0.6495 - val_loss: 0.6809 - val_accuracy: 0.5470 - val_my_auc: 0.6191
#  epoch:7 auc: 0.6191
# Epoch 9/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6691 - accuracy: 0.5424 - my_auc: 0.6513 - val_loss: 0.6848 - val_accuracy: 0.5780 - val_my_auc: 0.6225
#  epoch:8 auc: 0.6222
# Epoch 10/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6401 - accuracy: 0.5684 - my_auc: 0.6503 - val_loss: 0.6884 - val_accuracy: 0.5798 - val_my_auc: 0.6262
#  epoch:9 auc: 0.6267
# Epoch 11/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6336 - accuracy: 0.5612 - my_auc: 0.6835 - val_loss: 0.6925 - val_accuracy: 0.5923 - val_my_auc: 0.6284
#  epoch:10 auc: 0.6284
# Epoch 12/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6218 - accuracy: 0.5764 - my_auc: 0.6952 - val_loss: 0.6970 - val_accuracy: 0.5840 - val_my_auc: 0.6284
#  epoch:11 auc: 0.6285
# Epoch 13/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6433 - accuracy: 0.5826 - my_auc: 0.6622 - val_loss: 0.6993 - val_accuracy: 0.6030 - val_my_auc: 0.6267
#  epoch:12 auc: 0.6266
# Epoch 14/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6264 - accuracy: 0.5947 - my_auc: 0.6978 - val_loss: 0.7011 - val_accuracy: 0.6082 - val_my_auc: 0.6255
#  epoch:13 auc: 0.6250
# Epoch 15/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6317 - accuracy: 0.5910 - my_auc: 0.6994 - val_loss: 0.7038 - val_accuracy: 0.6218 - val_my_auc: 0.6260
#  epoch:14 auc: 0.6258
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_2 (Batch (None, 14)                56
# _________________________________________________________________
# layer_1 (Dense)              (None, 28)                420
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28)                0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28)                112
# _________________________________________________________________
# layer_2 (Dense)              (None, 14)                406
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 1,009
# Trainable params: 925
# Non-trainable params: 84
# _________________________________________________________________
# AUC:  0.6678
# iterate_num:  3
#  sum of test_y: 136
# train_x_shape (37046, 14)
# class_weights {0: 0.5044527356409488, 1: 56.64525993883792}
# Epoch 1/30
# 73/73 [==============================] - 3s 21ms/step - loss: 0.8462 - accuracy: 0.2050 - my_auc: 0.4745 - val_loss: 0.6880 - val_accuracy: 0.4915 - val_my_auc: 0.5463
#  epoch:0 auc: 0.5457
# Epoch 2/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7401 - accuracy: 0.3157 - my_auc: 0.5474 - val_loss: 0.6877 - val_accuracy: 0.5702 - val_my_auc: 0.5410
#  epoch:1 auc: 0.5402
# Epoch 3/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6823 - accuracy: 0.4138 - my_auc: 0.5781 - val_loss: 0.6880 - val_accuracy: 0.5459 - val_my_auc: 0.5385
#  epoch:2 auc: 0.5396
# Epoch 4/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6713 - accuracy: 0.4627 - my_auc: 0.6122 - val_loss: 0.6853 - val_accuracy: 0.5638 - val_my_auc: 0.5542
#  epoch:3 auc: 0.5537
# Epoch 5/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6775 - accuracy: 0.5013 - my_auc: 0.6223 - val_loss: 0.6838 - val_accuracy: 0.5857 - val_my_auc: 0.5624
#  epoch:4 auc: 0.5625
# Epoch 6/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6957 - accuracy: 0.5156 - my_auc: 0.6013 - val_loss: 0.6833 - val_accuracy: 0.5924 - val_my_auc: 0.5692
#  epoch:5 auc: 0.5696
# Epoch 7/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6727 - accuracy: 0.5313 - my_auc: 0.6580 - val_loss: 0.6820 - val_accuracy: 0.6032 - val_my_auc: 0.5787
#  epoch:6 auc: 0.5784
# Epoch 8/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6448 - accuracy: 0.5469 - my_auc: 0.6628 - val_loss: 0.6833 - val_accuracy: 0.6185 - val_my_auc: 0.5827
#  epoch:7 auc: 0.5826
# Epoch 9/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6586 - accuracy: 0.5557 - my_auc: 0.6198 - val_loss: 0.6836 - val_accuracy: 0.6334 - val_my_auc: 0.5901
#  epoch:8 auc: 0.5903
# Epoch 10/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6840 - accuracy: 0.5608 - my_auc: 0.6290 - val_loss: 0.6859 - val_accuracy: 0.6428 - val_my_auc: 0.5937
#  epoch:9 auc: 0.5934
# Epoch 11/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6394 - accuracy: 0.5752 - my_auc: 0.6689 - val_loss: 0.6860 - val_accuracy: 0.6367 - val_my_auc: 0.5956
#  epoch:10 auc: 0.5959
# Epoch 12/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6555 - accuracy: 0.5659 - my_auc: 0.6497 - val_loss: 0.6854 - val_accuracy: 0.6349 - val_my_auc: 0.5978
#  epoch:11 auc: 0.5977
# Epoch 13/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6405 - accuracy: 0.5638 - my_auc: 0.6474 - val_loss: 0.6874 - val_accuracy: 0.6314 - val_my_auc: 0.5963
#  epoch:12 auc: 0.5967
# Epoch 14/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6214 - accuracy: 0.5656 - my_auc: 0.6840 - val_loss: 0.6893 - val_accuracy: 0.6378 - val_my_auc: 0.5970
#  epoch:13 auc: 0.5973
# Epoch 15/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6394 - accuracy: 0.5692 - my_auc: 0.6677 - val_loss: 0.6892 - val_accuracy: 0.6388 - val_my_auc: 0.5994
#  epoch:14 auc: 0.5993
# Epoch 16/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6540 - accuracy: 0.5646 - my_auc: 0.6865 - val_loss: 0.6904 - val_accuracy: 0.6571 - val_my_auc: 0.5999
#  epoch:15 auc: 0.5998
# Epoch 17/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6500 - accuracy: 0.5829 - my_auc: 0.6919 - val_loss: 0.6917 - val_accuracy: 0.6585 - val_my_auc: 0.6005
#  epoch:16 auc: 0.6009
# Epoch 18/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6070 - accuracy: 0.6028 - my_auc: 0.6722 - val_loss: 0.6913 - val_accuracy: 0.6516 - val_my_auc: 0.6011
#  epoch:17 auc: 0.6017
# Epoch 19/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6192 - accuracy: 0.5845 - my_auc: 0.6828 - val_loss: 0.6916 - val_accuracy: 0.6477 - val_my_auc: 0.6017
#  epoch:18 auc: 0.6017
# Epoch 20/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6581 - accuracy: 0.5785 - my_auc: 0.6642 - val_loss: 0.6926 - val_accuracy: 0.6585 - val_my_auc: 0.6033
#  epoch:19 auc: 0.6035
# Epoch 21/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6308 - accuracy: 0.5916 - my_auc: 0.6827 - val_loss: 0.6922 - val_accuracy: 0.6529 - val_my_auc: 0.6041
#  epoch:20 auc: 0.6043
# Epoch 22/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6132 - accuracy: 0.5929 - my_auc: 0.6848 - val_loss: 0.6927 - val_accuracy: 0.6503 - val_my_auc: 0.6033
#  epoch:21 auc: 0.6039
# Epoch 23/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6080 - accuracy: 0.5981 - my_auc: 0.7206 - val_loss: 0.6925 - val_accuracy: 0.6477 - val_my_auc: 0.6037
#  epoch:22 auc: 0.6038
# Epoch 24/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6536 - accuracy: 0.5848 - my_auc: 0.7051 - val_loss: 0.6930 - val_accuracy: 0.6558 - val_my_auc: 0.6048
#  epoch:23 auc: 0.6046
# Epoch 25/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6100 - accuracy: 0.5967 - my_auc: 0.7102 - val_loss: 0.6930 - val_accuracy: 0.6547 - val_my_auc: 0.6061
#  epoch:24 auc: 0.6069
# Epoch 26/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6334 - accuracy: 0.5861 - my_auc: 0.6965 - val_loss: 0.6927 - val_accuracy: 0.6494 - val_my_auc: 0.6076
#  epoch:25 auc: 0.6076
# Epoch 27/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6387 - accuracy: 0.5839 - my_auc: 0.6981 - val_loss: 0.6922 - val_accuracy: 0.6435 - val_my_auc: 0.6095
#  epoch:26 auc: 0.6095
# Epoch 28/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6600 - accuracy: 0.5814 - my_auc: 0.6990 - val_loss: 0.6947 - val_accuracy: 0.6595 - val_my_auc: 0.6101
#  epoch:27 auc: 0.6093
# Epoch 29/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6216 - accuracy: 0.5972 - my_auc: 0.7128 - val_loss: 0.6960 - val_accuracy: 0.6616 - val_my_auc: 0.6090
#  epoch:28 auc: 0.6093
# Epoch 30/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.5900 - accuracy: 0.5996 - my_auc: 0.7058 - val_loss: 0.6948 - val_accuracy: 0.6509 - val_my_auc: 0.6097
#  epoch:29 auc: 0.6095
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_4 (Batch (None, 14)                56
# _________________________________________________________________
# layer_1 (Dense)              (None, 28)                420
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28)                0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 28)                112
# _________________________________________________________________
# layer_2 (Dense)              (None, 14)                406
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 1,009
# Trainable params: 925
# Non-trainable params: 84
# _________________________________________________________________
# AUC:  0.6962
# iterate_num:  4
#  sum of test_y: 137
# train_x_shape (37046, 14)
# class_weights {0: 0.5044389978213507, 1: 56.81901840490798}
# Epoch 1/30
# 73/73 [==============================] - 3s 20ms/step - loss: 0.7855 - accuracy: 0.7523 - my_auc: 0.5010 - val_loss: 0.7082 - val_accuracy: 0.9384 - val_my_auc: 0.5517
#  epoch:0 auc: 0.5499
# Epoch 2/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.7272 - accuracy: 0.7129 - my_auc: 0.5570 - val_loss: 0.6851 - val_accuracy: 0.7365 - val_my_auc: 0.5746
#  epoch:1 auc: 0.5754
# Epoch 3/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.7093 - accuracy: 0.6527 - my_auc: 0.5643 - val_loss: 0.6798 - val_accuracy: 0.5270 - val_my_auc: 0.5821
#  epoch:2 auc: 0.5821
# Epoch 4/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7145 - accuracy: 0.6003 - my_auc: 0.5903 - val_loss: 0.6763 - val_accuracy: 0.5126 - val_my_auc: 0.5923
#  epoch:3 auc: 0.5927
# Epoch 5/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6374 - accuracy: 0.6033 - my_auc: 0.6480 - val_loss: 0.6711 - val_accuracy: 0.5081 - val_my_auc: 0.6052
#  epoch:4 auc: 0.6062
# Epoch 6/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6408 - accuracy: 0.5800 - my_auc: 0.6321 - val_loss: 0.6682 - val_accuracy: 0.5173 - val_my_auc: 0.6139
#  epoch:5 auc: 0.6132
# Epoch 7/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6485 - accuracy: 0.5614 - my_auc: 0.6544 - val_loss: 0.6658 - val_accuracy: 0.5257 - val_my_auc: 0.6180
#  epoch:6 auc: 0.6181
# Epoch 8/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6705 - accuracy: 0.5546 - my_auc: 0.6525 - val_loss: 0.6648 - val_accuracy: 0.5345 - val_my_auc: 0.6209
#  epoch:7 auc: 0.6213
# Epoch 9/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6751 - accuracy: 0.5531 - my_auc: 0.6253 - val_loss: 0.6645 - val_accuracy: 0.5405 - val_my_auc: 0.6248
#  epoch:8 auc: 0.6253
# Epoch 10/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6593 - accuracy: 0.5489 - my_auc: 0.6746 - val_loss: 0.6644 - val_accuracy: 0.5473 - val_my_auc: 0.6252
#  epoch:9 auc: 0.6251
# Epoch 11/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6828 - accuracy: 0.5477 - my_auc: 0.6455 - val_loss: 0.6641 - val_accuracy: 0.5441 - val_my_auc: 0.6281
#  epoch:10 auc: 0.6284
# Epoch 12/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6509 - accuracy: 0.5464 - my_auc: 0.6864 - val_loss: 0.6625 - val_accuracy: 0.5438 - val_my_auc: 0.6286
#  epoch:11 auc: 0.6285
# Epoch 13/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6504 - accuracy: 0.5431 - my_auc: 0.6685 - val_loss: 0.6617 - val_accuracy: 0.5520 - val_my_auc: 0.6311
#  epoch:12 auc: 0.6304
# Epoch 14/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6038 - accuracy: 0.5615 - my_auc: 0.6914 - val_loss: 0.6611 - val_accuracy: 0.5456 - val_my_auc: 0.6314
#  epoch:13 auc: 0.6312
# Epoch 15/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6331 - accuracy: 0.5522 - my_auc: 0.6610 - val_loss: 0.6605 - val_accuracy: 0.5550 - val_my_auc: 0.6319
#  epoch:14 auc: 0.6325
# Epoch 16/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6255 - accuracy: 0.5570 - my_auc: 0.6759 - val_loss: 0.6606 - val_accuracy: 0.5611 - val_my_auc: 0.6344
#  epoch:15 auc: 0.6344
# Epoch 17/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6158 - accuracy: 0.5571 - my_auc: 0.6885 - val_loss: 0.6595 - val_accuracy: 0.5590 - val_my_auc: 0.6352
#  epoch:16 auc: 0.6354
# Epoch 18/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6046 - accuracy: 0.5630 - my_auc: 0.7109 - val_loss: 0.6575 - val_accuracy: 0.5666 - val_my_auc: 0.6377
#  epoch:17 auc: 0.6377
# Epoch 19/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6206 - accuracy: 0.5678 - my_auc: 0.7005 - val_loss: 0.6575 - val_accuracy: 0.5728 - val_my_auc: 0.6376
#  epoch:18 auc: 0.6371
# Epoch 20/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6350 - accuracy: 0.5588 - my_auc: 0.6600 - val_loss: 0.6554 - val_accuracy: 0.5658 - val_my_auc: 0.6389
#  epoch:19 auc: 0.6382
# Epoch 21/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6341 - accuracy: 0.5632 - my_auc: 0.7001 - val_loss: 0.6549 - val_accuracy: 0.5621 - val_my_auc: 0.6382
#  epoch:20 auc: 0.6384
# Epoch 22/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.5990 - accuracy: 0.5614 - my_auc: 0.7108 - val_loss: 0.6546 - val_accuracy: 0.5709 - val_my_auc: 0.6391
#  epoch:21 auc: 0.6394
# Epoch 23/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6237 - accuracy: 0.5671 - my_auc: 0.6957 - val_loss: 0.6537 - val_accuracy: 0.5747 - val_my_auc: 0.6403
#  epoch:22 auc: 0.6405
# Epoch 24/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5576 - my_auc: 0.6940 - val_loss: 0.6525 - val_accuracy: 0.5742 - val_my_auc: 0.6426
#  epoch:23 auc: 0.6431
# Epoch 25/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6309 - accuracy: 0.5642 - my_auc: 0.6882 - val_loss: 0.6535 - val_accuracy: 0.5745 - val_my_auc: 0.6415
#  epoch:24 auc: 0.6415
# Epoch 26/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6723 - accuracy: 0.5592 - my_auc: 0.6915 - val_loss: 0.6524 - val_accuracy: 0.5876 - val_my_auc: 0.6445
#  epoch:25 auc: 0.6442
# Epoch 27/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6042 - accuracy: 0.5746 - my_auc: 0.7196 - val_loss: 0.6521 - val_accuracy: 0.5822 - val_my_auc: 0.6431
#  epoch:26 auc: 0.6431
# Epoch 28/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.5985 - accuracy: 0.5750 - my_auc: 0.6832 - val_loss: 0.6506 - val_accuracy: 0.5683 - val_my_auc: 0.6453
#  epoch:27 auc: 0.6455
# Epoch 29/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6228 - accuracy: 0.5571 - my_auc: 0.6999 - val_loss: 0.6512 - val_accuracy: 0.5691 - val_my_auc: 0.6444
#  epoch:28 auc: 0.6445
# Epoch 30/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6450 - accuracy: 0.5583 - my_auc: 0.6813 - val_loss: 0.6506 - val_accuracy: 0.5762 - val_my_auc: 0.6468
#  epoch:29 auc: 0.6471
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_6 (Batch (None, 14)                56
# _________________________________________________________________
# layer_1 (Dense)              (None, 28)                420
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 28)                0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 28)                112
# _________________________________________________________________
# layer_2 (Dense)              (None, 14)                406
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 1,009
# Trainable params: 925
# Non-trainable params: 84
# _________________________________________________________________
# AUC:  0.6594
# avg_AUC :  0.6711452191974909
# avg_AUC_2 :  0.6711458997445472
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6711452191974909
# ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1']
# dataset:  (61744, 16) /n 545
# iterate_num:  1
#  sum of test_y: 136
# train_x_shape (37046, 15)
# class_weights {0: 0.5044527356409488, 1: 56.64525993883792}
# Epoch 1/30
# 73/73 [==============================] - 3s 20ms/step - loss: 0.7774 - accuracy: 0.4668 - my_auc: 0.4822 - val_loss: 0.7270 - val_accuracy: 0.9446 - val_my_auc: 0.4127
#  epoch:0 auc: 0.4130
# Epoch 2/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.7079 - accuracy: 0.4996 - my_auc: 0.5543 - val_loss: 0.7059 - val_accuracy: 0.8062 - val_my_auc: 0.4693
#  epoch:1 auc: 0.4701
# Epoch 3/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7120 - accuracy: 0.5126 - my_auc: 0.5883 - val_loss: 0.6852 - val_accuracy: 0.6224 - val_my_auc: 0.5645
#  epoch:2 auc: 0.5653
# Epoch 4/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6559 - accuracy: 0.5515 - my_auc: 0.6116 - val_loss: 0.6708 - val_accuracy: 0.5221 - val_my_auc: 0.6162
#  epoch:3 auc: 0.6168
# Epoch 5/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6790 - accuracy: 0.5384 - my_auc: 0.6289 - val_loss: 0.6629 - val_accuracy: 0.5266 - val_my_auc: 0.6361
#  epoch:4 auc: 0.6365
# Epoch 6/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6425 - accuracy: 0.5666 - my_auc: 0.6499 - val_loss: 0.6594 - val_accuracy: 0.5415 - val_my_auc: 0.6390
#  epoch:5 auc: 0.6391
# Epoch 7/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6635 - accuracy: 0.5582 - my_auc: 0.6379 - val_loss: 0.6588 - val_accuracy: 0.5848 - val_my_auc: 0.6397
#  epoch:6 auc: 0.6395
# Epoch 8/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6960 - accuracy: 0.5600 - my_auc: 0.6516 - val_loss: 0.6587 - val_accuracy: 0.6059 - val_my_auc: 0.6382
#  epoch:7 auc: 0.6382
# Epoch 9/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6444 - accuracy: 0.5795 - my_auc: 0.6811 - val_loss: 0.6581 - val_accuracy: 0.6148 - val_my_auc: 0.6399
#  epoch:8 auc: 0.6402
# Epoch 10/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6473 - accuracy: 0.5846 - my_auc: 0.6878 - val_loss: 0.6579 - val_accuracy: 0.6275 - val_my_auc: 0.6397
#  epoch:9 auc: 0.6396
# Epoch 11/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6553 - accuracy: 0.5839 - my_auc: 0.6613 - val_loss: 0.6552 - val_accuracy: 0.6262 - val_my_auc: 0.6452
#  epoch:10 auc: 0.6451
# Epoch 12/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6391 - accuracy: 0.5902 - my_auc: 0.6673 - val_loss: 0.6566 - val_accuracy: 0.6450 - val_my_auc: 0.6430
#  epoch:11 auc: 0.6437
# Epoch 13/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6422 - accuracy: 0.6005 - my_auc: 0.7009 - val_loss: 0.6559 - val_accuracy: 0.6513 - val_my_auc: 0.6437
#  epoch:12 auc: 0.6438
# Epoch 14/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6510 - accuracy: 0.6041 - my_auc: 0.6799 - val_loss: 0.6544 - val_accuracy: 0.6458 - val_my_auc: 0.6464
#  epoch:13 auc: 0.6462
# Epoch 15/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6137 - accuracy: 0.6109 - my_auc: 0.6759 - val_loss: 0.6558 - val_accuracy: 0.6547 - val_my_auc: 0.6444
#  epoch:14 auc: 0.6442
# Epoch 16/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6525 - accuracy: 0.6122 - my_auc: 0.7060 - val_loss: 0.6550 - val_accuracy: 0.6605 - val_my_auc: 0.6466
#  epoch:15 auc: 0.6473
# Epoch 17/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6276 - accuracy: 0.6206 - my_auc: 0.7035 - val_loss: 0.6552 - val_accuracy: 0.6651 - val_my_auc: 0.6479
#  epoch:16 auc: 0.6484
# Epoch 18/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6211 - accuracy: 0.6239 - my_auc: 0.7194 - val_loss: 0.6538 - val_accuracy: 0.6611 - val_my_auc: 0.6505
#  epoch:17 auc: 0.6500
# Epoch 19/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6280 - accuracy: 0.6192 - my_auc: 0.7147 - val_loss: 0.6560 - val_accuracy: 0.6618 - val_my_auc: 0.6479
#  epoch:18 auc: 0.6480
# Epoch 20/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6412 - accuracy: 0.6181 - my_auc: 0.6992 - val_loss: 0.6546 - val_accuracy: 0.6523 - val_my_auc: 0.6500
#  epoch:19 auc: 0.6499
# Epoch 21/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6532 - accuracy: 0.6195 - my_auc: 0.6774 - val_loss: 0.6547 - val_accuracy: 0.6616 - val_my_auc: 0.6503
#  epoch:20 auc: 0.6509
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_8 (Batch (None, 15)                60
# _________________________________________________________________
# layer_1 (Dense)              (None, 30)                480
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30)                0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 30)                120
# _________________________________________________________________
# layer_2 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,141
# Trainable params: 1,051
# Non-trainable params: 90
# _________________________________________________________________
# AUC:  0.6965
# iterate_num:  2
#  sum of test_y: 136
# train_x_shape (37046, 15)
# class_weights {0: 0.5044527356409488, 1: 56.64525993883792}
# Epoch 1/30
# 73/73 [==============================] - 3s 21ms/step - loss: 0.7096 - accuracy: 0.6960 - my_auc: 0.5705 - val_loss: 0.6946 - val_accuracy: 0.9198 - val_my_auc: 0.5378
#  epoch:0 auc: 0.5374
# Epoch 2/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7524 - accuracy: 0.6079 - my_auc: 0.5507 - val_loss: 0.6879 - val_accuracy: 0.7398 - val_my_auc: 0.5619
#  epoch:1 auc: 0.5597
# Epoch 3/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7148 - accuracy: 0.5722 - my_auc: 0.5926 - val_loss: 0.6817 - val_accuracy: 0.5250 - val_my_auc: 0.5834
#  epoch:2 auc: 0.5833
# Epoch 4/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6804 - accuracy: 0.5649 - my_auc: 0.6347 - val_loss: 0.6737 - val_accuracy: 0.4710 - val_my_auc: 0.6149
#  epoch:3 auc: 0.6158
# Epoch 5/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6576 - accuracy: 0.5627 - my_auc: 0.6399 - val_loss: 0.6678 - val_accuracy: 0.4661 - val_my_auc: 0.6327
#  epoch:4 auc: 0.6323
# Epoch 6/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6417 - accuracy: 0.5518 - my_auc: 0.6601 - val_loss: 0.6639 - val_accuracy: 0.4740 - val_my_auc: 0.6419
#  epoch:5 auc: 0.6420
# Epoch 7/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6387 - accuracy: 0.5511 - my_auc: 0.6599 - val_loss: 0.6584 - val_accuracy: 0.4902 - val_my_auc: 0.6551
#  epoch:6 auc: 0.6556
# Epoch 8/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6139 - accuracy: 0.5621 - my_auc: 0.6925 - val_loss: 0.6542 - val_accuracy: 0.5066 - val_my_auc: 0.6660
#  epoch:7 auc: 0.6655
# Epoch 9/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6725 - accuracy: 0.5498 - my_auc: 0.6686 - val_loss: 0.6522 - val_accuracy: 0.5227 - val_my_auc: 0.6708
#  epoch:8 auc: 0.6708
# Epoch 10/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6710 - accuracy: 0.5582 - my_auc: 0.6387 - val_loss: 0.6492 - val_accuracy: 0.5289 - val_my_auc: 0.6761
#  epoch:9 auc: 0.6769
# Epoch 11/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6311 - accuracy: 0.5666 - my_auc: 0.6738 - val_loss: 0.6478 - val_accuracy: 0.5340 - val_my_auc: 0.6799
#  epoch:10 auc: 0.6800
# Epoch 12/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6534 - accuracy: 0.5485 - my_auc: 0.6659 - val_loss: 0.6468 - val_accuracy: 0.5443 - val_my_auc: 0.6826
#  epoch:11 auc: 0.6824
# Epoch 13/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6416 - accuracy: 0.5674 - my_auc: 0.6588 - val_loss: 0.6453 - val_accuracy: 0.5397 - val_my_auc: 0.6853
#  epoch:12 auc: 0.6853
# Epoch 14/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6584 - accuracy: 0.5557 - my_auc: 0.6667 - val_loss: 0.6461 - val_accuracy: 0.5457 - val_my_auc: 0.6854
#  epoch:13 auc: 0.6856
# Epoch 15/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6181 - accuracy: 0.5784 - my_auc: 0.6739 - val_loss: 0.6472 - val_accuracy: 0.5349 - val_my_auc: 0.6834
#  epoch:14 auc: 0.6835
# Epoch 16/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6413 - accuracy: 0.5592 - my_auc: 0.6788 - val_loss: 0.6463 - val_accuracy: 0.5432 - val_my_auc: 0.6861
#  epoch:15 auc: 0.6863
# Epoch 17/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6395 - accuracy: 0.5640 - my_auc: 0.6784 - val_loss: 0.6469 - val_accuracy: 0.5430 - val_my_auc: 0.6857
#  epoch:16 auc: 0.6859
# Epoch 18/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6145 - accuracy: 0.5731 - my_auc: 0.6874 - val_loss: 0.6462 - val_accuracy: 0.5444 - val_my_auc: 0.6868
#  epoch:17 auc: 0.6868
# Epoch 19/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6483 - accuracy: 0.5696 - my_auc: 0.6600 - val_loss: 0.6467 - val_accuracy: 0.5541 - val_my_auc: 0.6860
#  epoch:18 auc: 0.6862
# Epoch 20/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6558 - accuracy: 0.5593 - my_auc: 0.6584 - val_loss: 0.6468 - val_accuracy: 0.5512 - val_my_auc: 0.6866
#  epoch:19 auc: 0.6873
# Epoch 21/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6274 - accuracy: 0.5688 - my_auc: 0.6748 - val_loss: 0.6461 - val_accuracy: 0.5608 - val_my_auc: 0.6874
#  epoch:20 auc: 0.6874
# Epoch 22/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6313 - accuracy: 0.5755 - my_auc: 0.7044 - val_loss: 0.6459 - val_accuracy: 0.5525 - val_my_auc: 0.6874
#  epoch:21 auc: 0.6878
# Epoch 23/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6269 - accuracy: 0.5734 - my_auc: 0.6905 - val_loss: 0.6460 - val_accuracy: 0.5482 - val_my_auc: 0.6892
#  epoch:22 auc: 0.6892
# Epoch 24/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6419 - accuracy: 0.5730 - my_auc: 0.6885 - val_loss: 0.6459 - val_accuracy: 0.5528 - val_my_auc: 0.6906
#  epoch:23 auc: 0.6908
# Epoch 25/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6064 - accuracy: 0.5696 - my_auc: 0.6777 - val_loss: 0.6447 - val_accuracy: 0.5534 - val_my_auc: 0.6932
#  epoch:24 auc: 0.6931
# Epoch 26/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6178 - accuracy: 0.5688 - my_auc: 0.7156 - val_loss: 0.6439 - val_accuracy: 0.5591 - val_my_auc: 0.6921
#  epoch:25 auc: 0.6923
# Epoch 27/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6215 - accuracy: 0.5748 - my_auc: 0.6949 - val_loss: 0.6428 - val_accuracy: 0.5618 - val_my_auc: 0.6946
#  epoch:26 auc: 0.6949
# Epoch 28/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6400 - accuracy: 0.5721 - my_auc: 0.6891 - val_loss: 0.6428 - val_accuracy: 0.5664 - val_my_auc: 0.6927
#  epoch:27 auc: 0.6933
# Epoch 29/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6232 - accuracy: 0.5785 - my_auc: 0.6828 - val_loss: 0.6433 - val_accuracy: 0.5668 - val_my_auc: 0.6923
#  epoch:28 auc: 0.6922
# Epoch 30/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.5863 - accuracy: 0.5843 - my_auc: 0.7149 - val_loss: 0.6425 - val_accuracy: 0.5538 - val_my_auc: 0.6947
#  epoch:29 auc: 0.6948
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_10 (Batc (None, 15)                60
# _________________________________________________________________
# layer_1 (Dense)              (None, 30)                480
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30)                0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 30)                120
# _________________________________________________________________
# layer_2 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,141
# Trainable params: 1,051
# Non-trainable params: 90
# _________________________________________________________________
# AUC:  0.6665
# iterate_num:  3
#  sum of test_y: 136
# train_x_shape (37046, 15)
# class_weights {0: 0.5044527356409488, 1: 56.64525993883792}
# Epoch 1/30
# 73/73 [==============================] - 3s 21ms/step - loss: 0.8314 - accuracy: 0.7455 - my_auc: 0.5311 - val_loss: 0.7055 - val_accuracy: 0.0613 - val_my_auc: 0.5998
#  epoch:0 auc: 0.6006
# Epoch 2/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7744 - accuracy: 0.6742 - my_auc: 0.5757 - val_loss: 0.6986 - val_accuracy: 0.1157 - val_my_auc: 0.5842
#  epoch:1 auc: 0.5844
# Epoch 3/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6814 - accuracy: 0.6434 - my_auc: 0.6488 - val_loss: 0.6906 - val_accuracy: 0.2088 - val_my_auc: 0.5919
#  epoch:2 auc: 0.5918
# Epoch 4/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6627 - accuracy: 0.6001 - my_auc: 0.6382 - val_loss: 0.6786 - val_accuracy: 0.3372 - val_my_auc: 0.5996
#  epoch:3 auc: 0.5999
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_12 (Batc (None, 15)                60
# _________________________________________________________________
# layer_1 (Dense)              (None, 30)                480
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30)                0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 30)                120
# _________________________________________________________________
# layer_2 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,141
# Trainable params: 1,051
# Non-trainable params: 90
# _________________________________________________________________
# AUC:  0.5922
# iterate_num:  4
#  sum of test_y: 137
# train_x_shape (37046, 15)
# class_weights {0: 0.5044389978213507, 1: 56.81901840490798}
# Epoch 1/30
# 73/73 [==============================] - 3s 21ms/step - loss: 0.8036 - accuracy: 0.5898 - my_auc: 0.5297 - val_loss: 0.7073 - val_accuracy: 0.2900 - val_my_auc: 0.4766
#  epoch:0 auc: 0.4772
# Epoch 2/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7364 - accuracy: 0.5758 - my_auc: 0.5261 - val_loss: 0.6951 - val_accuracy: 0.3339 - val_my_auc: 0.5359
#  epoch:1 auc: 0.5349
# Epoch 3/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6938 - accuracy: 0.5743 - my_auc: 0.5959 - val_loss: 0.6810 - val_accuracy: 0.4274 - val_my_auc: 0.5835
#  epoch:2 auc: 0.5839
# Epoch 4/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6723 - accuracy: 0.5904 - my_auc: 0.6466 - val_loss: 0.6727 - val_accuracy: 0.4936 - val_my_auc: 0.6045
#  epoch:3 auc: 0.6049
# Epoch 5/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6543 - accuracy: 0.5926 - my_auc: 0.6410 - val_loss: 0.6670 - val_accuracy: 0.5387 - val_my_auc: 0.6194
#  epoch:4 auc: 0.6194
# Epoch 6/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6367 - accuracy: 0.5996 - my_auc: 0.6709 - val_loss: 0.6620 - val_accuracy: 0.5628 - val_my_auc: 0.6320
#  epoch:5 auc: 0.6328
# Epoch 7/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6435 - accuracy: 0.6036 - my_auc: 0.6483 - val_loss: 0.6580 - val_accuracy: 0.5694 - val_my_auc: 0.6427
#  epoch:6 auc: 0.6429
# Epoch 8/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.5902 - my_auc: 0.6589 - val_loss: 0.6546 - val_accuracy: 0.5912 - val_my_auc: 0.6509
#  epoch:7 auc: 0.6509
# Epoch 9/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6624 - accuracy: 0.5973 - my_auc: 0.6642 - val_loss: 0.6553 - val_accuracy: 0.5978 - val_my_auc: 0.6508
#  epoch:8 auc: 0.6505
# Epoch 10/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6179 - accuracy: 0.6035 - my_auc: 0.6845 - val_loss: 0.6552 - val_accuracy: 0.6055 - val_my_auc: 0.6522
#  epoch:9 auc: 0.6521
# Epoch 11/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6885 - accuracy: 0.6009 - my_auc: 0.6681 - val_loss: 0.6556 - val_accuracy: 0.6022 - val_my_auc: 0.6505
#  epoch:10 auc: 0.6504
# Epoch 12/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6253 - accuracy: 0.6053 - my_auc: 0.6939 - val_loss: 0.6555 - val_accuracy: 0.6065 - val_my_auc: 0.6540
#  epoch:11 auc: 0.6534
# Epoch 13/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6322 - accuracy: 0.5997 - my_auc: 0.6978 - val_loss: 0.6558 - val_accuracy: 0.6083 - val_my_auc: 0.6537
#  epoch:12 auc: 0.6537
# Epoch 14/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6515 - accuracy: 0.5995 - my_auc: 0.6856 - val_loss: 0.6554 - val_accuracy: 0.6156 - val_my_auc: 0.6556
#  epoch:13 auc: 0.6557
# Epoch 15/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6083 - accuracy: 0.6147 - my_auc: 0.7054 - val_loss: 0.6574 - val_accuracy: 0.6137 - val_my_auc: 0.6535
#  epoch:14 auc: 0.6536
# Epoch 16/30
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6585 - accuracy: 0.6009 - my_auc: 0.6859 - val_loss: 0.6589 - val_accuracy: 0.6219 - val_my_auc: 0.6521
#  epoch:15 auc: 0.6523
# Epoch 17/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6368 - accuracy: 0.6123 - my_auc: 0.7018 - val_loss: 0.6616 - val_accuracy: 0.6255 - val_my_auc: 0.6497
#  epoch:16 auc: 0.6498
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_14 (Batc (None, 15)                60
# _________________________________________________________________
# layer_1 (Dense)              (None, 30)                480
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 30)                0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 30)                120
# _________________________________________________________________
# layer_2 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,141
# Trainable params: 1,051
# Non-trainable params: 90
# _________________________________________________________________
# AUC:  0.6424
# avg_AUC :  0.6494013071603664
# avg_AUC_2 :  0.6493599043244813
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.6494013071603664
# ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1']
# dataset:  (61744, 42) /n 545
# iterate_num:  1
#  sum of test_y: 136
# train_x_shape (37046, 41)
# class_weights {0: 0.5044527356409488, 1: 56.64525993883792}
# Epoch 1/30
# 73/73 [==============================] - 3s 22ms/step - loss: 0.7542 - accuracy: 0.6632 - my_auc: 0.5626 - val_loss: 0.6919 - val_accuracy: 0.0441 - val_my_auc: 0.5566
#  epoch:0 auc: 0.5633
# Epoch 2/30
# 73/73 [==============================] - 0s 7ms/step - loss: 0.6935 - accuracy: 0.5966 - my_auc: 0.5907 - val_loss: 0.6906 - val_accuracy: 0.0717 - val_my_auc: 0.5804
#  epoch:1 auc: 0.5833
# Epoch 3/30
# 73/73 [==============================] - 1s 7ms/step - loss: 0.6854 - accuracy: 0.5540 - my_auc: 0.6038 - val_loss: 0.6936 - val_accuracy: 0.0730 - val_my_auc: 0.5917
#  epoch:2 auc: 0.5889
# Epoch 4/30
# 73/73 [==============================] - 1s 7ms/step - loss: 0.7119 - accuracy: 0.5620 - my_auc: 0.6001 - val_loss: 0.6948 - val_accuracy: 0.1152 - val_my_auc: 0.6001
#  epoch:3 auc: 0.5999
# Epoch 5/30
# 73/73 [==============================] - 1s 7ms/step - loss: 0.6630 - accuracy: 0.5621 - my_auc: 0.6578 - val_loss: 0.6879 - val_accuracy: 0.2333 - val_my_auc: 0.5989
#  epoch:4 auc: 0.6000
# Epoch 6/30
# 73/73 [==============================] - 1s 7ms/step - loss: 0.6622 - accuracy: 0.5773 - my_auc: 0.6652 - val_loss: 0.6839 - val_accuracy: 0.3298 - val_my_auc: 0.6007
#  epoch:5 auc: 0.6001
# Epoch 7/30
# 73/73 [==============================] - 0s 7ms/step - loss: 0.6113 - accuracy: 0.6130 - my_auc: 0.6729 - val_loss: 0.6807 - val_accuracy: 0.3879 - val_my_auc: 0.6044
#  epoch:6 auc: 0.6038
# Epoch 8/30
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6495 - accuracy: 0.5700 - my_auc: 0.7139 - val_loss: 0.6775 - val_accuracy: 0.5108 - val_my_auc: 0.6038
#  epoch:7 auc: 0.6038
# Epoch 9/30
# 73/73 [==============================] - 0s 7ms/step - loss: 0.6263 - accuracy: 0.5969 - my_auc: 0.7168 - val_loss: 0.6775 - val_accuracy: 0.5936 - val_my_auc: 0.6043
#  epoch:8 auc: 0.6045
# Epoch 10/30
# 73/73 [==============================] - 1s 7ms/step - loss: 0.6432 - accuracy: 0.6214 - my_auc: 0.7084 - val_loss: 0.6816 - val_accuracy: 0.6177 - val_my_auc: 0.6064
#  epoch:9 auc: 0.6066
# Epoch 11/30
# 73/73 [==============================] - 1s 7ms/step - loss: 0.6223 - accuracy: 0.6291 - my_auc: 0.6894 - val_loss: 0.6868 - val_accuracy: 0.6359 - val_my_auc: 0.6061
#  epoch:10 auc: 0.6065
# Epoch 12/30
# 73/73 [==============================] - 0s 7ms/step - loss: 0.6186 - accuracy: 0.6313 - my_auc: 0.6993 - val_loss: 0.6878 - val_accuracy: 0.6259 - val_my_auc: 0.6066
#  epoch:11 auc: 0.6068
# Epoch 13/30
# 73/73 [==============================] - 1s 7ms/step - loss: 0.5905 - accuracy: 0.6249 - my_auc: 0.7431 - val_loss: 0.6895 - val_accuracy: 0.6324 - val_my_auc: 0.6045
#  epoch:12 auc: 0.6045
# Epoch 14/30
# 73/73 [==============================] - 0s 7ms/step - loss: 0.6015 - accuracy: 0.6166 - my_auc: 0.7518 - val_loss: 0.6969 - val_accuracy: 0.6733 - val_my_auc: 0.6054
#  epoch:13 auc: 0.6052
# Epoch 15/30
# 73/73 [==============================] - 0s 7ms/step - loss: 0.5861 - accuracy: 0.6629 - my_auc: 0.7327 - val_loss: 0.6995 - val_accuracy: 0.6740 - val_my_auc: 0.6039
#  epoch:14 auc: 0.6037
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_16 (Batc (None, 41)                164
# _________________________________________________________________
# layer_1 (Dense)              (None, 82)                3444
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 82)                0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 82)                328
# _________________________________________________________________
# layer_2 (Dense)              (None, 41)                3403
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 42
# ...
#  epoch:2 auc: 0.6101
# Epoch 4/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.6358 - accuracy: 0.6149 - my_auc: 0.7193 - val_loss: 0.6677 - val_accuracy: 0.3862 - val_my_auc: 0.6355
#  epoch:3 auc: 0.6359
# Epoch 5/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5955 - accuracy: 0.6237 - my_auc: 0.7584 - val_loss: 0.6559 - val_accuracy: 0.5124 - val_my_auc: 0.6457
#  epoch:4 auc: 0.6456
# Epoch 6/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5811 - accuracy: 0.6602 - my_auc: 0.7653 - val_loss: 0.6504 - val_accuracy: 0.5635 - val_my_auc: 0.6534
#  epoch:5 auc: 0.6536
# Epoch 7/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5855 - accuracy: 0.6634 - my_auc: 0.7543 - val_loss: 0.6518 - val_accuracy: 0.6155 - val_my_auc: 0.6544
#  epoch:6 auc: 0.6545
# Epoch 8/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5556 - accuracy: 0.6690 - my_auc: 0.7750 - val_loss: 0.6601 - val_accuracy: 0.6745 - val_my_auc: 0.6587
#  epoch:7 auc: 0.6586
# Epoch 9/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5460 - accuracy: 0.6896 - my_auc: 0.7898 - val_loss: 0.6545 - val_accuracy: 0.6945 - val_my_auc: 0.6734
#  epoch:8 auc: 0.6734
# Epoch 10/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5533 - accuracy: 0.6819 - my_auc: 0.7859 - val_loss: 0.6631 - val_accuracy: 0.7090 - val_my_auc: 0.6748
#  epoch:9 auc: 0.6745
# Epoch 11/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5082 - accuracy: 0.6977 - my_auc: 0.8025 - val_loss: 0.6619 - val_accuracy: 0.7047 - val_my_auc: 0.6755
#  epoch:10 auc: 0.6752
# Epoch 12/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5118 - accuracy: 0.6859 - my_auc: 0.8222 - val_loss: 0.6665 - val_accuracy: 0.7277 - val_my_auc: 0.6792
#  epoch:11 auc: 0.6790
# Epoch 13/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5130 - accuracy: 0.6909 - my_auc: 0.8191 - val_loss: 0.6777 - val_accuracy: 0.7517 - val_my_auc: 0.6786
#  epoch:12 auc: 0.6785
# Epoch 14/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5174 - accuracy: 0.7111 - my_auc: 0.7993 - val_loss: 0.6701 - val_accuracy: 0.7295 - val_my_auc: 0.6824
#  epoch:13 auc: 0.6824
# Epoch 15/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5021 - accuracy: 0.6911 - my_auc: 0.8276 - val_loss: 0.6921 - val_accuracy: 0.7764 - val_my_auc: 0.6846
#  epoch:14 auc: 0.6849
# Epoch 16/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5218 - accuracy: 0.7196 - my_auc: 0.8225 - val_loss: 0.7053 - val_accuracy: 0.7894 - val_my_auc: 0.6857
#  epoch:15 auc: 0.6858
# Epoch 17/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4869 - accuracy: 0.7468 - my_auc: 0.8416 - val_loss: 0.7088 - val_accuracy: 0.7883 - val_my_auc: 0.6850
#  epoch:16 auc: 0.6851
# Epoch 18/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4463 - accuracy: 0.7543 - my_auc: 0.8642 - val_loss: 0.7016 - val_accuracy: 0.7606 - val_my_auc: 0.6828
#  epoch:17 auc: 0.6831
# Epoch 19/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4850 - accuracy: 0.7267 - my_auc: 0.8457 - val_loss: 0.7105 - val_accuracy: 0.7715 - val_my_auc: 0.6853
#  epoch:18 auc: 0.6854
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_24 (Batc (None, 55)                220
# _________________________________________________________________
# layer_1 (Dense)              (None, 110)               6160
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 110)               0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 110)               440
# _________________________________________________________________
# layer_2 (Dense)              (None, 55)                6105
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 56
# =================================================================
# Total params: 12,981
# Trainable params: 12,651
# Non-trainable params: 330
# _________________________________________________________________
# AUC:  0.723
# iterate_num:  2
#  sum of test_y: 136
# train_x_shape (37046, 55)
# class_weights {0: 0.5044527356409488, 1: 56.64525993883792}
# Epoch 1/30
# 73/73 [==============================] - 3s 24ms/step - loss: 0.6604 - accuracy: 0.6228 - my_auc: 0.6306 - val_loss: 0.6907 - val_accuracy: 0.0649 - val_my_auc: 0.6010
#  epoch:0 auc: 0.6036
# Epoch 2/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.6337 - accuracy: 0.5949 - my_auc: 0.6841 - val_loss: 0.6871 - val_accuracy: 0.1021 - val_my_auc: 0.6445
#  epoch:1 auc: 0.6439
# Epoch 3/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.6561 - accuracy: 0.5841 - my_auc: 0.6956 - val_loss: 0.6767 - val_accuracy: 0.2050 - val_my_auc: 0.6543
#  epoch:2 auc: 0.6548
# Epoch 4/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5820 - accuracy: 0.6169 - my_auc: 0.7409 - val_loss: 0.6648 - val_accuracy: 0.3061 - val_my_auc: 0.6529
#  epoch:3 auc: 0.6535
# Epoch 5/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5900 - accuracy: 0.6260 - my_auc: 0.7484 - val_loss: 0.6552 - val_accuracy: 0.4023 - val_my_auc: 0.6502
#  epoch:4 auc: 0.6500
# Epoch 6/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5791 - accuracy: 0.6356 - my_auc: 0.7269 - val_loss: 0.6516 - val_accuracy: 0.4794 - val_my_auc: 0.6525
#  epoch:5 auc: 0.6526
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_26 (Batc (None, 55)                220
# _________________________________________________________________
# layer_1 (Dense)              (None, 110)               6160
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 110)               0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 110)               440
# _________________________________________________________________
# layer_2 (Dense)              (None, 55)                6105
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 56
# =================================================================
# Total params: 12,981
# Trainable params: 12,651
# Non-trainable params: 330
# _________________________________________________________________
# AUC:  0.6646
# iterate_num:  3
#  sum of test_y: 136
# train_x_shape (37046, 55)
# class_weights {0: 0.5044527356409488, 1: 56.64525993883792}
# Epoch 1/30
# 73/73 [==============================] - 3s 24ms/step - loss: 0.8115 - accuracy: 0.1881 - my_auc: 0.5503 - val_loss: 0.6889 - val_accuracy: 0.1992 - val_my_auc: 0.5695
#  epoch:0 auc: 0.5716
# Epoch 2/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.6665 - accuracy: 0.5142 - my_auc: 0.6208 - val_loss: 0.6792 - val_accuracy: 0.2169 - val_my_auc: 0.6340
#  epoch:1 auc: 0.6333
# Epoch 3/30
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6207 - accuracy: 0.5644 - my_auc: 0.6900 - val_loss: 0.6699 - val_accuracy: 0.3026 - val_my_auc: 0.6493
#  epoch:2 auc: 0.6494
# Epoch 4/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.6503 - accuracy: 0.5879 - my_auc: 0.6780 - val_loss: 0.6586 - val_accuracy: 0.4349 - val_my_auc: 0.6499
#  epoch:3 auc: 0.6500
# Epoch 5/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5868 - accuracy: 0.6435 - my_auc: 0.7500 - val_loss: 0.6532 - val_accuracy: 0.4744 - val_my_auc: 0.6557
#  epoch:4 auc: 0.6559
# Epoch 6/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5930 - accuracy: 0.6281 - my_auc: 0.7486 - val_loss: 0.6489 - val_accuracy: 0.5965 - val_my_auc: 0.6613
#  epoch:5 auc: 0.6613
# Epoch 7/30
# 73/73 [==============================] - 1s 7ms/step - loss: 0.5807 - accuracy: 0.6522 - my_auc: 0.7682 - val_loss: 0.6446 - val_accuracy: 0.6249 - val_my_auc: 0.6695
#  epoch:6 auc: 0.6696
# Epoch 8/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5514 - accuracy: 0.6554 - my_auc: 0.7760 - val_loss: 0.6513 - val_accuracy: 0.6740 - val_my_auc: 0.6677
#  epoch:7 auc: 0.6677
# Epoch 9/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5107 - accuracy: 0.6902 - my_auc: 0.7978 - val_loss: 0.6520 - val_accuracy: 0.6813 - val_my_auc: 0.6759
#  epoch:8 auc: 0.6753
# Epoch 10/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5268 - accuracy: 0.6613 - my_auc: 0.8135 - val_loss: 0.6673 - val_accuracy: 0.7292 - val_my_auc: 0.6733
#  epoch:9 auc: 0.6732
# Epoch 11/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5526 - accuracy: 0.6766 - my_auc: 0.8001 - val_loss: 0.6827 - val_accuracy: 0.7600 - val_my_auc: 0.6696
#  epoch:10 auc: 0.6698
# Epoch 12/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4945 - accuracy: 0.6995 - my_auc: 0.8291 - val_loss: 0.6800 - val_accuracy: 0.7455 - val_my_auc: 0.6807
#  epoch:11 auc: 0.6805
# Epoch 13/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5143 - accuracy: 0.6953 - my_auc: 0.8111 - val_loss: 0.6894 - val_accuracy: 0.7784 - val_my_auc: 0.6802
#  epoch:12 auc: 0.6804
# Epoch 14/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4953 - accuracy: 0.7163 - my_auc: 0.8326 - val_loss: 0.6923 - val_accuracy: 0.7702 - val_my_auc: 0.6832
#  epoch:13 auc: 0.6834
# Epoch 15/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4960 - accuracy: 0.7112 - my_auc: 0.8310 - val_loss: 0.6940 - val_accuracy: 0.7512 - val_my_auc: 0.6825
#  epoch:14 auc: 0.6825
# Epoch 16/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4982 - accuracy: 0.6969 - my_auc: 0.8504 - val_loss: 0.7169 - val_accuracy: 0.7870 - val_my_auc: 0.6863
#  epoch:15 auc: 0.6862
# Epoch 17/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4659 - accuracy: 0.7349 - my_auc: 0.8567 - val_loss: 0.7246 - val_accuracy: 0.7714 - val_my_auc: 0.6762
#  epoch:16 auc: 0.6764
# Epoch 18/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4581 - accuracy: 0.7350 - my_auc: 0.8607 - val_loss: 0.7351 - val_accuracy: 0.7640 - val_my_auc: 0.6778
#  epoch:17 auc: 0.6783
# Epoch 19/30
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4806 - accuracy: 0.7128 - my_auc: 0.8519 - val_loss: 0.7514 - val_accuracy: 0.7967 - val_my_auc: 0.6841
#  epoch:18 auc: 0.6842
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_28 (Batc (None, 55)                220
# _________________________________________________________________
# layer_1 (Dense)              (None, 110)               6160
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 110)               0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 110)               440
# _________________________________________________________________
# layer_2 (Dense)              (None, 55)                6105
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 56
# =================================================================
# Total params: 12,981
# Trainable params: 12,651
# Non-trainable params: 330
# _________________________________________________________________
# AUC:  0.7391
# iterate_num:  4
#  sum of test_y: 137
# train_x_shape (37046, 55)
# class_weights {0: 0.5044389978213507, 1: 56.81901840490798}
# Epoch 1/30
# 73/73 [==============================] - 3s 24ms/step - loss: 0.7571 - accuracy: 0.7418 - my_auc: 0.5934 - val_loss: 0.6795 - val_accuracy: 0.4104 - val_my_auc: 0.6276
#  epoch:0 auc: 0.6279
# Epoch 2/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.6198 - accuracy: 0.6424 - my_auc: 0.6810 - val_loss: 0.6806 - val_accuracy: 0.1146 - val_my_auc: 0.6566
#  epoch:1 auc: 0.6577
# Epoch 3/30
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6538 - accuracy: 0.6045 - my_auc: 0.6898 - val_loss: 0.6747 - val_accuracy: 0.1612 - val_my_auc: 0.6789
#  epoch:2 auc: 0.6782
# Epoch 4/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.6036 - accuracy: 0.6196 - my_auc: 0.7262 - val_loss: 0.6669 - val_accuracy: 0.2197 - val_my_auc: 0.6862
#  epoch:3 auc: 0.6856
# Epoch 5/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.6099 - accuracy: 0.6039 - my_auc: 0.7574 - val_loss: 0.6441 - val_accuracy: 0.3498 - val_my_auc: 0.6867
#  epoch:4 auc: 0.6873
# Epoch 6/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5737 - accuracy: 0.6652 - my_auc: 0.7511 - val_loss: 0.6369 - val_accuracy: 0.3968 - val_my_auc: 0.6948
#  epoch:5 auc: 0.6949
# Epoch 7/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5845 - accuracy: 0.6350 - my_auc: 0.7694 - val_loss: 0.6295 - val_accuracy: 0.4981 - val_my_auc: 0.6904
#  epoch:6 auc: 0.6909
# Epoch 8/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5477 - accuracy: 0.6562 - my_auc: 0.7776 - val_loss: 0.6353 - val_accuracy: 0.5673 - val_my_auc: 0.6928
#  epoch:7 auc: 0.6923
# Epoch 9/30
# 73/73 [==============================] - 1s 8ms/step - loss: 0.5412 - accuracy: 0.6570 - my_auc: 0.7805 - val_loss: 0.6411 - val_accuracy: 0.5984 - val_my_auc: 0.6936
#  epoch:8 auc: 0.6935
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_30 (Batc (None, 55)                220
# _________________________________________________________________
# layer_1 (Dense)              (None, 110)               6160
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 110)               0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 110)               440
# _________________________________________________________________
# layer_2 (Dense)              (None, 55)                6105
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 56
# =================================================================
# Total params: 12,981
# Trainable params: 12,651
# Non-trainable params: 330
# _________________________________________________________________
# AUC:  0.6937
# avg_AUC :  0.7051131737500133
# avg_AUC_2 :  0.7051545402500748
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7051131737500133

# %% [markdown]
# ---

# %% [markdown]
# # LSTM
# ##### T =2,3
# ##### variables:
# ##### A. Quant. Indicators
# ##### C. Quant. Indicators + Overall Similarity

# %%
def model_lstm(n1,n2,n,w,l):
    model = None
    
    input_all = Input(shape=(w,l), \
               dtype='float32', name='input')
    #nor = BatchNormalization()(input_all)
    LSTM_w_1 = Bidirectional(LSTM(n1, dropout = 0.2, recurrent_dropout = 0.2, \
              name = 'layer_lstm_1', return_sequences=True))(input_all)
    LSTM_w_2 = LSTM(n2, activation='relu', dropout = 0.3, recurrent_dropout = 0.3,
                   name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)

    dense = Dense(n, activation='relu', name='dense')(LSTM_w_2)
    drop = Dropout(0.3)(dense)
    preds = Dense(1, activation='sigmoid', name='output')(drop)
    model = Model(inputs=input_all, outputs=preds)
    model._name = "model_lstm"
    model.summary()
    
    return model

# %%
def performance_measure(pred_yp, y):
    '''
    Given lists of predicted y probability and x, y, return a dataframe of AR, AUC, Brier, Decile Table
    '''
    
    tenc_dat = pd.DataFrame({'y_true':y,'probability':pred_yp.flatten()})
    tenc_dat.sort_values('probability',axis = 0,ascending=False, inplace = True)
    tenc_dat.index = range(0,len(tenc_dat))
    y = tenc_dat['y_true']
    point = float(len(tenc_dat))/10
    point = int(round(point))
    tenc = []
    for i in range(0,10):
        tenc.append(y[(i*point):((i+1)*point)])
    tenc[9]=tenc[9].append(y[10*point:])
    total = sum(y)
    num_of_bkr = []
    for j in range(0,10):
        num_of_bkr.append(sum(tenc[j]))
    tencile_bkr = np.array(num_of_bkr)
    rate = tencile_bkr.astype(float)/total

    return rate

# %%
class AUCEvaluation(Callback):
    """ Show AUC after interval number of epoches """
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()
        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            logs['auc'] = score
            tencile=performance_measure(y_pred, self.y_val)
            logs['tencile'] = tencile
            print(" epoch:{:d} auc: {:.4f}".format(epoch, score))

# %%
def fit_model( model,x_train, y_train, x_val, y_val, x_test, y_test, model_name, epoch, verbose = 0):
    
    history = None
    result = None
    
    model_df = model
    
    #class weight for test 
    class_weights = class_weight.compute_class_weight('balanced',
                              np.unique(y_train),
                              y_train)
    class_weights = {l:c for l,c in zip(np.unique(y_train), class_weights)}
    print(class_weights)
    # class weight for val
    val_class_weights = class_weight.compute_class_weight('balanced',
                                np.unique(y_val),
                                y_val)
    val_class_weights = {l:c for l,c in zip(np.unique(y_val), val_class_weights)}
    val_sample_weights = []
    for y in y_val:
        if y == 1:
          val_sample_weights.append(val_class_weights[1])
        else: val_sample_weights.append(val_class_weights[0])
    val_sample_weights = np.asarray(val_sample_weights)
    
    
    auc_eval = AUCEvaluation(validation_data=(x_val, y_val), interval=1)
    earlyStopping = EarlyStopping(monitor='val_my_auc',patience = 3, 
                      verbose =verbose, mode ='max')
    checkpoint = ModelCheckpoint(model_name,monitor='val_my_auc',verbose=verbose,
              save_best_only=True, save_weights_only=True, mode ='max')

    opt = optimizers.RMSprop(lr=0.0005)
    model_df.compile(optimizer= opt,
              loss='binary_crossentropy',
              metrics=['accuracy', metrics.AUC(name='my_auc')])
    
    history = model_df.fit(x_train,
                y_train,
                epochs=epoch,
                batch_size=512,
                callbacks=[auc_eval, earlyStopping,checkpoint], #checkpoint
                class_weight = class_weights, \
                validation_data=(x_val,y_val,val_sample_weights)) 
    model_df.load_weights(model_name)
    y_pred = model_df.predict(x_test)
    y_pred_1= np.reshape(y_pred, -1)
    auc_score = roc_auc_score(y_test, y_pred_1)
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_1)
    print("AUC: " ,round(auc_score,4))
        
    return history, auc_score, fpr, tpr, thresholds, [y_test, y_pred_1]

# %%
def cross_val(data, label, perf_cols, name, w, epoch):
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    predicted_res =[]
    his_auc = []
    
    kf = StratifiedKFold(n_splits = 4, shuffle = True, random_state = 33)
    c = 0

    X_perf,  Y = shift_data(df_fl, w, \
                    perf_cols, \
                    'label')
    
    for train_index, test_index in kf.split(range(len(X_perf)),Y):
        
        c += 1
        
        l1 = X_perf.shape[-1]
        print('l1',X_perf.shape[-1])
        
        model = model_lstm(l1,l1*2,12,\
                    X_perf.shape[1],X_perf.shape[2])
    
        #model = model_lstm(n1,n2,n,w)
        # train_x, train_val = train_test_split(train_index,test_size=0.2, \
        #             random_state=42, stratify = Y[train_index])
        train_perf_data = X_perf[train_index]
        #train_word_data = X_word[train_x]
        #train_perf_val = X_perf[train_val]
        #train_word_val = X_word[train_val]

        train_label = Y[train_index]
        #val_label = Y[train_val]

        test_perf_x = X_perf[test_index]
        #test_word_x = X_word[test_index]
        test_y = Y[test_index] 
        
        # train_data = [train_perf_data, train_word_data]
        # val_data = [train_perf_val,train_word_val]       
        # test_x = [test_perf_x, test_word_x]

        mod_res = fit_model(model, train_perf_data, train_label, test_perf_x, test_y, test_perf_x, test_y,\
                  name+'_'+str(c), epoch)
        his_auc.append(mod_res[0].history['val_my_auc'])
        
        
        
        
        auc_list.append(mod_res[1])
        tprs.append(np.interp(mean_fpr, mod_res[2], mod_res[3]))
        temp_pred_res = [mod_res[-1],test_index]
        print(len(test_index))
        predicted_res.append(temp_pred_res)
        
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    print(pd.DataFrame(his_auc))
    print(pd.DataFrame(his_auc).mean())
    
    return np.average(auc_list), mean_tpr, predicted_res

# %%
def shift_data(data, step, perf_cols, label):
    A = []
    
    cols = perf_cols #+ words_cols
    A.append(data[cols].values)
    
    for t in range(1, step):
        d = data.groupby("cik")[cols].shift(t)
        A.append(d.values)
    A = A[::-1]
    A = np.concatenate(A, axis = 1)  # flatten shifted columns
    A = np.concatenate([data[label].values[:,None], A], axis = 1)  # add target
    #np.random.shuffle(A)
    #print(A[3])
    print('init A shape: ',A.shape)
    #print(A[3,:])
    #print(data[cols].iloc[4,:])


    
    A = A[~np.isnan(A).any(axis=1)]  # drop nan
    

    Y = A[:,0]  # get target
    A = np.reshape(A[:,1:], (len(A), step, len(cols))) # reshape

    #A = np.reshape(A[:,1:], (len(A), step, len(perf_cols) + len(words_cols)))
    
    A_perf = A[:, :, 0:len(perf_cols)]
    # # CNN_LSTM must be None x T x words x 4
    # A_words = A[:, :, len(perf_cols):]
    # #convert the shape to [[_p,_new][_dis,_n]]
    # A_words = A_words.reshape((len(A), step, int(len(words_cols)/2), 2), order = 'C')
    
    print(A_perf.shape, Y.sum())
    return A_perf, Y

# %%
# financial performance + overall change + word change timestep = 1
# cross_val(df_fl, 'label', v_perf + v_1 +selected_new_all, 'lstm_wrdperf', 1, epoch = 10)

# %%
# financial performance + overall change + word change timestep = 2
cross_val(df_fl, 'label_new', v_perf + v_1 +selected_new_all, 'lstm_perf', 2, epoch = 30)
# Out:
# init A shape:  (61744, 111)
# (53600, 2, 55) 408.0
# l1 55
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 55)]           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 2, 110)            48840
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 110)               97240
# _________________________________________________________________
# dense (Dense)                (None, 12)                1332
# _________________________________________________________________
# dropout (Dropout)            (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 147,425
# Trainable params: 147,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/30
# 79/79 [==============================] - 16s 104ms/step - loss: 0.6753 - accuracy: 0.6432 - my_auc: 0.5282 - val_loss: 0.6892 - val_accuracy: 0.1269 - val_my_auc: 0.6503
#  epoch:0 auc: 0.6506
# Epoch 2/30
# 79/79 [==============================] - 6s 71ms/step - loss: 0.6893 - accuracy: 0.4523 - my_auc: 0.5761 - val_loss: 0.6854 - val_accuracy: 0.2011 - val_my_auc: 0.6606
#  epoch:1 auc: 0.6633
# Epoch 3/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6620 - accuracy: 0.5326 - my_auc: 0.6046 - val_loss: 0.6769 - val_accuracy: 0.7869 - val_my_auc: 0.6464
#  epoch:2 auc: 0.6466
# Epoch 4/30
# 79/79 [==============================] - 6s 70ms/step - loss: 0.6841 - accuracy: 0.5677 - my_auc: 0.5852 - val_loss: 0.6715 - val_accuracy: 0.7731 - val_my_auc: 0.6567
#  epoch:3 auc: 0.6553
# Epoch 5/30
# 79/79 [==============================] - 6s 70ms/step - loss: 0.6511 - accuracy: 0.6209 - my_auc: 0.6286 - val_loss: 0.6838 - val_accuracy: 0.9074 - val_my_auc: 0.6475
#  epoch:4 auc: 0.6496
# AUC:  0.6633
# 13400
# l1 55
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 55)]           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 2, 110)            48840
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 110)               97240
# _________________________________________________________________
# dense (Dense)                (None, 12)                1332
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 147,425
# Trainable params: 147,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/30
# 79/79 [==============================] - 16s 99ms/step - loss: 0.6902 - accuracy: 0.4305 - my_auc: 0.5024 - val_loss: 0.6897 - val_accuracy: 0.5628 - val_my_auc: 0.6224
#  epoch:0 auc: 0.6351
# Epoch 2/30
# 79/79 [==============================] - 6s 71ms/step - loss: 0.6849 - accuracy: 0.4327 - my_auc: 0.5819 - val_loss: 0.6835 - val_accuracy: 0.2879 - val_my_auc: 0.6485
#  epoch:1 auc: 0.6470
# Epoch 3/30
# 79/79 [==============================] - 6s 71ms/step - loss: 0.6948 - accuracy: 0.3943 - my_auc: 0.6182 - val_loss: 0.6768 - val_accuracy: 0.3745 - val_my_auc: 0.6483
#  epoch:2 auc: 0.6506
# Epoch 4/30
# 79/79 [==============================] - 6s 71ms/step - loss: 0.6587 - accuracy: 0.5503 - my_auc: 0.6185 - val_loss: 0.6711 - val_accuracy: 0.3167 - val_my_auc: 0.6519
#  epoch:3 auc: 0.6528
# Epoch 5/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6698 - accuracy: 0.5560 - my_auc: 0.6211 - val_loss: 0.6632 - val_accuracy: 0.5372 - val_my_auc: 0.6507
#  epoch:4 auc: 0.6521
# Epoch 6/30
# 79/79 [==============================] - 6s 70ms/step - loss: 0.6619 - accuracy: 0.5986 - my_auc: 0.6899 - val_loss: 0.6578 - val_accuracy: 0.6457 - val_my_auc: 0.6560
#  epoch:5 auc: 0.6558
# Epoch 7/30
# 79/79 [==============================] - 6s 71ms/step - loss: 0.6511 - accuracy: 0.6004 - my_auc: 0.6907 - val_loss: 0.6605 - val_accuracy: 0.7858 - val_my_auc: 0.6593
#  epoch:6 auc: 0.6590
# Epoch 8/30
# 79/79 [==============================] - 6s 71ms/step - loss: 0.6539 - accuracy: 0.6171 - my_auc: 0.6604 - val_loss: 0.6580 - val_accuracy: 0.7958 - val_my_auc: 0.6642
#  epoch:7 auc: 0.6644
# Epoch 9/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6247 - accuracy: 0.6748 - my_auc: 0.6760 - val_loss: 0.6542 - val_accuracy: 0.4469 - val_my_auc: 0.6758
#  epoch:8 auc: 0.6758
# Epoch 10/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6477 - accuracy: 0.6025 - my_auc: 0.6574 - val_loss: 0.6486 - val_accuracy: 0.6613 - val_my_auc: 0.6766
#  epoch:9 auc: 0.6763
# Epoch 11/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6457 - accuracy: 0.6304 - my_auc: 0.6703 - val_loss: 0.6622 - val_accuracy: 0.8477 - val_my_auc: 0.6749
#  epoch:10 auc: 0.6748
# Epoch 12/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6540 - accuracy: 0.6635 - my_auc: 0.6546 - val_loss: 0.6542 - val_accuracy: 0.4131 - val_my_auc: 0.6816
#  epoch:11 auc: 0.6818
# Epoch 13/30
# 79/79 [==============================] - 6s 71ms/step - loss: 0.6372 - accuracy: 0.6194 - my_auc: 0.6996 - val_loss: 0.6433 - val_accuracy: 0.5744 - val_my_auc: 0.6801
#  epoch:12 auc: 0.6799
# Epoch 14/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6432 - accuracy: 0.6086 - my_auc: 0.6655 - val_loss: 0.6470 - val_accuracy: 0.4525 - val_my_auc: 0.6858
#  epoch:13 auc: 0.6855
# Epoch 15/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6562 - accuracy: 0.5552 - my_auc: 0.6584 - val_loss: 0.6468 - val_accuracy: 0.7802 - val_my_auc: 0.6829
#  epoch:14 auc: 0.6822
# Epoch 16/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6396 - accuracy: 0.6464 - my_auc: 0.6805 - val_loss: 0.6495 - val_accuracy: 0.4251 - val_my_auc: 0.6854
#  epoch:15 auc: 0.6856
# Epoch 17/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6383 - accuracy: 0.5797 - my_auc: 0.6926 - val_loss: 0.6400 - val_accuracy: 0.5029 - val_my_auc: 0.6905
#  epoch:16 auc: 0.6904
# Epoch 18/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6286 - accuracy: 0.6091 - my_auc: 0.6996 - val_loss: 0.6491 - val_accuracy: 0.3749 - val_my_auc: 0.6924
#  epoch:17 auc: 0.6918
# Epoch 19/30
# 79/79 [==============================] - 6s 74ms/step - loss: 0.6064 - accuracy: 0.5981 - my_auc: 0.7157 - val_loss: 0.6363 - val_accuracy: 0.5436 - val_my_auc: 0.6930
#  epoch:18 auc: 0.6931
# Epoch 20/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6040 - accuracy: 0.6444 - my_auc: 0.6919 - val_loss: 0.6397 - val_accuracy: 0.4743 - val_my_auc: 0.6947
#  epoch:19 auc: 0.6940
# Epoch 21/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6325 - accuracy: 0.6120 - my_auc: 0.7023 - val_loss: 0.6351 - val_accuracy: 0.6845 - val_my_auc: 0.6924
#  epoch:20 auc: 0.6922
# Epoch 22/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6130 - accuracy: 0.6939 - my_auc: 0.6917 - val_loss: 0.6434 - val_accuracy: 0.4381 - val_my_auc: 0.6922
#  epoch:21 auc: 0.6930
# Epoch 23/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6467 - accuracy: 0.5796 - my_auc: 0.6873 - val_loss: 0.6360 - val_accuracy: 0.6850 - val_my_auc: 0.6935
#  epoch:22 auc: 0.6931
# AUC:  0.694
# 13400
# l1 55
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 55)]           0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 2, 110)            48840
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 110)               97240
# _________________________________________________________________
# dense (Dense)                (None, 12)                1332
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 147,425
# Trainable params: 147,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/30
# 79/79 [==============================] - 16s 100ms/step - loss: 0.7013 - accuracy: 0.3228 - my_auc: 0.5171 - val_loss: 0.6897 - val_accuracy: 0.8471 - val_my_auc: 0.6363
#  epoch:0 auc: 0.6636
# Epoch 2/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.7109 - accuracy: 0.6007 - my_auc: 0.5313 - val_loss: 0.6821 - val_accuracy: 0.8996 - val_my_auc: 0.6745
#  epoch:1 auc: 0.6751
# Epoch 3/30
# 79/79 [==============================] - 6s 74ms/step - loss: 0.7128 - accuracy: 0.6927 - my_auc: 0.6108 - val_loss: 0.6748 - val_accuracy: 0.8715 - val_my_auc: 0.6812
#  epoch:2 auc: 0.6803
# Epoch 4/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6604 - accuracy: 0.7723 - my_auc: 0.6567 - val_loss: 0.6629 - val_accuracy: 0.5756 - val_my_auc: 0.6908
#  epoch:3 auc: 0.6901
# Epoch 5/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.5998 - accuracy: 0.7507 - my_auc: 0.5944 - val_loss: 0.6660 - val_accuracy: 0.2831 - val_my_auc: 0.6903
#  epoch:4 auc: 0.6903
# Epoch 6/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6863 - accuracy: 0.5227 - my_auc: 0.6388 - val_loss: 0.6485 - val_accuracy: 0.8105 - val_my_auc: 0.6974
#  epoch:5 auc: 0.6980
# Epoch 7/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6723 - accuracy: 0.6632 - my_auc: 0.6281 - val_loss: 0.6458 - val_accuracy: 0.4684 - val_my_auc: 0.7061
#  epoch:6 auc: 0.7054
# Epoch 8/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6739 - accuracy: 0.5491 - my_auc: 0.6464 - val_loss: 0.6464 - val_accuracy: 0.4315 - val_my_auc: 0.7085
#  epoch:7 auc: 0.7087
# Epoch 9/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6401 - accuracy: 0.5394 - my_auc: 0.6714 - val_loss: 0.6429 - val_accuracy: 0.4078 - val_my_auc: 0.7079
#  epoch:8 auc: 0.7086
# Epoch 10/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6270 - accuracy: 0.5927 - my_auc: 0.6540 - val_loss: 0.6485 - val_accuracy: 0.3162 - val_my_auc: 0.7075
#  epoch:9 auc: 0.7079
# Epoch 11/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6548 - accuracy: 0.5295 - my_auc: 0.6370 - val_loss: 0.6322 - val_accuracy: 0.4722 - val_my_auc: 0.7111
#  epoch:10 auc: 0.7106
# Epoch 12/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6428 - accuracy: 0.5789 - my_auc: 0.6546 - val_loss: 0.6294 - val_accuracy: 0.5007 - val_my_auc: 0.7141
#  epoch:11 auc: 0.7141
# Epoch 13/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6536 - accuracy: 0.5532 - my_auc: 0.6696 - val_loss: 0.6239 - val_accuracy: 0.6056 - val_my_auc: 0.7187
#  epoch:12 auc: 0.7184
# Epoch 14/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6596 - accuracy: 0.6026 - my_auc: 0.6558 - val_loss: 0.6369 - val_accuracy: 0.4092 - val_my_auc: 0.7179
#  epoch:13 auc: 0.7180
# Epoch 15/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6573 - accuracy: 0.5501 - my_auc: 0.6798 - val_loss: 0.6229 - val_accuracy: 0.5453 - val_my_auc: 0.7234
#  epoch:14 auc: 0.7230
# Epoch 16/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6141 - accuracy: 0.6637 - my_auc: 0.7050 - val_loss: 0.6167 - val_accuracy: 0.6907 - val_my_auc: 0.7262
#  epoch:15 auc: 0.7262
# Epoch 17/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6053 - accuracy: 0.6542 - my_auc: 0.6959 - val_loss: 0.6370 - val_accuracy: 0.3362 - val_my_auc: 0.7222
#  epoch:16 auc: 0.7216
# Epoch 18/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6363 - accuracy: 0.5361 - my_auc: 0.6788 - val_loss: 0.6155 - val_accuracy: 0.5128 - val_my_auc: 0.7281
#  epoch:17 auc: 0.7276
# Epoch 19/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6586 - accuracy: 0.5521 - my_auc: 0.6451 - val_loss: 0.6208 - val_accuracy: 0.4965 - val_my_auc: 0.7262
#  epoch:18 auc: 0.7265
# Epoch 20/30
# 79/79 [==============================] - 6s 74ms/step - loss: 0.6366 - accuracy: 0.6182 - my_auc: 0.6611 - val_loss: 0.6420 - val_accuracy: 0.2750 - val_my_auc: 0.7230
#  epoch:19 auc: 0.7229
# Epoch 21/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6278 - accuracy: 0.5475 - my_auc: 0.6967 - val_loss: 0.6257 - val_accuracy: 0.3829 - val_my_auc: 0.7233
#  epoch:20 auc: 0.7242
# AUC:  0.7276
# 13400
# l1 55
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 55)]           0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 2, 110)            48840
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 110)               97240
# _________________________________________________________________
# dense (Dense)                (None, 12)                1332
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 147,425
# Trainable params: 147,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/30
# 79/79 [==============================] - 16s 100ms/step - loss: 0.6990 - accuracy: 0.1939 - my_auc: 0.5020 - val_loss: 0.6904 - val_accuracy: 0.7840 - val_my_auc: 0.6588
#  epoch:0 auc: 0.6861
# Epoch 2/30
# 79/79 [==============================] - 6s 74ms/step - loss: 0.6897 - accuracy: 0.5064 - my_auc: 0.5496 - val_loss: 0.6834 - val_accuracy: 0.4212 - val_my_auc: 0.7091
#  epoch:1 auc: 0.7129
# Epoch 3/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6835 - accuracy: 0.6269 - my_auc: 0.5805 - val_loss: 0.6740 - val_accuracy: 0.8087 - val_my_auc: 0.7086
#  epoch:2 auc: 0.7088
# Epoch 4/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6706 - accuracy: 0.6603 - my_auc: 0.5868 - val_loss: 0.6580 - val_accuracy: 0.7734 - val_my_auc: 0.7142
#  epoch:3 auc: 0.7136
# Epoch 5/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6711 - accuracy: 0.6248 - my_auc: 0.6154 - val_loss: 0.6513 - val_accuracy: 0.5296 - val_my_auc: 0.7191
#  epoch:4 auc: 0.7195
# Epoch 6/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6727 - accuracy: 0.5913 - my_auc: 0.6551 - val_loss: 0.6308 - val_accuracy: 0.7330 - val_my_auc: 0.7206
#  epoch:5 auc: 0.7206
# Epoch 7/30
# 79/79 [==============================] - 6s 74ms/step - loss: 0.6756 - accuracy: 0.6022 - my_auc: 0.6696 - val_loss: 0.6440 - val_accuracy: 0.3966 - val_my_auc: 0.7290
#  epoch:6 auc: 0.7282
# Epoch 8/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6794 - accuracy: 0.5387 - my_auc: 0.6372 - val_loss: 0.6337 - val_accuracy: 0.4657 - val_my_auc: 0.7252
#  epoch:7 auc: 0.7248
# Epoch 9/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6727 - accuracy: 0.5326 - my_auc: 0.6216 - val_loss: 0.6258 - val_accuracy: 0.6393 - val_my_auc: 0.7242
#  epoch:8 auc: 0.7242
# Epoch 10/30
# 79/79 [==============================] - 6s 72ms/step - loss: 0.6929 - accuracy: 0.5447 - my_auc: 0.6404 - val_loss: 0.6366 - val_accuracy: 0.3811 - val_my_auc: 0.7307
#  epoch:9 auc: 0.7304
# Epoch 11/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6472 - accuracy: 0.5421 - my_auc: 0.6643 - val_loss: 0.6349 - val_accuracy: 0.3896 - val_my_auc: 0.7327
#  epoch:10 auc: 0.7323
# Epoch 12/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6552 - accuracy: 0.5723 - my_auc: 0.6702 - val_loss: 0.6264 - val_accuracy: 0.4656 - val_my_auc: 0.7296
#  epoch:11 auc: 0.7295
# Epoch 13/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6382 - accuracy: 0.5694 - my_auc: 0.6590 - val_loss: 0.6344 - val_accuracy: 0.3507 - val_my_auc: 0.7360
#  epoch:12 auc: 0.7354
# Epoch 14/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6603 - accuracy: 0.5347 - my_auc: 0.6588 - val_loss: 0.6214 - val_accuracy: 0.5191 - val_my_auc: 0.7300
#  epoch:13 auc: 0.7299
# Epoch 15/30
# 79/79 [==============================] - 6s 73ms/step - loss: 0.6629 - accuracy: 0.5841 - my_auc: 0.6565 - val_loss: 0.6252 - val_accuracy: 0.4500 - val_my_auc: 0.7311
#  epoch:14 auc: 0.7311
# Epoch 16/30
# 79/79 [==============================] - 6s 74ms/step - loss: 0.5986 - accuracy: 0.6038 - my_auc: 0.6911 - val_loss: 0.6232 - val_accuracy: 0.4210 - val_my_auc: 0.7331
#  epoch:15 auc: 0.7332
# AUC:  0.7354
# 13400
# avg_AUC :  0.7050493550556033
# avg_AUC_2 :  0.705189146365617
#          0         1         2   ...        20       21        22
# 0  0.650263  0.660572  0.646395  ...       NaN      NaN       NaN
# 1  0.622436  0.648528  0.648349  ...  0.692408  0.69219  0.693518
# 2  0.636271  0.674481  0.681196  ...  0.723306      NaN       NaN
# 3  0.658825  0.709146  0.708559  ...       NaN      NaN       NaN
#
# [4 rows x 23 columns]
# 0     0.641949
# 1     0.673182
# 2     0.671125
# 3     0.678390
# 4     0.676908
# 5     0.691322
# 6     0.698107
# 7     0.699282
# 8     0.702611
# 9     0.704951
# 10    0.706232
# 11    0.708442
# 12    0.711564
# 13    0.711219
# 14    0.712454
# 15    0.714882
# 16    0.706390
# 17    0.710215
# 18    0.709632
# 19    0.708832
# 20    0.707857
# 21    0.692190
# 22    0.693518
# dtype: float64
# (0.7050493550556033,
#  array([0.        , 0.07843137, 0.11029412, 0.125     , 0.13970588,
#         0.17892157, 0.20833333, 0.23039216, 0.26715686, 0.27205882,
#         0.29656863, 0.31617647, 0.32843137, 0.33823529, 0.35784314,
#         0.38235294, 0.38970588, 0.40686275, 0.42647059, 0.43382353,
#         0.44852941, 0.46813725, 0.49264706, 0.49754902, 0.51470588,
#         0.53676471, 0.55147059, 0.55882353, 0.56862745, 0.58088235,
#         0.59068627, 0.60294118, 0.61029412, 0.61764706, 0.63235294,
#         0.6372549 , 0.66421569, 0.66911765, 0.67647059, 0.67892157,
#         0.69117647, 0.69852941, 0.70343137, 0.71813725, 0.74019608,
#         0.74509804, 0.75245098, 0.76715686, 0.77205882, 0.78431373,
#         0.78676471, 0.79166667, 0.80637255, 0.82352941, 0.82843137,
#         0.83823529, 0.84803922, 0.86029412, 0.86029412, 0.8627451 ,
#         0.86519608, 0.87009804, 0.87745098, 0.88235294, 0.88235294,
#         0.8872549 , 0.89460784, 0.8995098 , 0.90196078, 0.90441176,
#         0.90686275, 0.90931373, 0.91176471, 0.91176471, 0.92401961,
#         0.92647059, 0.93382353, 0.93627451, 0.93872549, 0.94852941,
#         0.94852941, 0.95588235, 0.96323529, 0.96568627, 0.97058824,
#         0.9754902 , 0.9754902 , 0.97794118, 0.98039216, 0.98284314,
#         0.98529412, 0.9877451 , 0.9877451 , 0.99019608, 0.99264706,
#         0.99754902, 1.        , 1.        , 1.        , 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5043338 , 0.5229884 , 0.5306649 , ..., 0.50092214, 0.5332497 ,
#            0.50962186], dtype=float32)],
#    array([    4,     9,    10, ..., 53593, 53596, 53598])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.56682193, 0.6780138 , 0.51263535, ..., 0.4829686 , 0.31935784,
#            0.14261222], dtype=float32)],
#    array([    2,     7,    12, ..., 53586, 53591, 53599])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5582932 , 0.44052505, 0.5628052 , ..., 0.37447983, 0.53531355,
#            0.15504706], dtype=float32)],
#    array([    3,     5,     8, ..., 53594, 53595, 53597])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.52454764, 0.60678697, 0.6344055 , ..., 0.66243696, 0.53448504,
#            0.56618595], dtype=float32)],
#    array([    0,     1,     6, ..., 53579, 53588, 53589])]])

# %%
# financial performance + overall change + word change timestep = 3
cross_val(df_fl, 'label_new', v_perf + v_1 +selected_new_all, 'lstm_perf', 3, epoch = 30)
# Out:
# init A shape:  (61744, 166)
# (46409, 3, 55) 341.0
# l1 55
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 55)]           0
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 3, 110)            48840
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 110)               97240
# _________________________________________________________________
# dense (Dense)                (None, 12)                1332
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 147,425
# Trainable params: 147,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5036901970999392, 1.0: 68.24705882352941}
# Epoch 1/30
# 68/68 [==============================] - 19s 163ms/step - loss: 0.6812 - accuracy: 0.9454 - my_auc: 0.4907 - val_loss: 0.6916 - val_accuracy: 0.9926 - val_my_auc: 0.6378
#  epoch:0 auc: 0.6766
# Epoch 2/30
# 68/68 [==============================] - 8s 117ms/step - loss: 0.6898 - accuracy: 0.8560 - my_auc: 0.5325 - val_loss: 0.6897 - val_accuracy: 0.9922 - val_my_auc: 0.6746
#  epoch:1 auc: 0.6765
# Epoch 3/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6952 - accuracy: 0.8043 - my_auc: 0.5982 - val_loss: 0.6778 - val_accuracy: 0.9386 - val_my_auc: 0.6802
#  epoch:2 auc: 0.6813
# Epoch 4/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6651 - accuracy: 0.7079 - my_auc: 0.5816 - val_loss: 0.6710 - val_accuracy: 0.2750 - val_my_auc: 0.6810
#  epoch:3 auc: 0.6823
# Epoch 5/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6607 - accuracy: 0.5791 - my_auc: 0.6296 - val_loss: 0.6552 - val_accuracy: 0.8412 - val_my_auc: 0.6858
#  epoch:4 auc: 0.6859
# Epoch 6/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6201 - accuracy: 0.6900 - my_auc: 0.6644 - val_loss: 0.6650 - val_accuracy: 0.3000 - val_my_auc: 0.6849
#  epoch:5 auc: 0.6846
# Epoch 7/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6670 - accuracy: 0.5774 - my_auc: 0.6422 - val_loss: 0.6452 - val_accuracy: 0.7304 - val_my_auc: 0.6883
#  epoch:6 auc: 0.6881
# Epoch 8/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6301 - accuracy: 0.6206 - my_auc: 0.6914 - val_loss: 0.6425 - val_accuracy: 0.5790 - val_my_auc: 0.6932
#  epoch:7 auc: 0.6932
# Epoch 9/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6863 - accuracy: 0.5075 - my_auc: 0.6632 - val_loss: 0.6421 - val_accuracy: 0.5262 - val_my_auc: 0.6979
#  epoch:8 auc: 0.6986
# Epoch 10/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6477 - accuracy: 0.5480 - my_auc: 0.6862 - val_loss: 0.6507 - val_accuracy: 0.3929 - val_my_auc: 0.7000
#  epoch:9 auc: 0.6996
# Epoch 11/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6513 - accuracy: 0.5150 - my_auc: 0.6499 - val_loss: 0.6441 - val_accuracy: 0.5020 - val_my_auc: 0.7012
#  epoch:10 auc: 0.7015
# Epoch 12/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6346 - accuracy: 0.6090 - my_auc: 0.6976 - val_loss: 0.6463 - val_accuracy: 0.4769 - val_my_auc: 0.7010
#  epoch:11 auc: 0.7019
# Epoch 13/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6272 - accuracy: 0.5896 - my_auc: 0.6463 - val_loss: 0.6589 - val_accuracy: 0.3041 - val_my_auc: 0.7007
#  epoch:12 auc: 0.7016
# Epoch 14/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6820 - accuracy: 0.4880 - my_auc: 0.6574 - val_loss: 0.6411 - val_accuracy: 0.5699 - val_my_auc: 0.7047
#  epoch:13 auc: 0.7045
# Epoch 15/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6049 - accuracy: 0.5977 - my_auc: 0.6841 - val_loss: 0.6443 - val_accuracy: 0.3462 - val_my_auc: 0.7039
#  epoch:14 auc: 0.7043
# Epoch 16/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.5955 - accuracy: 0.5848 - my_auc: 0.6929 - val_loss: 0.6399 - val_accuracy: 0.4335 - val_my_auc: 0.7056
#  epoch:15 auc: 0.7057
# Epoch 17/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6281 - accuracy: 0.5401 - my_auc: 0.6961 - val_loss: 0.6338 - val_accuracy: 0.4762 - val_my_auc: 0.7114
#  epoch:16 auc: 0.7116
# Epoch 18/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6851 - accuracy: 0.5248 - my_auc: 0.6635 - val_loss: 0.6346 - val_accuracy: 0.4992 - val_my_auc: 0.7086
#  epoch:17 auc: 0.7084
# Epoch 19/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6575 - accuracy: 0.5511 - my_auc: 0.6805 - val_loss: 0.6345 - val_accuracy: 0.4624 - val_my_auc: 0.7132
#  epoch:18 auc: 0.7128
# Epoch 20/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.5968 - accuracy: 0.5899 - my_auc: 0.7160 - val_loss: 0.6375 - val_accuracy: 0.3664 - val_my_auc: 0.7171
#  epoch:19 auc: 0.7176
# Epoch 21/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.5905 - accuracy: 0.6126 - my_auc: 0.6928 - val_loss: 0.6317 - val_accuracy: 0.4373 - val_my_auc: 0.7165
#  epoch:20 auc: 0.7171
# Epoch 22/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6327 - accuracy: 0.5766 - my_auc: 0.7103 - val_loss: 0.6332 - val_accuracy: 0.4462 - val_my_auc: 0.7199
#  epoch:21 auc: 0.7202
# Epoch 23/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6602 - accuracy: 0.5332 - my_auc: 0.6795 - val_loss: 0.6395 - val_accuracy: 0.6099 - val_my_auc: 0.7214
#  epoch:22 auc: 0.7207
# Epoch 24/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6192 - accuracy: 0.5933 - my_auc: 0.7321 - val_loss: 0.6428 - val_accuracy: 0.3159 - val_my_auc: 0.7214
#  epoch:23 auc: 0.7209
# Epoch 25/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6406 - accuracy: 0.5270 - my_auc: 0.6972 - val_loss: 0.6338 - val_accuracy: 0.3716 - val_my_auc: 0.7260
#  epoch:24 auc: 0.7260
# Epoch 26/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.5999 - accuracy: 0.5908 - my_auc: 0.7396 - val_loss: 0.6252 - val_accuracy: 0.5530 - val_my_auc: 0.7256
#  epoch:25 auc: 0.7259
# Epoch 27/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6233 - accuracy: 0.5544 - my_auc: 0.7013 - val_loss: 0.6308 - val_accuracy: 0.5153 - val_my_auc: 0.7294
#  epoch:26 auc: 0.7294
# Epoch 28/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.5696 - accuracy: 0.6203 - my_auc: 0.7311 - val_loss: 0.6334 - val_accuracy: 0.3309 - val_my_auc: 0.7254
#  epoch:27 auc: 0.7257
# Epoch 29/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6623 - accuracy: 0.5186 - my_auc: 0.6908 - val_loss: 0.6429 - val_accuracy: 0.4303 - val_my_auc: 0.7210
#  epoch:28 auc: 0.7206
# Epoch 30/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6351 - accuracy: 0.5228 - my_auc: 0.7005 - val_loss: 0.6282 - val_accuracy: 0.3731 - val_my_auc: 0.7285
#  epoch:29 auc: 0.7276
# AUC:  0.7294
# 11603
# l1 55
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 55)]           0
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 3, 110)            48840
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 110)               97240
# _________________________________________________________________
# dense (Dense)                (None, 12)                1332
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 147,425
# Trainable params: 147,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5037046684611155, 1.0: 67.982421875}
# Epoch 1/30
# 68/68 [==============================] - 17s 133ms/step - loss: 0.6815 - accuracy: 0.8872 - my_auc: 0.5411 - val_loss: 0.6890 - val_accuracy: 0.7399 - val_my_auc: 0.6878
#  epoch:0 auc: 0.6992
# Epoch 2/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6253 - accuracy: 0.8602 - my_auc: 0.5450 - val_loss: 0.6860 - val_accuracy: 0.3018 - val_my_auc: 0.7127
#  epoch:1 auc: 0.7202
# Epoch 3/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6974 - accuracy: 0.6151 - my_auc: 0.5947 - val_loss: 0.6708 - val_accuracy: 0.7684 - val_my_auc: 0.7158
#  epoch:2 auc: 0.7188
# Epoch 4/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6746 - accuracy: 0.6790 - my_auc: 0.6046 - val_loss: 0.6742 - val_accuracy: 0.2046 - val_my_auc: 0.7215
#  epoch:3 auc: 0.7302
# Epoch 5/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6759 - accuracy: 0.5388 - my_auc: 0.6196 - val_loss: 0.6570 - val_accuracy: 0.3348 - val_my_auc: 0.7324
#  epoch:4 auc: 0.7330
# Epoch 6/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6881 - accuracy: 0.5037 - my_auc: 0.6507 - val_loss: 0.6331 - val_accuracy: 0.7141 - val_my_auc: 0.7291
#  epoch:5 auc: 0.7292
# Epoch 7/30
# 68/68 [==============================] - 7s 100ms/step - loss: 0.6472 - accuracy: 0.5951 - my_auc: 0.6443 - val_loss: 0.6496 - val_accuracy: 0.3355 - val_my_auc: 0.7373
#  epoch:6 auc: 0.7358
# Epoch 8/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6839 - accuracy: 0.5055 - my_auc: 0.6498 - val_loss: 0.6226 - val_accuracy: 0.5734 - val_my_auc: 0.7348
#  epoch:7 auc: 0.7354
# Epoch 9/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6778 - accuracy: 0.5444 - my_auc: 0.6564 - val_loss: 0.6318 - val_accuracy: 0.3987 - val_my_auc: 0.7378
#  epoch:8 auc: 0.7383
# Epoch 10/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6396 - accuracy: 0.5344 - my_auc: 0.6549 - val_loss: 0.6260 - val_accuracy: 0.3870 - val_my_auc: 0.7391
#  epoch:9 auc: 0.7389
# Epoch 11/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6544 - accuracy: 0.4948 - my_auc: 0.6498 - val_loss: 0.6469 - val_accuracy: 0.2326 - val_my_auc: 0.7390
#  epoch:10 auc: 0.7408
# Epoch 12/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6314 - accuracy: 0.5148 - my_auc: 0.6624 - val_loss: 0.6126 - val_accuracy: 0.4822 - val_my_auc: 0.7424
#  epoch:11 auc: 0.7433
# Epoch 13/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6367 - accuracy: 0.5593 - my_auc: 0.6912 - val_loss: 0.6150 - val_accuracy: 0.4473 - val_my_auc: 0.7440
#  epoch:12 auc: 0.7440
# Epoch 14/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6307 - accuracy: 0.5396 - my_auc: 0.6894 - val_loss: 0.6217 - val_accuracy: 0.3792 - val_my_auc: 0.7443
#  epoch:13 auc: 0.7447
# Epoch 15/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6532 - accuracy: 0.5230 - my_auc: 0.6694 - val_loss: 0.6365 - val_accuracy: 0.2577 - val_my_auc: 0.7426
#  epoch:14 auc: 0.7432
# Epoch 16/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6416 - accuracy: 0.4802 - my_auc: 0.6639 - val_loss: 0.6167 - val_accuracy: 0.3639 - val_my_auc: 0.7476
#  epoch:15 auc: 0.7473
# Epoch 17/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6403 - accuracy: 0.5202 - my_auc: 0.6729 - val_loss: 0.6178 - val_accuracy: 0.3440 - val_my_auc: 0.7481
#  epoch:16 auc: 0.7486
# Epoch 18/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6226 - accuracy: 0.5320 - my_auc: 0.6964 - val_loss: 0.5946 - val_accuracy: 0.6140 - val_my_auc: 0.7479
#  epoch:17 auc: 0.7480
# Epoch 19/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.5944 - accuracy: 0.5936 - my_auc: 0.7061 - val_loss: 0.6196 - val_accuracy: 0.3239 - val_my_auc: 0.7535
#  epoch:18 auc: 0.7530
# Epoch 20/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6306 - accuracy: 0.5314 - my_auc: 0.6787 - val_loss: 0.6264 - val_accuracy: 0.2612 - val_my_auc: 0.7532
#  epoch:19 auc: 0.7525
# Epoch 21/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6297 - accuracy: 0.5109 - my_auc: 0.7038 - val_loss: 0.6334 - val_accuracy: 0.2285 - val_my_auc: 0.7531
#  epoch:20 auc: 0.7533
# Epoch 22/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6200 - accuracy: 0.4924 - my_auc: 0.6966 - val_loss: 0.5960 - val_accuracy: 0.4539 - val_my_auc: 0.7589
#  epoch:21 auc: 0.7580
# Epoch 23/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6467 - accuracy: 0.5329 - my_auc: 0.6603 - val_loss: 0.6206 - val_accuracy: 0.2578 - val_my_auc: 0.7503
#  epoch:22 auc: 0.7505
# Epoch 24/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6424 - accuracy: 0.4804 - my_auc: 0.7093 - val_loss: 0.5960 - val_accuracy: 0.4222 - val_my_auc: 0.7582
#  epoch:23 auc: 0.7589
# Epoch 25/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6702 - accuracy: 0.4721 - my_auc: 0.6453 - val_loss: 0.5911 - val_accuracy: 0.6785 - val_my_auc: 0.7569
#  epoch:24 auc: 0.7569
# AUC:  0.758
# 11602
# l1 55
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 55)]           0
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 3, 110)            48840
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 110)               97240
# _________________________________________________________________
# dense (Dense)                (None, 12)                1332
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 147,425
# Trainable params: 147,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5037046684611155, 1.0: 67.982421875}
# Epoch 1/30
# 68/68 [==============================] - 17s 132ms/step - loss: 0.6973 - accuracy: 0.5814 - my_auc: 0.4737 - val_loss: 0.6919 - val_accuracy: 0.9429 - val_my_auc: 0.5688
#  epoch:0 auc: 0.5728
# Epoch 2/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6753 - accuracy: 0.6920 - my_auc: 0.5395 - val_loss: 0.6888 - val_accuracy: 0.7547 - val_my_auc: 0.6169
#  epoch:1 auc: 0.6169
# Epoch 3/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.6936 - accuracy: 0.6208 - my_auc: 0.5977 - val_loss: 0.6804 - val_accuracy: 0.7599 - val_my_auc: 0.6304
#  epoch:2 auc: 0.6314
# Epoch 4/30
# 68/68 [==============================] - 7s 101ms/step - loss: 0.7027 - accuracy: 0.6348 - my_auc: 0.6119 - val_loss: 0.6739 - val_accuracy: 0.7824 - val_my_auc: 0.6384
#  epoch:3 auc: 0.6382
# Epoch 5/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6710 - accuracy: 0.6573 - my_auc: 0.6208 - val_loss: 0.6675 - val_accuracy: 0.7978 - val_my_auc: 0.6530
#  epoch:4 auc: 0.6533
# Epoch 6/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6931 - accuracy: 0.5737 - my_auc: 0.6312 - val_loss: 0.6617 - val_accuracy: 0.7985 - val_my_auc: 0.6631
#  epoch:5 auc: 0.6635
# Epoch 7/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6104 - accuracy: 0.6717 - my_auc: 0.6717 - val_loss: 0.6455 - val_accuracy: 0.6678 - val_my_auc: 0.6750
#  epoch:6 auc: 0.6747
# Epoch 8/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.5976 - accuracy: 0.6568 - my_auc: 0.6523 - val_loss: 0.6427 - val_accuracy: 0.6032 - val_my_auc: 0.6782
#  epoch:7 auc: 0.6782
# Epoch 9/30
# 68/68 [==============================] - 7s 104ms/step - loss: 0.6330 - accuracy: 0.6201 - my_auc: 0.6854 - val_loss: 0.6448 - val_accuracy: 0.6923 - val_my_auc: 0.6799
#  epoch:8 auc: 0.6800
# Epoch 10/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6647 - accuracy: 0.5917 - my_auc: 0.6720 - val_loss: 0.6424 - val_accuracy: 0.6727 - val_my_auc: 0.6847
#  epoch:9 auc: 0.6847
# Epoch 11/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6544 - accuracy: 0.6427 - my_auc: 0.6889 - val_loss: 0.6374 - val_accuracy: 0.4308 - val_my_auc: 0.6902
#  epoch:10 auc: 0.6901
# Epoch 12/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6570 - accuracy: 0.5875 - my_auc: 0.6796 - val_loss: 0.6311 - val_accuracy: 0.5340 - val_my_auc: 0.6928
#  epoch:11 auc: 0.6929
# Epoch 13/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6499 - accuracy: 0.5798 - my_auc: 0.6953 - val_loss: 0.6361 - val_accuracy: 0.5007 - val_my_auc: 0.6917
#  epoch:12 auc: 0.6912
# Epoch 14/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6127 - accuracy: 0.6193 - my_auc: 0.6921 - val_loss: 0.6398 - val_accuracy: 0.3422 - val_my_auc: 0.6924
#  epoch:13 auc: 0.6924
# Epoch 15/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6440 - accuracy: 0.5490 - my_auc: 0.7023 - val_loss: 0.6287 - val_accuracy: 0.4452 - val_my_auc: 0.6928
#  epoch:14 auc: 0.6929
# AUC:  0.6929
# 11602
# l1 55
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 55)]           0
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 3, 110)            48840
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 110)               97240
# _________________________________________________________________
# dense (Dense)                (None, 12)                1332
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 147,425
# Trainable params: 147,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5037046684611155, 1.0: 67.982421875}
# Epoch 1/30
# 68/68 [==============================] - 17s 132ms/step - loss: 0.7176 - accuracy: 0.5025 - my_auc: 0.4862 - val_loss: 0.6901 - val_accuracy: 0.9398 - val_my_auc: 0.6943
#  epoch:0 auc: 0.7109
# Epoch 2/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6762 - accuracy: 0.8052 - my_auc: 0.4966 - val_loss: 0.6860 - val_accuracy: 0.5303 - val_my_auc: 0.6819
#  epoch:1 auc: 0.6915
# Epoch 3/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6859 - accuracy: 0.6659 - my_auc: 0.5915 - val_loss: 0.6814 - val_accuracy: 0.2703 - val_my_auc: 0.6925
#  epoch:2 auc: 0.6964
# Epoch 4/30
# 68/68 [==============================] - 7s 108ms/step - loss: 0.6797 - accuracy: 0.5610 - my_auc: 0.5848 - val_loss: 0.6692 - val_accuracy: 0.5765 - val_my_auc: 0.7099
#  epoch:3 auc: 0.7096
# Epoch 5/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6609 - accuracy: 0.7072 - my_auc: 0.6228 - val_loss: 0.6602 - val_accuracy: 0.3988 - val_my_auc: 0.7207
#  epoch:4 auc: 0.7206
# Epoch 6/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.7011 - accuracy: 0.5337 - my_auc: 0.6103 - val_loss: 0.6439 - val_accuracy: 0.6252 - val_my_auc: 0.7256
#  epoch:5 auc: 0.7250
# Epoch 7/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6575 - accuracy: 0.6641 - my_auc: 0.6389 - val_loss: 0.6398 - val_accuracy: 0.4132 - val_my_auc: 0.7309
#  epoch:6 auc: 0.7308
# Epoch 8/30
# 68/68 [==============================] - 7s 105ms/step - loss: 0.6568 - accuracy: 0.6509 - my_auc: 0.6718 - val_loss: 0.6434 - val_accuracy: 0.3526 - val_my_auc: 0.7363
#  epoch:7 auc: 0.7360
# Epoch 9/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6691 - accuracy: 0.5939 - my_auc: 0.6536 - val_loss: 0.6493 - val_accuracy: 0.2675 - val_my_auc: 0.7334
#  epoch:8 auc: 0.7344
# Epoch 10/30
# 68/68 [==============================] - 7s 102ms/step - loss: 0.6517 - accuracy: 0.5577 - my_auc: 0.6129 - val_loss: 0.6484 - val_accuracy: 0.2408 - val_my_auc: 0.7370
#  epoch:9 auc: 0.7389
# Epoch 11/30
# 68/68 [==============================] - 7s 104ms/step - loss: 0.6874 - accuracy: 0.4787 - my_auc: 0.6381 - val_loss: 0.6185 - val_accuracy: 0.4113 - val_my_auc: 0.7439
#  epoch:10 auc: 0.7440
# Epoch 12/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6483 - accuracy: 0.5925 - my_auc: 0.6687 - val_loss: 0.6159 - val_accuracy: 0.4591 - val_my_auc: 0.7453
#  epoch:11 auc: 0.7457
# Epoch 13/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6630 - accuracy: 0.6221 - my_auc: 0.6950 - val_loss: 0.6107 - val_accuracy: 0.5085 - val_my_auc: 0.7502
#  epoch:12 auc: 0.7501
# Epoch 14/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6304 - accuracy: 0.6180 - my_auc: 0.6815 - val_loss: 0.6139 - val_accuracy: 0.4863 - val_my_auc: 0.7519
#  epoch:13 auc: 0.7528
# Epoch 15/30
# 68/68 [==============================] - 7s 104ms/step - loss: 0.6412 - accuracy: 0.5662 - my_auc: 0.6814 - val_loss: 0.6085 - val_accuracy: 0.4901 - val_my_auc: 0.7503
#  epoch:14 auc: 0.7508
# Epoch 16/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6472 - accuracy: 0.6042 - my_auc: 0.6451 - val_loss: 0.6075 - val_accuracy: 0.5643 - val_my_auc: 0.7526
#  epoch:15 auc: 0.7528
# Epoch 17/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6312 - accuracy: 0.6047 - my_auc: 0.6624 - val_loss: 0.6335 - val_accuracy: 0.2942 - val_my_auc: 0.7485
#  epoch:16 auc: 0.7479
# Epoch 18/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6577 - accuracy: 0.5597 - my_auc: 0.6523 - val_loss: 0.5961 - val_accuracy: 0.5394 - val_my_auc: 0.7535
#  epoch:17 auc: 0.7536
# Epoch 19/30
# 68/68 [==============================] - 7s 104ms/step - loss: 0.6677 - accuracy: 0.6053 - my_auc: 0.6621 - val_loss: 0.6092 - val_accuracy: 0.4304 - val_my_auc: 0.7586
#  epoch:18 auc: 0.7576
# Epoch 20/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6477 - accuracy: 0.5761 - my_auc: 0.6731 - val_loss: 0.6134 - val_accuracy: 0.5048 - val_my_auc: 0.7544
#  epoch:19 auc: 0.7539
# Epoch 21/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6348 - accuracy: 0.6413 - my_auc: 0.6866 - val_loss: 0.5869 - val_accuracy: 0.5710 - val_my_auc: 0.7565
#  epoch:20 auc: 0.7561
# Epoch 22/30
# 68/68 [==============================] - 7s 103ms/step - loss: 0.6016 - accuracy: 0.6781 - my_auc: 0.7246 - val_loss: 0.6048 - val_accuracy: 0.4819 - val_my_auc: 0.7523
#  epoch:21 auc: 0.7522
# AUC:  0.7576
# 11602
# avg_AUC :  0.734489151646047
# avg_AUC_2 :  0.7343828158465642
#          0         1         2   ...        27        28       29
# 0  0.637809  0.674551  0.680217  ...  0.725409  0.721043  0.72845
# 1  0.687833  0.712656  0.715756  ...       NaN       NaN      NaN
# 2  0.568755  0.616858  0.630397  ...       NaN       NaN      NaN
# 3  0.694301  0.681912  0.692499  ...       NaN       NaN      NaN
#
# [4 rows x 30 columns]
# 0     0.647175
# 1     0.671495
# 2     0.679717
# 3     0.687671
# 4     0.697957
# 5     0.700663
# 6     0.707890
# 7     0.710625
# 8     0.712268
# 9     0.715205
# 10    0.718595
# 11    0.720385
# 12    0.721666
# 13    0.723323
# 14    0.722407
# 15    0.735253
# 16    0.735994
# 17    0.736629
# 18    0.741766
# 19    0.741593
# 20    0.742041
# 21    0.743700
# 22    0.735843
# 23    0.739819
# 24    0.741462
# 25    0.725630
# 26    0.729376
# 27    0.725409
# 28    0.721043
# 29    0.728450
# dtype: float64
# (0.734489151646047,
#  array([0.        , 0.07045144, 0.12606019, 0.16716826, 0.17889877,
#         0.20235978, 0.22000684, 0.25218878, 0.27270862, 0.29326265,
#         0.30495896, 0.33129275, 0.36655267, 0.38997948, 0.41053352,
#         0.42226402, 0.4369357 , 0.45444596, 0.46323529, 0.48084815,
#         0.50143639, 0.51022572, 0.51901505, 0.5248632 , 0.54825581,
#         0.5628933 , 0.57171683, 0.58929549, 0.59517784, 0.60106019,
#         0.6127907 , 0.62158003, 0.63334473, 0.64801642, 0.65389877,
#         0.66562927, 0.68026676, 0.70078659, 0.71545828, 0.72722298,
#         0.73601231, 0.74480164, 0.75950752, 0.76833105, 0.77421341,
#         0.78009576, 0.80355677, 0.80943912, 0.83290014, 0.84165527,
#         0.84753762, 0.85926813, 0.8622093 , 0.86805746, 0.87393981,
#         0.87393981, 0.87982216, 0.89452804, 0.89452804, 0.89746922,
#         0.9121409 , 0.91508208, 0.92096443, 0.92387141, 0.92387141,
#         0.92677839, 0.92677839, 0.92971956, 0.93560192, 0.93560192,
#         0.93560192, 0.93854309, 0.94148427, 0.94442544, 0.94442544,
#         0.94736662, 0.95324897, 0.95619015, 0.95913133, 0.96788646,
#         0.96788646, 0.97370041, 0.97664159, 0.98245554, 0.98536252,
#         0.99415185, 0.99415185, 0.99415185, 0.99415185, 0.99415185,
#         0.99415185, 0.99415185, 0.99705882, 0.99705882, 0.99705882,
#         1.        , 1.        , 1.        , 1.        , 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.58184594, 0.4594573 , 0.6441419 , ..., 0.52048016, 0.04207808,
#            0.63456273], dtype=float32)],
#    array([    2,     4,     9, ..., 46402, 46405, 46407])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5159124 , 0.57562613, 0.5382006 , ..., 0.5875475 , 0.48845845,
#            0.3185798 ], dtype=float32)],
#    array([    3,    11,    12, ..., 46390, 46397, 46400])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5543689 , 0.5396448 , 0.5976448 , ..., 0.59255654, 0.4022002 ,
#            0.24704298], dtype=float32)],
#    array([    1,     5,     6, ..., 46403, 46404, 46408])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.54065865, 0.5822923 , 0.5865673 , ..., 0.63106453, 0.57791215,
#            0.27296096], dtype=float32)],
#    array([    0,     8,    17, ..., 46398, 46399, 46406])]])

# %%
# financial performance + overall change timestep = 3
cross_val(df_fl, 'label_new', v_perf + v_1, 'lstm_perf', 3, epoch=50)
# Out:
# init A shape:  (61744, 46)
# (46409, 3, 15) 341.0
# l1 15
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 15)]           0
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, 3, 30)             3720
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 12)                372
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 11,425
# Trainable params: 11,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5036901970999392, 1.0: 68.24705882352941}
# Epoch 1/50
# 68/68 [==============================] - 13s 61ms/step - loss: 0.7152 - accuracy: 0.7064 - my_auc: 0.5034 - val_loss: 0.6930 - val_accuracy: 0.9760 - val_my_auc: 0.5302
#  epoch:0 auc: 0.5128
# Epoch 2/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6317 - accuracy: 0.9234 - my_auc: 0.5426 - val_loss: 0.6914 - val_accuracy: 0.4383 - val_my_auc: 0.5779
#  epoch:1 auc: 0.5777
# Epoch 3/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.7193 - accuracy: 0.7278 - my_auc: 0.5736 - val_loss: 0.6885 - val_accuracy: 0.9164 - val_my_auc: 0.6517
#  epoch:2 auc: 0.6513
# Epoch 4/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6834 - accuracy: 0.8533 - my_auc: 0.5801 - val_loss: 0.6864 - val_accuracy: 0.4928 - val_my_auc: 0.6523
#  epoch:3 auc: 0.6522
# Epoch 5/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6750 - accuracy: 0.7623 - my_auc: 0.5842 - val_loss: 0.6851 - val_accuracy: 0.3600 - val_my_auc: 0.6500
#  epoch:4 auc: 0.6506
# Epoch 6/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6864 - accuracy: 0.7086 - my_auc: 0.6074 - val_loss: 0.6820 - val_accuracy: 0.3141 - val_my_auc: 0.6530
#  epoch:5 auc: 0.6540
# Epoch 7/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.7036 - accuracy: 0.6220 - my_auc: 0.5727 - val_loss: 0.6766 - val_accuracy: 0.8100 - val_my_auc: 0.6535
#  epoch:6 auc: 0.6548
# Epoch 8/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6690 - accuracy: 0.7896 - my_auc: 0.5865 - val_loss: 0.6763 - val_accuracy: 0.3547 - val_my_auc: 0.6501
#  epoch:7 auc: 0.6501
# Epoch 9/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.7094 - accuracy: 0.5949 - my_auc: 0.6388 - val_loss: 0.6686 - val_accuracy: 0.5968 - val_my_auc: 0.6566
#  epoch:8 auc: 0.6548
# Epoch 10/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6891 - accuracy: 0.6683 - my_auc: 0.5988 - val_loss: 0.6661 - val_accuracy: 0.5577 - val_my_auc: 0.6543
#  epoch:9 auc: 0.6557
# Epoch 11/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6653 - accuracy: 0.6880 - my_auc: 0.6272 - val_loss: 0.6627 - val_accuracy: 0.5452 - val_my_auc: 0.6558
#  epoch:10 auc: 0.6558
# Epoch 12/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6266 - accuracy: 0.7158 - my_auc: 0.6667 - val_loss: 0.6693 - val_accuracy: 0.3090 - val_my_auc: 0.6504
#  epoch:11 auc: 0.6503
# AUC:  0.6548
# 11603
# l1 15
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 15)]           0
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 3, 30)             3720
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 12)                372
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 11,425
# Trainable params: 11,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5037046684611155, 1.0: 67.982421875}
# Epoch 1/50
# 68/68 [==============================] - 12s 59ms/step - loss: 0.6825 - accuracy: 0.3078 - my_auc: 0.4975 - val_loss: 0.6916 - val_accuracy: 0.0131 - val_my_auc: 0.6447
#  epoch:0 auc: 0.6622
# Epoch 2/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6809 - accuracy: 0.2822 - my_auc: 0.4913 - val_loss: 0.6919 - val_accuracy: 0.0629 - val_my_auc: 0.6158
#  epoch:1 auc: 0.6752
# Epoch 3/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.7020 - accuracy: 0.2959 - my_auc: 0.5388 - val_loss: 0.6905 - val_accuracy: 0.5502 - val_my_auc: 0.6765
#  epoch:2 auc: 0.7028
# Epoch 4/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6799 - accuracy: 0.6217 - my_auc: 0.5482 - val_loss: 0.6894 - val_accuracy: 0.7495 - val_my_auc: 0.6657
#  epoch:3 auc: 0.6895
# Epoch 5/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6700 - accuracy: 0.6509 - my_auc: 0.5566 - val_loss: 0.6874 - val_accuracy: 0.4376 - val_my_auc: 0.7094
#  epoch:4 auc: 0.7031
# Epoch 6/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.7063 - accuracy: 0.4167 - my_auc: 0.5894 - val_loss: 0.6856 - val_accuracy: 0.9535 - val_my_auc: 0.6853
#  epoch:5 auc: 0.6904
# Epoch 7/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6697 - accuracy: 0.7474 - my_auc: 0.5519 - val_loss: 0.6810 - val_accuracy: 0.5579 - val_my_auc: 0.7010
#  epoch:6 auc: 0.7036
# Epoch 8/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6399 - accuracy: 0.6737 - my_auc: 0.5729 - val_loss: 0.6770 - val_accuracy: 0.4326 - val_my_auc: 0.7088
#  epoch:7 auc: 0.7074
# AUC:  0.7031
# 11602
# l1 15
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 15)]           0
# _________________________________________________________________
# bidirectional_10 (Bidirectio (None, 3, 30)             3720
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 12)                372
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 11,425
# Trainable params: 11,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5037046684611155, 1.0: 67.982421875}
# Epoch 1/50
# 68/68 [==============================] - 12s 68ms/step - loss: 0.6955 - accuracy: 0.7940 - my_auc: 0.4462 - val_loss: 0.6934 - val_accuracy: 0.9512 - val_my_auc: 0.5002
#  epoch:0 auc: 0.4987
# Epoch 2/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6666 - accuracy: 0.8227 - my_auc: 0.5216 - val_loss: 0.6922 - val_accuracy: 0.6995 - val_my_auc: 0.5492
#  epoch:1 auc: 0.5415
# Epoch 3/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6776 - accuracy: 0.7315 - my_auc: 0.4826 - val_loss: 0.6910 - val_accuracy: 0.7574 - val_my_auc: 0.5652
#  epoch:2 auc: 0.5646
# Epoch 4/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6933 - accuracy: 0.6891 - my_auc: 0.5315 - val_loss: 0.6881 - val_accuracy: 0.5592 - val_my_auc: 0.5864
#  epoch:3 auc: 0.5857
# Epoch 5/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6864 - accuracy: 0.6540 - my_auc: 0.6222 - val_loss: 0.6849 - val_accuracy: 0.6692 - val_my_auc: 0.5939
#  epoch:4 auc: 0.5962
# Epoch 6/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.7005 - accuracy: 0.6540 - my_auc: 0.6079 - val_loss: 0.6826 - val_accuracy: 0.7173 - val_my_auc: 0.6018
#  epoch:5 auc: 0.6027
# Epoch 7/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6835 - accuracy: 0.6867 - my_auc: 0.6249 - val_loss: 0.6790 - val_accuracy: 0.3407 - val_my_auc: 0.6135
#  epoch:6 auc: 0.6149
# Epoch 8/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6881 - accuracy: 0.6010 - my_auc: 0.5925 - val_loss: 0.6755 - val_accuracy: 0.5029 - val_my_auc: 0.6145
#  epoch:7 auc: 0.6151
# Epoch 9/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6474 - accuracy: 0.6633 - my_auc: 0.6036 - val_loss: 0.6739 - val_accuracy: 0.4148 - val_my_auc: 0.6175
#  epoch:8 auc: 0.6183
# Epoch 10/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6787 - accuracy: 0.5871 - my_auc: 0.6022 - val_loss: 0.6737 - val_accuracy: 0.7224 - val_my_auc: 0.6216
#  epoch:9 auc: 0.6209
# Epoch 11/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6839 - accuracy: 0.7047 - my_auc: 0.6125 - val_loss: 0.6687 - val_accuracy: 0.5684 - val_my_auc: 0.6260
#  epoch:10 auc: 0.6253
# Epoch 12/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6489 - accuracy: 0.6663 - my_auc: 0.6445 - val_loss: 0.6673 - val_accuracy: 0.6090 - val_my_auc: 0.6260
#  epoch:11 auc: 0.6267
# Epoch 13/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6734 - accuracy: 0.6696 - my_auc: 0.6527 - val_loss: 0.6674 - val_accuracy: 0.6431 - val_my_auc: 0.6271
#  epoch:12 auc: 0.6271
# Epoch 14/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6552 - accuracy: 0.6866 - my_auc: 0.6744 - val_loss: 0.6645 - val_accuracy: 0.6117 - val_my_auc: 0.6320
#  epoch:13 auc: 0.6318
# Epoch 15/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6449 - accuracy: 0.7062 - my_auc: 0.6540 - val_loss: 0.6677 - val_accuracy: 0.3431 - val_my_auc: 0.6367
#  epoch:14 auc: 0.6372
# Epoch 16/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6218 - accuracy: 0.6154 - my_auc: 0.6476 - val_loss: 0.6617 - val_accuracy: 0.5531 - val_my_auc: 0.6377
#  epoch:15 auc: 0.6376
# Epoch 17/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6422 - accuracy: 0.6722 - my_auc: 0.6606 - val_loss: 0.6610 - val_accuracy: 0.5490 - val_my_auc: 0.6393
#  epoch:16 auc: 0.6398
# Epoch 18/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6515 - accuracy: 0.6501 - my_auc: 0.6662 - val_loss: 0.6593 - val_accuracy: 0.5427 - val_my_auc: 0.6421
#  epoch:17 auc: 0.6424
# Epoch 19/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6586 - accuracy: 0.6561 - my_auc: 0.6479 - val_loss: 0.6580 - val_accuracy: 0.4502 - val_my_auc: 0.6475
#  epoch:18 auc: 0.6475
# Epoch 20/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6431 - accuracy: 0.6149 - my_auc: 0.6500 - val_loss: 0.6606 - val_accuracy: 0.3535 - val_my_auc: 0.6516
#  epoch:19 auc: 0.6511
# Epoch 21/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6882 - accuracy: 0.5353 - my_auc: 0.6510 - val_loss: 0.6540 - val_accuracy: 0.4417 - val_my_auc: 0.6531
#  epoch:20 auc: 0.6536
# Epoch 22/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6769 - accuracy: 0.6131 - my_auc: 0.6349 - val_loss: 0.6520 - val_accuracy: 0.5299 - val_my_auc: 0.6524
#  epoch:21 auc: 0.6529
# Epoch 23/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6835 - accuracy: 0.6057 - my_auc: 0.6673 - val_loss: 0.6529 - val_accuracy: 0.5844 - val_my_auc: 0.6511
#  epoch:22 auc: 0.6513
# Epoch 24/50
# 68/68 [==============================] - 2s 30ms/step - loss: 0.6519 - accuracy: 0.6255 - my_auc: 0.6889 - val_loss: 0.6519 - val_accuracy: 0.4854 - val_my_auc: 0.6519
#  epoch:23 auc: 0.6514
# AUC:  0.6536
# 11602
# l1 15
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 15)]           0
# _________________________________________________________________
# bidirectional_11 (Bidirectio (None, 3, 30)             3720
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 12)                372
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 11,425
# Trainable params: 11,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5037046684611155, 1.0: 67.982421875}
# Epoch 1/50
# 68/68 [==============================] - 12s 58ms/step - loss: 0.6965 - accuracy: 0.6953 - my_auc: 0.5396 - val_loss: 0.6903 - val_accuracy: 0.6395 - val_my_auc: 0.6846
#  epoch:0 auc: 0.7106
# Epoch 2/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.7171 - accuracy: 0.6166 - my_auc: 0.5292 - val_loss: 0.6889 - val_accuracy: 0.9741 - val_my_auc: 0.7068
#  epoch:1 auc: 0.7088
# Epoch 3/50
# 68/68 [==============================] - 2s 30ms/step - loss: 0.7234 - accuracy: 0.6911 - my_auc: 0.5189 - val_loss: 0.6876 - val_accuracy: 0.3184 - val_my_auc: 0.7056
#  epoch:2 auc: 0.7056
# Epoch 4/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6651 - accuracy: 0.7145 - my_auc: 0.5734 - val_loss: 0.6856 - val_accuracy: 0.7057 - val_my_auc: 0.6941
#  epoch:3 auc: 0.6985
# Epoch 5/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.7079 - accuracy: 0.7108 - my_auc: 0.5387 - val_loss: 0.6827 - val_accuracy: 0.7081 - val_my_auc: 0.6956
#  epoch:4 auc: 0.6993
# AUC:  0.7088
# 11602
# avg_AUC :  0.6800693336573651
# avg_AUC_2 :  0.6797900344069975
#          0         1         2   ...        21        22        23
# 0  0.530217  0.577911  0.651695  ...       NaN       NaN       NaN
# 1  0.644697  0.615841  0.676470  ...       NaN       NaN       NaN
# 2  0.500212  0.549222  0.565211  ...  0.652446  0.651088  0.651915
# 3  0.684614  0.706811  0.705553  ...       NaN       NaN       NaN
#
# [4 rows x 24 columns]
# 0     0.589935
# 1     0.612446
# 2     0.649732
# 3     0.649622
# 4     0.662239
# 5     0.646691
# 6     0.655990
# 7     0.657783
# 8     0.637049
# 9     0.637926
# 10    0.640908
# 11    0.638211
# 12    0.627098
# 13    0.632010
# 14    0.636712
# 15    0.637740
# 16    0.639256
# 17    0.642101
# 18    0.647543
# 19    0.651610
# 20    0.653106
# 21    0.652446
# 22    0.651088
# 23    0.651915
# dtype: float64
# (0.6800693336573651,
#  array([0.        , 0.0498632 , 0.09678523, 0.12612859, 0.15256498,
#         0.16723666, 0.18488372, 0.20253078, 0.21716826, 0.22592339,
#         0.25523256, 0.28153215, 0.30796854, 0.3255472 , 0.34900821,
#         0.35489056, 0.3754104 , 0.39004788, 0.39589603, 0.41350889,
#         0.44288646, 0.45160739, 0.45454856, 0.46039672, 0.46915185,
#         0.48378933, 0.49849521, 0.50731874, 0.51316689, 0.5249316 ,
#         0.53963748, 0.55136799, 0.56019152, 0.56898085, 0.5748632 ,
#         0.58361833, 0.59240766, 0.59534884, 0.60995212, 0.61877565,
#         0.64227086, 0.65984952, 0.6745554 , 0.68628591, 0.68628591,
#         0.71562927, 0.72151163, 0.7244528 , 0.73033516, 0.74206566,
#         0.74500684, 0.75379617, 0.76846785, 0.78023256, 0.78902189,
#         0.78902189, 0.79784542, 0.80666895, 0.81542408, 0.82421341,
#         0.83009576, 0.83009576, 0.83594391, 0.8505472 , 0.85345417,
#         0.86521888, 0.87985636, 0.88573871, 0.89158687, 0.89743502,
#         0.90625855, 0.90625855, 0.91508208, 0.92096443, 0.92390561,
#         0.92390561, 0.93269494, 0.93563611, 0.93857729, 0.94148427,
#         0.9502736 , 0.95318057, 0.95318057, 0.95899453, 0.9619357 ,
#         0.96781806, 0.97075923, 0.97660739, 0.97660739, 0.98539672,
#         0.98539672, 0.98539672, 0.98830369, 0.99411765, 1.        ,
#         1.        , 1.        , 1.        , 1.        , 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.48511404, 0.45139036, 0.5519036 , ..., 0.5051386 , 0.36479574,
#            0.5154198 ], dtype=float32)],
#    array([    2,     4,     9, ..., 46402, 46405, 46407])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.4962062 , 0.50439477, 0.5019341 , ..., 0.50882024, 0.49905032,
#            0.48523137], dtype=float32)],
#    array([    3,    11,    12, ..., 46390, 46397, 46400])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5236915 , 0.52526397, 0.60137576, ..., 0.63226897, 0.43441647,
#            0.40029526], dtype=float32)],
#    array([    1,     5,     6, ..., 46403, 46404, 46408])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.48645487, 0.4909984 , 0.4899992 , ..., 0.49259448, 0.4906312 ,
#            0.4668142 ], dtype=float32)],
#    array([    0,     8,    17, ..., 46398, 46399, 46406])]])

# %%
# financial performance + overall change timestep = 2
cross_val(df_fl, 'label_new', v_perf + v_1, 'lstm_perf', 2, epoch=50)
# Out:
# init A shape:  (61744, 31)
# (53600, 2, 15) 408.0
# l1 15
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 15)]           0
# _________________________________________________________________
# bidirectional_12 (Bidirectio (None, 2, 30)             3720
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 12)                372
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 11,425
# Trainable params: 11,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/50
# 79/79 [==============================] - 12s 49ms/step - loss: 0.6926 - accuracy: 0.6170 - my_auc: 0.4963 - val_loss: 0.6927 - val_accuracy: 0.0509 - val_my_auc: 0.5624
#  epoch:0 auc: 0.6323
# Epoch 2/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7028 - accuracy: 0.5504 - my_auc: 0.5212 - val_loss: 0.6921 - val_accuracy: 0.9037 - val_my_auc: 0.6377
#  epoch:1 auc: 0.6666
# Epoch 3/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7140 - accuracy: 0.6608 - my_auc: 0.5378 - val_loss: 0.6912 - val_accuracy: 0.9727 - val_my_auc: 0.6337
#  epoch:2 auc: 0.6651
# Epoch 4/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6638 - accuracy: 0.8763 - my_auc: 0.4939 - val_loss: 0.6907 - val_accuracy: 0.8009 - val_my_auc: 0.6366
#  epoch:3 auc: 0.6630
# Epoch 5/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7117 - accuracy: 0.6878 - my_auc: 0.5636 - val_loss: 0.6893 - val_accuracy: 0.8569 - val_my_auc: 0.6650
#  epoch:4 auc: 0.6616
# Epoch 6/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6760 - accuracy: 0.8168 - my_auc: 0.6064 - val_loss: 0.6869 - val_accuracy: 0.7545 - val_my_auc: 0.6539
#  epoch:5 auc: 0.6610
# Epoch 7/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6901 - accuracy: 0.7112 - my_auc: 0.5621 - val_loss: 0.6850 - val_accuracy: 0.8699 - val_my_auc: 0.6537
#  epoch:6 auc: 0.6581
# Epoch 8/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6924 - accuracy: 0.7833 - my_auc: 0.5888 - val_loss: 0.6820 - val_accuracy: 0.7728 - val_my_auc: 0.6564
#  epoch:7 auc: 0.6571
# AUC:  0.6616
# 13400
# l1 15
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 15)]           0
# _________________________________________________________________
# bidirectional_13 (Bidirectio (None, 2, 30)             3720
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 12)                372
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 11,425
# Trainable params: 11,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/50
# 79/79 [==============================] - 12s 48ms/step - loss: 0.6974 - accuracy: 0.4342 - my_auc: 0.5449 - val_loss: 0.6911 - val_accuracy: 0.4654 - val_my_auc: 0.6207
#  epoch:0 auc: 0.6194
# Epoch 2/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7122 - accuracy: 0.4316 - my_auc: 0.5232 - val_loss: 0.6896 - val_accuracy: 0.6210 - val_my_auc: 0.6320
#  epoch:1 auc: 0.6376
# Epoch 3/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6887 - accuracy: 0.6043 - my_auc: 0.5549 - val_loss: 0.6874 - val_accuracy: 0.2813 - val_my_auc: 0.6535
#  epoch:2 auc: 0.6488
# Epoch 4/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6826 - accuracy: 0.5036 - my_auc: 0.5730 - val_loss: 0.6846 - val_accuracy: 0.7601 - val_my_auc: 0.6444
#  epoch:3 auc: 0.6457
# Epoch 5/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7159 - accuracy: 0.6169 - my_auc: 0.5906 - val_loss: 0.6813 - val_accuracy: 0.6961 - val_my_auc: 0.6480
#  epoch:4 auc: 0.6471
# Epoch 6/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6603 - accuracy: 0.6944 - my_auc: 0.5692 - val_loss: 0.6778 - val_accuracy: 0.5264 - val_my_auc: 0.6494
#  epoch:5 auc: 0.6476
# AUC:  0.6488
# 13400
# l1 15
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 15)]           0
# _________________________________________________________________
# bidirectional_14 (Bidirectio (None, 2, 30)             3720
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 12)                372
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 11,425
# Trainable params: 11,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/50
# 79/79 [==============================] - 12s 49ms/step - loss: 0.6820 - accuracy: 0.4160 - my_auc: 0.4738 - val_loss: 0.6927 - val_accuracy: 0.4768 - val_my_auc: 0.5346
#  epoch:0 auc: 0.5717
# Epoch 2/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6907 - accuracy: 0.5894 - my_auc: 0.5045 - val_loss: 0.6921 - val_accuracy: 0.5886 - val_my_auc: 0.5887
#  epoch:1 auc: 0.6320
# Epoch 3/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6586 - accuracy: 0.7605 - my_auc: 0.5190 - val_loss: 0.6912 - val_accuracy: 0.8469 - val_my_auc: 0.6034
#  epoch:2 auc: 0.6408
# Epoch 4/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6779 - accuracy: 0.7862 - my_auc: 0.5244 - val_loss: 0.6902 - val_accuracy: 0.9028 - val_my_auc: 0.6484
#  epoch:3 auc: 0.6478
# Epoch 5/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6956 - accuracy: 0.8235 - my_auc: 0.5768 - val_loss: 0.6885 - val_accuracy: 0.9407 - val_my_auc: 0.6457
#  epoch:4 auc: 0.6558
# Epoch 6/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7104 - accuracy: 0.8064 - my_auc: 0.5878 - val_loss: 0.6869 - val_accuracy: 0.9429 - val_my_auc: 0.6501
#  epoch:5 auc: 0.6552
# Epoch 7/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6955 - accuracy: 0.8608 - my_auc: 0.5528 - val_loss: 0.6848 - val_accuracy: 0.9122 - val_my_auc: 0.6538
#  epoch:6 auc: 0.6583
# Epoch 8/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6803 - accuracy: 0.8123 - my_auc: 0.5825 - val_loss: 0.6823 - val_accuracy: 0.5410 - val_my_auc: 0.6627
#  epoch:7 auc: 0.6639
# Epoch 9/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6841 - accuracy: 0.6664 - my_auc: 0.5920 - val_loss: 0.6778 - val_accuracy: 0.5658 - val_my_auc: 0.6640
#  epoch:8 auc: 0.6656
# Epoch 10/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6855 - accuracy: 0.6654 - my_auc: 0.5886 - val_loss: 0.6739 - val_accuracy: 0.6790 - val_my_auc: 0.6683
#  epoch:9 auc: 0.6661
# Epoch 11/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6930 - accuracy: 0.6710 - my_auc: 0.6229 - val_loss: 0.6692 - val_accuracy: 0.7673 - val_my_auc: 0.6660
#  epoch:10 auc: 0.6661
# Epoch 12/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6339 - accuracy: 0.7687 - my_auc: 0.5937 - val_loss: 0.6646 - val_accuracy: 0.6319 - val_my_auc: 0.6695
#  epoch:11 auc: 0.6692
# Epoch 13/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6603 - accuracy: 0.6432 - my_auc: 0.6286 - val_loss: 0.6613 - val_accuracy: 0.7453 - val_my_auc: 0.6689
#  epoch:12 auc: 0.6689
# Epoch 14/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6848 - accuracy: 0.6568 - my_auc: 0.6523 - val_loss: 0.6585 - val_accuracy: 0.6460 - val_my_auc: 0.6704
#  epoch:13 auc: 0.6708
# Epoch 15/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6711 - accuracy: 0.6284 - my_auc: 0.6331 - val_loss: 0.6605 - val_accuracy: 0.4635 - val_my_auc: 0.6707
#  epoch:14 auc: 0.6719
# Epoch 16/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6918 - accuracy: 0.5591 - my_auc: 0.6225 - val_loss: 0.6575 - val_accuracy: 0.5301 - val_my_auc: 0.6734
#  epoch:15 auc: 0.6725
# Epoch 17/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7065 - accuracy: 0.5675 - my_auc: 0.6279 - val_loss: 0.6550 - val_accuracy: 0.5744 - val_my_auc: 0.6740
#  epoch:16 auc: 0.6736
# Epoch 18/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6476 - accuracy: 0.6278 - my_auc: 0.6358 - val_loss: 0.6532 - val_accuracy: 0.6096 - val_my_auc: 0.6741
#  epoch:17 auc: 0.6745
# Epoch 19/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6579 - accuracy: 0.6143 - my_auc: 0.6458 - val_loss: 0.6536 - val_accuracy: 0.5719 - val_my_auc: 0.6748
#  epoch:18 auc: 0.6751
# Epoch 20/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6864 - accuracy: 0.5381 - my_auc: 0.6126 - val_loss: 0.6597 - val_accuracy: 0.4249 - val_my_auc: 0.6760
#  epoch:19 auc: 0.6760
# Epoch 21/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6446 - accuracy: 0.5467 - my_auc: 0.6488 - val_loss: 0.6555 - val_accuracy: 0.4722 - val_my_auc: 0.6763
#  epoch:20 auc: 0.6770
# Epoch 22/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6713 - accuracy: 0.5511 - my_auc: 0.6180 - val_loss: 0.6536 - val_accuracy: 0.4775 - val_my_auc: 0.6783
#  epoch:21 auc: 0.6773
# Epoch 23/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6587 - accuracy: 0.5897 - my_auc: 0.6663 - val_loss: 0.6495 - val_accuracy: 0.5449 - val_my_auc: 0.6780
#  epoch:22 auc: 0.6773
# Epoch 24/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6812 - accuracy: 0.5740 - my_auc: 0.6512 - val_loss: 0.6498 - val_accuracy: 0.5625 - val_my_auc: 0.6787
#  epoch:23 auc: 0.6786
# Epoch 25/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6929 - accuracy: 0.5495 - my_auc: 0.6121 - val_loss: 0.6505 - val_accuracy: 0.5914 - val_my_auc: 0.6778
#  epoch:24 auc: 0.6781
# Epoch 26/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6298 - accuracy: 0.6303 - my_auc: 0.6406 - val_loss: 0.6488 - val_accuracy: 0.5301 - val_my_auc: 0.6799
#  epoch:25 auc: 0.6798
# Epoch 27/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6244 - accuracy: 0.6303 - my_auc: 0.6731 - val_loss: 0.6543 - val_accuracy: 0.3988 - val_my_auc: 0.6797
#  epoch:26 auc: 0.6805
# Epoch 28/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6610 - accuracy: 0.5506 - my_auc: 0.6405 - val_loss: 0.6523 - val_accuracy: 0.4359 - val_my_auc: 0.6812
#  epoch:27 auc: 0.6815
# Epoch 29/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6368 - accuracy: 0.5953 - my_auc: 0.6719 - val_loss: 0.6472 - val_accuracy: 0.5245 - val_my_auc: 0.6815
#  epoch:28 auc: 0.6820
# Epoch 30/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6411 - accuracy: 0.6242 - my_auc: 0.6432 - val_loss: 0.6487 - val_accuracy: 0.5022 - val_my_auc: 0.6828
#  epoch:29 auc: 0.6824
# Epoch 31/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6662 - accuracy: 0.5880 - my_auc: 0.6396 - val_loss: 0.6501 - val_accuracy: 0.4881 - val_my_auc: 0.6823
#  epoch:30 auc: 0.6819
# Epoch 32/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6577 - accuracy: 0.5817 - my_auc: 0.6638 - val_loss: 0.6465 - val_accuracy: 0.6426 - val_my_auc: 0.6820
#  epoch:31 auc: 0.6816
# Epoch 33/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6863 - accuracy: 0.6163 - my_auc: 0.6257 - val_loss: 0.6455 - val_accuracy: 0.5987 - val_my_auc: 0.6819
#  epoch:32 auc: 0.6821
# AUC:  0.6824
# 13400
# l1 15
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 15)]           0
# _________________________________________________________________
# bidirectional_15 (Bidirectio (None, 2, 30)             3720
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 12)                372
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 11,425
# Trainable params: 11,425
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/50
# 79/79 [==============================] - 12s 50ms/step - loss: 0.6956 - accuracy: 0.3328 - my_auc: 0.5095 - val_loss: 0.6930 - val_accuracy: 0.0113 - val_my_auc: 0.5261
#  epoch:0 auc: 0.5220
# Epoch 2/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6808 - accuracy: 0.2982 - my_auc: 0.4704 - val_loss: 0.6919 - val_accuracy: 0.0728 - val_my_auc: 0.5935
#  epoch:1 auc: 0.6486
# Epoch 3/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.7029 - accuracy: 0.3822 - my_auc: 0.5207 - val_loss: 0.6904 - val_accuracy: 0.1647 - val_my_auc: 0.6638
#  epoch:2 auc: 0.7187
# Epoch 4/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.7138 - accuracy: 0.4615 - my_auc: 0.5408 - val_loss: 0.6895 - val_accuracy: 0.6298 - val_my_auc: 0.6234
#  epoch:3 auc: 0.6335
# Epoch 5/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6874 - accuracy: 0.7255 - my_auc: 0.5729 - val_loss: 0.6880 - val_accuracy: 0.5740 - val_my_auc: 0.6648
#  epoch:4 auc: 0.6619
# Epoch 6/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6708 - accuracy: 0.7345 - my_auc: 0.5767 - val_loss: 0.6853 - val_accuracy: 0.4159 - val_my_auc: 0.6771
#  epoch:5 auc: 0.6873
# Epoch 7/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.7028 - accuracy: 0.5874 - my_auc: 0.5509 - val_loss: 0.6838 - val_accuracy: 0.4743 - val_my_auc: 0.7025
#  epoch:6 auc: 0.7045
# Epoch 8/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6607 - accuracy: 0.6610 - my_auc: 0.5593 - val_loss: 0.6813 - val_accuracy: 0.3483 - val_my_auc: 0.6887
#  epoch:7 auc: 0.6965
# Epoch 9/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6772 - accuracy: 0.6426 - my_auc: 0.6118 - val_loss: 0.6768 - val_accuracy: 0.4113 - val_my_auc: 0.6928
#  epoch:8 auc: 0.6904
# Epoch 10/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.7243 - accuracy: 0.5283 - my_auc: 0.5709 - val_loss: 0.6714 - val_accuracy: 0.5569 - val_my_auc: 0.6963
#  epoch:9 auc: 0.6972
# AUC:  0.7045
# 13400
# avg_AUC :  0.6743104521098559
# avg_AUC_2 :  0.6742052881758763
#          0         1         2   ...        30        31        32
# 0  0.562372  0.637743  0.633711  ...       NaN       NaN       NaN
# 1  0.620670  0.632007  0.653486  ...       NaN       NaN       NaN
# 2  0.534567  0.588677  0.603420  ...  0.682251  0.681979  0.681908
# 3  0.526093  0.593491  0.663784  ...       NaN       NaN       NaN
#
# [4 rows x 33 columns]
# 0     0.560926
# 1     0.612979
# 2     0.638600
# 3     0.638208
# 4     0.655850
# 5     0.657607
# 6     0.670001
# 7     0.669289
# 8     0.678431
# 9     0.682283
# 10    0.665956
# 11    0.669505
# 12    0.668925
# 13    0.670448
# 14    0.670744
# 15    0.673404
# 16    0.673970
# 17    0.674057
# 18    0.674818
# 19    0.676032
# 20    0.676316
# 21    0.678284
# 22    0.678028
# 23    0.678707
# 24    0.677823
# 25    0.679869
# 26    0.679668
# 27    0.681163
# 28    0.681475
# 29    0.682773
# 30    0.682251
# 31    0.681979
# 32    0.681908
# dtype: float64
# (0.6743104521098559,
#  array([0.00245098, 0.05637255, 0.08823529, 0.11764706, 0.14705882,
#         0.16421569, 0.18872549, 0.21813725, 0.24264706, 0.24754902,
#         0.25490196, 0.27941176, 0.30147059, 0.32107843, 0.34558824,
#         0.36029412, 0.375     , 0.38480392, 0.39215686, 0.40196078,
#         0.42156863, 0.43137255, 0.44117647, 0.44362745, 0.45588235,
#         0.46568627, 0.48039216, 0.49264706, 0.5       , 0.51715686,
#         0.5245098 , 0.53921569, 0.55147059, 0.55882353, 0.57598039,
#         0.58578431, 0.6004902 , 0.61029412, 0.62254902, 0.63235294,
#         0.65196078, 0.66421569, 0.66911765, 0.68137255, 0.68872549,
#         0.69852941, 0.71568627, 0.72794118, 0.73284314, 0.74019608,
#         0.74264706, 0.75245098, 0.75980392, 0.76470588, 0.76470588,
#         0.77205882, 0.7745098 , 0.77941176, 0.78186275, 0.79411765,
#         0.80637255, 0.80882353, 0.81372549, 0.83088235, 0.84068627,
#         0.8504902 , 0.85784314, 0.87254902, 0.87254902, 0.87990196,
#         0.88970588, 0.8995098 , 0.90686275, 0.91666667, 0.92401961,
#         0.93137255, 0.93382353, 0.94117647, 0.94362745, 0.94607843,
#         0.95098039, 0.95588235, 0.95833333, 0.96078431, 0.96078431,
#         0.96813725, 0.97303922, 0.9754902 , 0.97794118, 0.98039216,
#         0.98529412, 0.98529412, 0.9877451 , 0.9877451 , 0.99019608,
#         0.99509804, 0.99509804, 0.99754902, 0.99754902, 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.48674336, 0.4934795 , 0.49897763, ..., 0.48974317, 0.505397  ,
#            0.48756817], dtype=float32)],
#    array([    4,     9,    10, ..., 53593, 53596, 53598])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5091131 , 0.5133706 , 0.50340843, ..., 0.5137228 , 0.49580628,
#            0.49312398], dtype=float32)],
#    array([    2,     7,    12, ..., 53586, 53591, 53599])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.4946292 , 0.3943778 , 0.5375565 , ..., 0.490574  , 0.5838204 ,
#            0.27667403], dtype=float32)],
#    array([    3,     5,     8, ..., 53594, 53595, 53597])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.49200916, 0.50629014, 0.5092073 , ..., 0.5125862 , 0.49156848,
#            0.4994577 ], dtype=float32)],
#    array([    0,     1,     6, ..., 53579, 53588, 53589])]])

# %%
sum(df_fl.label)
# Out:
# 487.0

# %%
# financial performance timestep = 3
cross_val(df_fl, 'label_new', v_perf, 'lstm_perf', 3, epoch=50)
# Out:
# init A shape:  (61744, 43)
# (46409, 3, 14) 341.0
# l1 14
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 14)]           0
# _________________________________________________________________
# bidirectional_16 (Bidirectio (None, 3, 28)             3248
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 28)                6384
# _________________________________________________________________
# dense (Dense)                (None, 12)                348
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 9,993
# Trainable params: 9,993
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5036901970999392, 1.0: 68.24705882352941}
# Epoch 1/50
# 68/68 [==============================] - 13s 59ms/step - loss: 0.6928 - accuracy: 0.3308 - my_auc: 0.4844 - val_loss: 0.6925 - val_accuracy: 0.6536 - val_my_auc: 0.5316
#  epoch:0 auc: 0.5680
# Epoch 2/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6789 - accuracy: 0.4441 - my_auc: 0.5256 - val_loss: 0.6913 - val_accuracy: 0.3039 - val_my_auc: 0.6077
#  epoch:1 auc: 0.6014
# Epoch 3/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6974 - accuracy: 0.4194 - my_auc: 0.5276 - val_loss: 0.6898 - val_accuracy: 0.3373 - val_my_auc: 0.6006
#  epoch:2 auc: 0.6154
# Epoch 4/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6917 - accuracy: 0.3888 - my_auc: 0.5608 - val_loss: 0.6876 - val_accuracy: 0.3503 - val_my_auc: 0.6332
#  epoch:3 auc: 0.6355
# Epoch 5/50
# 68/68 [==============================] - 2s 26ms/step - loss: 0.6760 - accuracy: 0.4423 - my_auc: 0.5509 - val_loss: 0.6847 - val_accuracy: 0.3504 - val_my_auc: 0.6381
#  epoch:4 auc: 0.6394
# Epoch 6/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6880 - accuracy: 0.4112 - my_auc: 0.5822 - val_loss: 0.6816 - val_accuracy: 0.4283 - val_my_auc: 0.6385
#  epoch:5 auc: 0.6389
# Epoch 7/50
# 68/68 [==============================] - 2s 26ms/step - loss: 0.7265 - accuracy: 0.4201 - my_auc: 0.6215 - val_loss: 0.6784 - val_accuracy: 0.5565 - val_my_auc: 0.6420
#  epoch:6 auc: 0.6418
# Epoch 8/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6957 - accuracy: 0.5613 - my_auc: 0.5893 - val_loss: 0.6748 - val_accuracy: 0.6658 - val_my_auc: 0.6414
#  epoch:7 auc: 0.6414
# Epoch 9/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6598 - accuracy: 0.6592 - my_auc: 0.6325 - val_loss: 0.6708 - val_accuracy: 0.4596 - val_my_auc: 0.6447
#  epoch:8 auc: 0.6449
# Epoch 10/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6805 - accuracy: 0.5594 - my_auc: 0.6370 - val_loss: 0.6667 - val_accuracy: 0.6371 - val_my_auc: 0.6454
#  epoch:9 auc: 0.6462
# Epoch 11/50
# 68/68 [==============================] - 2s 26ms/step - loss: 0.6791 - accuracy: 0.5989 - my_auc: 0.6248 - val_loss: 0.6639 - val_accuracy: 0.6826 - val_my_auc: 0.6501
#  epoch:10 auc: 0.6496
# Epoch 12/50
# 68/68 [==============================] - 2s 26ms/step - loss: 0.6635 - accuracy: 0.6551 - my_auc: 0.6189 - val_loss: 0.6657 - val_accuracy: 0.7894 - val_my_auc: 0.6468
#  epoch:11 auc: 0.6478
# Epoch 13/50
# 68/68 [==============================] - 2s 26ms/step - loss: 0.6804 - accuracy: 0.6827 - my_auc: 0.6254 - val_loss: 0.6610 - val_accuracy: 0.5098 - val_my_auc: 0.6515
#  epoch:12 auc: 0.6508
# Epoch 14/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6283 - accuracy: 0.6257 - my_auc: 0.6339 - val_loss: 0.6581 - val_accuracy: 0.6210 - val_my_auc: 0.6518
#  epoch:13 auc: 0.6518
# Epoch 15/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6416 - accuracy: 0.6193 - my_auc: 0.6553 - val_loss: 0.6601 - val_accuracy: 0.4792 - val_my_auc: 0.6535
#  epoch:14 auc: 0.6527
# Epoch 16/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6894 - accuracy: 0.5348 - my_auc: 0.6606 - val_loss: 0.6576 - val_accuracy: 0.6825 - val_my_auc: 0.6514
#  epoch:15 auc: 0.6514
# Epoch 17/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6603 - accuracy: 0.6491 - my_auc: 0.6466 - val_loss: 0.6623 - val_accuracy: 0.4115 - val_my_auc: 0.6538
#  epoch:16 auc: 0.6536
# Epoch 18/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6508 - accuracy: 0.5608 - my_auc: 0.6389 - val_loss: 0.6584 - val_accuracy: 0.4691 - val_my_auc: 0.6547
#  epoch:17 auc: 0.6545
# Epoch 19/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6640 - accuracy: 0.5434 - my_auc: 0.6190 - val_loss: 0.6561 - val_accuracy: 0.5369 - val_my_auc: 0.6540
#  epoch:18 auc: 0.6540
# Epoch 20/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6564 - accuracy: 0.6057 - my_auc: 0.6686 - val_loss: 0.6570 - val_accuracy: 0.4743 - val_my_auc: 0.6554
#  epoch:19 auc: 0.6556
# Epoch 21/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6639 - accuracy: 0.5772 - my_auc: 0.6356 - val_loss: 0.6545 - val_accuracy: 0.6650 - val_my_auc: 0.6564
#  epoch:20 auc: 0.6565
# Epoch 22/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6808 - accuracy: 0.5859 - my_auc: 0.6437 - val_loss: 0.6543 - val_accuracy: 0.6094 - val_my_auc: 0.6559
#  epoch:21 auc: 0.6563
# Epoch 23/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6576 - accuracy: 0.6184 - my_auc: 0.6192 - val_loss: 0.6562 - val_accuracy: 0.4492 - val_my_auc: 0.6584
#  epoch:22 auc: 0.6580
# Epoch 24/50
# 68/68 [==============================] - 2s 26ms/step - loss: 0.6888 - accuracy: 0.5324 - my_auc: 0.6461 - val_loss: 0.6554 - val_accuracy: 0.4425 - val_my_auc: 0.6598
#  epoch:23 auc: 0.6598
# Epoch 25/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6060 - accuracy: 0.6028 - my_auc: 0.6893 - val_loss: 0.6626 - val_accuracy: 0.3183 - val_my_auc: 0.6614
#  epoch:24 auc: 0.6616
# Epoch 26/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.7052 - accuracy: 0.4450 - my_auc: 0.6209 - val_loss: 0.6576 - val_accuracy: 0.6859 - val_my_auc: 0.6557
#  epoch:25 auc: 0.6559
# Epoch 27/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6438 - accuracy: 0.6288 - my_auc: 0.6770 - val_loss: 0.6585 - val_accuracy: 0.3696 - val_my_auc: 0.6617
#  epoch:26 auc: 0.6618
# Epoch 28/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6473 - accuracy: 0.5450 - my_auc: 0.6611 - val_loss: 0.6566 - val_accuracy: 0.3766 - val_my_auc: 0.6637
#  epoch:27 auc: 0.6641
# Epoch 29/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6955 - accuracy: 0.4831 - my_auc: 0.6472 - val_loss: 0.6518 - val_accuracy: 0.5461 - val_my_auc: 0.6659
#  epoch:28 auc: 0.6659
# Epoch 30/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6506 - accuracy: 0.6093 - my_auc: 0.6539 - val_loss: 0.6506 - val_accuracy: 0.5058 - val_my_auc: 0.6645
#  epoch:29 auc: 0.6655
# Epoch 31/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6677 - accuracy: 0.5529 - my_auc: 0.6437 - val_loss: 0.6556 - val_accuracy: 0.3654 - val_my_auc: 0.6666
#  epoch:30 auc: 0.6664
# Epoch 32/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6299 - accuracy: 0.5568 - my_auc: 0.6667 - val_loss: 0.6506 - val_accuracy: 0.4888 - val_my_auc: 0.6663
#  epoch:31 auc: 0.6666
# Epoch 33/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6344 - accuracy: 0.6022 - my_auc: 0.6424 - val_loss: 0.6537 - val_accuracy: 0.3996 - val_my_auc: 0.6669
#  epoch:32 auc: 0.6668
# Epoch 34/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.5966 - accuracy: 0.5835 - my_auc: 0.7052 - val_loss: 0.6518 - val_accuracy: 0.4548 - val_my_auc: 0.6673
#  epoch:33 auc: 0.6674
# Epoch 35/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6344 - accuracy: 0.5765 - my_auc: 0.6557 - val_loss: 0.6608 - val_accuracy: 0.3052 - val_my_auc: 0.6677
#  epoch:34 auc: 0.6685
# Epoch 36/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6207 - accuracy: 0.5268 - my_auc: 0.6782 - val_loss: 0.6499 - val_accuracy: 0.5096 - val_my_auc: 0.6672
#  epoch:35 auc: 0.6678
# Epoch 37/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6333 - accuracy: 0.5880 - my_auc: 0.6823 - val_loss: 0.6518 - val_accuracy: 0.4404 - val_my_auc: 0.6681
#  epoch:36 auc: 0.6682
# Epoch 38/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6370 - accuracy: 0.5705 - my_auc: 0.6816 - val_loss: 0.6507 - val_accuracy: 0.4585 - val_my_auc: 0.6671
#  epoch:37 auc: 0.6672
# Epoch 39/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6294 - accuracy: 0.5611 - my_auc: 0.6489 - val_loss: 0.6509 - val_accuracy: 0.4237 - val_my_auc: 0.6680
#  epoch:38 auc: 0.6686
# Epoch 40/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6536 - accuracy: 0.5460 - my_auc: 0.6582 - val_loss: 0.6483 - val_accuracy: 0.5576 - val_my_auc: 0.6682
#  epoch:39 auc: 0.6682
# Epoch 41/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6061 - accuracy: 0.6228 - my_auc: 0.6440 - val_loss: 0.6522 - val_accuracy: 0.3705 - val_my_auc: 0.6715
#  epoch:40 auc: 0.6712
# Epoch 42/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6074 - accuracy: 0.5394 - my_auc: 0.6788 - val_loss: 0.6513 - val_accuracy: 0.4091 - val_my_auc: 0.6689
#  epoch:41 auc: 0.6686
# Epoch 43/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6185 - accuracy: 0.5829 - my_auc: 0.6896 - val_loss: 0.6526 - val_accuracy: 0.4100 - val_my_auc: 0.6665
#  epoch:42 auc: 0.6667
# Epoch 44/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6514 - accuracy: 0.5303 - my_auc: 0.6450 - val_loss: 0.6504 - val_accuracy: 0.3799 - val_my_auc: 0.6717
#  epoch:43 auc: 0.6718
# Epoch 45/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6350 - accuracy: 0.5409 - my_auc: 0.6871 - val_loss: 0.6479 - val_accuracy: 0.4705 - val_my_auc: 0.6676
#  epoch:44 auc: 0.6684
# Epoch 46/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6162 - accuracy: 0.5913 - my_auc: 0.6929 - val_loss: 0.6512 - val_accuracy: 0.3591 - val_my_auc: 0.6719
#  epoch:45 auc: 0.6722
# Epoch 47/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6330 - accuracy: 0.5260 - my_auc: 0.6626 - val_loss: 0.6478 - val_accuracy: 0.4389 - val_my_auc: 0.6700
#  epoch:46 auc: 0.6695
# Epoch 48/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6397 - accuracy: 0.5569 - my_auc: 0.6840 - val_loss: 0.6476 - val_accuracy: 0.4573 - val_my_auc: 0.6699
#  epoch:47 auc: 0.6702
# Epoch 49/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6593 - accuracy: 0.5637 - my_auc: 0.6728 - val_loss: 0.6478 - val_accuracy: 0.4261 - val_my_auc: 0.6715
#  epoch:48 auc: 0.6715
# AUC:  0.6722
# 11603
# l1 14
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 14)]           0
# _________________________________________________________________
# bidirectional_17 (Bidirectio (None, 3, 28)             3248
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 28)                6384
# _________________________________________________________________
# dense (Dense)                (None, 12)                348
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 9,993
# Trainable params: 9,993
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5037046684611155, 1.0: 67.982421875}
# Epoch 1/50
# 68/68 [==============================] - 12s 56ms/step - loss: 0.6789 - accuracy: 0.8865 - my_auc: 0.4717 - val_loss: 0.6924 - val_accuracy: 0.9681 - val_my_auc: 0.5634
#  epoch:0 auc: 0.5964
# Epoch 2/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.7151 - accuracy: 0.7280 - my_auc: 0.5097 - val_loss: 0.6908 - val_accuracy: 0.6614 - val_my_auc: 0.6438
#  epoch:1 auc: 0.6556
# Epoch 3/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6951 - accuracy: 0.6042 - my_auc: 0.5004 - val_loss: 0.6888 - val_accuracy: 0.5599 - val_my_auc: 0.6931
#  epoch:2 auc: 0.6966
# Epoch 4/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6852 - accuracy: 0.7035 - my_auc: 0.5985 - val_loss: 0.6860 - val_accuracy: 0.6066 - val_my_auc: 0.6987
#  epoch:3 auc: 0.6991
# Epoch 5/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6844 - accuracy: 0.7228 - my_auc: 0.5453 - val_loss: 0.6842 - val_accuracy: 0.6332 - val_my_auc: 0.7051
#  epoch:4 auc: 0.7093
# Epoch 6/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6525 - accuracy: 0.7420 - my_auc: 0.5428 - val_loss: 0.6836 - val_accuracy: 0.3949 - val_my_auc: 0.7137
#  epoch:5 auc: 0.7137
# Epoch 7/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6694 - accuracy: 0.6485 - my_auc: 0.5808 - val_loss: 0.6796 - val_accuracy: 0.5917 - val_my_auc: 0.7149
#  epoch:6 auc: 0.7105
# Epoch 8/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6697 - accuracy: 0.7114 - my_auc: 0.6284 - val_loss: 0.6739 - val_accuracy: 0.5684 - val_my_auc: 0.7133
#  epoch:7 auc: 0.7126
# Epoch 9/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.7093 - accuracy: 0.5325 - my_auc: 0.6005 - val_loss: 0.6684 - val_accuracy: 0.6240 - val_my_auc: 0.7121
#  epoch:8 auc: 0.7135
# Epoch 10/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6851 - accuracy: 0.6249 - my_auc: 0.6226 - val_loss: 0.6640 - val_accuracy: 0.5874 - val_my_auc: 0.7108
#  epoch:9 auc: 0.7144
# AUC:  0.7105
# 11602
# l1 14
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 14)]           0
# _________________________________________________________________
# bidirectional_18 (Bidirectio (None, 3, 28)             3248
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 28)                6384
# _________________________________________________________________
# dense (Dense)                (None, 12)                348
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 9,993
# Trainable params: 9,993
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5037046684611155, 1.0: 67.982421875}
# Epoch 1/50
# 68/68 [==============================] - 13s 58ms/step - loss: 0.6915 - accuracy: 0.2924 - my_auc: 0.5163 - val_loss: 0.6928 - val_accuracy: 0.3452 - val_my_auc: 0.5456
#  epoch:0 auc: 0.5451
# Epoch 2/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6947 - accuracy: 0.4057 - my_auc: 0.5145 - val_loss: 0.6920 - val_accuracy: 0.7215 - val_my_auc: 0.5648
#  epoch:1 auc: 0.5841
# Epoch 3/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.7345 - accuracy: 0.5161 - my_auc: 0.4770 - val_loss: 0.6918 - val_accuracy: 0.9392 - val_my_auc: 0.5560
#  epoch:2 auc: 0.5692
# Epoch 4/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.7116 - accuracy: 0.6916 - my_auc: 0.4950 - val_loss: 0.6910 - val_accuracy: 0.8306 - val_my_auc: 0.5819
#  epoch:3 auc: 0.5763
# Epoch 5/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6784 - accuracy: 0.7406 - my_auc: 0.6257 - val_loss: 0.6888 - val_accuracy: 0.7043 - val_my_auc: 0.5985
#  epoch:4 auc: 0.5954
# Epoch 6/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6884 - accuracy: 0.6752 - my_auc: 0.5517 - val_loss: 0.6880 - val_accuracy: 0.7190 - val_my_auc: 0.5880
#  epoch:5 auc: 0.5911
# Epoch 7/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6599 - accuracy: 0.7508 - my_auc: 0.6289 - val_loss: 0.6856 - val_accuracy: 0.4938 - val_my_auc: 0.6057
#  epoch:6 auc: 0.6072
# Epoch 8/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6852 - accuracy: 0.5845 - my_auc: 0.5964 - val_loss: 0.6845 - val_accuracy: 0.7898 - val_my_auc: 0.5976
#  epoch:7 auc: 0.5948
# Epoch 9/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6490 - accuracy: 0.7588 - my_auc: 0.6199 - val_loss: 0.6805 - val_accuracy: 0.5407 - val_my_auc: 0.6134
#  epoch:8 auc: 0.6130
# Epoch 10/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6619 - accuracy: 0.6486 - my_auc: 0.6138 - val_loss: 0.6780 - val_accuracy: 0.5546 - val_my_auc: 0.6115
#  epoch:9 auc: 0.6133
# Epoch 11/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6717 - accuracy: 0.5713 - my_auc: 0.5938 - val_loss: 0.6761 - val_accuracy: 0.6665 - val_my_auc: 0.6139
#  epoch:10 auc: 0.6147
# Epoch 12/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6878 - accuracy: 0.6029 - my_auc: 0.6195 - val_loss: 0.6749 - val_accuracy: 0.4330 - val_my_auc: 0.6243
#  epoch:11 auc: 0.6239
# Epoch 13/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6687 - accuracy: 0.5340 - my_auc: 0.6413 - val_loss: 0.6713 - val_accuracy: 0.5806 - val_my_auc: 0.6204
#  epoch:12 auc: 0.6219
# Epoch 14/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6658 - accuracy: 0.6250 - my_auc: 0.6347 - val_loss: 0.6695 - val_accuracy: 0.4699 - val_my_auc: 0.6271
#  epoch:13 auc: 0.6254
# Epoch 15/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6548 - accuracy: 0.5667 - my_auc: 0.6523 - val_loss: 0.6676 - val_accuracy: 0.4947 - val_my_auc: 0.6250
#  epoch:14 auc: 0.6247
# Epoch 16/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6833 - accuracy: 0.5155 - my_auc: 0.6430 - val_loss: 0.6683 - val_accuracy: 0.6816 - val_my_auc: 0.6241
#  epoch:15 auc: 0.6244
# Epoch 17/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6523 - accuracy: 0.6344 - my_auc: 0.6202 - val_loss: 0.6644 - val_accuracy: 0.5138 - val_my_auc: 0.6273
#  epoch:16 auc: 0.6280
# Epoch 18/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6558 - accuracy: 0.5301 - my_auc: 0.6141 - val_loss: 0.6668 - val_accuracy: 0.3756 - val_my_auc: 0.6304
#  epoch:17 auc: 0.6307
# Epoch 19/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6998 - accuracy: 0.4721 - my_auc: 0.6393 - val_loss: 0.6641 - val_accuracy: 0.5417 - val_my_auc: 0.6272
#  epoch:18 auc: 0.6276
# Epoch 20/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6943 - accuracy: 0.5618 - my_auc: 0.6090 - val_loss: 0.6628 - val_accuracy: 0.4957 - val_my_auc: 0.6296
#  epoch:19 auc: 0.6302
# Epoch 21/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6991 - accuracy: 0.5396 - my_auc: 0.6306 - val_loss: 0.6609 - val_accuracy: 0.4857 - val_my_auc: 0.6331
#  epoch:20 auc: 0.6331
# Epoch 22/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6531 - accuracy: 0.5553 - my_auc: 0.6375 - val_loss: 0.6593 - val_accuracy: 0.4874 - val_my_auc: 0.6338
#  epoch:21 auc: 0.6341
# Epoch 23/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6696 - accuracy: 0.5389 - my_auc: 0.6328 - val_loss: 0.6588 - val_accuracy: 0.4154 - val_my_auc: 0.6370
#  epoch:22 auc: 0.6376
# Epoch 24/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6658 - accuracy: 0.5638 - my_auc: 0.6509 - val_loss: 0.6587 - val_accuracy: 0.4042 - val_my_auc: 0.6381
#  epoch:23 auc: 0.6387
# Epoch 25/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6262 - accuracy: 0.5569 - my_auc: 0.6781 - val_loss: 0.6584 - val_accuracy: 0.3965 - val_my_auc: 0.6380
#  epoch:24 auc: 0.6380
# Epoch 26/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6341 - accuracy: 0.5677 - my_auc: 0.6853 - val_loss: 0.6589 - val_accuracy: 0.3894 - val_my_auc: 0.6396
#  epoch:25 auc: 0.6386
# Epoch 27/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6650 - accuracy: 0.4975 - my_auc: 0.6355 - val_loss: 0.6577 - val_accuracy: 0.3938 - val_my_auc: 0.6400
#  epoch:26 auc: 0.6394
# Epoch 28/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6471 - accuracy: 0.5374 - my_auc: 0.6298 - val_loss: 0.6579 - val_accuracy: 0.5201 - val_my_auc: 0.6366
#  epoch:27 auc: 0.6362
# Epoch 29/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6402 - accuracy: 0.6082 - my_auc: 0.6485 - val_loss: 0.6564 - val_accuracy: 0.4142 - val_my_auc: 0.6391
#  epoch:28 auc: 0.6389
# Epoch 30/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6614 - accuracy: 0.5655 - my_auc: 0.6652 - val_loss: 0.6580 - val_accuracy: 0.3873 - val_my_auc: 0.6381
#  epoch:29 auc: 0.6389
# AUC:  0.6394
# 11602
# l1 14
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 14)]           0
# _________________________________________________________________
# bidirectional_19 (Bidirectio (None, 3, 28)             3248
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 28)                6384
# _________________________________________________________________
# dense (Dense)                (None, 12)                348
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 9,993
# Trainable params: 9,993
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5037046684611155, 1.0: 67.982421875}
# Epoch 1/50
# 68/68 [==============================] - 12s 58ms/step - loss: 0.7134 - accuracy: 0.6769 - my_auc: 0.5293 - val_loss: 0.6914 - val_accuracy: 0.9507 - val_my_auc: 0.6173
#  epoch:0 auc: 0.6377
# Epoch 2/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6882 - accuracy: 0.7473 - my_auc: 0.5424 - val_loss: 0.6887 - val_accuracy: 0.6225 - val_my_auc: 0.6795
#  epoch:1 auc: 0.6796
# Epoch 3/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.7144 - accuracy: 0.7071 - my_auc: 0.5510 - val_loss: 0.6852 - val_accuracy: 0.6772 - val_my_auc: 0.6930
#  epoch:2 auc: 0.6955
# Epoch 4/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6597 - accuracy: 0.8315 - my_auc: 0.5856 - val_loss: 0.6811 - val_accuracy: 0.4304 - val_my_auc: 0.6958
#  epoch:3 auc: 0.7009
# Epoch 5/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6919 - accuracy: 0.6851 - my_auc: 0.5890 - val_loss: 0.6759 - val_accuracy: 0.4867 - val_my_auc: 0.7012
#  epoch:4 auc: 0.7013
# Epoch 6/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.7005 - accuracy: 0.6736 - my_auc: 0.5897 - val_loss: 0.6717 - val_accuracy: 0.4697 - val_my_auc: 0.6994
#  epoch:5 auc: 0.7013
# Epoch 7/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6943 - accuracy: 0.5999 - my_auc: 0.5656 - val_loss: 0.6659 - val_accuracy: 0.4891 - val_my_auc: 0.7004
#  epoch:6 auc: 0.7020
# Epoch 8/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6712 - accuracy: 0.6814 - my_auc: 0.6154 - val_loss: 0.6571 - val_accuracy: 0.6076 - val_my_auc: 0.7024
#  epoch:7 auc: 0.7023
# Epoch 9/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6624 - accuracy: 0.6591 - my_auc: 0.6336 - val_loss: 0.6641 - val_accuracy: 0.2610 - val_my_auc: 0.7068
#  epoch:8 auc: 0.7092
# Epoch 10/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6819 - accuracy: 0.5148 - my_auc: 0.6150 - val_loss: 0.6523 - val_accuracy: 0.4086 - val_my_auc: 0.7038
#  epoch:9 auc: 0.7062
# Epoch 11/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6636 - accuracy: 0.6141 - my_auc: 0.6046 - val_loss: 0.6517 - val_accuracy: 0.3614 - val_my_auc: 0.7066
#  epoch:10 auc: 0.7066
# Epoch 12/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.7087 - accuracy: 0.5170 - my_auc: 0.6239 - val_loss: 0.6440 - val_accuracy: 0.4884 - val_my_auc: 0.7071
#  epoch:11 auc: 0.7068
# Epoch 13/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6645 - accuracy: 0.6450 - my_auc: 0.6045 - val_loss: 0.6433 - val_accuracy: 0.4491 - val_my_auc: 0.7090
#  epoch:12 auc: 0.7081
# Epoch 14/50
# 68/68 [==============================] - 2s 29ms/step - loss: 0.6237 - accuracy: 0.6466 - my_auc: 0.6546 - val_loss: 0.6591 - val_accuracy: 0.2451 - val_my_auc: 0.7068
#  epoch:13 auc: 0.7073
# Epoch 15/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.6613 - accuracy: 0.4831 - my_auc: 0.6323 - val_loss: 0.6444 - val_accuracy: 0.3595 - val_my_auc: 0.7050
#  epoch:14 auc: 0.7061
# Epoch 16/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.6819 - accuracy: 0.5253 - my_auc: 0.6214 - val_loss: 0.6359 - val_accuracy: 0.4530 - val_my_auc: 0.7058
#  epoch:15 auc: 0.7061
# AUC:  0.7081
# 11602
# avg_AUC :  0.6825464337676286
# avg_AUC_2 :  0.6824420677361854
#          0         1         2   ...        46        47        48
# 0  0.531606  0.607681  0.600605  ...  0.669952  0.669879  0.671485
# 1  0.563384  0.643833  0.693133  ...       NaN       NaN       NaN
# 2  0.545640  0.564791  0.556034  ...       NaN       NaN       NaN
# 3  0.617277  0.679512  0.693034  ...       NaN       NaN       NaN
#
# [4 rows x 49 columns]
# 0     0.564477
# 1     0.623954
# 2     0.635702
# 3     0.652408
# 4     0.660723
# 5     0.659907
# 6     0.665756
# 7     0.663678
# 8     0.669241
# 9     0.667850
# 10    0.656860
# 11    0.659404
# 12    0.660283
# 13    0.661863
# 14    0.661179
# 15    0.660429
# 16    0.640512
# 17    0.642543
# 18    0.640580
# 19    0.642475
# 20    0.644784
# 21    0.644855
# 22    0.647693
# 23    0.648948
# 24    0.649713
# 25    0.647664
# 26    0.650854
# 27    0.650150
# 28    0.652509
# 29    0.651342
# 30    0.666632
# 31    0.666253
# 32    0.666876
# 33    0.667319
# 34    0.667749
# 35    0.667157
# 36    0.668117
# 37    0.667108
# 38    0.668035
# 39    0.668158
# 40    0.671471
# 41    0.668869
# 42    0.666545
# 43    0.671699
# 44    0.667571
# 45    0.671876
# 46    0.669952
# 47    0.669879
# 48    0.671485
# dtype: float64
# (0.6825464337676286,
#  array([0.        , 0.06744186, 0.10557456, 0.12906977, 0.1496238 ,
#         0.17311902, 0.19661423, 0.21720246, 0.23478112, 0.25536936,
#         0.27294802, 0.28461012, 0.29924761, 0.32859097, 0.34025308,
#         0.36073871, 0.37246922, 0.3870725 , 0.38997948, 0.39873461,
#         0.41337209, 0.42804378, 0.43980848, 0.46621067, 0.47209302,
#         0.48382353, 0.50434337, 0.50725034, 0.51607387, 0.53956908,
#         0.54251026, 0.55714774, 0.56887825, 0.5747606 , 0.58358413,
#         0.58943228, 0.60410397, 0.624658  , 0.63050616, 0.64811902,
#         0.65988372, 0.67161423, 0.67746238, 0.67746238, 0.68919289,
#         0.70386457, 0.70974692, 0.71562927, 0.72151163, 0.72739398,
#         0.74199726, 0.75369357, 0.75663475, 0.77127223, 0.77712038,
#         0.78006156, 0.78888509, 0.8005472 , 0.81521888, 0.83279754,
#         0.84162107, 0.84456224, 0.8504446 , 0.8504446 , 0.85632695,
#         0.86515048, 0.86515048, 0.87688098, 0.89158687, 0.89743502,
#         0.90625855, 0.90916553, 0.91501368, 0.91501368, 0.91501368,
#         0.92383721, 0.93262654, 0.93556772, 0.94141587, 0.94432285,
#         0.94432285, 0.9619015 , 0.97363201, 0.98245554, 0.98539672,
#         0.98539672, 0.98539672, 0.98833789, 0.99124487, 0.99124487,
#         0.99415185, 0.99415185, 0.99415185, 0.99415185, 0.99415185,
#         0.99705882, 0.99705882, 1.        , 1.        , 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5657545 , 0.50543404, 0.67413646, ..., 0.598733  , 0.36783832,
#            0.6307067 ], dtype=float32)],
#    array([    2,     4,     9, ..., 46402, 46405, 46407])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.47802818, 0.51075476, 0.4926128 , ..., 0.5138513 , 0.4894239 ,
#            0.46269122], dtype=float32)],
#    array([    3,    11,    12, ..., 46390, 46397, 46400])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.53468317, 0.55455655, 0.6118373 , ..., 0.6305713 , 0.42859787,
#            0.40265992], dtype=float32)],
#    array([    1,     5,     6, ..., 46403, 46404, 46408])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.4660206 , 0.5832207 , 0.5775671 , ..., 0.57858205, 0.55782276,
#            0.32483447], dtype=float32)],
#    array([    0,     8,    17, ..., 46398, 46399, 46406])]])

# %%
# financial performance timestep = 2
cross_val(df_fl, 'label_new', v_perf, 'lstm_perf', 2, epoch=50)
# Out:
# init A shape:  (61744, 29)
# (53600, 2, 14) 408.0
# l1 14
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 14)]           0
# _________________________________________________________________
# bidirectional_20 (Bidirectio (None, 2, 28)             3248
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 28)                6384
# _________________________________________________________________
# dense (Dense)                (None, 12)                348
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 9,993
# Trainable params: 9,993
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/50
# 79/79 [==============================] - 13s 48ms/step - loss: 0.6698 - accuracy: 0.7566 - my_auc: 0.4452 - val_loss: 0.6925 - val_accuracy: 0.7365 - val_my_auc: 0.5482
#  epoch:0 auc: 0.5780
# Epoch 2/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6721 - accuracy: 0.8380 - my_auc: 0.5600 - val_loss: 0.6920 - val_accuracy: 0.8042 - val_my_auc: 0.5631
#  epoch:1 auc: 0.5829
# Epoch 3/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6898 - accuracy: 0.8167 - my_auc: 0.5715 - val_loss: 0.6914 - val_accuracy: 0.7641 - val_my_auc: 0.5750
#  epoch:2 auc: 0.5901
# Epoch 4/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6913 - accuracy: 0.7688 - my_auc: 0.5701 - val_loss: 0.6901 - val_accuracy: 0.8978 - val_my_auc: 0.6073
#  epoch:3 auc: 0.6097
# Epoch 5/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6586 - accuracy: 0.8729 - my_auc: 0.5640 - val_loss: 0.6888 - val_accuracy: 0.5931 - val_my_auc: 0.6326
#  epoch:4 auc: 0.6371
# Epoch 6/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6865 - accuracy: 0.6770 - my_auc: 0.5662 - val_loss: 0.6873 - val_accuracy: 0.8122 - val_my_auc: 0.6187
#  epoch:5 auc: 0.6220
# Epoch 7/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7240 - accuracy: 0.6934 - my_auc: 0.5761 - val_loss: 0.6857 - val_accuracy: 0.8883 - val_my_auc: 0.6282
#  epoch:6 auc: 0.6279
# Epoch 8/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6841 - accuracy: 0.7703 - my_auc: 0.5935 - val_loss: 0.6824 - val_accuracy: 0.8352 - val_my_auc: 0.6406
#  epoch:7 auc: 0.6390
# Epoch 9/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7159 - accuracy: 0.7010 - my_auc: 0.6004 - val_loss: 0.6792 - val_accuracy: 0.7073 - val_my_auc: 0.6462
#  epoch:8 auc: 0.6478
# Epoch 10/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6883 - accuracy: 0.6699 - my_auc: 0.6125 - val_loss: 0.6762 - val_accuracy: 0.6504 - val_my_auc: 0.6562
#  epoch:9 auc: 0.6560
# Epoch 11/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6443 - accuracy: 0.6960 - my_auc: 0.6146 - val_loss: 0.6733 - val_accuracy: 0.5621 - val_my_auc: 0.6576
#  epoch:10 auc: 0.6584
# Epoch 12/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6935 - accuracy: 0.5399 - my_auc: 0.5974 - val_loss: 0.6713 - val_accuracy: 0.5734 - val_my_auc: 0.6516
#  epoch:11 auc: 0.6519
# Epoch 13/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6721 - accuracy: 0.6191 - my_auc: 0.6480 - val_loss: 0.6688 - val_accuracy: 0.5028 - val_my_auc: 0.6539
#  epoch:12 auc: 0.6547
# Epoch 14/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7013 - accuracy: 0.5174 - my_auc: 0.6245 - val_loss: 0.6627 - val_accuracy: 0.5672 - val_my_auc: 0.6610
#  epoch:13 auc: 0.6603
# Epoch 15/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6344 - accuracy: 0.6127 - my_auc: 0.6304 - val_loss: 0.6621 - val_accuracy: 0.4404 - val_my_auc: 0.6689
#  epoch:14 auc: 0.6692
# Epoch 16/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7009 - accuracy: 0.5121 - my_auc: 0.6251 - val_loss: 0.6592 - val_accuracy: 0.6705 - val_my_auc: 0.6626
#  epoch:15 auc: 0.6622
# Epoch 17/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7184 - accuracy: 0.5427 - my_auc: 0.6127 - val_loss: 0.6568 - val_accuracy: 0.6167 - val_my_auc: 0.6662
#  epoch:16 auc: 0.6660
# Epoch 18/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6812 - accuracy: 0.5823 - my_auc: 0.6174 - val_loss: 0.6575 - val_accuracy: 0.4326 - val_my_auc: 0.6742
#  epoch:17 auc: 0.6737
# Epoch 19/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6431 - accuracy: 0.5631 - my_auc: 0.6256 - val_loss: 0.6527 - val_accuracy: 0.5355 - val_my_auc: 0.6722
#  epoch:18 auc: 0.6727
# Epoch 20/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6469 - accuracy: 0.5936 - my_auc: 0.6434 - val_loss: 0.6551 - val_accuracy: 0.4284 - val_my_auc: 0.6740
#  epoch:19 auc: 0.6756
# Epoch 21/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6822 - accuracy: 0.4932 - my_auc: 0.5929 - val_loss: 0.6502 - val_accuracy: 0.5600 - val_my_auc: 0.6753
#  epoch:20 auc: 0.6752
# Epoch 22/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6493 - accuracy: 0.6345 - my_auc: 0.6550 - val_loss: 0.6523 - val_accuracy: 0.4324 - val_my_auc: 0.6785
#  epoch:21 auc: 0.6787
# Epoch 23/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7245 - accuracy: 0.4764 - my_auc: 0.5882 - val_loss: 0.6502 - val_accuracy: 0.5381 - val_my_auc: 0.6750
#  epoch:22 auc: 0.6751
# Epoch 24/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6756 - accuracy: 0.5584 - my_auc: 0.6620 - val_loss: 0.6503 - val_accuracy: 0.5167 - val_my_auc: 0.6734
#  epoch:23 auc: 0.6740
# Epoch 25/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6535 - accuracy: 0.6003 - my_auc: 0.6374 - val_loss: 0.6497 - val_accuracy: 0.4962 - val_my_auc: 0.6748
#  epoch:24 auc: 0.6751
# AUC:  0.6787
# 13400
# l1 14
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 14)]           0
# _________________________________________________________________
# bidirectional_21 (Bidirectio (None, 2, 28)             3248
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 28)                6384
# _________________________________________________________________
# dense (Dense)                (None, 12)                348
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 9,993
# Trainable params: 9,993
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/50
# 79/79 [==============================] - 12s 48ms/step - loss: 0.7160 - accuracy: 0.9344 - my_auc: 0.4998 - val_loss: 0.6914 - val_accuracy: 0.9788 - val_my_auc: 0.6222
#  epoch:0 auc: 0.6087
# Epoch 2/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7184 - accuracy: 0.8635 - my_auc: 0.5780 - val_loss: 0.6904 - val_accuracy: 0.8685 - val_my_auc: 0.6084
#  epoch:1 auc: 0.6211
# Epoch 3/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6985 - accuracy: 0.7985 - my_auc: 0.5694 - val_loss: 0.6888 - val_accuracy: 0.9388 - val_my_auc: 0.6225
#  epoch:2 auc: 0.6279
# Epoch 4/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7077 - accuracy: 0.8293 - my_auc: 0.5588 - val_loss: 0.6867 - val_accuracy: 0.7289 - val_my_auc: 0.6363
#  epoch:3 auc: 0.6332
# Epoch 5/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6805 - accuracy: 0.6976 - my_auc: 0.5761 - val_loss: 0.6844 - val_accuracy: 0.7361 - val_my_auc: 0.6323
#  epoch:4 auc: 0.6347
# Epoch 6/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6852 - accuracy: 0.7406 - my_auc: 0.6134 - val_loss: 0.6831 - val_accuracy: 0.4176 - val_my_auc: 0.6372
#  epoch:5 auc: 0.6367
# Epoch 7/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7026 - accuracy: 0.5609 - my_auc: 0.6362 - val_loss: 0.6792 - val_accuracy: 0.6789 - val_my_auc: 0.6361
#  epoch:6 auc: 0.6335
# Epoch 8/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6660 - accuracy: 0.6969 - my_auc: 0.5782 - val_loss: 0.6783 - val_accuracy: 0.4827 - val_my_auc: 0.6339
#  epoch:7 auc: 0.6369
# Epoch 9/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7163 - accuracy: 0.5321 - my_auc: 0.5830 - val_loss: 0.6752 - val_accuracy: 0.7423 - val_my_auc: 0.6324
#  epoch:8 auc: 0.6316
# AUC:  0.6367
# 13400
# l1 14
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 14)]           0
# _________________________________________________________________
# bidirectional_22 (Bidirectio (None, 2, 28)             3248
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 28)                6384
# _________________________________________________________________
# dense (Dense)                (None, 12)                348
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 9,993
# Trainable params: 9,993
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/50
# 79/79 [==============================] - 12s 49ms/step - loss: 0.6831 - accuracy: 0.5088 - my_auc: 0.5290 - val_loss: 0.6918 - val_accuracy: 0.2642 - val_my_auc: 0.5804
#  epoch:0 auc: 0.6000
# Epoch 2/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6597 - accuracy: 0.5621 - my_auc: 0.5030 - val_loss: 0.6907 - val_accuracy: 0.1982 - val_my_auc: 0.6057
#  epoch:1 auc: 0.6239
# Epoch 3/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7073 - accuracy: 0.3396 - my_auc: 0.5365 - val_loss: 0.6901 - val_accuracy: 0.3631 - val_my_auc: 0.6411
#  epoch:2 auc: 0.6365
# Epoch 4/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7097 - accuracy: 0.4172 - my_auc: 0.5958 - val_loss: 0.6885 - val_accuracy: 0.5436 - val_my_auc: 0.6370
#  epoch:3 auc: 0.6418
# Epoch 5/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6497 - accuracy: 0.6945 - my_auc: 0.5683 - val_loss: 0.6869 - val_accuracy: 0.1980 - val_my_auc: 0.6509
#  epoch:4 auc: 0.6550
# Epoch 6/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6836 - accuracy: 0.4232 - my_auc: 0.5901 - val_loss: 0.6834 - val_accuracy: 0.4516 - val_my_auc: 0.6556
#  epoch:5 auc: 0.6566
# Epoch 7/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7000 - accuracy: 0.5567 - my_auc: 0.5776 - val_loss: 0.6792 - val_accuracy: 0.4676 - val_my_auc: 0.6610
#  epoch:6 auc: 0.6615
# Epoch 8/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6568 - accuracy: 0.6156 - my_auc: 0.5765 - val_loss: 0.6763 - val_accuracy: 0.3934 - val_my_auc: 0.6665
#  epoch:7 auc: 0.6662
# Epoch 9/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.7152 - accuracy: 0.4541 - my_auc: 0.5924 - val_loss: 0.6732 - val_accuracy: 0.7034 - val_my_auc: 0.6668
#  epoch:8 auc: 0.6667
# Epoch 10/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6523 - accuracy: 0.7035 - my_auc: 0.5968 - val_loss: 0.6696 - val_accuracy: 0.4034 - val_my_auc: 0.6685
#  epoch:9 auc: 0.6698
# Epoch 11/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6345 - accuracy: 0.6168 - my_auc: 0.6346 - val_loss: 0.6661 - val_accuracy: 0.3804 - val_my_auc: 0.6716
#  epoch:10 auc: 0.6721
# Epoch 12/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6486 - accuracy: 0.6103 - my_auc: 0.6530 - val_loss: 0.6605 - val_accuracy: 0.5113 - val_my_auc: 0.6726
#  epoch:11 auc: 0.6721
# Epoch 13/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6712 - accuracy: 0.5865 - my_auc: 0.6203 - val_loss: 0.6571 - val_accuracy: 0.6546 - val_my_auc: 0.6718
#  epoch:12 auc: 0.6727
# Epoch 14/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6842 - accuracy: 0.6207 - my_auc: 0.5935 - val_loss: 0.6564 - val_accuracy: 0.4908 - val_my_auc: 0.6744
#  epoch:13 auc: 0.6747
# Epoch 15/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6429 - accuracy: 0.6103 - my_auc: 0.6454 - val_loss: 0.6545 - val_accuracy: 0.5150 - val_my_auc: 0.6758
#  epoch:14 auc: 0.6754
# Epoch 16/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.6833 - accuracy: 0.5604 - my_auc: 0.6133 - val_loss: 0.6505 - val_accuracy: 0.6301 - val_my_auc: 0.6755
#  epoch:15 auc: 0.6755
# Epoch 17/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6694 - accuracy: 0.6228 - my_auc: 0.6102 - val_loss: 0.6495 - val_accuracy: 0.5781 - val_my_auc: 0.6773
#  epoch:16 auc: 0.6774
# Epoch 18/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6614 - accuracy: 0.6366 - my_auc: 0.6645 - val_loss: 0.6492 - val_accuracy: 0.5327 - val_my_auc: 0.6779
#  epoch:17 auc: 0.6777
# Epoch 19/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6666 - accuracy: 0.6089 - my_auc: 0.6529 - val_loss: 0.6483 - val_accuracy: 0.6934 - val_my_auc: 0.6783
#  epoch:18 auc: 0.6782
# Epoch 20/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6352 - accuracy: 0.6725 - my_auc: 0.6254 - val_loss: 0.6533 - val_accuracy: 0.4099 - val_my_auc: 0.6793
#  epoch:19 auc: 0.6791
# Epoch 21/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6897 - accuracy: 0.5075 - my_auc: 0.6309 - val_loss: 0.6477 - val_accuracy: 0.5951 - val_my_auc: 0.6798
#  epoch:20 auc: 0.6799
# Epoch 22/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6803 - accuracy: 0.6022 - my_auc: 0.6564 - val_loss: 0.6506 - val_accuracy: 0.4447 - val_my_auc: 0.6800
#  epoch:21 auc: 0.6795
# Epoch 23/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6510 - accuracy: 0.5802 - my_auc: 0.6155 - val_loss: 0.6547 - val_accuracy: 0.3745 - val_my_auc: 0.6803
#  epoch:22 auc: 0.6800
# Epoch 24/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6637 - accuracy: 0.5484 - my_auc: 0.6221 - val_loss: 0.6476 - val_accuracy: 0.5272 - val_my_auc: 0.6801
#  epoch:23 auc: 0.6797
# Epoch 25/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6863 - accuracy: 0.5701 - my_auc: 0.6419 - val_loss: 0.6465 - val_accuracy: 0.5228 - val_my_auc: 0.6801
#  epoch:24 auc: 0.6801
# Epoch 26/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6911 - accuracy: 0.5797 - my_auc: 0.6292 - val_loss: 0.6482 - val_accuracy: 0.7425 - val_my_auc: 0.6793
#  epoch:25 auc: 0.6798
# AUC:  0.68
# 13400
# l1 14
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 14)]           0
# _________________________________________________________________
# bidirectional_23 (Bidirectio (None, 2, 28)             3248
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 28)                6384
# _________________________________________________________________
# dense (Dense)                (None, 12)                348
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 12)                0
# _________________________________________________________________
# output (Dense)               (None, 1)                 13
# =================================================================
# Total params: 9,993
# Trainable params: 9,993
# Non-trainable params: 0
# _________________________________________________________________
# {0.0: 0.5038351631824335, 1.0: 65.68627450980392}
# Epoch 1/50
# 79/79 [==============================] - 12s 48ms/step - loss: 0.6504 - accuracy: 0.8418 - my_auc: 0.4697 - val_loss: 0.6926 - val_accuracy: 0.7693 - val_my_auc: 0.5235
#  epoch:0 auc: 0.6333
# Epoch 2/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6778 - accuracy: 0.7611 - my_auc: 0.5069 - val_loss: 0.6914 - val_accuracy: 0.3234 - val_my_auc: 0.6382
#  epoch:1 auc: 0.6594
# Epoch 3/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6908 - accuracy: 0.6697 - my_auc: 0.5694 - val_loss: 0.6887 - val_accuracy: 0.8622 - val_my_auc: 0.6681
#  epoch:2 auc: 0.6736
# Epoch 4/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6799 - accuracy: 0.8168 - my_auc: 0.5537 - val_loss: 0.6869 - val_accuracy: 0.3887 - val_my_auc: 0.6801
#  epoch:3 auc: 0.6873
# Epoch 5/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6887 - accuracy: 0.6135 - my_auc: 0.5514 - val_loss: 0.6840 - val_accuracy: 0.6116 - val_my_auc: 0.6773
#  epoch:4 auc: 0.6837
# Epoch 6/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.7005 - accuracy: 0.6179 - my_auc: 0.5751 - val_loss: 0.6823 - val_accuracy: 0.4126 - val_my_auc: 0.6944
#  epoch:5 auc: 0.6958
# Epoch 7/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6971 - accuracy: 0.5739 - my_auc: 0.6030 - val_loss: 0.6781 - val_accuracy: 0.4824 - val_my_auc: 0.6950
#  epoch:6 auc: 0.6947
# Epoch 8/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6500 - accuracy: 0.7249 - my_auc: 0.5837 - val_loss: 0.6744 - val_accuracy: 0.4210 - val_my_auc: 0.7000
#  epoch:7 auc: 0.7018
# Epoch 9/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6480 - accuracy: 0.6439 - my_auc: 0.5896 - val_loss: 0.6704 - val_accuracy: 0.4220 - val_my_auc: 0.6984
#  epoch:8 auc: 0.6990
# Epoch 10/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6550 - accuracy: 0.6290 - my_auc: 0.5850 - val_loss: 0.6662 - val_accuracy: 0.5024 - val_my_auc: 0.6992
#  epoch:9 auc: 0.6984
# Epoch 11/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6636 - accuracy: 0.6404 - my_auc: 0.5876 - val_loss: 0.6657 - val_accuracy: 0.3592 - val_my_auc: 0.7033
#  epoch:10 auc: 0.7027
# Epoch 12/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6583 - accuracy: 0.5644 - my_auc: 0.5921 - val_loss: 0.6631 - val_accuracy: 0.3788 - val_my_auc: 0.7043
#  epoch:11 auc: 0.7045
# Epoch 13/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6736 - accuracy: 0.5663 - my_auc: 0.6237 - val_loss: 0.6575 - val_accuracy: 0.4819 - val_my_auc: 0.7036
#  epoch:12 auc: 0.7030
# Epoch 14/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6801 - accuracy: 0.5384 - my_auc: 0.6044 - val_loss: 0.6578 - val_accuracy: 0.4250 - val_my_auc: 0.7049
#  epoch:13 auc: 0.7047
# Epoch 15/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6670 - accuracy: 0.5844 - my_auc: 0.6228 - val_loss: 0.6581 - val_accuracy: 0.3634 - val_my_auc: 0.7049
#  epoch:14 auc: 0.7057
# Epoch 16/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6661 - accuracy: 0.5482 - my_auc: 0.6244 - val_loss: 0.6508 - val_accuracy: 0.4448 - val_my_auc: 0.7087
#  epoch:15 auc: 0.7088
# Epoch 17/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6551 - accuracy: 0.5948 - my_auc: 0.6094 - val_loss: 0.6469 - val_accuracy: 0.4714 - val_my_auc: 0.7115
#  epoch:16 auc: 0.7109
# Epoch 18/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6375 - accuracy: 0.6150 - my_auc: 0.6157 - val_loss: 0.6508 - val_accuracy: 0.3701 - val_my_auc: 0.7125
#  epoch:17 auc: 0.7127
# Epoch 19/50
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6638 - accuracy: 0.5347 - my_auc: 0.6488 - val_loss: 0.6432 - val_accuracy: 0.4543 - val_my_auc: 0.7139
#  epoch:18 auc: 0.7137
# Epoch 20/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6817 - accuracy: 0.5420 - my_auc: 0.6109 - val_loss: 0.6361 - val_accuracy: 0.5330 - val_my_auc: 0.7140
#  epoch:19 auc: 0.7142
# Epoch 21/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6433 - accuracy: 0.6258 - my_auc: 0.6546 - val_loss: 0.6356 - val_accuracy: 0.5325 - val_my_auc: 0.7120
#  epoch:20 auc: 0.7123
# Epoch 22/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6580 - accuracy: 0.6025 - my_auc: 0.6275 - val_loss: 0.6408 - val_accuracy: 0.4536 - val_my_auc: 0.7117
#  epoch:21 auc: 0.7122
# Epoch 23/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.6795 - accuracy: 0.5569 - my_auc: 0.6529 - val_loss: 0.6310 - val_accuracy: 0.6665 - val_my_auc: 0.7118
#  epoch:22 auc: 0.7118
# AUC:  0.7142
# 13400
# avg_AUC :  0.6774099341195344
# avg_AUC_2 :  0.6775103980986334
#          0         1         2   ...        23        24        25
# 0  0.548210  0.563086  0.574978  ...  0.673393  0.674818       NaN
# 1  0.622170  0.608358  0.622477  ...       NaN       NaN       NaN
# 2  0.580358  0.605724  0.641060  ...  0.680112  0.680086  0.679282
# 3  0.523455  0.638200  0.668141  ...       NaN       NaN       NaN
#
# [4 rows x 26 columns]
# 0     0.568548
# 1     0.603842
# 2     0.626664
# 3     0.640151
# 4     0.648273
# 5     0.651470
# 6     0.655089
# 7     0.660234
# 8     0.660948
# 9     0.674640
# 10    0.677512
# 11    0.676139
# 12    0.676442
# 13    0.680127
# 14    0.683173
# 15    0.682257
# 16    0.685023
# 17    0.688223
# 18    0.688127
# 19    0.689097
# 20    0.689046
# 21    0.690069
# 22    0.689032
# 23    0.676753
# 24    0.677452
# 25    0.679282
# dtype: float64
# (0.6774099341195344,
#  array([0.        , 0.06372549, 0.10294118, 0.13235294, 0.15686275,
#         0.18627451, 0.20833333, 0.22058824, 0.24019608, 0.25245098,
#         0.27205882, 0.29166667, 0.30392157, 0.32352941, 0.33333333,
#         0.34313725, 0.36029412, 0.37990196, 0.39705882, 0.41421569,
#         0.42647059, 0.44117647, 0.44362745, 0.45098039, 0.46078431,
#         0.4754902 , 0.4877451 , 0.49754902, 0.51960784, 0.52205882,
#         0.52696078, 0.54166667, 0.55147059, 0.56617647, 0.57352941,
#         0.58823529, 0.59803922, 0.60539216, 0.62009804, 0.63480392,
#         0.64460784, 0.64705882, 0.65931373, 0.66666667, 0.67156863,
#         0.69362745, 0.70343137, 0.72303922, 0.72794118, 0.73284314,
#         0.74754902, 0.75735294, 0.76715686, 0.77205882, 0.77941176,
#         0.79901961, 0.81862745, 0.81862745, 0.81862745, 0.82598039,
#         0.83823529, 0.84558824, 0.84803922, 0.86029412, 0.86519608,
#         0.87009804, 0.875     , 0.87745098, 0.87745098, 0.87990196,
#         0.88970588, 0.89705882, 0.90441176, 0.91666667, 0.92401961,
#         0.92401961, 0.92401961, 0.92647059, 0.93627451, 0.93872549,
#         0.94362745, 0.94607843, 0.94852941, 0.95098039, 0.95343137,
#         0.96323529, 0.96323529, 0.96813725, 0.97058824, 0.97058824,
#         0.97058824, 0.97794118, 0.98529412, 0.9877451 , 0.9877451 ,
#         0.99019608, 0.99264706, 0.99509804, 1.        , 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.42393547, 0.59969777, 0.6310841 , ..., 0.520631  , 0.64707536,
#            0.5110784 ], dtype=float32)],
#    array([    4,     9,    10, ..., 53593, 53596, 53598])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.50872916, 0.5266703 , 0.5023642 , ..., 0.51565146, 0.47577882,
#            0.43723968], dtype=float32)],
#    array([    2,     7,    12, ..., 53586, 53591, 53599])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.54225194, 0.4433646 , 0.5828205 , ..., 0.52770495, 0.6551257 ,
#            0.34818354], dtype=float32)],
#    array([    3,     5,     8, ..., 53594, 53595, 53597])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.35326213, 0.45966223, 0.550637  , ..., 0.65515715, 0.55061245,
#            0.5958046 ], dtype=float32)],
#    array([    0,     1,     6, ..., 53579, 53588, 53589])]])

# %% [markdown]
# # LSTM+TCN
#
# ## There are two models "model_tcn" and "model_tcn_1"
# ##### model "model_tcn":
# ##### T=1
# ##### variables:
# ##### B. Overall Similarity+ Word Changes
# ##### D. Quant. Indicators + Overall Similarity + Word Changes
# #####
# ##### model "model_tcn_1":
# ##### T= 2,3
# ##### variables:
# ##### B. Overall Similarity+ Word Changes
# ##### D. Quant. Indicators + Overall Similarity + Word Changes

# %%
#TCN for timestep = 1
def model_tcn(n1,n2,n3,T, perf, words, channel, filters = 24, dropout = 0):
    model = None
    
    input_perf = Input(shape=(T,perf), \
                      dtype='float32', name='input_perf')
    
    input_words = Input(shape=(T,words,channel), \
                      dtype='float32', name='input_words') 
    
    word_norm = BatchNormalization()(input_words)
    padding = ZeroPadding2D(padding=((0,0),(words-1,0)))(word_norm)
    
    print("shape after padding:", K.int_shape(padding))
    
    conv = Conv2D(filters = filters,\
                  kernel_size = (1,words),\
                  use_bias = False,\
                  activation = None)(padding)  # Shape None x T x words x filters
    print("conv shape:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    
    pool = MaxPooling2D(pool_size=(1, words), \
                        strides=(1,1))(conv) # None x T x filters
    
    pool = Reshape((T, filters))(pool)
    print("pool shape:", K.int_shape(pool))
    pool = Dropout(0.3)(pool)

    # Now concatenate
    perf_norm = BatchNormalization()(input_perf)
    all_input = Concatenate(axis = -1)([perf_norm, pool])
    all_rsp = Reshape((filters+ input_perf.shape[2],))(all_input)

    
    dense = Dense(120, activation='relu', name='dense0')(all_rsp)
    drop = Dropout(0.3)(dense)
    dense = Dense(60, activation='relu', name='dense')(drop)

    preds = Dense(1, activation='sigmoid', name='output')(dense)
    model = Model(inputs=[input_perf, input_words], outputs=preds)
    model._name = "model_tcn"
    model.summary()
    
    return model

# %%
#TCN for timestep > 1
def model_tcn_1(n1,n2,n3,T, perf, words, channel, filters = 24, dropout = 0):
    model = None
    
    input_perf = Input(shape=(T,perf), \
                      dtype='float32', name='input_perf')
    
    input_words = Input(shape=(T,words,channel), \
                      dtype='float32', name='input_words') 
    
    word_norm = BatchNormalization()(input_words)
    padding = ZeroPadding2D(padding=((0,0),(words-1,0)))(word_norm)
    
    print("shape after padding:", K.int_shape(padding))
    
    conv = Conv2D(filters = filters,\
                  kernel_size = (1,words),\
                  use_bias = False,\
                  activation = None)(padding)  # Shape None x T x words x filters
    print("conv shape:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    
    pool = MaxPooling2D(pool_size=(1, words), \
                        strides=(1,1))(conv) # None x T x filters
    pool = Reshape((T, filters))(pool)
    print("pool shape:", K.int_shape(pool))

    #drop = Dropout(0.3)(input_all)
    # Now concatenate
    perf_norm = BatchNormalization()(input_perf)
    all_input = Concatenate(axis = -1)([perf_norm, pool])
    #all_rsp = Reshape((filters+15,))(all_input)
    #nor = BatchNormalization()(all_input)
    
    LSTM_w_1 =Bidirectional(LSTM(n1, dropout = 0.3, recurrent_dropout = 0.3,
                    name = 'layer_lstm_1', return_sequences=True,
                    # kernel_regularizer = regularizers.l2(0.01),
                    # activity_regularizer = regularizers.l2(0.01),
                    # bias_regularizer = regularizers.l2(0.01)
                    ))(all_input)
    LSTM_w_2 = LSTM(n2, dropout= 0.3, recurrent_dropout = 0.3,
                   name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)
    
    dense = Dense(n3, activation='relu', name='dense')(LSTM_w_2)
    drop = Dropout(0.3)(dense)
    
    preds = Dense(1, activation='sigmoid', name='output')(drop)
    model = Model(inputs=[input_perf, input_words], outputs=preds)
    model._name = "model_tcn"
    model.summary()
    
    return model

# %%
def performance_measure(pred_yp, y):
    '''
    Given lists of predicted y probability and x, y, return a dataframe of AR, AUC, Brier, Decile Table
    '''
    
    tenc_dat = pd.DataFrame({'y_true':y,'probability':pred_yp.flatten()})
    tenc_dat.sort_values('probability',axis = 0,ascending=False, inplace = True)
    tenc_dat.index = range(0,len(tenc_dat))
    y = tenc_dat['y_true']
    point = float(len(tenc_dat))/10
    point = int(round(point))
    tenc = []
    for i in range(0,10):
        tenc.append(y[(i*point):((i+1)*point)])
    tenc[9]=tenc[9].append(y[10*point:])
    total = sum(y)
    num_of_bkr = []
    for j in range(0,10):
        num_of_bkr.append(sum(tenc[j]))
    tencile_bkr = np.array(num_of_bkr)
    rate = tencile_bkr.astype(float)/total

    return rate

# %%
class AUCEvaluation(Callback):
    """ Show AUC after interval number of epoches """
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()
        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            logs['auc'] = score
            tencile=performance_measure(y_pred, self.y_val)
            logs['tencile'] = tencile
            print(" epoch:{:d} auc: {:.4f}".format(epoch, score))

# %%
def fit_model( model,x_train, y_train, x_val, y_val, x_test, y_test, model_name, verbose, epoch):
    
    history = None
    result = None
    
    model_df = model
    print('in fit, val_y: ', sum(y_val), 'test_y',sum(y_test), 'train_y',sum(y_train))

    #class weight for test 
    class_weights = class_weight.compute_class_weight('balanced',
                              np.unique(y_train),
                              y_train)
    class_weights = {l:c for l,c in zip(np.unique(y_train), class_weights)}
    # class weight for val
    val_class_weights = class_weight.compute_class_weight('balanced',
                                np.unique(y_val),
                                y_val)
    val_class_weights = {l:c for l,c in zip(np.unique(y_val), val_class_weights)}
    val_sample_weights = []
    for y in y_val:
        if y == 1:
          val_sample_weights.append(val_class_weights[1])
        else: val_sample_weights.append(val_class_weights[0])
    val_sample_weights = np.asarray(val_sample_weights)
    #print('in fit val weights', val_sample_weights.shape)
    
    auc_eval = AUCEvaluation(validation_data=(x_val, y_val), interval=1)
    # earlyStopping = EarlyStopping(monitor='val_loss',patience = 3, 
    #                   verbose =verbose, mode ='min')
    # checkpoint = ModelCheckpoint(model_name,monitor='val_my_auc',verbose=verbose,
    #           save_best_only=True, save_weights_only=True, mode ='max')

    opt = optimizers.RMSprop(lr=0.0005)
    model_df.compile(optimizer= opt,
              loss='binary_crossentropy',
              metrics=['accuracy', metrics.AUC(name='my_auc')])

    history = model_df.fit(x_train,
                y_train,
                epochs=epoch,
                batch_size=128,
                verbose =verbose,
                callbacks=[auc_eval],\
                #callbacks=[auc_eval, earlyStopping, checkpoint], #checkpoint
                class_weight = class_weights, \
                validation_data=(x_val, y_val, val_sample_weights)) 
    model_df.save(model_name+".h5")
    #model_df.load_weights(model_name)
    y_pred = model_df.predict(x_test)
    print('y_pred',y_pred)
    y_pred_1=np.reshape(y_pred, -1)
    auc_score = roc_auc_score(y_test, y_pred_1)
    #auc_score = roc_auc_score(y_test, y_pred_1)
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_1)
    print("AUC: " ,round(auc_score,4))
    print([ round(h,4) for h in history.history['val_loss']])    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

        
    return history, auc_score, fpr, tpr, thresholds, [y_test, y_pred_1]

# %%
def cross_val(data, label, perf_cols, words_cols, name, w, filters, epoch):
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    predicted_res =[]
    his_auc = []
    
    kf = StratifiedKFold(n_splits = 4, shuffle = True, random_state = 42)
    c = 0

    X_perf, X_word, Y = shift_data(df_fl, w, \
                    perf_cols, \
                    words_cols, \
                    'label')
    
    for train_index, test_index in kf.split(range(len(X_perf)),Y):
        
        c += 1
        
        l1 = X_perf.shape[-1]+ filters

        model = model_tcn(1,l1*2,64,\
                    X_perf.shape[1],\
                    X_perf.shape[2],
                    X_word.shape[2], \
                    X_word.shape[3], \
                    filters = filters)
    
        #model = model_lstm(n1,n2,n,w)
        # train_x, train_val = train_test_split(train_index,test_size=0.2, \
        #             random_state=42, stratify = Y[train_index])
        train_perf_data = X_perf[train_index]
        train_word_data = X_word[train_index]
        # train_perf_val = X_perf[train_val]
        # train_word_val = X_word[train_val]

        train_label = Y[train_index]
        #val_label = Y[train_val]

        test_perf_x = X_perf[test_index]
        test_word_x = X_word[test_index]
        test_y = Y[test_index] 
        
        train_data = [train_perf_data, train_word_data]
        #val_data = [train_perf_val,train_word_val]
        test_x = [test_perf_x, test_word_x]

        mod_res = fit_model(model, train_data, train_label, test_x, test_y, test_x, test_y,\
                  name+'_'+str(c), 0, epoch)
        his_auc.append(mod_res[0].history['val_my_auc'])
        
        
        
        
        auc_list.append(mod_res[1])
        tprs.append(np.interp(mean_fpr, mod_res[2], mod_res[3]))
        temp_pred_res = [mod_res[-1],test_index]
        print(len(test_index))
        predicted_res.append(temp_pred_res)
        
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    print(pd.DataFrame(his_auc))
    print(pd.DataFrame(his_auc).mean())
    
    return np.average(auc_list), mean_tpr, predicted_res

# %%
def shift_data(data, step, perf_cols, words_cols, label):
    A = []
    
    cols = perf_cols + words_cols
    A.append(data[cols].values)
    
    for t in range(1, step):
        d = data.groupby("cik")[cols].shift(t)
        A.append(d.values)
    A = A[::-1]
    A = np.concatenate(A, axis = 1)  # flatten shifted columns
    A = np.concatenate([data[label].values[:,None], A], axis = 1)  # add target
    #np.random.shuffle(A)
    #print(A[3])
    print('init A shape: ',A.shape)
    #print(A[3,:])
    #print(data[cols].iloc[4,:])


    
    A = A[~np.isnan(A).any(axis=1)]  # drop nan
    

    Y = A[:,0]  # get target
    #A = np.reshape(A[:,1:], (len(A), step, len(cols))) # reshape

    A = np.reshape(A[:,1:], (len(A), step, len(perf_cols) + len(words_cols)))
    
    A_perf = A[:, :, 0:len(perf_cols)]
    # CNN_LSTM must be None x T x words x 4
    A_words = A[:, :, len(perf_cols):]
    #convert the shape to [[_p,_new][_dis,_n]]
    A_words = A_words.reshape((len(A), step, int(len(words_cols)/4), 4), order = 'C')
    
    print(A_perf.shape, A_words.shape, Y.sum())
    return A_perf, A_words, Y

# %%
#shift_perf,shit_wrd, _y = shift_data(df_fl, 3, v_perf + v_1+ v_2, selected_new_all_sorted, label='label')

# %%
#shit_wrd[2]

# %%
# for k , fr in df_fl.groupby("cik"):
#   print(fr[selected_new_all_sorted])
#   break

# %%
import os, random

seed_value = 43
os.environ['PYTHONASHSEED'] = str(seed_value)

random.seed(seed_value)

from numpy.random import seed
seed(seed_value)

import tensorflow
tensorflow.random.set_seed(seed_value)

# %%
#use model model_tcn
# T=1, 
# variables: Overall Similarity + Word Changes
w = 1
perf_cols =  v_1 
words_cols = selected_new_all_sorted
label = 'label'
h = cross_val( df_fl, 'label_new', \
          perf_cols,\
          words_cols, \
          'model_tcn_w1_v1words',w, \
          76, 22)
# Out:
# init A shape:  (61744, 42)
# (61744, 1, 1) (61744, 1, 10, 4) 487.0
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 76)
# pool shape: (None, 1, 76)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 1, 19, 4)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 1, 10, 76)    3040        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 1, 10, 76)    304         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 10, 76)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 1, 1, 76)     0           activation[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 76)        0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 1, 76)        0           reshape[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 77)        0           batch_normalization_2[0][0]
#                                                                  dropout_24[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 77)           0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          9360        reshape_1[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_25[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 20,045
# Trainable params: 19,883
# Non-trainable params: 162
# __________________________________________________________________________________________________
# in fit, val_y:  121.0 test_y 121.0 train_y 366.0
#  epoch:0 auc: 0.5910
#  epoch:1 auc: 0.5903
#  epoch:2 auc: 0.5895
#  epoch:3 auc: 0.5934
#  epoch:4 auc: 0.5689
#  epoch:5 auc: 0.6271
#  epoch:6 auc: 0.6262
#  epoch:7 auc: 0.6257
#  epoch:8 auc: 0.6414
#  epoch:9 auc: 0.6367
#  epoch:10 auc: 0.6512
#  epoch:11 auc: 0.6264
#  epoch:12 auc: 0.6202
#  epoch:13 auc: 0.6286
#  epoch:14 auc: 0.6087
#  epoch:15 auc: 0.6059
#  epoch:16 auc: 0.6360
#  epoch:17 auc: 0.6419
#  epoch:18 auc: 0.6408
#  epoch:19 auc: 0.6471
#  epoch:20 auc: 0.6495
#  epoch:21 auc: 0.6544
# y_pred [[0.5324889 ]
#  [0.4943323 ]
#  [0.49068508]
#  ...
#  [0.42272466]
#  [0.4685601 ]
#  [0.6050403 ]]
# AUC:  0.6544
# [0.6948, 0.7165, 0.7104, 0.6934, 0.691, 0.6702, 0.6664, 0.677, 0.6671, 0.679, 0.662, 0.6658, 0.6667, 0.6625, 0.6669, 0.6679, 0.6818, 0.664, 0.6629, 0.6588, 0.6697, 0.6572]
# 15436
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 76)
# pool shape: (None, 1, 76)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 1, 10, 76)    3040        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1, 10, 76)    304         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 10, 76)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 1, 76)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 76)        0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 1, 76)        0           reshape_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1, 77)        0           batch_normalization_5[0][0]
#                                                                  dropout_26[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 77)           0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          9360        reshape_3[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_27[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 20,045
# Trainable params: 19,883
# Non-trainable params: 162
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5806
#  epoch:1 auc: 0.6047
#  epoch:2 auc: 0.6101
#  epoch:3 auc: 0.6120
#  epoch:4 auc: 0.6070
#  epoch:5 auc: 0.5812
#  epoch:6 auc: 0.6190
#  epoch:7 auc: 0.6453
#  epoch:8 auc: 0.6478
#  epoch:9 auc: 0.6405
#  epoch:10 auc: 0.6386
#  epoch:11 auc: 0.6483
#  epoch:12 auc: 0.6282
#  epoch:13 auc: 0.6053
#  epoch:14 auc: 0.6125
#  epoch:15 auc: 0.6077
#  epoch:16 auc: 0.6252
#  epoch:17 auc: 0.6213
#  epoch:18 auc: 0.6194
#  epoch:19 auc: 0.6236
#  epoch:20 auc: 0.6225
#  epoch:21 auc: 0.6362
# y_pred [[0.58626956]
#  [0.6132972 ]
#  [0.5452095 ]
#  ...
#  [0.33420902]
#  [0.25787672]
#  [0.5545566 ]]
# AUC:  0.6362
# [0.6944, 0.7125, 0.717, 0.6939, 0.7312, 0.7356, 0.7206, 0.6761, 0.682, 0.6852, 0.729, 0.6654, 0.6723, 0.7471, 0.6819, 0.6784, 0.6767, 0.6822, 0.6923, 0.6732, 0.7069, 0.6674]
# 15436
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 76)
# pool shape: (None, 1, 76)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 10, 76)    3040        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 1, 10, 76)    304         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 10, 76)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 1, 76)     0           activation_2[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 76)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 1, 76)        0           reshape_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 77)        0           batch_normalization_8[0][0]
#                                                                  dropout_28[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 77)           0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          9360        reshape_5[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_29[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 20,045
# Trainable params: 19,883
# Non-trainable params: 162
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.6254
#  epoch:1 auc: 0.6232
#  epoch:2 auc: 0.6479
#  epoch:3 auc: 0.6514
#  epoch:4 auc: 0.6476
#  epoch:5 auc: 0.6497
#  epoch:6 auc: 0.6578
#  epoch:7 auc: 0.6195
#  epoch:8 auc: 0.6278
#  epoch:9 auc: 0.6169
#  epoch:10 auc: 0.6470
#  epoch:11 auc: 0.6343
#  epoch:12 auc: 0.6065
#  epoch:13 auc: 0.5895
#  epoch:14 auc: 0.5662
#  epoch:15 auc: 0.6199
#  epoch:16 auc: 0.6053
#  epoch:17 auc: 0.6295
#  epoch:18 auc: 0.6251
#  epoch:19 auc: 0.6215
#  epoch:20 auc: 0.6012
#  epoch:21 auc: 0.6271
# y_pred [[0.55988234]
#  [0.48211664]
#  [0.63374925]
#  ...
#  [0.31902307]
#  [0.49076638]
#  [0.58398515]]
# AUC:  0.6271
# [0.6798, 0.6938, 0.6712, 0.6937, 0.6784, 0.6773, 0.682, 0.6809, 0.6815, 0.6728, 0.67, 0.6648, 0.6967, 0.7635, 0.7049, 0.6708, 0.6789, 0.6647, 0.6679, 0.6704, 0.6841, 0.6649]
# 15436
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 76)
# pool shape: (None, 1, 76)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 10, 76)    3040        zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 1, 10, 76)    304         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 10, 76)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 76)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 76)        0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 1, 76)        0           reshape_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1, 77)        0           batch_normalization_11[0][0]
#                                                                  dropout_30[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 77)           0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          9360        reshape_7[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_31[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 20,045
# Trainable params: 19,883
# Non-trainable params: 162
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.6110
#  epoch:1 auc: 0.5967
#  epoch:2 auc: 0.5984
#  epoch:3 auc: 0.5993
#  epoch:4 auc: 0.6065
#  epoch:5 auc: 0.6042
#  epoch:6 auc: 0.6112
#  epoch:7 auc: 0.6041
#  epoch:8 auc: 0.6100
#  epoch:9 auc: 0.5955
#  epoch:10 auc: 0.5919
#  epoch:11 auc: 0.6066
#  epoch:12 auc: 0.5870
#  epoch:13 auc: 0.6038
#  epoch:14 auc: 0.6049
#  epoch:15 auc: 0.5949
#  epoch:16 auc: 0.5893
#  epoch:17 auc: 0.6018
#  epoch:18 auc: 0.5971
#  epoch:19 auc: 0.5902
#  epoch:20 auc: 0.5996
#  epoch:21 auc: 0.6041
# y_pred [[0.6562253 ]
#  [0.48823383]
#  [0.38087144]
#  ...
#  [0.63489765]
#  [0.39636475]
#  [0.509585  ]]
# AUC:  0.6041
# [0.6828, 0.7248, 0.7053, 0.7019, 0.6874, 0.6913, 0.6889, 0.7426, 0.6923, 0.6768, 0.6882, 0.6778, 0.7047, 0.6769, 0.6741, 0.6954, 0.6765, 0.7125, 0.7455, 0.7015, 0.6774, 0.6784]
# 15436
# avg_AUC :  0.6304449251669901
# avg_AUC_2 :  0.6301384321469676
#          0         1         2   ...        19        20        21
# 0  0.590112  0.590270  0.590706  ...  0.646832  0.650128  0.654435
# 1  0.579623  0.604460  0.610223  ...  0.623940  0.622559  0.636096
# 2  0.623862  0.623573  0.648059  ...  0.621577  0.600896  0.627026
# 3  0.611084  0.596984  0.598231  ...  0.590569  0.599794  0.604110
#
# [4 rows x 22 columns]
# 0     0.601170
# 1     0.603821
# 2     0.611805
# 3     0.614147
# 4     0.607596
# 5     0.615970
# 6     0.628337
# 7     0.623731
# 8     0.631731
# 9     0.622524
# 10    0.632109
# 11    0.628778
# 12    0.611584
# 13    0.606779
# 14    0.598235
# 15    0.606386
# 16    0.613913
# 17    0.623678
# 18    0.620615
# 19    0.620729
# 20    0.618344
# 21    0.630417
# dtype: float64

# %%
#use model model_tcn
# T=1, 
# variables: Quant. Indicators + Overall Similarity + Word Changes
w = 1
perf_cols =  v_1 + v_perf
words_cols = selected_new_all_sorted
label = 'label'
h = cross_val( df_fl, 'label_new', \
          perf_cols,\
          words_cols, \
          'model_tcn_w1_v1words',w, \
          36,12)
# Out:
# init A shape:  (61744, 56)
# (61744, 1, 15) (61744, 1, 10, 4) 487.0
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 36)
# pool shape: (None, 1, 36)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 10, 36)    1440        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 1, 10, 36)    144         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 10, 36)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 36)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 15)]      0
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 36)        0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 1, 36)        0           reshape_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 1, 51)        0           batch_normalization_14[0][0]
#                                                                  dropout_32[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 51)           0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          6240        reshape_9[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_33[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 15,221
# Trainable params: 15,111
# Non-trainable params: 110
# __________________________________________________________________________________________________
# in fit, val_y:  121.0 test_y 121.0 train_y 366.0
#  epoch:0 auc: 0.6575
#  epoch:1 auc: 0.6541
#  epoch:2 auc: 0.6740
#  epoch:3 auc: 0.6738
#  epoch:4 auc: 0.6895
#  epoch:5 auc: 0.6891
#  epoch:6 auc: 0.6931
#  epoch:7 auc: 0.6949
#  epoch:8 auc: 0.6936
#  epoch:9 auc: 0.6863
#  epoch:10 auc: 0.6982
#  epoch:11 auc: 0.6959
# y_pred [[0.38487816]
#  [0.5340742 ]
#  [0.5712621 ]
#  ...
#  [0.3190195 ]
#  [0.07086521]
#  [0.07848638]]
# AUC:  0.6959
# [0.6627, 0.6959, 0.6752, 0.6862, 0.6625, 0.6633, 0.6599, 0.6563, 0.6424, 0.6392, 0.6339, 0.6333]
# 15436
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 36)
# pool shape: (None, 1, 36)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 10, 36)    1440        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1, 10, 36)    144         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 10, 36)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 1, 1, 36)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 15)]      0
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 36)        0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 1, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 1, 36)        0           reshape_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 1, 51)        0           batch_normalization_17[0][0]
#                                                                  dropout_34[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 51)           0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          6240        reshape_11[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_35[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 15,221
# Trainable params: 15,111
# Non-trainable params: 110
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.6608
#  epoch:1 auc: 0.6825
#  epoch:2 auc: 0.6810
#  epoch:3 auc: 0.6911
#  epoch:4 auc: 0.6896
#  epoch:5 auc: 0.6888
#  epoch:6 auc: 0.6965
#  epoch:7 auc: 0.6871
#  epoch:8 auc: 0.6925
#  epoch:9 auc: 0.6987
#  epoch:10 auc: 0.6955
#  epoch:11 auc: 0.7030
# y_pred [[0.56906366]
#  [0.6768004 ]
#  [0.5628264 ]
#  ...
#  [0.08809862]
#  [0.30699703]
#  [0.1881415 ]]
# AUC:  0.703
# [0.661, 0.6508, 0.6831, 0.6726, 0.6819, 0.6974, 0.6788, 0.6771, 0.6654, 0.65, 0.6573, 0.6433]
# 15436
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 36)
# pool shape: (None, 1, 36)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 10, 36)    1440        zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 1, 10, 36)    144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 10, 36)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 1, 1, 36)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 15)]      0
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 1, 36)        0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 1, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 1, 36)        0           reshape_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 1, 51)        0           batch_normalization_20[0][0]
#                                                                  dropout_36[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 51)           0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          6240        reshape_13[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_37[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 15,221
# Trainable params: 15,111
# Non-trainable params: 110
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.7215
#  epoch:1 auc: 0.7323
#  epoch:2 auc: 0.7287
#  epoch:3 auc: 0.7347
#  epoch:4 auc: 0.7476
#  epoch:5 auc: 0.7494
#  epoch:6 auc: 0.7515
#  epoch:7 auc: 0.7320
#  epoch:8 auc: 0.7502
#  epoch:9 auc: 0.7352
#  epoch:10 auc: 0.7521
#  epoch:11 auc: 0.7478
# y_pred [[0.50827163]
#  [0.24256003]
#  [0.59733284]
#  ...
#  [0.14050615]
#  [0.7365962 ]
#  [0.6700757 ]]
# AUC:  0.7478
# [0.6305, 0.6469, 0.64, 0.6615, 0.6454, 0.6306, 0.6329, 0.6283, 0.6224, 0.6253, 0.6165, 0.6189]
# 15436
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 36)
# pool shape: (None, 1, 36)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 10, 36)    1440        zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 1, 10, 36)    144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1, 10, 36)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 1, 1, 36)     0           activation_7[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 15)]      0
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 1, 36)        0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 1, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 1, 36)        0           reshape_14[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1, 51)        0           batch_normalization_23[0][0]
#                                                                  dropout_38[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 51)           0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          6240        reshape_15[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_39[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 15,221
# Trainable params: 15,111
# Non-trainable params: 110
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.7011
#  epoch:1 auc: 0.7119
#  epoch:2 auc: 0.7207
#  epoch:3 auc: 0.7266
#  epoch:4 auc: 0.7303
#  epoch:5 auc: 0.7250
#  epoch:6 auc: 0.7163
#  epoch:7 auc: 0.7107
#  epoch:8 auc: 0.7137
#  epoch:9 auc: 0.7121
#  epoch:10 auc: 0.7129
#  epoch:11 auc: 0.7106
# y_pred [[0.6714161 ]
#  [0.58426106]
#  [0.43619812]
#  ...
#  [0.66947865]
#  [0.44018376]
#  [0.7026645 ]]
# AUC:  0.7106
# [0.6377, 0.6728, 0.6669, 0.6337, 0.6342, 0.6576, 0.6462, 0.6561, 0.6689, 0.6319, 0.6383, 0.6273]
# 15436
# avg_AUC :  0.7143208581501352
# avg_AUC_2 :  0.714167912015426
#          0         1         2   ...        9         10        11
# 0  0.657867  0.654411  0.674069  ...  0.686106  0.698300  0.696087
# 1  0.660649  0.682660  0.681038  ...  0.698681  0.695366  0.703119
# 2  0.720922  0.732680  0.728758  ...  0.735134  0.752455  0.747523
# 3  0.701299  0.712195  0.720937  ...  0.712283  0.713165  0.710743
#
# [4 rows x 12 columns]
# 0     0.685184
# 1     0.695486
# 2     0.701201
# 3     0.706353
# 4     0.714169
# 5     0.713153
# 6     0.714374
# 7     0.706249
# 8     0.712377
# 9     0.708051
# 10    0.714821
# 11    0.714368
# dtype: float64

# %%
#use model model_tcn_1
# T=2 
# variables: Overall Similarity + Word Changes


w = 2
perf_cols =  v_1
words_cols = selected_new_all_sorted
label = 'label_new'
h2 = cross_val( df_fl, label, \
          perf_cols,\
          words_cols, \
          'model_tcn_w2_v1words',w, \
          56, 20
          )
# Out:
# init A shape:  (61744, 83)
# (53600, 2, 1) (53600, 2, 10, 4) 408.0
# shape after padding: (None, 2, 19, 4)
# conv shape: (None, 2, 10, 56)
# pool shape: (None, 2, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 2, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 2, 19, 4)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 2, 10, 56)    2240        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 2, 10, 56)    224         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 2, 10, 56)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 1, 56)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 2, 56)        0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 2, 57)        0           batch_normalization_14[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 2, 114)       52440       concatenate_4[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 114)          104424      bidirectional_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           7360        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_4[0][0]
# ==================================================================================================
# Total params: 166,773
# Trainable params: 166,651
# Non-trainable params: 122
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.6326
#  epoch:1 auc: 0.6431
#  epoch:2 auc: 0.6032
#  epoch:3 auc: 0.6275
#  epoch:4 auc: 0.5828
#  epoch:5 auc: 0.6308
#  epoch:6 auc: 0.6106
#  epoch:7 auc: 0.6127
#  epoch:8 auc: 0.6396
#  epoch:9 auc: 0.6415
#  epoch:10 auc: 0.6592
#  epoch:11 auc: 0.6446
#  epoch:12 auc: 0.6494
#  epoch:13 auc: 0.6286
#  epoch:14 auc: 0.6390
#  epoch:15 auc: 0.6577
#  epoch:16 auc: 0.6456
#  epoch:17 auc: 0.6748
#  epoch:18 auc: 0.6627
#  epoch:19 auc: 0.6222
# y_pred [[0.7215002 ]
#  [0.5173744 ]
#  [0.5122043 ]
#  ...
#  [0.03272396]
#  [0.41853487]
#  [0.00164062]]
# AUC:  0.6222
# [0.6824, 0.67, 0.6639, 0.6729, 0.6746, 0.6804, 0.6862, 0.6711, 0.6661, 0.6791, 0.7627, 0.7656, 0.8376, 0.9496, 0.7521, 0.7759, 0.9049, 0.7185, 0.9094, 0.9649]
# 13400
# shape after padding: (None, 2, 19, 4)
# conv shape: (None, 2, 10, 56)
# pool shape: (None, 2, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 2, 19, 4)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 10, 56)    2240        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2, 10, 56)    224         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 2, 10, 56)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 2, 1, 56)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 2, 56)        0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 2, 57)        0           batch_normalization_17[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 2, 114)       52440       concatenate_5[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 114)          104424      bidirectional_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           7360        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_5[0][0]
# ==================================================================================================
# Total params: 166,773
# Trainable params: 166,651
# Non-trainable params: 122
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.6127
#  epoch:1 auc: 0.6436
#  epoch:2 auc: 0.6637
#  epoch:3 auc: 0.6683
#  epoch:4 auc: 0.6659
#  epoch:5 auc: 0.6672
#  epoch:6 auc: 0.6699
#  epoch:7 auc: 0.6825
#  epoch:8 auc: 0.6709
#  epoch:9 auc: 0.6882
#  epoch:10 auc: 0.6970
#  epoch:11 auc: 0.7119
#  epoch:12 auc: 0.7049
#  epoch:13 auc: 0.7039
#  epoch:14 auc: 0.7013
#  epoch:15 auc: 0.6978
#  epoch:16 auc: 0.7060
#  epoch:17 auc: 0.7217
#  epoch:18 auc: 0.7208
#  epoch:19 auc: 0.7181
# y_pred [[0.10091922]
#  [0.25235432]
#  [0.0388363 ]
#  ...
#  [0.26264647]
#  [0.00151232]
#  [0.01231441]]
# AUC:  0.7181
# [0.6894, 0.6845, 0.6779, 0.7384, 0.837, 0.667, 0.7163, 0.6827, 0.6608, 0.7406, 0.7992, 0.6495, 0.8264, 0.6796, 1.0435, 0.7381, 0.691, 0.6881, 0.7553, 0.7503]
# 13400
# shape after padding: (None, 2, 19, 4)
# conv shape: (None, 2, 10, 56)
# pool shape: (None, 2, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 2, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 2, 19, 4)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 2, 10, 56)    2240        zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 2, 10, 56)    224         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 2, 10, 56)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 2, 1, 56)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 2, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 2, 56)        0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 2, 57)        0           batch_normalization_20[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 2, 114)       52440       concatenate_6[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 114)          104424      bidirectional_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           7360        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_6[0][0]
# ==================================================================================================
# Total params: 166,773
# Trainable params: 166,651
# Non-trainable params: 122
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.6024
#  epoch:1 auc: 0.6264
#  epoch:2 auc: 0.6530
#  epoch:3 auc: 0.6834
#  epoch:4 auc: 0.6809
#  epoch:5 auc: 0.6962
#  epoch:6 auc: 0.6819
#  epoch:7 auc: 0.6971
#  epoch:8 auc: 0.6760
#  epoch:9 auc: 0.7015
#  epoch:10 auc: 0.6988
#  epoch:11 auc: 0.6890
#  epoch:12 auc: 0.7125
#  epoch:13 auc: 0.7017
#  epoch:14 auc: 0.7255
#  epoch:15 auc: 0.6966
#  epoch:16 auc: 0.6978
#  epoch:17 auc: 0.6928
#  epoch:18 auc: 0.6908
#  epoch:19 auc: 0.7080
# y_pred [[0.48626652]
#  [0.43646324]
#  [0.17275375]
#  ...
#  [0.00082484]
#  [0.32242167]
#  [0.00121167]]
# AUC:  0.708
# [0.6875, 0.6745, 0.659, 0.6469, 0.7154, 0.6105, 0.6111, 0.6166, 0.6406, 0.6845, 0.617, 0.6647, 0.6431, 0.6232, 0.6809, 0.6778, 0.6275, 0.6371, 0.7752, 0.9558]
# 13400
# shape after padding: (None, 2, 19, 4)
# conv shape: (None, 2, 10, 56)
# pool shape: (None, 2, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 2, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 2, 19, 4)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 2, 10, 56)    2240        zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 2, 10, 56)    224         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 2, 10, 56)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 2, 1, 56)     0           activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 2, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 2, 56)        0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 2, 57)        0           batch_normalization_23[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 2, 114)       52440       concatenate_7[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 114)          104424      bidirectional_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           7360        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_7[0][0]
# ==================================================================================================
# Total params: 166,773
# Trainable params: 166,651
# Non-trainable params: 122
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.5941
#  epoch:1 auc: 0.6211
#  epoch:2 auc: 0.6529
#  epoch:3 auc: 0.6827
#  epoch:4 auc: 0.6991
#  epoch:5 auc: 0.6898
#  epoch:6 auc: 0.7082
#  epoch:7 auc: 0.7121
#  epoch:8 auc: 0.7144
#  epoch:9 auc: 0.7189
#  epoch:10 auc: 0.6937
#  epoch:11 auc: 0.7212
#  epoch:12 auc: 0.7306
#  epoch:13 auc: 0.7325
#  epoch:14 auc: 0.7326
#  epoch:15 auc: 0.7273
#  epoch:16 auc: 0.7365
#  epoch:17 auc: 0.7423
#  epoch:18 auc: 0.7427
#  epoch:19 auc: 0.7393
# y_pred [[6.5820450e-01]
#  [6.2537736e-01]
#  [2.2057977e-01]
#  ...
#  [1.8305361e-02]
#  [1.2725592e-04]
#  [3.4457147e-01]]
# AUC:  0.7393
# [0.6852, 0.6687, 0.6721, 0.6459, 0.6312, 0.6347, 0.6175, 0.6147, 0.6896, 0.6176, 0.7721, 0.7548, 0.7615, 0.704, 0.7281, 0.6612, 0.7132, 0.6611, 0.716, 0.7185]
# 13400
# avg_AUC :  0.6969188938923442
# avg_AUC_2 :  0.6969944543473955
#          0         1         2   ...        17        18        19
# 0  0.633179  0.640269  0.603722  ...  0.674069  0.664579  0.621383
# 1  0.610153  0.644360  0.664387  ...  0.721169  0.719481  0.718276
# 2  0.604032  0.627629  0.652214  ...  0.692915  0.690735  0.705322
# 3  0.593780  0.620633  0.652634  ...  0.742501  0.741355  0.738434
#
# [4 rows x 20 columns]
# 0     0.610286
# 1     0.633223
# 2     0.643239
# 3     0.665893
# 4     0.656925
# 5     0.670817
# 6     0.667416
# 7     0.675889
# 8     0.675163
# 9     0.687397
# 10    0.686684
# 11    0.691355
# 12    0.699033
# 13    0.691436
# 14    0.699114
# 15    0.694393
# 16    0.696266
# 17    0.707663
# 18    0.704037
# 19    0.695854
# dtype: float64

# %%
#use model model_tcn_1
# T=2 
# variables: Quant. Indicators + Overall Similarity + Word Changes
w = 2
perf_cols =  v_1 + v_perf
words_cols = selected_new_all_sorted
label = 'label'
h2 = cross_val( df_fl, 'label_new', \
          perf_cols,\
          words_cols, \
          'model_tcn_w2',w, \
          56, 19)
# Out:
# init A shape:  (61744, 111)
# (53600, 2, 15) (53600, 2, 10, 4) 408.0
# shape after padding: (None, 2, 19, 4)
# conv shape: (None, 2, 10, 56)
# pool shape: (None, 2, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 2, 19, 4)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 2, 10, 56)    2240        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 2, 10, 56)    224         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 2, 10, 56)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 2, 1, 56)     0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 2, 56)        0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 71)        0           batch_normalization_2[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 2, 142)       81224       concatenate[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 142)          161880      bidirectional[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           9152        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout[0][0]
# ==================================================================================================
# Total params: 254,861
# Trainable params: 254,711
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.6903
#  epoch:1 auc: 0.6969
#  epoch:2 auc: 0.7115
#  epoch:3 auc: 0.7323
#  epoch:4 auc: 0.7330
#  epoch:5 auc: 0.7329
#  epoch:6 auc: 0.7260
#  epoch:7 auc: 0.7341
#  epoch:8 auc: 0.7368
#  epoch:9 auc: 0.7111
#  epoch:10 auc: 0.7554
#  epoch:11 auc: 0.7442
#  epoch:12 auc: 0.7409
#  epoch:13 auc: 0.7400
#  epoch:14 auc: 0.7210
#  epoch:15 auc: 0.7358
#  epoch:16 auc: 0.7494
#  epoch:17 auc: 0.7650
#  epoch:18 auc: 0.7486
# y_pred [[8.1489384e-01]
#  [7.2105187e-01]
#  [2.9689237e-01]
#  ...
#  [1.6784668e-04]
#  [9.3089640e-03]
#  [4.0158629e-04]]
# AUC:  0.7486
# [0.6551, 0.7291, 0.6348, 0.6424, 0.6244, 0.6707, 0.6642, 0.6274, 0.6023, 0.6632, 0.6287, 0.6339, 0.6788, 0.6067, 0.7136, 0.7518, 0.8745, 0.6344, 0.8725]
# 13400
# shape after padding: (None, 2, 19, 4)
# conv shape: (None, 2, 10, 56)
# pool shape: (None, 2, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 2, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 2, 19, 4)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 2, 10, 56)    2240        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 2, 10, 56)    224         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 2, 10, 56)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 2, 1, 56)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 2, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 2, 56)        0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2, 71)        0           batch_normalization_5[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 2, 142)       81224       concatenate_1[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 142)          161880      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           9152        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 254,861
# Trainable params: 254,711
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.6788
#  epoch:1 auc: 0.7090
#  epoch:2 auc: 0.7325
#  epoch:3 auc: 0.7381
#  epoch:4 auc: 0.7413
#  epoch:5 auc: 0.7501
#  epoch:6 auc: 0.7599
#  epoch:7 auc: 0.7639
#  epoch:8 auc: 0.7455
#  epoch:9 auc: 0.7579
#  epoch:10 auc: 0.7623
#  epoch:11 auc: 0.7661
#  epoch:12 auc: 0.7717
#  epoch:13 auc: 0.7642
#  epoch:14 auc: 0.7661
#  epoch:15 auc: 0.7634
#  epoch:16 auc: 0.7656
#  epoch:17 auc: 0.7713
#  epoch:18 auc: 0.7750
# y_pred [[0.50540644]
#  [0.19038579]
#  [0.48678163]
#  ...
#  [0.29355043]
#  [0.07169017]
#  [0.00092807]]
# AUC:  0.775
# [0.6582, 0.6877, 0.6365, 0.6551, 0.7234, 0.6414, 0.647, 0.6287, 0.6324, 0.6596, 0.708, 0.6095, 1.0432, 0.6894, 0.9381, 0.6741, 0.7677, 0.7168, 0.6582]
# 13400
# shape after padding: (None, 2, 19, 4)
# conv shape: (None, 2, 10, 56)
# pool shape: (None, 2, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 2, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 2, 19, 4)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 2, 10, 56)    2240        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 2, 10, 56)    224         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 2, 10, 56)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 2, 1, 56)     0           activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 2, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 2, 56)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2, 71)        0           batch_normalization_8[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 2, 142)       81224       concatenate_2[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 142)          161880      bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           9152        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_2[0][0]
# ==================================================================================================
# Total params: 254,861
# Trainable params: 254,711
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.7653
#  epoch:1 auc: 0.7951
#  epoch:2 auc: 0.7808
#  epoch:3 auc: 0.8049
#  epoch:4 auc: 0.7940
#  epoch:5 auc: 0.8026
#  epoch:6 auc: 0.7971
#  epoch:7 auc: 0.8047
#  epoch:8 auc: 0.7902
#  epoch:9 auc: 0.7705
#  epoch:10 auc: 0.7985
#  epoch:11 auc: 0.7524
#  epoch:12 auc: 0.7785
#  epoch:13 auc: 0.7691
#  epoch:14 auc: 0.7743
#  epoch:15 auc: 0.7739
#  epoch:16 auc: 0.7863
#  epoch:17 auc: 0.7653
#  epoch:18 auc: 0.7739
# y_pred [[6.0832322e-01]
#  [5.8002406e-01]
#  [8.3327156e-01]
#  ...
#  [2.5649118e-01]
#  [5.3512293e-01]
#  [4.9873315e-06]]
# AUC:  0.7739
# [0.6296, 0.5671, 0.5589, 0.5908, 0.5575, 0.5558, 0.579, 0.5861, 0.5923, 0.8637, 0.5682, 0.6992, 0.6704, 0.6582, 0.6498, 0.778, 0.6394, 0.6493, 0.686]
# 13400
# shape after padding: (None, 2, 19, 4)
# conv shape: (None, 2, 10, 56)
# pool shape: (None, 2, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 2, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 2, 19, 4)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 2, 10, 56)    2240        zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 2, 10, 56)    224         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 2, 10, 56)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 2, 1, 56)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 2, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 2, 56)        0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2, 71)        0           batch_normalization_11[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 2, 142)       81224       concatenate_3[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 142)          161880      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           9152        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 254,861
# Trainable params: 254,711
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.6884
#  epoch:1 auc: 0.7302
#  epoch:2 auc: 0.7501
#  epoch:3 auc: 0.7737
#  epoch:4 auc: 0.7776
#  epoch:5 auc: 0.7829
#  epoch:6 auc: 0.7897
#  epoch:7 auc: 0.7826
#  epoch:8 auc: 0.7859
#  epoch:9 auc: 0.7870
#  epoch:10 auc: 0.7827
#  epoch:11 auc: 0.7908
#  epoch:12 auc: 0.7846
#  epoch:13 auc: 0.7827
#  epoch:14 auc: 0.7890
#  epoch:15 auc: 0.7817
#  epoch:16 auc: 0.7906
#  epoch:17 auc: 0.7906
#  epoch:18 auc: 0.7895
# y_pred [[5.0185227e-01]
#  [6.3496339e-01]
#  [1.0793862e-01]
#  ...
#  [6.7600518e-02]
#  [5.4498287e-06]
#  [6.5818489e-01]]
# AUC:  0.7895
# [0.6584, 0.6079, 0.6077, 0.5779, 0.5626, 0.5657, 0.5823, 0.5574, 0.6528, 0.5613, 0.7995, 0.7372, 0.8345, 0.595, 0.6605, 0.6592, 0.6814, 0.6626, 0.6344]
# 13400
# avg_AUC :  0.7717360932942887
# avg_AUC_2 :  0.7714398890869479
#          0         1         2   ...        16        17        18
# 0  0.690511  0.696578  0.711930  ...  0.748184  0.765184  0.747247
# 1  0.678709  0.708705  0.732435  ...  0.765646  0.770981  0.774172
# 2  0.767196  0.794807  0.780957  ...  0.785547  0.765466  0.771969
# 3  0.687098  0.729928  0.749659  ...  0.788689  0.790017  0.788934
#
# [4 rows x 19 columns]
# 0     0.705878
# 1     0.732504
# 2     0.743745
# 3     0.762159
# 4     0.761489
# 5     0.767101
# 6     0.768284
# 7     0.770888
# 8     0.764368
# 9     0.756462
# 10    0.773640
# 11    0.762887
# 12    0.766109
# 13    0.763631
# 14    0.761732
# 15    0.763493
# 16    0.772016
# 17    0.772912
# 18    0.770581
# dtype: float64

# %%
#use model model_tcn_1
# T=3 
# variables: Overall Similarity + Word Changes

w = 3 
perf_cols =  v_1
words_cols = selected_new_all_sorted
label = 'label'
h3 = cross_val( df_fl, 'label_new', \
          perf_cols,\
          words_cols, \
          'model_tcn_w3_v1words',w, \
          56, 20)
# Out:
# init A shape:  (61744, 124)
# (46409, 3, 1) (46409, 3, 10, 4) 341.0
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 3, 10, 56)    224         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 3, 10, 56)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 3, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 3, 56)        0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 3, 57)        0           batch_normalization_14[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 3, 114)       52440       concatenate_4[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 114)          104424      bidirectional_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           7360        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_4[0][0]
# ==================================================================================================
# Total params: 166,773
# Trainable params: 166,651
# Non-trainable params: 122
# __________________________________________________________________________________________________
# in fit, val_y:  86.0 test_y 86.0 train_y 255.0
#  epoch:0 auc: 0.5782
#  epoch:1 auc: 0.6355
#  epoch:2 auc: 0.6517
#  epoch:3 auc: 0.6431
#  epoch:4 auc: 0.6661
#  epoch:5 auc: 0.6824
#  epoch:6 auc: 0.6871
#  epoch:7 auc: 0.6751
#  epoch:8 auc: 0.6688
#  epoch:9 auc: 0.6790
#  epoch:10 auc: 0.7042
#  epoch:11 auc: 0.6992
#  epoch:12 auc: 0.7192
#  epoch:13 auc: 0.7107
#  epoch:14 auc: 0.6972
#  epoch:15 auc: 0.7122
#  epoch:16 auc: 0.7180
#  epoch:17 auc: 0.6922
#  epoch:18 auc: 0.7330
#  epoch:19 auc: 0.7311
# y_pred [[7.1224642e-01]
#  [2.9960275e-04]
#  [6.5171856e-01]
#  ...
#  [7.9074335e-01]
#  [4.8267335e-02]
#  [6.1213487e-01]]
# AUC:  0.7311
# [0.6942, 0.6972, 0.705, 0.6567, 0.7914, 0.6704, 0.6902, 0.754, 0.8155, 1.0431, 0.741, 1.0099, 0.6833, 0.8556, 0.6795, 1.1069, 0.6851, 0.8353, 0.7496, 0.744]
# 11603
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 3, 10, 56)    224         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 3, 10, 56)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 3, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 3, 56)        0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 3, 57)        0           batch_normalization_17[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 3, 114)       52440       concatenate_5[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 114)          104424      bidirectional_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           7360        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_5[0][0]
# ==================================================================================================
# Total params: 166,773
# Trainable params: 166,651
# Non-trainable params: 122
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.6308
#  epoch:1 auc: 0.6513
#  epoch:2 auc: 0.6722
#  epoch:3 auc: 0.6938
#  epoch:4 auc: 0.7049
#  epoch:5 auc: 0.7134
#  epoch:6 auc: 0.7228
#  epoch:7 auc: 0.7249
#  epoch:8 auc: 0.7275
#  epoch:9 auc: 0.7298
#  epoch:10 auc: 0.7453
#  epoch:11 auc: 0.7325
#  epoch:12 auc: 0.7572
#  epoch:13 auc: 0.7506
#  epoch:14 auc: 0.7519
#  epoch:15 auc: 0.7505
#  epoch:16 auc: 0.7590
#  epoch:17 auc: 0.7492
#  epoch:18 auc: 0.7567
#  epoch:19 auc: 0.7696
# y_pred [[2.3985404e-01]
#  [8.6431623e-02]
#  [1.7775619e-01]
#  ...
#  [1.0456857e-01]
#  [6.6624068e-07]
#  [1.2214273e-02]]
# AUC:  0.7696
# [0.6827, 0.6636, 0.6857, 0.6282, 0.6157, 0.6028, 0.6007, 0.6208, 0.5947, 0.5899, 0.585, 0.587, 0.5791, 0.6379, 0.5948, 0.8295, 0.5885, 0.6752, 0.5958, 0.8679]
# 11602
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 3, 10, 56)    224         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 3, 10, 56)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 3, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 3, 56)        0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 3, 57)        0           batch_normalization_20[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 3, 114)       52440       concatenate_6[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 114)          104424      bidirectional_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           7360        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_6[0][0]
# ==================================================================================================
# Total params: 166,773
# Trainable params: 166,651
# Non-trainable params: 122
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.6563
#  epoch:1 auc: 0.6896
#  epoch:2 auc: 0.7070
#  epoch:3 auc: 0.7090
#  epoch:4 auc: 0.7071
#  epoch:5 auc: 0.7195
#  epoch:6 auc: 0.6985
#  epoch:7 auc: 0.7050
#  epoch:8 auc: 0.7080
#  epoch:9 auc: 0.7335
#  epoch:10 auc: 0.7403
#  epoch:11 auc: 0.7611
#  epoch:12 auc: 0.7503
#  epoch:13 auc: 0.7649
#  epoch:14 auc: 0.7772
#  epoch:15 auc: 0.7783
#  epoch:16 auc: 0.7931
#  epoch:17 auc: 0.7758
#  epoch:18 auc: 0.7974
#  epoch:19 auc: 0.7994
# y_pred [[0.0938383 ]
#  [0.15834355]
#  [0.09516069]
#  ...
#  [0.5815346 ]
#  [0.0216414 ]
#  [0.43082586]]
# AUC:  0.7994
# [0.6875, 0.6477, 0.6337, 0.6396, 0.6657, 0.6161, 0.6193, 0.6242, 0.8613, 0.8394, 0.6161, 0.6065, 0.587, 0.594, 0.5975, 0.574, 0.5962, 0.6267, 0.5956, 0.5531]
# 11602
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 3, 10, 56)    224         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 3, 10, 56)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 3, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 3, 56)        0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 3, 57)        0           batch_normalization_23[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 3, 114)       52440       concatenate_7[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 114)          104424      bidirectional_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           7360        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_7[0][0]
# ==================================================================================================
# Total params: 166,773
# Trainable params: 166,651
# Non-trainable params: 122
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.5552
#  epoch:1 auc: 0.6036
#  epoch:2 auc: 0.6675
#  epoch:3 auc: 0.6583
#  epoch:4 auc: 0.6833
#  epoch:5 auc: 0.7330
#  epoch:6 auc: 0.7093
#  epoch:7 auc: 0.7169
#  epoch:8 auc: 0.7303
#  epoch:9 auc: 0.7268
#  epoch:10 auc: 0.7584
#  epoch:11 auc: 0.7540
#  epoch:12 auc: 0.7515
#  epoch:13 auc: 0.7298
#  epoch:14 auc: 0.7413
#  epoch:15 auc: 0.7754
#  epoch:16 auc: 0.7083
#  epoch:17 auc: 0.7424
#  epoch:18 auc: 0.7734
#  epoch:19 auc: 0.7740
# y_pred [[1.7762154e-02]
#  [5.8763063e-01]
#  [4.3576866e-01]
#  ...
#  [1.0117590e-02]
#  [4.7336674e-05]
#  [9.1159025e-05]]
# AUC:  0.774
# [0.6911, 0.6739, 0.7381, 0.6376, 0.6272, 0.6015, 0.6195, 0.6235, 0.6176, 0.8313, 0.6139, 0.5932, 0.6179, 0.7145, 0.7755, 0.5931, 0.8567, 0.7892, 0.634, 1.0128]
# 11602
# avg_AUC :  0.7685170984378413
# avg_AUC_2 :  0.7683484986665561
#          0         1         2   ...        17        18        19
# 0  0.578667  0.634969  0.651266  ...  0.691674  0.733677  0.731744
# 1  0.628791  0.652416  0.672250  ...  0.749191  0.756985  0.754467
# 2  0.656164  0.690406  0.706599  ...  0.775461  0.797308  0.799505
# 3  0.552761  0.603076  0.667481  ...  0.738939  0.772662  0.772116
#
# [4 rows x 20 columns]
# 0     0.604096
# 1     0.645217
# 2     0.674399
# 3     0.675529
# 4     0.690498
# 5     0.711511
# 6     0.704503
# 7     0.705571
# 8     0.708081
# 9     0.715229
# 10    0.736672
# 11    0.735918
# 12    0.744478
# 13    0.738557
# 14    0.741314
# 15    0.751541
# 16    0.743731
# 17    0.738816
# 18    0.765158
# 19    0.764458
# dtype: float64

# %%
#use model model_tcn_1
# T=3 
# variables: Quant. Indicators + Overall Similarity + Word Changes
w = 3
perf_cols =  v_1 + v_perf
words_cols = selected_new_all_sorted
label = 'label'
h3 = cross_val( df_fl, 'label_new', \
          perf_cols,\
          words_cols, \
          'model_tcn_w3',w, \
          56, 22)
# Out:
# init A shape:  (61744, 166)
# (46409, 3, 15) (46409, 3, 10, 4) 341.0
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 3, 19, 4)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 3, 10, 56)    2240        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 3, 10, 56)    224         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 3, 10, 56)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 3, 1, 56)     0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 3, 56)        0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3, 71)        0           batch_normalization_2[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 3, 142)       81224       concatenate[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 142)          161880      bidirectional[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           9152        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout[0][0]
# ==================================================================================================
# Total params: 254,861
# Trainable params: 254,711
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  86.0 test_y 86.0 train_y 255.0
#  epoch:0 auc: 0.6676
#  epoch:1 auc: 0.6931
#  epoch:2 auc: 0.7260
#  epoch:3 auc: 0.7281
#  epoch:4 auc: 0.7463
#  epoch:5 auc: 0.6702
#  epoch:6 auc: 0.7476
#  epoch:7 auc: 0.7493
#  epoch:8 auc: 0.7595
#  epoch:9 auc: 0.7372
#  epoch:10 auc: 0.7561
#  epoch:11 auc: 0.7532
#  epoch:12 auc: 0.7570
#  epoch:13 auc: 0.7449
#  epoch:14 auc: 0.7426
#  epoch:15 auc: 0.7536
#  epoch:16 auc: 0.7550
#  epoch:17 auc: 0.7390
#  epoch:18 auc: 0.7599
#  epoch:19 auc: 0.7563
#  epoch:20 auc: 0.7342
#  epoch:21 auc: 0.7563
# y_pred [[6.6181457e-01]
#  [7.1185827e-04]
#  [7.3003030e-01]
#  ...
#  [8.7829483e-01]
#  [7.8765154e-03]
#  [1.6706684e-01]]
# AUC:  0.7563
# [0.6583, 0.6757, 0.6543, 0.7702, 0.7325, 0.7722, 0.7876, 0.9089, 0.7118, 1.1027, 0.7735, 0.9306, 0.8268, 1.0561, 1.0746, 0.8932, 0.8497, 1.1647, 0.9207, 1.2209, 1.0946, 1.0691]
# 11603
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 3, 10, 56)    224         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 3, 10, 56)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 3, 56)        0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3, 71)        0           batch_normalization_5[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 3, 142)       81224       concatenate_1[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 142)          161880      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           9152        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 254,861
# Trainable params: 254,711
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7028
#  epoch:1 auc: 0.7391
#  epoch:2 auc: 0.7566
#  epoch:3 auc: 0.7747
#  epoch:4 auc: 0.7865
#  epoch:5 auc: 0.7744
#  epoch:6 auc: 0.7926
#  epoch:7 auc: 0.7966
#  epoch:8 auc: 0.7961
#  epoch:9 auc: 0.8029
#  epoch:10 auc: 0.8117
#  epoch:11 auc: 0.8068
#  epoch:12 auc: 0.8206
#  epoch:13 auc: 0.8231
#  epoch:14 auc: 0.8180
#  epoch:15 auc: 0.8084
#  epoch:16 auc: 0.8236
#  epoch:17 auc: 0.8310
#  epoch:18 auc: 0.8202
#  epoch:19 auc: 0.8318
#  epoch:20 auc: 0.8328
#  epoch:21 auc: 0.8270
# y_pred [[7.0210648e-01]
#  [4.9160337e-01]
#  [8.0864197e-01]
#  ...
#  [4.5413318e-01]
#  [2.0406194e-05]
#  [3.4856796e-04]]
# AUC:  0.827
# [0.6536, 0.6151, 0.669, 0.5771, 0.5584, 0.5797, 0.5495, 0.5355, 0.5619, 0.5717, 0.514, 0.5203, 0.5225, 0.4945, 0.4967, 0.7229, 0.4905, 0.6563, 0.5016, 0.4739, 0.6173, 0.5188]
# 11602
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 3, 10, 56)    224         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 3, 10, 56)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 3, 56)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 3, 71)        0           batch_normalization_8[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 3, 142)       81224       concatenate_2[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 142)          161880      bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           9152        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_2[0][0]
# ==================================================================================================
# Total params: 254,861
# Trainable params: 254,711
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7217
#  epoch:1 auc: 0.7942
#  epoch:2 auc: 0.8170
#  epoch:3 auc: 0.8238
#  epoch:4 auc: 0.8397
#  epoch:5 auc: 0.8319
#  epoch:6 auc: 0.8224
#  epoch:7 auc: 0.8467
#  epoch:8 auc: 0.8430
#  epoch:9 auc: 0.8471
#  epoch:10 auc: 0.8480
#  epoch:11 auc: 0.8579
#  epoch:12 auc: 0.8431
#  epoch:13 auc: 0.8633
#  epoch:14 auc: 0.8533
#  epoch:15 auc: 0.8627
#  epoch:16 auc: 0.8747
#  epoch:17 auc: 0.8641
#  epoch:18 auc: 0.8458
#  epoch:19 auc: 0.8565
#  epoch:20 auc: 0.8568
#  epoch:21 auc: 0.8612
# y_pred [[3.9247274e-02]
#  [7.3264241e-03]
#  [9.8233521e-03]
#  ...
#  [2.3279396e-01]
#  [1.8696528e-07]
#  [9.1049026e-07]]
# AUC:  0.8612
# [0.639, 0.5806, 0.5255, 0.5049, 0.5135, 0.5658, 0.525, 0.5051, 0.7637, 0.5591, 0.5081, 0.5004, 0.5178, 0.4786, 0.5965, 0.5667, 0.5248, 0.5885, 0.6489, 0.5791, 0.5143, 0.6845]
# 11602
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 3, 10, 56)    224         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 3, 10, 56)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 3, 56)        0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 3, 71)        0           batch_normalization_11[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 3, 142)       81224       concatenate_3[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 142)          161880      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           9152        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 254,861
# Trainable params: 254,711
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7118
#  epoch:1 auc: 0.7404
#  epoch:2 auc: 0.7647
#  epoch:3 auc: 0.7669
#  epoch:4 auc: 0.7808
#  epoch:5 auc: 0.8028
#  epoch:6 auc: 0.7899
#  epoch:7 auc: 0.8052
#  epoch:8 auc: 0.8081
#  epoch:9 auc: 0.8163
#  epoch:10 auc: 0.8272
#  epoch:11 auc: 0.8129
#  epoch:12 auc: 0.8273
#  epoch:13 auc: 0.8251
#  epoch:14 auc: 0.8216
#  epoch:15 auc: 0.7884
#  epoch:16 auc: 0.7975
#  epoch:17 auc: 0.8458
#  epoch:18 auc: 0.8190
#  epoch:19 auc: 0.8270
#  epoch:20 auc: 0.8417
#  epoch:21 auc: 0.8571
# y_pred [[4.7607705e-01]
#  [8.8880926e-01]
#  [8.4376621e-01]
#  ...
#  [8.0539155e-01]
#  [9.3179941e-04]
#  [2.3020975e-05]]
# AUC:  0.8571
# [0.6552, 0.637, 0.649, 0.572, 0.5951, 0.5785, 0.5902, 0.5374, 0.5895, 0.541, 0.4971, 0.5279, 0.6243, 0.6954, 0.9562, 0.7429, 0.9081, 0.7102, 0.6468, 1.0036, 0.5814, 0.4938]
# 11602
# avg_AUC :  0.8253945633451863
# avg_AUC_2 :  0.825166507758847
#          0         1         2   ...        19        20        21
# 0  0.667044  0.693421  0.725866  ...  0.750209  0.730473  0.759161
# 1  0.702108  0.739198  0.756638  ...  0.831599  0.832696  0.826920
# 2  0.721831  0.794381  0.816944  ...  0.853670  0.855597  0.853073
# 3  0.712482  0.740396  0.764571  ...  0.802979  0.841141  0.855563
#
# [4 rows x 22 columns]
# 0     0.700866
# 1     0.741849
# 2     0.766005
# 3     0.773243
# 4     0.788187
# 5     0.769715
# 6     0.787426
# 7     0.798211
# 8     0.801130
# 9     0.798940
# 10    0.810265
# 11    0.807586
# 12    0.810599
# 13    0.811595
# 14    0.803568
# 15    0.801069
# 16    0.811692
# 17    0.816070
# 18    0.810213
# 19    0.809614
# 20    0.814977
# 21    0.823679
# dtype: float64

# %%
mean_fpr = np.linspace(0,1,100)

# %%
plt.figure(figsize=(15,8))
plt.plot(mean_fpr,mean_tpr_dict_svm['perf+spc+wrd'], color='k',
         label=r'SVM: Mean ROC (AUC = %0.2f)' % (0.7040),
         lw=2, alpha=.8)
plt.plot(mean_fpr,mean_tpr_dict_lg['perf+spc+wrd'], color='y',
         label=r'Logit: Mean ROC (AUC = %0.2f)' % (0.6977),
         lw=2, alpha=.8)
# plt.plot(mean_fpr,mean_tpr_dict_nn['perf+spc+wrd'], color='r',
#          label=r'NeuralNet: Mean ROC (AUC = %0.2f)' % (0.708418330709835),
#          lw=2, alpha=.8)
plt.plot(mean_fpr,h[1], color='g',
         label=r'Deeplearn(t=1): Mean ROC (AUC = %0.2f)' % (0.7049),
         lw=2, alpha=.8)
plt.plot(mean_fpr,h2[1], color='r',
         label=r'Deeplearn(t=2): Mean ROC (AUC = %0.2f)' % (0.7550),
         lw=2, alpha=.8)
plt.plot(mean_fpr,h3[1], color='b',
         label=r'Deeplearn(t=3): Mean ROC (AUC = %0.2f)' % (0.8042),
         lw=2, alpha=.8)
plt.legend(loc="lower right", prop={'size': 15})
plt.title('Quant. Indicators + Overall Change + Word Change: ROC Curve')
plt.show()
# Out:
# Text(0.5, 1.0, 'Quant. Indicators + Overall Change + Word Change: ROC Curve')

# %% [markdown]
# # calculate the predicted proba

# %%
from sklearn.isotonic import IsotonicRegression
import random

# %%
target_data = df_fl[df_fl.cik == 56873]

# %%
target_index = list(target_data.index)

# %%
df_fl_1 = df_fl.drop(target_index)

# %%
fraud_cik = list(set(df_fl_1[df_fl_1.label == 1].cik))
non_fraud_cik = list(set(df_fl_1[df_fl_1.label == 0].cik))

# %%
fraud_cik_1 = random.choices(fraud_cik,k = 25)
non_fraud_cik_1 = random.choices(non_fraud_cik, k =25)

# %%
selected_cik = fraud_cik_1 + non_fraud_cik_1

# %%
test_data = df_fl_1[df_fl_1.cik.isin(selected_cik)]

# %%
test_data.shape
# Out:
# (367, 212)

# %%
train_data = df_fl_1[~df_fl_1.cik.isin(selected_cik)]

# %%
train_data.shape
# Out:
# (53251, 212)

# %%
train_data[train_data.cik == 56873]
# Out:
# Empty DataFrame
# Columns: [cik, y1, y2, s1, window, label, sic_class_x, rsst_acc, ch_rec, ch_inv, soft_asset, ch_cs, ch_roa, issue, aqi, asset_turnover, cfed, depi, gmi, ig, opm, rg, sg, sgee, pastavg5, pastavg3, pastavg1, cr5, cr3, cr1, WeakModal_3_avg, WeakModal_3_dis, WeakModal_3_n, WeakModal_3_new, WeakModal_3_p, WeakModal_3_u, Litigious_3_avg, Litigious_3_dis, Litigious_3_n, Litigious_3_new, Litigious_3_p, Litigious_3_u, StrongModal_3_avg, StrongModal_3_dis, StrongModal_3_n, StrongModal_3_new, StrongModal_3_p, StrongModal_3_u, Negative_3_avg, Negative_3_dis, Negative_3_n, Negative_3_new, Negative_3_p, Negative_3_u, Positive_3_avg, Positive_3_dis, Positive_3_n, Positive_3_new, Positive_3_p, Positive_3_u, Uncertainty_3_avg, Uncertainty_3_dis, Uncertainty_3_n, Uncertainty_3_new, Uncertainty_3_p, Uncertainty_3_u, Negate_3_avg, Negate_3_dis, Negate_3_n, Negate_3_new, Negate_3_p, Negate_3_u, Interrog_3_avg, Interrog_3_dis, Interrog_3_n, Interrog_3_new, Interrog_3_p, Interrog_3_u, Number_3_avg, Number_3_dis, Number_3_n, Number_3_new, Number_3_p, Number_3_u, Quant_3_avg, Quant_3_dis, Quant_3_n, Quant_3_new, Quant_3_p, Quant_3_u, Compare_3_avg, Compare_3_dis, Compare_3_n, Compare_3_new, Compare_3_p, Compare_3_u, Affect_3_avg, Affect_3_dis, Affect_3_n, Affect_3_new, ...]
# Index: []
#
# [0 rows x 212 columns]

# %%
test_data[test_data.cik == 56873]
# Out:
# Empty DataFrame
# Columns: [cik, y1, y2, s1, window, label, sic_class_x, rsst_acc, ch_rec, ch_inv, soft_asset, ch_cs, ch_roa, issue, aqi, asset_turnover, cfed, depi, gmi, ig, opm, rg, sg, sgee, pastavg5, pastavg3, pastavg1, cr5, cr3, cr1, WeakModal_3_avg, WeakModal_3_dis, WeakModal_3_n, WeakModal_3_new, WeakModal_3_p, WeakModal_3_u, Litigious_3_avg, Litigious_3_dis, Litigious_3_n, Litigious_3_new, Litigious_3_p, Litigious_3_u, StrongModal_3_avg, StrongModal_3_dis, StrongModal_3_n, StrongModal_3_new, StrongModal_3_p, StrongModal_3_u, Negative_3_avg, Negative_3_dis, Negative_3_n, Negative_3_new, Negative_3_p, Negative_3_u, Positive_3_avg, Positive_3_dis, Positive_3_n, Positive_3_new, Positive_3_p, Positive_3_u, Uncertainty_3_avg, Uncertainty_3_dis, Uncertainty_3_n, Uncertainty_3_new, Uncertainty_3_p, Uncertainty_3_u, Negate_3_avg, Negate_3_dis, Negate_3_n, Negate_3_new, Negate_3_p, Negate_3_u, Interrog_3_avg, Interrog_3_dis, Interrog_3_n, Interrog_3_new, Interrog_3_p, Interrog_3_u, Number_3_avg, Number_3_dis, Number_3_n, Number_3_new, Number_3_p, Number_3_u, Quant_3_avg, Quant_3_dis, Quant_3_n, Quant_3_new, Quant_3_p, Quant_3_u, Compare_3_avg, Compare_3_dis, Compare_3_n, Compare_3_new, Compare_3_p, Compare_3_u, Affect_3_avg, Affect_3_dis, Affect_3_n, Affect_3_new, ...]
# Index: []
#
# [0 rows x 212 columns]

# %%
train_x = train_data[v_perf +v_1 +selected_new_all]
train_y = train_data['label']
test_x = test_data[v_perf +v_1 +selected_new_all]
test_y = test_data['label']

# %%
svm = LinearSVC(class_weight = {0:1, 1:200})
svm.fit(train_x, train_y)
pickle.dump(svm, open('svm_fordisplay', 'wb'))
decision_values = svm.decision_function(test_x)
auc_score_svm = roc_auc_score(test_y, decision_values)
print(auc_score_svm)
# Out:
# LinearSVC(C=1.0, class_weight={0: 1, 1: 200}, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)
# 0.7377698667891593

# %%
prob_target = svm.decision_function(target_data[v_perf +v_1 +selected_new_all])

# %%
prob_target
# Out:
# array([-0.56175935, -0.41649336, -0.67245259, -0.36471707, -0.17145531,
#        -0.54259997, -0.85336318, -0.62310378, -0.8858555 , -1.03192812,
#        -1.02311428, -1.31782147, -0.82593878, -0.80730556, -1.01182286,
#        -1.19717493, -1.12341224])

# %%
lg = LogisticRegression(class_weight = {0:1, 1:200})
lg.fit(decision_values.reshape(-1,1),test_y)
op_list_svm_t_lg = lg.predict_proba(prob_target.reshape(-1,1))
# Out:
# LogisticRegression(C=1.0, class_weight={0: 1, 1: 200}, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
op_list_svm_t_lg
# Out:
# array([[0.04123083, 0.95876917],
#        [0.0270635 , 0.9729365 ],
#        [0.05654655, 0.94345345],
#        [0.02326158, 0.97673842],
#        [0.01316385, 0.98683615],
#        [0.03901828, 0.96098172],
#        [0.09347607, 0.90652393],
#        [0.04914972, 0.95085028],
#        [0.1020672 , 0.8979328 ],
#        [0.14977385, 0.85022615],
#        [0.14643882, 0.85356118],
#        [0.29339541, 0.70660459],
#        [0.08673562, 0.91326438],
#        [0.08241   , 0.91759   ],
#        [0.14225645, 0.85774355],
#        [0.22429984, 0.77570016],
#        [0.18816088, 0.81183912]])

# %%
ir = IsotonicRegression()
ir.fit(decision_values,test_y)
op_list_svm_t_ir = ir.predict(prob_target)
# Out:
# IsotonicRegression(increasing=True, out_of_bounds='nan', y_max=None, y_min=None)

# %%
op_list_svm_t_ir
# Out:
# array([0.10344828, 0.12765957, 0.07936508, 0.21333333, 0.25      ,
#        0.10344828, 0.06818182, 0.07936508, 0.06818182, 0.        ,
#        0.        , 0.        , 0.06818182, 0.06818182, 0.        ,
#        0.        , 0.        ])

# %%
w = 3
perf_cols =  v_1 + v_perf
words_cols = selected_new_all_sorted
label = 'label'
h3_t = cross_val(train_data, 'label', \
          perf_cols,\
          words_cols, \
          'model_tcn_w3_fordisplay',w, \
          filters = 56)
# Out:
# init A shape:  (53635, 166)
# (39123, 3, 15) (39123, 3, 10, 4) 341.0
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 3, 19, 4)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 3, 10, 56)    2240        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 3, 10, 56)    224         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 3, 10, 56)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 3, 1, 56)     0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 3, 56)        0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3, 71)        0           batch_normalization_2[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 3, 174)       110664      concatenate[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           2816        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout[0][0]
# ==================================================================================================
# Total params: 207,229
# Trainable params: 207,079
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7140
#  epoch:1 auc: 0.7410
#  epoch:2 auc: 0.7599
#  epoch:3 auc: 0.7606
#  epoch:4 auc: 0.7637
#  epoch:5 auc: 0.7592
#  epoch:6 auc: 0.7694
#  epoch:7 auc: 0.7781
#  epoch:8 auc: 0.7772
#  epoch:9 auc: 0.7723
#  epoch:10 auc: 0.7906
#  epoch:11 auc: 0.7863
# y_pred [[0.9602585 ]
#  [0.1802975 ]
#  [0.37031516]
#  ...
#  [0.00342962]
#  [0.28380746]
#  [0.13355744]]
# AUC:  0.7863
# [0.6706, 0.6279, 0.6086, 0.6029, 0.5761, 0.6101, 0.7217, 0.7196, 0.7129, 1.0491, 0.6625, 0.6486]
# 9781
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 3, 10, 56)    224         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 3, 10, 56)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 3, 56)        0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3, 71)        0           batch_normalization_5[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 3, 174)       110664      concatenate_1[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           2816        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_1[0][0]
# ==================================================================================================
# Total params: 207,229
# Trainable params: 207,079
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7008
#  epoch:1 auc: 0.7202
#  epoch:2 auc: 0.7599
#  epoch:3 auc: 0.7685
#  epoch:4 auc: 0.7696
#  epoch:5 auc: 0.7953
#  epoch:6 auc: 0.7876
#  epoch:7 auc: 0.8126
#  epoch:8 auc: 0.8043
#  epoch:9 auc: 0.8158
#  epoch:10 auc: 0.8085
#  epoch:11 auc: 0.8076
# y_pred [[0.70565045]
#  [0.9387306 ]
#  [0.31781337]
#  ...
#  [0.0026933 ]
#  [0.5178203 ]
#  [0.00356758]]
# AUC:  0.8076
# [0.6646, 0.6232, 0.8732, 0.6727, 0.5852, 0.5673, 0.5557, 0.8607, 0.748, 0.5551, 1.2553, 0.6262]
# 9781
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 3, 10, 56)    224         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 3, 10, 56)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 3, 56)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 3, 71)        0           batch_normalization_8[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 3, 174)       110664      concatenate_2[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           2816        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_2[0][0]
# ==================================================================================================
# Total params: 207,229
# Trainable params: 207,079
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  86.0 test_y 86.0 train_y 255.0
#  epoch:0 auc: 0.6843
#  epoch:1 auc: 0.7297
#  epoch:2 auc: 0.7599
#  epoch:3 auc: 0.7538
#  epoch:4 auc: 0.7733
#  epoch:5 auc: 0.8024
#  epoch:6 auc: 0.7862
#  epoch:7 auc: 0.8112
#  epoch:8 auc: 0.7931
#  epoch:9 auc: 0.8084
#  epoch:10 auc: 0.8072
#  epoch:11 auc: 0.8087
# y_pred [[3.1021148e-01]
#  [2.8573245e-01]
#  [1.3689810e-01]
#  ...
#  [1.8091798e-03]
#  [3.0470192e-03]
#  [7.2785821e-05]]
# AUC:  0.8087
# [0.6638, 0.614, 0.6398, 0.6186, 0.6263, 0.6158, 0.7232, 0.674, 0.7006, 0.5946, 0.6747, 1.1167]
# 9781
# shape after padding: (None, 3, 19, 4)
# conv shape: (None, 3, 10, 56)
# pool shape: (None, 3, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 3, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 3, 19, 4)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 3, 10, 56)    2240        zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 3, 10, 56)    224         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 3, 10, 56)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 3, 1, 56)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 3, 56)        0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 3, 71)        0           batch_normalization_11[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 3, 174)       110664      concatenate_3[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           2816        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_3[0][0]
# ==================================================================================================
# Total params: 207,229
# Trainable params: 207,079
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7021
#  epoch:1 auc: 0.7042
#  epoch:2 auc: 0.7451
#  epoch:3 auc: 0.7659
#  epoch:4 auc: 0.7396
#  epoch:5 auc: 0.7603
#  epoch:6 auc: 0.7738
#  epoch:7 auc: 0.7716
#  epoch:8 auc: 0.7570
#  epoch:9 auc: 0.7462
#  epoch:10 auc: 0.7596
#  epoch:11 auc: 0.7492
# y_pred [[1.5919536e-02]
#  [1.3679230e-01]
#  [2.5434703e-02]
#  ...
#  [5.1448541e-07]
#  [1.1721779e-05]
#  [1.2119085e-02]]
# AUC:  0.7492
# [0.674, 0.6827, 0.6526, 0.571, 0.6237, 0.654, 0.5784, 0.6387, 0.7745, 1.3443, 1.1647, 1.3065]
# 9780
# avg_AUC :  0.7879416936304351
# avg_AUC_2 :  0.7876400806975362
#          0         1         2   ...        9         10        11
# 0  0.710842  0.740732  0.759553  ...  0.768802  0.790354  0.786254
# 1  0.701399  0.720076  0.760847  ...  0.816044  0.790214  0.807507
# 2  0.683563  0.729587  0.759801  ...  0.807370  0.805988  0.792528
# 3  0.702318  0.704526  0.745001  ...  0.734399  0.748603  0.738467
#
# [4 rows x 12 columns]
# 0     0.699530
# 1     0.723730
# 2     0.756301
# 3     0.762140
# 4     0.761482
# 5     0.779285
# 6     0.779202
# 7     0.790093
# 8     0.779418
# 9     0.781654
# 10    0.783790
# 11    0.781189
# dtype: float64

# %%
from keras.models import load_model

# %%
model_dl = load_model('model_tcn_w3_fordisplay_3.h5')

# %%
A_perf_test, A_words_test, Y_test = shift_data(test_data, 3, v_perf+v_1, selected_new_all_sorted, 'label')
A_perf_t, A_words_t, Y_t = shift_data(target_data, 3, v_perf+v_1, selected_new_all_sorted, 'label')
# Out:
# init A shape:  (367, 166)
# (274, 3, 15) (274, 3, 10, 4) 38.0
# init A shape:  (17, 166)
# (15, 3, 15) (15, 3, 10, 4) 2.0

# %%
op_list_dl_test = model_dl.predict([A_perf_test, A_words_test])
#lop_list_dl = op_list_dl[:,0]

op_list_dl_t = model_dl.predict([A_perf_t, A_words_t])
#op_list_dl_t = op_list_dl_t[:,0]

# %%
ir = IsotonicRegression()
ir.fit(op_list_dl_test[:,0],Y_test)
op_list_dl_t_ir = ir.predict(op_list_dl_t[:,0])
# Out:
# IsotonicRegression(increasing=True, out_of_bounds='nan', y_max=None, y_min=None)

# %%
op_list_dl_t_ir = [None, None] + op_list_dl_t_ir.tolist()

# %%
lg = LogisticRegression(class_weight = {0:1, 1:200})
lg.fit(op_list_dl_test,Y_test)
op_list_dl_t_lg = lg.predict_proba(op_list_dl_t)
# Out:
# LogisticRegression(C=1.0, class_weight={0: 1, 1: 200}, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
op_list_dl_t_lg[:,1]
# Out:
# array([0.96987632, 0.96987688, 0.96986869, 0.969862  , 0.96986524,
#        0.96986278, 0.96985983, 0.96985873, 0.96985821, 0.96985809,
#        0.96985839, 0.96985878, 0.96985887, 0.96985932, 0.96985865])

# %%
target_data.y2
# Out:
# 4485    1996.0
# 4486    1997.0
# 4487    1998.0
# 4488    1999.0
# 4489    2000.0
# 4490    2001.0
# 4491    2002.0
# 4492    2003.0
# 4493    2004.0
# 4494    2005.0
# 4495    2006.0
# 4496    2007.0
# 4497    2008.0
# 4498    2009.0
# 4499    2010.0
# 4500    2011.0
# 4501    2012.0
# Name: y2, dtype: float64

# %%
target_data.y1
# Out:
# 4485    1995.0
# 4486    1996.0
# 4487    1997.0
# 4488    1998.0
# 4489    1999.0
# 4490    2000.0
# 4491    2001.0
# 4492    2002.0
# 4493    2003.0
# 4494    2004.0
# 4495    2005.0
# 4496    2006.0
# 4497    2007.0
# 4498    2008.0
# 4499    2009.0
# 4500    2010.0
# 4501    2011.0
# Name: y1, dtype: float64

# %%
target_res_tb = pd.DataFrame({'year':target_data.y2, 's1':target_data.s1, 'svm':op_list_svm_t_ir, 'dl':op_list_dl_t_ir} )

# %%
target_res_tb.to_csv('target_res_tb_fordisplay.csv',index = False)

# %%
fig, ax1 = plt.subplots(2)
fig.set_figwidth(15)
fig.set_figheight(8)

fontP = FontProperties()
fontP.set_size('large')

ax2 = ax1[0].twinx()
ax3 = ax1[1].twinx()
#ax4 = ax1.twinx()

#ax3.spines['right'].set_position(('outward', 60))
#ax4.spines['right'].set_position(('outward', 60))

ax2.plot(target_data.y2, target_data.s1, linestyle=(0, (1, 1)), c= 'y' , label = 'Overall Similarity')
ax3.plot(target_data.y2, target_data.s1, linestyle=(0, (1, 1)), c= 'y' ) #
ax1[0].plot(target_data.y2, op_list_svm_t_ir, marker='x', linewidth=2.0, c = 'b', linestyle=(0, (3, 1, 1, 1)), label = 'SVM')
#ax2.plot(target_data.y2, op_list_lg_t, linewidth=2.0,marker='.', c = 'g', linestyle=(0, (3, 1, 1, 1, 1, 1)), label = 'LogitReg')
#ax3.plot(target_data.y2, op_list_dl2, c= 'm' , marker='x', linestyle=(0, (5, 1)), label = 'DeepLearning(T=2)')
ax1[1].plot(target_data.y2, op_list_dl_t_ir, c= 'r' , marker='o', label = 'DeepLearning(T=3)')
ax2.set_ylabel('Overall Similarity')
ax3.set_ylabel('Overall Similarity')
ax1[0].set_ylabel('Predicted Proba')
ax1[1].set_ylabel('Predicted Proba')
#ax3.set_ylabel('Predicted Proba of Deeplearning(T=2)')
#ax4.set_ylabel('Predicted Proba for Deeplearning(T=3)')

#lt.xticks(mean_s_tb.index)
# ax1.plot(tbtb_temp.y2, temp_tb.nn_proba, linewidth=2.0, c = 'b',label = 'neualnet')
# ax2.plot(temp_tb.y2, temp_tb.s1, linewidth=2.0, c = 'g',label = 'overall similarity')
fig.legend(loc="best", prop=fontP,  ncol=5)
# ax1.set_ylabel('similarity score for fraud case')
# ax2.set_ylabel('similarity score for avg. overall similarity')

#ax1.scatter(target_data[target_data.label == 1].y2, target_data[target_data.label == 1].s1, c = 'r')
# ax1.scatter(temp_tb[temp_tb.label == 1].y2, temp_tb[temp_tb.label == 1].nn_proba, c = 'b')
# ax2.scatter(temp_tb[temp_tb.label == 1].y2, temp_tb[temp_tb.label == 1].s1, c = 'g')
ax1[0].set_xticks(target_data.y2)
ax1[1].set_xticks(target_data.y2)
ax1[0].set_title('Prediction Result of SVM')
ax1[1].set_title('Prediction Result of DeepLearning')
# ax1[0].set_xticklabels(target_data.y2)
# ax1[1].set_xticklabels(target_data.y2)
# Out:
# Text(0, 0.5, 'Overall Similarity')
# Text(0, 0.5, 'Overall Similarity')
# Text(0, 0.5, 'Predicted Proba')
# Text(0, 0.5, 'Predicted Proba')
# [<matplotlib.axis.XTick at 0x7fdce522cf50>,
#  <matplotlib.axis.XTick at 0x7fdce522c290>,
#  <matplotlib.axis.XTick at 0x7fdce522cd50>,
#  <matplotlib.axis.XTick at 0x7fdce50bf110>,
#  <matplotlib.axis.XTick at 0x7fdce50e4910>,
#  <matplotlib.axis.XTick at 0x7fdce50e4e50>,
#  <matplotlib.axis.XTick at 0x7fdce50da410>,
#  <matplotlib.axis.XTick at 0x7fdce50da950>,
#  <matplotlib.axis.XTick at 0x7fdce50dae90>,
#  <matplotlib.axis.XTick at 0x7fdce50bec90>,
#  <matplotlib.axis.XTick at 0x7fdce50be490>,
#  <matplotlib.axis.XTick at 0x7fdce50be110>,
#  <matplotlib.axis.XTick at 0x7fdce50be910>,
#  <matplotlib.axis.XTick at 0x7fdce50da290>,
#  <matplotlib.axis.XTick at 0x7fdce50f8350>,
#  <matplotlib.axis.XTick at 0x7fdcdfc29610>,
#  <matplotlib.axis.XTick at 0x7fdcdfc29b50>]
# [<matplotlib.axis.XTick at 0x7fdce547f310>,
#  <matplotlib.axis.XTick at 0x7fdce547f2d0>,
#  <matplotlib.axis.XTick at 0x7fdce547f090>,
#  <matplotlib.axis.XTick at 0x7fdcdfc038d0>,
#  <matplotlib.axis.XTick at 0x7fdcdfc03e50>,
#  <matplotlib.axis.XTick at 0x7fdcdfc29f50>,
#  <matplotlib.axis.XTick at 0x7fdce50da490>,
#  <matplotlib.axis.XTick at 0x7fdcdfc32350>,
#  <matplotlib.axis.XTick at 0x7fdcdfc32890>,
#  <matplotlib.axis.XTick at 0x7fdcdfc32dd0>,
#  <matplotlib.axis.XTick at 0x7fdcdfbfde10>,
#  <matplotlib.axis.XTick at 0x7fdcdfbfde50>,
#  <matplotlib.axis.XTick at 0x7fdcdfbfd110>,
#  <matplotlib.axis.XTick at 0x7fdcdfbfd810>,
#  <matplotlib.axis.XTick at 0x7fdcdfc29fd0>,
#  <matplotlib.axis.XTick at 0x7fdcdfc03790>,
#  <matplotlib.axis.XTick at 0x7fdcdfc0b150>]
# Text(0.5, 1.0, 'Prediction Result of SVM')
# Text(0.5, 1.0, 'Prediction Result of DeepLearning')

# %%
target_wrds = target_data[v_1 +selected_new_all_sorted + ['y2']]

# %%
target_wrds
# Out:
#             s1  WeakModal_3_p  ...  Litigious_3_dis      y2
# 4485  0.685423       0.000000  ...         0.002315  1996.0
# 4486  0.676390       0.115385  ...         0.001276  1997.0
# 4487  0.487491       0.150000  ...         0.000905  1998.0
# 4488  0.539512       0.050000  ...         0.007789  1999.0
# 4489  0.466077       0.136364  ...         0.001563  2000.0
# 4490  0.791387       0.068182  ...         0.000000  2001.0
# 4491  0.672189       0.094118  ...         0.005372  2002.0
# 4492  0.662140       0.017544  ...         0.004264  2003.0
# 4493  0.689602       0.068966  ...         0.003719  2004.0
# 4494  0.772592       0.070866  ...         0.004658  2005.0
# 4495  0.810547       0.039370  ...         0.002079  2006.0
# 4496  0.802272       0.046512  ...         0.000314  2007.0
# 4497  0.821680       0.031250  ...         0.004760  2008.0
# 4498  0.822290       0.015625  ...         0.003442  2009.0
# 4499  0.880014       0.038168  ...         0.004306  2010.0
# 4500  0.880352       0.030534  ...         0.007289  2011.0
# 4501  0.880352       0.029630  ...         0.011259  2012.0
#
# [17 rows x 42 columns]

# %%
fig, ax1 = plt.subplots(6)
fig.set_figwidth(15)
fig.set_figheight(24)

fontP = FontProperties()
fontP.set_size('large')

#ax2 = ax1[0].twinx()
#ax3 = ax1[1].twinx()
#ax4 = ax1.twinx()

#ax3.spines['right'].set_position(('outward', 60))
#ax4.spines['right'].set_position(('outward', 60))

#ax2.plot(target_wrds.y2, target_wrds.s1, linestyle=(0, (1, 1)), c= 'y' , label = 'Overall Similarity')
#ax3.plot(target_wrds.y2, target_wrds.s1, linestyle=(0, (1, 1)), c= 'y' ) #
ax1[0].plot(target_wrds.y2, target_wrds.WeakModal_3_new, marker='x', c = 'r')
#ax2.plot(target_data.y2, op_list_lg_t, linewidth=2.0,marker='.', c = 'g', linestyle=(0, (3, 1, 1, 1, 1, 1)), label = 'LogitReg')
#ax3.plot(target_data.y2, op_list_dl2, c= 'm' , marker='x', linestyle=(0, (5, 1)), label = 'DeepLearning(T=2)')
ax1[1].plot(target_wrds.y2, target_wrds.WeakModal_3_dis, c= 'r' , marker='x')
ax1[2].plot(target_wrds.y2, target_wrds.Compare_3_p, c= 'r' , marker='x')
ax1[3].plot(target_wrds.y2, target_wrds.Compare_3_n, c= 'r' , marker='x')
ax1[4].plot(target_wrds.y2, target_wrds.Negative_3_new, c= 'r' , marker='x')
ax1[5].plot(target_wrds.y2, target_wrds.Positive_3_new, c= 'r' , marker='x')
#ax2.set_ylabel('Overall Similarity')
#ax3.set_ylabel('Overall Similarity')
ax1[0].set_ylabel('Deleted Content with Weak Modal')
ax1[1].set_ylabel('Added Content with Weak Modal')
ax1[2].set_ylabel('Increased Content with Comparision')
ax1[3].set_ylabel('Decreased Content with Comparison')
ax1[4].set_ylabel('Added Content with Positive')
ax1[5].set_ylabel('Added Content with Negative')
#ax3.set_ylabel('Predicted Proba of Deeplearning(T=2)')
#ax4.set_ylabel('Predicted Proba for Deeplearning(T=3)')

#lt.xticks(mean_s_tb.index)
# ax1.plot(tbtb_temp.y2, temp_tb.nn_proba, linewidth=2.0, c = 'b',label = 'neualnet')
# ax2.plot(temp_tb.y2, temp_tb.s1, linewidth=2.0, c = 'g',label = 'overall similarity')
fig.legend(loc="best", prop=fontP,  ncol=5)
# ax1.set_ylabel('similarity score for fraud case')
# ax2.set_ylabel('similarity score for avg. overall similarity')

#ax1.scatter(target_data[target_data.label == 1].y2, target_data[target_data.label == 1].s1, c = 'r')
# ax1.scatter(temp_tb[temp_tb.label == 1].y2, temp_tb[temp_tb.label == 1].nn_proba, c = 'b')
# ax2.scatter(temp_tb[temp_tb.label == 1].y2, temp_tb[temp_tb.label == 1].s1, c = 'g')
ax1[0].set_xticks(target_wrds.y2)
ax1[1].set_xticks(target_wrds.y2)
ax1[2].set_xticks(target_wrds.y2)
ax1[3].set_xticks(target_wrds.y2)
ax1[4].set_xticks(target_wrds.y2)
ax1[5].set_xticks(target_wrds.y2)
# ax1[0].set_title('Prediction Result of SVM')
# ax1[1].set_title('Prediction Result of DeepLearning')
# ax1[0].set_xticklabels(target_data.y2)
# ax1[1].set_xticklabels(target_data.y2)
# Out:
# Text(0, 0.5, 'Deleted Content with Weak Modal')
# Text(0, 0.5, 'Added Content with Weak Modal')
# Text(0, 0.5, 'Increased Content with Comparision')
# Text(0, 0.5, 'Decreased Content with Comparison')
# Text(0, 0.5, 'Added Content with Positive')
# Text(0, 0.5, 'Added Content with Negative')
# No handles with labels found to put in legend.
# [<matplotlib.axis.XTick at 0x7f8f71a43c90>,
#  <matplotlib.axis.XTick at 0x7f8f71a43cd0>,
#  <matplotlib.axis.XTick at 0x7f8f71a43ad0>,
#  <matplotlib.axis.XTick at 0x7f8f72837250>,
#  <matplotlib.axis.XTick at 0x7f8f7503fc50>,
#  <matplotlib.axis.XTick at 0x7f8f75204990>,
#  <matplotlib.axis.XTick at 0x7f8f72f8f210>,
#  <matplotlib.axis.XTick at 0x7f8f727d3310>,
#  <matplotlib.axis.XTick at 0x7f8f727e0410>,
#  <matplotlib.axis.XTick at 0x7f8f72790e50>,
#  <matplotlib.axis.XTick at 0x7f8f72797750>,
#  <matplotlib.axis.XTick at 0x7f8f72e9fbd0>,
#  <matplotlib.axis.XTick at 0x7f8f727efe10>,
#  <matplotlib.axis.XTick at 0x7f8f72837710>,
#  <matplotlib.axis.XTick at 0x7f8f72e44350>,
#  <matplotlib.axis.XTick at 0x7f8f727fb8d0>,
#  <matplotlib.axis.XTick at 0x7f8f72eb4050>]
# [<matplotlib.axis.XTick at 0x7f8f71989a90>,
#  <matplotlib.axis.XTick at 0x7f8f71989a50>,
#  <matplotlib.axis.XTick at 0x7f8f71989750>,
#  <matplotlib.axis.XTick at 0x7f8f72fe75d0>,
#  <matplotlib.axis.XTick at 0x7f8f72e99690>,
#  <matplotlib.axis.XTick at 0x7f8f7514c8d0>,
#  <matplotlib.axis.XTick at 0x7f8f727fbd90>,
#  <matplotlib.axis.XTick at 0x7f8f750b9ed0>,
#  <matplotlib.axis.XTick at 0x7f8f730cd6d0>,
#  <matplotlib.axis.XTick at 0x7f8f730cd110>,
#  <matplotlib.axis.XTick at 0x7f8f72786410>,
#  <matplotlib.axis.XTick at 0x7f8f74f77810>,
#  <matplotlib.axis.XTick at 0x7f8f74f77ad0>,
#  <matplotlib.axis.XTick at 0x7f8f72797cd0>,
#  <matplotlib.axis.XTick at 0x7f8f74fe9cd0>,
#  <matplotlib.axis.XTick at 0x7f8f731c60d0>,
#  <matplotlib.axis.XTick at 0x7f8f730f6c50>]
# [<matplotlib.axis.XTick at 0x7f8f719c0050>,
#  <matplotlib.axis.XTick at 0x7f8f719bafd0>,
#  <matplotlib.axis.XTick at 0x7f8f719bacd0>,
#  <matplotlib.axis.XTick at 0x7f8f72753790>,
#  <matplotlib.axis.XTick at 0x7f8f7a4fdf10>,
#  <matplotlib.axis.XTick at 0x7f8f75416ad0>,
#  <matplotlib.axis.XTick at 0x7f8f750b0ed0>,
#  <matplotlib.axis.XTick at 0x7f8f75416150>,
#  <matplotlib.axis.XTick at 0x7f8f751c0750>,
#  <matplotlib.axis.XTick at 0x7f8f726eebd0>,
#  <matplotlib.axis.XTick at 0x7f8f72700950>,
#  <matplotlib.axis.XTick at 0x7f8f726b8090>,
#  <matplotlib.axis.XTick at 0x7f8f72700810>,
#  <matplotlib.axis.XTick at 0x7f8f730e8b10>,
#  <matplotlib.axis.XTick at 0x7f8f726b5150>,
#  <matplotlib.axis.XTick at 0x7f8f726b5d10>,
#  <matplotlib.axis.XTick at 0x7f8f7266e3d0>]
# [<matplotlib.axis.XTick at 0x7f8f719755d0>,
#  <matplotlib.axis.XTick at 0x7f8f71975590>,
#  <matplotlib.axis.XTick at 0x7f8f71975350>,
#  <matplotlib.axis.XTick at 0x7f8f72656c90>,
#  <matplotlib.axis.XTick at 0x7f8f72625d50>,
#  <matplotlib.axis.XTick at 0x7f8f7262ab10>,
#  <matplotlib.axis.XTick at 0x7f8f72662b10>,
#  <matplotlib.axis.XTick at 0x7f8f72641b10>,
#  <matplotlib.axis.XTick at 0x7f8f725d8d50>,
#  <matplotlib.axis.XTick at 0x7f8f72ddc310>,
#  <matplotlib.axis.XTick at 0x7f8f725e4e10>,
#  <matplotlib.axis.XTick at 0x7f8f751c4b90>,
#  <matplotlib.axis.XTick at 0x7f8f725e4c50>,
#  <matplotlib.axis.XTick at 0x7f8f725e4ed0>,
#  <matplotlib.axis.XTick at 0x7f8f724034d0>,
#  <matplotlib.axis.XTick at 0x7f8f724cfd50>,
#  <matplotlib.axis.XTick at 0x7f8f724cc110>]
# [<matplotlib.axis.XTick at 0x7f8f7192ab50>,
#  <matplotlib.axis.XTick at 0x7f8f7192ab10>,
#  <matplotlib.axis.XTick at 0x7f8f725e8390>,
#  <matplotlib.axis.XTick at 0x7f8f724ee510>,
#  <matplotlib.axis.XTick at 0x7f8f724e6b10>,
#  <matplotlib.axis.XTick at 0x7f8f724e6cd0>,
#  <matplotlib.axis.XTick at 0x7f8f724cc590>,
#  <matplotlib.axis.XTick at 0x7f8f72ddc4d0>,
#  <matplotlib.axis.XTick at 0x7f8f7249d190>,
#  <matplotlib.axis.XTick at 0x7f8f724dfc50>,
#  <matplotlib.axis.XTick at 0x7f8f7248ed90>,
#  <matplotlib.axis.XTick at 0x7f8f724c3950>,
#  <matplotlib.axis.XTick at 0x7f8f724ab110>,
#  <matplotlib.axis.XTick at 0x7f8f724cc290>,
#  <matplotlib.axis.XTick at 0x7f8f7280aa10>,
#  <matplotlib.axis.XTick at 0x7f8f7245ec50>,
#  <matplotlib.axis.XTick at 0x7f8f72393d10>]
# [<matplotlib.axis.XTick at 0x7f8f718ea1d0>,
#  <matplotlib.axis.XTick at 0x7f8f718ea190>,
#  <matplotlib.axis.XTick at 0x7f8f718e4fd0>,
#  <matplotlib.axis.XTick at 0x7f8f72392890>,
#  <matplotlib.axis.XTick at 0x7f8f7238fd90>,
#  <matplotlib.axis.XTick at 0x7f8f72392750>,
#  <matplotlib.axis.XTick at 0x7f8f72475f10>,
#  <matplotlib.axis.XTick at 0x7f8f7249d310>,
#  <matplotlib.axis.XTick at 0x7f8f71aab790>,
#  <matplotlib.axis.XTick at 0x7f8f71abd510>,
#  <matplotlib.axis.XTick at 0x7f8f71a4ee90>,
#  <matplotlib.axis.XTick at 0x7f8f71a48bd0>,
#  <matplotlib.axis.XTick at 0x7f8f71a4e210>,
#  <matplotlib.axis.XTick at 0x7f8f72396e10>,
#  <matplotlib.axis.XTick at 0x7f8f7238f690>,
#  <matplotlib.axis.XTick at 0x7f8f71a67850>,
#  <matplotlib.axis.XTick at 0x7f8f71a767d0>]

# %%
fig, ax1 = plt.subplots()
fig.set_figwidth(15)
fig.set_figheight(5)

fontP = FontProperties()
fontP.set_size('large')

ax2 = ax1.twinx()
#ax3 = ax1.twinx()
#ax4 = ax1.twinx()

#ax3.spines['right'].set_position(('outward', 60))
#ax4.spines['right'].set_position(('outward', 60))

ax1.plot(target_data.y2, target_data.s1, linestyle=(0, (1, 1)), c= 'y' , label = 'Overall Similarity') #
ax2.plot(target_data.y2, op_list_svm_t_lg[:,1], linewidth=2.0, c = 'b', linestyle=(0, (3, 1, 1, 1)), label = 'SVM')
#ax2.plot(target_data.y2, op_list_lg_t, linewidth=2.0,marker='.', c = 'g', linestyle=(0, (3, 1, 1, 1, 1, 1)), label = 'LogitReg')
#ax3.plot(target_data.y2, op_list_dl2, c= 'm' , marker='x', linestyle=(0, (5, 1)), label = 'DeepLearning(T=2)')
ax2.plot(target_data.y2, [None,None] + op_list_dl_t_lg[:,1].tolist() , c= 'r' , marker='o', label = 'DeepLearning(T=3)')
ax1.set_ylabel('Overall Similarity')
ax2.set_ylabel('Predicted Proba')
#ax3.set_ylabel('Predicted Proba of Deeplearning(T=2)')
#ax4.set_ylabel('Predicted Proba for Deeplearning(T=3)')

#lt.xticks(mean_s_tb.index)
# ax1.plot(tbtb_temp.y2, temp_tb.nn_proba, linewidth=2.0, c = 'b',label = 'neualnet')
# ax2.plot(temp_tb.y2, temp_tb.s1, linewidth=2.0, c = 'g',label = 'overall similarity')
fig.legend(loc="best", prop=fontP,  ncol=5)
# ax1.set_ylabel('similarity score for fraud case')
# ax2.set_ylabel('similarity score for avg. overall similarity')

#ax1.scatter(target_data[target_data.label == 1].y2, target_data[target_data.label == 1].s1, c = 'r')
# ax1.scatter(temp_tb[temp_tb.label == 1].y2, temp_tb[temp_tb.label == 1].nn_proba, c = 'b')
# ax2.scatter(temp_tb[temp_tb.label == 1].y2, temp_tb[temp_tb.label == 1].s1, c = 'g')

plt.xticks(target_data.y2)
# Out:
# Text(0, 0.5, 'Overall Similarity')
# Text(0, 0.5, 'Predicted Proba')
# ([<matplotlib.axis.XTick at 0x7fdce0384590>,
#   <matplotlib.axis.XTick at 0x7fdce03846d0>,
#   <matplotlib.axis.XTick at 0x7fdce03b9210>,
#   <matplotlib.axis.XTick at 0x7fdce03944d0>,
#   <matplotlib.axis.XTick at 0x7fdce0345f50>,
#   <matplotlib.axis.XTick at 0x7fdce0358510>,
#   <matplotlib.axis.XTick at 0x7fdce0358a90>,
#   <matplotlib.axis.XTick at 0x7fdce0358b90>,
#   <matplotlib.axis.XTick at 0x7fdce0361550>,
#   <matplotlib.axis.XTick at 0x7fdce0361a90>,
#   <matplotlib.axis.XTick at 0x7fdce0361950>,
#   <matplotlib.axis.XTick at 0x7fdce0367510>,
#   <matplotlib.axis.XTick at 0x7fdce0361290>,
#   <matplotlib.axis.XTick at 0x7fdce0358110>,
#   <matplotlib.axis.XTick at 0x7fdce03678d0>,
#   <matplotlib.axis.XTick at 0x7fdce0367050>,
#   <matplotlib.axis.XTick at 0x7fdce0370290>],
#  <a list of 17 Text major ticklabel objects>)

# %%
# ### SVM
loaded_model = pickle.load(open('svm_perf+spc+wrd_4', 'rb'))

prob = loaded_model.decision_function(data[v_perf +v_1 +selected_new_all])
prob_1 = loaded_model.decision_function(target_data[v_perf +v_1 +selected_new_all])

prob = prob.reshape(-1, 1)
prob_1 = prob_1.reshape(-1, 1)

ir = LogisticRegression(class_weight = {0:1, 1:200})
ir.fit(prob,data['label'])
op_list_svm_t = ir.predict_proba(prob_1)

# def convert_p(x):
#   r = 1/(1 + math.exp(-x))
#   return r


# op_list = []
# for p in prob:
#   op = convert_p(p)
#   op_list.append(op)
# Out:
# LogisticRegression(C=1.0, class_weight={0: 1, 1: 200}, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
prob
# Out:
# array([[-0.10902747],
#        [ 0.10220726],
#        [ 0.27376173],
#        ...,
#        [-0.60560191],
#        [-0.40211444],
#        [-0.40616745]])

# %%
op_list_svm_t[:,1]
# Out:
# array([0.4971907 , 0.64878813, 0.63465469, 0.65758829, 0.82666658,
#        0.56598724, 0.33879334, 0.51213757, 0.33127903, 0.2736542 ,
#        0.29794971, 0.13874033, 0.40208689, 0.3893303 , 0.28820185,
#        0.20863494, 0.2466696 ])

# %%
op_list_svm_t
# Out:
# array([0.00607367, 0.00947368, 0.00970874, 0.00970874, 0.02838137,
#        0.00607367, 0.0029164 , 0.00313589, 0.0029164 , 0.0029164 ,
#        0.0029164 , 0.        , 0.0029164 , 0.0029164 , 0.00177117,
#        0.00177117, 0.00177117])

# %%
# def lg_3( data, vs, label, target_index):

#     data_1 = data.drop(target_index)

#     columns_fl = vs
#     data_target = data_1.loc[:,columns_fl + [label]]

#     #data for targeted individual
#     indiv_target = data.loc[target_index,columns_fl]

#     tprs = []
#     auc_list = []
#     mean_fpr = np.linspace(0,1,100)
    
#     class_report = []
#     sum_pred_list = []
#     kf = StratifiedKFold(n_splits = 4, shuffle = True)
#     c = 0
#     data_target = data[columns_fl + [label]]
#     data_target = data_target.dropna()
#     data_target = data_target.reset_index(drop = True)


#     tprs = []
#     auc_list = []
#     target_proba_list = []
#     mean_fpr = np.linspace(0,1,100)
    
#     class_report = []
#     sum_pred_list = []
#     kf = StratifiedKFold(n_splits = 4, shuffle = True)
#     c = 0
#     # data_target = data[columns_fl + [label]]
#     # data_target = data_target.dropna()
#     # data_target = data_target.reset_index(drop = True)
#     for train_index, test_index in kf.split(data_target[columns_fl],data_target[label]):
        
#         c += 1

#         train_x = data_target.loc[train_index,columns_fl]
#         train_y = data_target.loc[train_index,label]
#         test_x = data_target.loc[test_index,columns_fl]
#         test_y = data_target.loc[test_index,label] 

#         print('iterate_num: ', c, '\n','sum of test_y:', sum(test_y))
    
#         lg = LogisticRegression(class_weight = 'balanced')
#         lg.fit(train_x, train_y )
#         pickle.dump(lg, open('lg_'+str(vs[0])+ '_'+str(c), 'wb'))

#         pred = lg.predict(test_x)
#         sum_pred_list.append(pred)
#         print('sum of pred: ', sum(pred), '\n')
#         # c_r = metrics.classification_report(test_y, pred, labels=[0,1], output_dict = True)
#         # class_report.append(c_r)
#         #print(metrics.classification_report(test_y, pred, labels=[0,1]))
        
#         decision_values = lg.predict_proba(test_x)
#         auc_score = roc_auc_score(test_y, decision_values[:,1])
#         print(auc_score)
#         auc_list.append(auc_score)
#         fpr, tpr, thresholds = roc_curve(test_y, decision_values[:,1])
#         tprs.append(np.interp(mean_fpr, fpr, tpr))

#         clf_sigmoid = CalibratedClassifierCV(lg, cv=3, method='sigmoid')
#         clf_sigmoid.fit(train_x, train_y )
#         indiv_predict_proba = clf_sigmoid.predict_proba(indiv_target)[:, 1]
#         target_proba_list.append(indiv_predict_proba)
#         #print('AUC',auc_score)
        
#     mean_tpr = np.mean(tprs, axis=0)
#     print('avg_AUC : ', np.mean(auc_list))
#     print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
#     frauds_prec = []
#     fradus_recall = []
#     for d in class_report:
#         frauds_prec.append(d['1']['precision'])
#         fradus_recall.append(d['1']['recall'])
        
#     print('frauds_prec : ', np.mean(frauds_prec))
#     print('fradus_recall : ', np.mean(fradus_recall))
#     print('\n')

#     return np.mean(auc_list), mean_tpr, target_proba_list

# %%
# _a, _b, target_proba_list =  lg_3(df_fl, v_perf +v_1 +selected_new_all, 'label', target_index)
# Out:
# iterate_num:  1
#  sum of test_y: 122.0
# sum of pred:  4513.0
#
# 0.7034874467462958
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  4851.0
#
# 0.7258203815636385
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  4712.0
#
# 0.6772816274257966
# iterate_num:  4
#  sum of test_y: 121.0
# sum of pred:  4782.0
#
# 0.6931742764785315
# avg_AUC :  0.6999409330535656
# avg_AUC_2 :  0.6999741008513533
# frauds_prec :  nan
# fradus_recall :  nan

# %%
# target_proba_list[0]
# Out:
# array([0.01256771, 0.00852629, 0.00964477, 0.01262843, 0.0126376 ,
#        0.00791638, 0.00573315, 0.00709556, 0.0054265 , 0.00523731,
#        0.00439192, 0.00290963, 0.00442599, 0.00427527, 0.0035782 ,
#        0.00416393, 0.00381549])

# %%
###LG
loaded_mode_lg = pickle.load(open('lg_perf+spc+wrd_2', 'rb'))
op_list_lg = loaded_mode_lg.predict_proba(data[v_perf +v_1 +selected_new_all])
op_list_lg = op_list_lg[:,1]

# %%
op_list_lg_t = loaded_mode_lg.predict_proba(target_data[v_perf +v_1 +selected_new_all])
op_list_lg_t = op_list_lg_t[:,1]

# %%
ir = IsotonicRegression()
ir.fit(op_list_lg,data['label'])
# Out:
# IsotonicRegression(increasing=True, out_of_bounds='nan', y_max=None, y_min=None)

# %%
op_list_lg_t = ir.predict(op_list_lg_t)

# %%
### deep learning w = 3
from keras.models import load_model

# %%
model = load_model('model_tcn_w3_perfv1words_4.h5')

# %%
A_perf, A_words, Y = shift_data(data, 3, v_perf+v_1, selected_new_all_sorted, 'label')
A_perf_t, A_words_t, Y_t = shift_data(target_data, 3, v_perf+v_1, selected_new_all_sorted, 'label')
# Out:
# init A shape:  (53618, 166)
# (39108, 3, 15) (39108, 3, 10, 4) 339.0
# init A shape:  (17, 166)
# (15, 3, 15) (15, 3, 10, 4) 2.0

# %%
op_list_dl = model.predict([A_perf, A_words])
#lop_list_dl = op_list_dl[:,0]

op_list_dl_t = model.predict([A_perf_t, A_words_t])
#op_list_dl_t = op_list_dl_t[:,0]

# %%
#op_list_dl = np.log(op_list_dl)

# %%
op_list_dl
# Out:
# array([[0.00430837],
#        [0.00103664],
#        [0.00116396],
#        ...,
#        [0.00109646],
#        [0.00050098],
#        [0.00039327]], dtype=float32)

# %%
op_list_dl = op_list_dl[:,0]

# %%
for o in op_list_dl:
  if o > 0.2:
    print(o)
# Out:
# 0.35882562
# 0.28463432
# 0.2481407
# 0.21713385

# %%
plt.hist(op_list_dl)
# Out:
# (array([3.9e+04, 7.3e+01, 1.6e+01, 9.0e+00, 4.0e+00, 2.0e+00, 2.0e+00,
#         1.0e+00, 0.0e+00, 1.0e+00]),
#  array([6.0598424e-05, 3.5937101e-02, 7.1813606e-02, 1.0769010e-01,
#         1.4356661e-01, 1.7944311e-01, 2.1531962e-01, 2.5119612e-01,
#         2.8707263e-01, 3.2294911e-01, 3.5882562e-01], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
op_list_dl_t = np.log(op_list_dl_t)

# %%
op_list_dl_t = op_list_dl_t[:,0]

# %%
#op_list_dl_t = op_list_dl_t.reshape(1,-1)

# %%
sum(Y)
# Out:
# 339.0

# %%
ir = IsotonicRegression()
ir.fit(op_list_dl,Y)
op_list_dl_t_res = ir.predict(op_list_dl_t)
# op_list_dl_t = op_list_dl_t.tolist()
# op_list_dl_t = [None,None] + op_list_dl_t
# Out:
# IsotonicRegression(increasing=True, out_of_bounds='nan', y_max=None, y_min=None)

# %%
op_list_dl_t_res
# Out:
# array([0.01398026, 0.01342756, 0.00923645, 0.00638607, 0.00851683,
#        0.00851683, 0.0063887 , 0.00544774, 0.00229008, 0.00229008,
#        0.00229008, 0.00544774, 0.00544774, 0.00532387, 0.00229008],
#       dtype=float32)

# %%
### deep learning w = 2
# model2 = load_model('model_tcn_w2_perfv1words_4.h5')
# A_perf2, A_words2, Y2 = shift_data(target_data, 2, v_perf+v_1, selected_new_all_sorted, 'label')
# op_list_dl2 = model2.predict([A_perf2, A_words2])
# op_list_dl2 = op_list_dl2.tolist()
# op_list_dl2 = [x[0] for x in op_list_dl2]
# op_list_dl2 = [None] + op_list_dl2

# %%
fig, ax1 = plt.subplots()
fig.set_figwidth(15)
fig.set_figheight(5)

fontP = FontProperties()
fontP.set_size('large')

ax2 = ax1.twinx()
#ax3 = ax1.twinx()
ax4 = ax1.twinx()

#ax3.spines['right'].set_position(('outward', 60))
ax4.spines['right'].set_position(('outward', 60))

ax1.plot(target_data.y2, target_data.s1, linestyle=(0, (1, 1)), c= 'y' , label = 'Overall Similarity') #
ax2.plot(target_data.y2, op_list_svm_t, linewidth=2.0, c = 'b', linestyle=(0, (3, 1, 1, 1)), label = 'SVM')
#ax2.plot(target_data.y2, op_list_lg_t, linewidth=2.0,marker='.', c = 'g', linestyle=(0, (3, 1, 1, 1, 1, 1)), label = 'LogitReg')
#ax3.plot(target_data.y2, op_list_dl2, c= 'm' , marker='x', linestyle=(0, (5, 1)), label = 'DeepLearning(T=2)')
ax4.plot(target_data.y2, op_list_dl_t, c= 'r' , marker='o', label = 'DeepLearning(T=3)')
ax1.set_ylabel('Overall Similarity')
ax2.set_ylabel('Predicted Proba for SVM')
#ax3.set_ylabel('Predicted Proba of Deeplearning(T=2)')
ax4.set_ylabel('Predicted Proba for Deeplearning(T=3)')

#lt.xticks(mean_s_tb.index)
# ax1.plot(tbtb_temp.y2, temp_tb.nn_proba, linewidth=2.0, c = 'b',label = 'neualnet')
# ax2.plot(temp_tb.y2, temp_tb.s1, linewidth=2.0, c = 'g',label = 'overall similarity')
fig.legend(loc="best", prop=fontP,  ncol=5)
# ax1.set_ylabel('similarity score for fraud case')
# ax2.set_ylabel('similarity score for avg. overall similarity')

#ax1.scatter(target_data[target_data.label == 1].y2, target_data[target_data.label == 1].s1, c = 'r')
# ax1.scatter(temp_tb[temp_tb.label == 1].y2, temp_tb[temp_tb.label == 1].nn_proba, c = 'b')
# ax2.scatter(temp_tb[temp_tb.label == 1].y2, temp_tb[temp_tb.label == 1].s1, c = 'g')

plt.xticks(target_data.y2)
# Out:
# Text(0, 0.5, 'Overall Similarity')
# Text(0, 0.5, 'Predicted Proba for SVM')
# Text(0, 0.5, 'Predicted Proba for Deeplearning(T=3)')
# ([<matplotlib.axis.XTick at 0x7fde9fbfc850>,
#   <matplotlib.axis.XTick at 0x7fde9fbfc810>,
#   <matplotlib.axis.XTick at 0x7fde9fbfdb10>,
#   <matplotlib.axis.XTick at 0x7fde9fb45a50>,
#   <matplotlib.axis.XTick at 0x7fde9fb45bd0>,
#   <matplotlib.axis.XTick at 0x7fde9fb4c550>,
#   <matplotlib.axis.XTick at 0x7fde9fb4cad0>,
#   <matplotlib.axis.XTick at 0x7fde9fb4cd10>,
#   <matplotlib.axis.XTick at 0x7fde9fb55590>,
#   <matplotlib.axis.XTick at 0x7fde9fb55ad0>,
#   <matplotlib.axis.XTick at 0x7fde9fb55110>,
#   <matplotlib.axis.XTick at 0x7fde9fb55f10>,
#   <matplotlib.axis.XTick at 0x7fde9fb4c650>,
#   <matplotlib.axis.XTick at 0x7fde9fb5d0d0>,
#   <matplotlib.axis.XTick at 0x7fde9fb5d910>,
#   <matplotlib.axis.XTick at 0x7fde9fb5de50>,
#   <matplotlib.axis.XTick at 0x7fde9fb653d0>],
#  <a list of 17 Text major ticklabel objects>)

# %% [markdown]
# # extra LSTM+TCN
# ##### T= 2,3
# ##### variables:
# ##### Quant. Indicators + Overall Similarity  (T years) + Word Changes (current year)

# %%
def model_tcn_ext(n1,n2,n3,T, perf, words, channel, filters = 24, dropout = 0):
    model = None
    
    input_perf = Input(shape=(T,perf), \
                      dtype='float32', name='input_perf')
    
    input_words = Input(shape=(words,channel), \
                      dtype='float32', name='input_words') 
    
    word_norm = BatchNormalization()(input_words)
    padding = ZeroPadding1D(padding=((0),(words-1)))(word_norm)
    
    print("shape after padding:", K.int_shape(padding))
    
    conv = Conv1D(filters = filters,\
                  kernel_size = words,\
                  use_bias = False,\
                  activation = None)(padding)  # Shape None x T x words x filters
    print("conv shape:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    
    wrd_pool = MaxPooling1D(pool_size=words, \
              strides=1)(conv) # None x T x filters
    wrd_pool = Reshape((filters,))(wrd_pool)
    print("pool shape:", K.int_shape(wrd_pool))

    #drop = Dropout(0.3)(input_all)
    # Now concatenate
    perf_norm = BatchNormalization()(input_perf)
    #all_input = Concatenate(axis = -1)([perf_norm, pool])
    #all_rsp = Reshape((filters+15,))(all_input)
    #nor = BatchNormalization()(all_input)
    
    LSTM_w_1 =Bidirectional(LSTM(n1, recurrent_dropout = 0.2,
                    name = 'layer_lstm_1', return_sequences=True,
                    # kernel_regularizer = regularizers.l2(0.01),
                    # activity_regularizer = regularizers.l2(0.01),
                    # bias_regularizer = regularizers.l2(0.01)
                    ))(perf_norm)
    LSTM_w_2 = LSTM(n2, dropout= 0.3, recurrent_dropout = 0.3,
                   name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)
    all_input = Concatenate(axis = -1)([wrd_pool, LSTM_w_2])
    dense = Dense(n3, activation='relu', name='dense')(all_input)
    drop = Dropout(0.3)(dense)
    
    preds = Dense(1, activation='sigmoid', name='output')(drop)
    model = Model(inputs=[input_perf, input_words], outputs=preds)
    model._name = "model_tcn"
    model.summary()
    
    return model

# %%
def fit_model_ext( model,x_train, y_train, x_val, y_val, x_test, y_test, model_name, verbose = 0):
    
    history = None
    result = None
    
    model_df = model
    print('in fit, val_y: ', sum(y_val), 'test_y',sum(y_test), 'train_y',sum(y_train))

    #class weight for test 
    class_weights = class_weight.compute_class_weight('balanced',
                              np.unique(y_train),
                              y_train)
    class_weights = {l:c for l,c in zip(np.unique(y_train), class_weights)}
    # class weight for val
    val_class_weights = class_weight.compute_class_weight('balanced',
                                np.unique(y_val),
                                y_val)
    val_class_weights = {l:c for l,c in zip(np.unique(y_val), val_class_weights)}
    val_sample_weights = []
    for y in y_val:
        if y == 1:
          val_sample_weights.append(val_class_weights[1])
        else: val_sample_weights.append(val_class_weights[0])
    val_sample_weights = np.asarray(val_sample_weights)
    #print('in fit val weights', val_sample_weights.shape)
    
    auc_eval = AUCEvaluation(validation_data=(x_val, y_val), interval=1)
    # earlyStopping = EarlyStopping(monitor='val_loss',patience = 3, 
    #                   verbose =verbose, mode ='min')
    # checkpoint = ModelCheckpoint(model_name,monitor='val_my_auc',verbose=verbose,
    #           save_best_only=True, save_weights_only=True, mode ='max')

    opt = optimizers.RMSprop(lr=0.0005)
    model_df.compile(optimizer= opt,
              loss='binary_crossentropy',
              metrics=['accuracy', metrics.AUC(name='my_auc')])

    history = model_df.fit(x_train,
                y_train,
                epochs=25,
                batch_size=128,
                verbose =verbose,
                callbacks=[auc_eval],\
                #callbacks=[auc_eval, earlyStopping, checkpoint], #checkpoint
                class_weight = class_weights, \
                validation_data=(x_val, y_val, val_sample_weights)) 
    model_df.save(model_name+".h5")
    #model_df.load_weights(model_name)
    y_pred = model_df.predict(x_test)
    y_pred_1=np.reshape(y_pred, -1)
    auc_score = roc_auc_score(y_test, y_pred_1)
    #auc_score = roc_auc_score(y_test, y_pred_1)
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_1)
    print("AUC: " ,round(auc_score,4))
    print([ round(h,4) for h in history.history['val_loss']])    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

        
    return history, auc_score, fpr, tpr, thresholds, [y_test, y_pred_1]

# %%
def cross_val_ext(data, label, perf_cols, words_cols, name, w, filters = 24):
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    predicted_res =[]
    his_auc = []
    
    kf = StratifiedKFold(n_splits = 4, shuffle = True, random_state = 42)
    c = 0

    X_perf,  X_word, Y = shift_data_ext(df_fl, w, \
                    perf_cols, \
                    words_cols, \
                    'label')
    
    for train_index, test_index in kf.split(range(len(X_perf)),Y):
        
        c += 1
        
        l1 = X_perf.shape[-1]+ filters + 16
        
        model = model_tcn_ext(l1,l1,32,\
                    X_perf.shape[1],\
                    X_perf.shape[2],
                    X_word.shape[1], \
                    X_word.shape[2], \
                    filters = filters)
    
        #model = model_lstm(n1,n2,n,w)
        # train_x, train_val = train_test_split(train_index,test_size=0.2, \
        #             random_state=42, stratify = Y[train_index])
        train_perf_data = X_perf[train_index]
        train_word_data = X_word[train_index]
        # train_perf_val = X_perf[train_val]
        # train_word_val = X_word[train_val]

        train_label = Y[train_index]
        #val_label = Y[train_val]

        test_perf_x = X_perf[test_index]
        test_word_x = X_word[test_index]
        test_y = Y[test_index] 
        
        train_data = [train_perf_data, train_word_data]
        #val_data = [train_perf_val,train_word_val]
        test_x = [test_perf_x, test_word_x]

        mod_res = fit_model_ext(model, train_data, train_label, test_x, test_y, test_x, test_y,\
                  name+'_'+str(c))
        his_auc.append(mod_res[0].history['val_my_auc'])
        
        
        
        
        auc_list.append(mod_res[1])
        tprs.append(np.interp(mean_fpr, mod_res[2], mod_res[3]))
        temp_pred_res = [mod_res[-1],test_index]
        print(len(test_index))
        predicted_res.append(temp_pred_res)
        
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    print(pd.DataFrame(his_auc))
    print(pd.DataFrame(his_auc).mean())
    
    return np.average(auc_list), mean_tpr, predicted_res

# %%
def shift_data_ext(data, step, perf_cols, words_cols, label):
    A = []
    
    #cols = perf_cols + words_cols
    A.append(data[perf_cols].values)
    
    for t in range(1, step):
        d = data.groupby("cik")[perf_cols].shift(t)
        A.append(d.values)
    A = A[::-1]
    A = np.concatenate(A, axis = 1)  # flatten shifted columns
    cols = [label] + words_cols
    A = np.concatenate([data[cols].values[:,], A], axis = 1)  # add target
    #np.random.shuffle(A)
    #print(A[3])
    print('init A shape: ',A.shape)
    #print(A[3,:])
    #print(data[cols].iloc[4,:])


    
    A = A[~np.isnan(A).any(axis=1)]  # drop nan
    

    Y = A[:,0]  # get target
    #A = np.reshape(A[:,1:], (len(A), step, len(cols))) # reshape
    A_words = A[:,1:len(words_cols)+1]
    A_perfs = np.reshape(A[:,1+len(words_cols):], (len(A), step, len(perf_cols)))
    
    
    # CNN_LSTM must be None x T x words x 4
    #A_perfs = A[:, :, len(words_cols):]
    print(A_perfs.shape, A_words.shape, Y.sum())
    #convert the shape to [[_p,_new][_dis,_n]]

    A_words = A_words.reshape((len(A), int(len(words_cols)/4), 4), order = 'C')
    
    print(A_perfs.shape, A_words.shape, Y.sum())
    return A_perfs, A_words, Y

# %%
#use  model_tcn_ext, shift_data_ext, cross_val_ext
#T=3
#Quant. Indicators + Overall Similarity  (T years) + Word Changes (current year)


w = 3
perf_cols =   v_perf +v_1
words_cols =  selected_new_all_sorted
label = 'label'
h3 = cross_val_ext( df_fl, 'label', \
          perf_cols,\
          words_cols, \
          'model_tcn_ext_w3',w, \
          filters = 56)
# Out:
# init A shape:  (53635, 86)
# (39123, 3, 15) (39123, 40) 341.0
# (39123, 3, 15) (39123, 10, 4) 341.0
# shape after padding: (None, 19, 4)
# conv shape: (None, 10, 56)
# pool shape: (None, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 10, 4)        16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_13 (ZeroPadding1 (None, 19, 4)        0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 10, 56)       2240        zero_padding1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 10, 56)       224         conv1d_12[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 10, 56)       0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_11 (MaxPooling1D) (None, 1, 56)        0           activation_31[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 3, 174)       71688       batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# reshape_45 (Reshape)            (None, 56)           0           max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_8[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 143)          0           reshape_45[0][0]
#                                                                  layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           4608        concatenate_25[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_39[0][0]
# ==================================================================================================
# Total params: 170,045
# Trainable params: 169,895
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7233
#  epoch:1 auc: 0.7216
#  epoch:2 auc: 0.7481
#  epoch:3 auc: 0.7474
#  epoch:4 auc: 0.7254
#  epoch:5 auc: 0.7422
#  epoch:6 auc: 0.7349
#  epoch:7 auc: 0.7488
#  epoch:8 auc: 0.7370
#  epoch:9 auc: 0.7060
#  epoch:10 auc: 0.7366
#  epoch:11 auc: 0.7427
#  epoch:12 auc: 0.7462
#  epoch:13 auc: 0.7302
#  epoch:14 auc: 0.7173
#  epoch:15 auc: 0.7246
#  epoch:16 auc: 0.7377
#  epoch:17 auc: 0.7464
#  epoch:18 auc: 0.7535
#  epoch:19 auc: 0.7513
#  epoch:20 auc: 0.7544
#  epoch:21 auc: 0.7327
#  epoch:22 auc: 0.7429
#  epoch:23 auc: 0.7492
#  epoch:24 auc: 0.7466
# AUC:  0.7466
# [0.6488, 0.6213, 0.5986, 0.6038, 0.6097, 0.5891, 0.6564, 0.6315, 0.5955, 0.7657, 0.6604, 0.7262, 0.7561, 0.8215, 0.8703, 1.0854, 0.8044, 0.9387, 0.8016, 0.8411, 0.881, 0.9965, 1.0879, 1.0788, 1.3295]
# 9781
# shape after padding: (None, 19, 4)
# conv shape: (None, 10, 56)
# pool shape: (None, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 10, 4)        16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_14 (ZeroPadding1 (None, 19, 4)        0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 10, 56)       2240        zero_padding1d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 10, 56)       224         conv1d_13[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 10, 56)       0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 1, 56)        0           activation_32[0][0]
# __________________________________________________________________________________________________
# bidirectional_9 (Bidirectional) (None, 3, 174)       71688       batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# reshape_46 (Reshape)            (None, 56)           0           max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_9[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 143)          0           reshape_46[0][0]
#                                                                  layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           4608        concatenate_26[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_40[0][0]
# ==================================================================================================
# Total params: 170,045
# Trainable params: 169,895
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7130
#  epoch:1 auc: 0.7200
#  epoch:2 auc: 0.7290
#  epoch:3 auc: 0.7306
#  epoch:4 auc: 0.7318
#  epoch:5 auc: 0.7281
#  epoch:6 auc: 0.7275
#  epoch:7 auc: 0.7241
#  epoch:8 auc: 0.7273
#  epoch:9 auc: 0.7291
#  epoch:10 auc: 0.7255
#  epoch:11 auc: 0.7208
#  epoch:12 auc: 0.7194
#  epoch:13 auc: 0.7195
#  epoch:14 auc: 0.7185
#  epoch:15 auc: 0.7073
#  epoch:16 auc: 0.7205
#  epoch:17 auc: 0.7221
#  epoch:18 auc: 0.7216
#  epoch:19 auc: 0.7285
#  epoch:20 auc: 0.7200
#  epoch:21 auc: 0.7211
#  epoch:22 auc: 0.7218
#  epoch:23 auc: 0.7095
#  epoch:24 auc: 0.7226
# AUC:  0.7226
# [0.648, 0.6086, 0.6282, 0.6694, 0.6024, 0.6425, 0.602, 0.688, 0.7231, 0.6942, 0.7356, 0.7101, 0.8435, 0.9304, 0.8838, 0.7982, 0.994, 1.1637, 1.1258, 1.0446, 1.0381, 1.3004, 1.1377, 1.4414, 1.3568]
# 9781
# shape after padding: (None, 19, 4)
# conv shape: (None, 10, 56)
# pool shape: (None, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 10, 4)        16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_15 (ZeroPadding1 (None, 19, 4)        0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 10, 56)       2240        zero_padding1d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 10, 56)       224         conv1d_14[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 10, 56)       0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 1, 56)        0           activation_33[0][0]
# __________________________________________________________________________________________________
# bidirectional_10 (Bidirectional (None, 3, 174)       71688       batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# reshape_47 (Reshape)            (None, 56)           0           max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_10[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 143)          0           reshape_47[0][0]
#                                                                  layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           4608        concatenate_27[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_41[0][0]
# ==================================================================================================
# Total params: 170,045
# Trainable params: 169,895
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  86.0 test_y 86.0 train_y 255.0
#  epoch:0 auc: 0.6634
#  epoch:1 auc: 0.6844
#  epoch:2 auc: 0.6560
#  epoch:3 auc: 0.6845
#  epoch:4 auc: 0.6633
#  epoch:5 auc: 0.6884
#  epoch:6 auc: 0.6754
#  epoch:7 auc: 0.6808
#  epoch:8 auc: 0.6845
#  epoch:9 auc: 0.6847
#  epoch:10 auc: 0.6897
#  epoch:11 auc: 0.6827
#  epoch:12 auc: 0.6808
#  epoch:13 auc: 0.6814
#  epoch:14 auc: 0.6881
#  epoch:15 auc: 0.6888
#  epoch:16 auc: 0.6936
#  epoch:17 auc: 0.6985
#  epoch:18 auc: 0.6987
#  epoch:19 auc: 0.6870
#  epoch:20 auc: 0.6956
#  epoch:21 auc: 0.6993
#  epoch:22 auc: 0.6996
#  epoch:23 auc: 0.6947
#  epoch:24 auc: 0.7035
# AUC:  0.7035
# [0.6627, 0.6405, 0.7239, 0.7121, 0.8392, 0.7785, 0.827, 0.8904, 0.8987, 0.7823, 0.8632, 0.9391, 1.0739, 1.244, 1.2023, 1.0357, 0.9971, 1.2074, 1.1548, 1.8705, 1.2949, 1.2074, 1.1522, 1.334, 1.4776]
# 9781
# shape after padding: (None, 19, 4)
# conv shape: (None, 10, 56)
# pool shape: (None, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 10, 4)        16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_16 (ZeroPadding1 (None, 19, 4)        0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 10, 56)       2240        zero_padding1d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 10, 56)       224         conv1d_15[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 10, 56)       0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 1, 56)        0           activation_34[0][0]
# __________________________________________________________________________________________________
# bidirectional_11 (Bidirectional (None, 3, 174)       71688       batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# reshape_48 (Reshape)            (None, 56)           0           max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_11[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 143)          0           reshape_48[0][0]
#                                                                  layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           4608        concatenate_28[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_42[0][0]
# ==================================================================================================
# Total params: 170,045
# Trainable params: 169,895
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.6937
#  epoch:1 auc: 0.7009
#  epoch:2 auc: 0.7053
#  epoch:3 auc: 0.7270
#  epoch:4 auc: 0.6987
#  epoch:5 auc: 0.7248
#  epoch:6 auc: 0.7267
#  epoch:7 auc: 0.7264
#  epoch:8 auc: 0.7303
#  epoch:9 auc: 0.7312
#  epoch:10 auc: 0.7372
#  epoch:11 auc: 0.7369
#  epoch:12 auc: 0.7200
#  epoch:13 auc: 0.7280
#  epoch:14 auc: 0.7319
#  epoch:15 auc: 0.7294
#  epoch:16 auc: 0.7335
#  epoch:17 auc: 0.7193
#  epoch:18 auc: 0.7178
#  epoch:19 auc: 0.7101
#  epoch:20 auc: 0.7099
#  epoch:21 auc: 0.7034
#  epoch:22 auc: 0.7030
#  epoch:23 auc: 0.7024
#  epoch:24 auc: 0.7066
# AUC:  0.7066
# [0.6537, 0.6345, 0.6323, 0.6678, 0.6851, 0.6851, 0.6455, 0.6755, 0.793, 0.7523, 0.7377, 0.863, 0.9805, 1.0509, 1.1286, 0.9299, 1.12, 1.1373, 1.1005, 1.291, 1.4725, 1.258, 1.758, 1.4581, 1.5889]
# 9780
# avg_AUC :  0.7198541630253016
# avg_AUC_2 :  0.7196935151791514
#          0         1         2   ...        22        23        24
# 0  0.723624  0.721168  0.747959  ...  0.734002  0.740390  0.731124
# 1  0.713462  0.719701  0.729321  ...  0.717735  0.695783  0.713472
# 2  0.664532  0.684141  0.655907  ...  0.697186  0.692308  0.699473
# 3  0.694288  0.700853  0.705178  ...  0.689020  0.696859  0.699329
#
# [4 rows x 25 columns]
# 0     0.698976
# 1     0.706466
# 2     0.709591
# 3     0.722340
# 4     0.704800
# 5     0.720964
# 6     0.715979
# 7     0.720123
# 8     0.718735
# 9     0.712176
# 10    0.721563
# 11    0.719861
# 12    0.713406
# 13    0.710300
# 14    0.710928
# 15    0.710347
# 16    0.717536
# 17    0.716705
# 18    0.718431
# 19    0.712026
# 20    0.714769
# 21    0.707672
# 22    0.709486
# 23    0.706335
# 24    0.710850
# dtype: float64

# %%
#use  model_tcn_ext, shift_data_ext, cross_val_ext
#T=2
#Quant. Indicators + Overall Similarity  (T years) + Word Changes (current year)
w = 2
perf_cols =  v_1 + v_perf
words_cols = selected_new_all_sorted
label = 'label'
h3 = cross_val_ext( df_fl, 'label', \
          perf_cols,\
          words_cols, \
          'model_tcn_ext_w3',w, \
          filters = 56)
# Out:
# init A shape:  (53635, 71)
# (45945, 2, 15) (45945, 40) 408.0
# (45945, 2, 15) (45945, 10, 4) 408.0
# shape after padding: (None, 19, 4)
# conv shape: (None, 10, 56)
# pool shape: (None, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 10, 4)        16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_17 (ZeroPadding1 (None, 19, 4)        0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 10, 56)       2240        zero_padding1d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 10, 56)       224         conv1d_16[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 15)]      0
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 10, 56)       0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 2, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_15 (MaxPooling1D) (None, 1, 56)        0           activation_35[0][0]
# __________________________________________________________________________________________________
# bidirectional_12 (Bidirectional (None, 2, 174)       71688       batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# reshape_49 (Reshape)            (None, 56)           0           max_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_12[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 143)          0           reshape_49[0][0]
#                                                                  layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           4608        concatenate_29[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_43[0][0]
# ==================================================================================================
# Total params: 170,045
# Trainable params: 169,895
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.7131
#  epoch:1 auc: 0.7099
#  epoch:2 auc: 0.6981
#  epoch:3 auc: 0.7077
#  epoch:4 auc: 0.7085
#  epoch:5 auc: 0.6790
#  epoch:6 auc: 0.7005
#  epoch:7 auc: 0.6926
#  epoch:8 auc: 0.6822
#  epoch:9 auc: 0.6981
#  epoch:10 auc: 0.6965
#  epoch:11 auc: 0.7089
#  epoch:12 auc: 0.6914
#  epoch:13 auc: 0.6914
#  epoch:14 auc: 0.6890
#  epoch:15 auc: 0.6865
#  epoch:16 auc: 0.6996
#  epoch:17 auc: 0.6885
#  epoch:18 auc: 0.6821
#  epoch:19 auc: 0.6827
#  epoch:20 auc: 0.6778
#  epoch:21 auc: 0.6946
#  epoch:22 auc: 0.6901
#  epoch:23 auc: 0.6888
#  epoch:24 auc: 0.6893
# AUC:  0.6893
# [0.6408, 0.6256, 0.6306, 0.6367, 0.6639, 0.7191, 0.6917, 0.7232, 0.7863, 0.8103, 0.8064, 0.8482, 0.8632, 0.9186, 0.9724, 1.1023, 1.0342, 0.9452, 1.225, 1.1249, 1.3084, 1.2382, 1.1379, 1.3847, 1.2858]
# 11487
# shape after padding: (None, 19, 4)
# conv shape: (None, 10, 56)
# pool shape: (None, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 10, 4)        16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_18 (ZeroPadding1 (None, 19, 4)        0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 10, 56)       2240        zero_padding1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 10, 56)       224         conv1d_17[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 15)]      0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 10, 56)       0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 2, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_16 (MaxPooling1D) (None, 1, 56)        0           activation_36[0][0]
# __________________________________________________________________________________________________
# bidirectional_13 (Bidirectional (None, 2, 174)       71688       batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# reshape_50 (Reshape)            (None, 56)           0           max_pooling1d_16[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_13[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 143)          0           reshape_50[0][0]
#                                                                  layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           4608        concatenate_30[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_44[0][0]
# ==================================================================================================
# Total params: 170,045
# Trainable params: 169,895
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.6861
#  epoch:1 auc: 0.6989
#  epoch:2 auc: 0.7113
#  epoch:3 auc: 0.7190
#  epoch:4 auc: 0.7206
#  epoch:5 auc: 0.7247
#  epoch:6 auc: 0.7309
#  epoch:7 auc: 0.7244
#  epoch:8 auc: 0.7209
#  epoch:9 auc: 0.7187
#  epoch:10 auc: 0.7171
#  epoch:11 auc: 0.7251
#  epoch:12 auc: 0.7232
#  epoch:13 auc: 0.7269
#  epoch:14 auc: 0.7159
#  epoch:15 auc: 0.7148
#  epoch:16 auc: 0.7169
#  epoch:17 auc: 0.7220
#  epoch:18 auc: 0.7157
#  epoch:19 auc: 0.7150
#  epoch:20 auc: 0.7194
#  epoch:21 auc: 0.7215
#  epoch:22 auc: 0.7200
#  epoch:23 auc: 0.7076
#  epoch:24 auc: 0.7166
# AUC:  0.7166
# [0.6479, 0.6504, 0.6663, 0.6667, 0.6544, 0.6599, 0.6765, 0.6788, 0.7072, 0.7538, 0.7733, 0.7554, 0.8529, 0.9185, 0.7833, 1.0416, 0.8886, 0.9599, 1.0342, 1.0207, 1.0798, 1.069, 1.0825, 1.1743, 1.2059]
# 11486
# shape after padding: (None, 19, 4)
# conv shape: (None, 10, 56)
# pool shape: (None, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 10, 4)        16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_19 (ZeroPadding1 (None, 19, 4)        0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 10, 56)       2240        zero_padding1d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 10, 56)       224         conv1d_18[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 15)]      0
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 10, 56)       0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 2, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_17 (MaxPooling1D) (None, 1, 56)        0           activation_37[0][0]
# __________________________________________________________________________________________________
# bidirectional_14 (Bidirectional (None, 2, 174)       71688       batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# reshape_51 (Reshape)            (None, 56)           0           max_pooling1d_17[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_14[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 143)          0           reshape_51[0][0]
#                                                                  layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           4608        concatenate_31[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_45[0][0]
# ==================================================================================================
# Total params: 170,045
# Trainable params: 169,895
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.7008
#  epoch:1 auc: 0.7141
#  epoch:2 auc: 0.7108
#  epoch:3 auc: 0.7087
#  epoch:4 auc: 0.7123
#  epoch:5 auc: 0.7084
#  epoch:6 auc: 0.7031
#  epoch:7 auc: 0.7144
#  epoch:8 auc: 0.7055
#  epoch:9 auc: 0.6884
#  epoch:10 auc: 0.7029
#  epoch:11 auc: 0.6781
#  epoch:12 auc: 0.6831
#  epoch:13 auc: 0.6864
#  epoch:14 auc: 0.6744
#  epoch:15 auc: 0.6962
#  epoch:16 auc: 0.6821
#  epoch:17 auc: 0.6817
#  epoch:18 auc: 0.6771
#  epoch:19 auc: 0.6789
#  epoch:20 auc: 0.6839
#  epoch:21 auc: 0.6914
#  epoch:22 auc: 0.6808
#  epoch:23 auc: 0.6845
#  epoch:24 auc: 0.6915
# AUC:  0.6915
# [0.6594, 0.6289, 0.6417, 0.6427, 0.639, 0.6514, 0.7097, 0.7023, 0.714, 0.8339, 0.7427, 0.9049, 0.8121, 0.736, 0.879, 0.7684, 0.7904, 0.827, 0.9066, 0.9612, 1.0134, 0.947, 1.0107, 1.1104, 0.9585]
# 11486
# shape after padding: (None, 19, 4)
# conv shape: (None, 10, 56)
# pool shape: (None, 56)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 10, 4)]      0
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 10, 4)        16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding1d_20 (ZeroPadding1 (None, 19, 4)        0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 10, 56)       2240        zero_padding1d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 10, 56)       224         conv1d_19[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 15)]      0
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 10, 56)       0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 2, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_18 (MaxPooling1D) (None, 1, 56)        0           activation_38[0][0]
# __________________________________________________________________________________________________
# bidirectional_15 (Bidirectional (None, 2, 174)       71688       batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# reshape_52 (Reshape)            (None, 56)           0           max_pooling1d_18[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 87)           91176       bidirectional_15[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 143)          0           reshape_52[0][0]
#                                                                  layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           4608        concatenate_32[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_46[0][0]
# ==================================================================================================
# Total params: 170,045
# Trainable params: 169,895
# Non-trainable params: 150
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.6879
#  epoch:1 auc: 0.7097
#  epoch:2 auc: 0.7277
#  epoch:3 auc: 0.7246
#  epoch:4 auc: 0.7227
#  epoch:5 auc: 0.7115
#  epoch:6 auc: 0.7151
#  epoch:7 auc: 0.7211
#  epoch:8 auc: 0.7302
#  epoch:9 auc: 0.7304
#  epoch:10 auc: 0.7343
#  epoch:11 auc: 0.7261
#  epoch:12 auc: 0.7277
#  epoch:13 auc: 0.7158
#  epoch:14 auc: 0.7238
#  epoch:15 auc: 0.7344
#  epoch:16 auc: 0.7332
#  epoch:17 auc: 0.7331
#  epoch:18 auc: 0.7400
#  epoch:19 auc: 0.7151
#  epoch:20 auc: 0.7337
#  epoch:21 auc: 0.7228
#  epoch:22 auc: 0.7269
#  epoch:23 auc: 0.7201
#  epoch:24 auc: 0.7188
# AUC:  0.7188
# [0.6547, 0.6255, 0.611, 0.6242, 0.6634, 0.6528, 0.6877, 0.639, 0.6215, 0.6642, 0.6288, 0.6922, 0.6776, 0.6887, 0.8006, 0.6892, 0.7496, 0.8269, 0.8245, 0.8887, 0.9332, 0.9398, 0.8862, 1.0998, 1.0863]
# 11486
# avg_AUC :  0.70405180182151
# avg_AUC_2 :  0.7038646266587443
#          0         1         2   ...        22        23        24
# 0  0.712675  0.709633  0.697938  ...  0.686912  0.685741  0.685311
# 1  0.686028  0.698829  0.711031  ...  0.718967  0.706327  0.715288
# 2  0.698850  0.714154  0.710972  ...  0.678622  0.681584  0.690897
# 3  0.687462  0.709463  0.727418  ...  0.724465  0.714783  0.711385
#
# [4 rows x 25 columns]
# 0     0.696254
# 1     0.708020
# 2     0.711840
# 3     0.715005
# 4     0.716013
# 5     0.705840
# 6     0.712228
# 7     0.713001
# 8     0.709183
# 9     0.708169
# 10    0.711683
# 11    0.708617
# 12    0.705530
# 13    0.704048
# 14    0.699656
# 15    0.706707
# 16    0.706460
# 17    0.705994
# 18    0.701631
# 19    0.694675
# 20    0.699790
# 21    0.703442
# 22    0.702242
# 23    0.697109
# 24    0.700720
# dtype: float64
