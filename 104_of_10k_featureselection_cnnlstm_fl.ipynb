# %% [markdown]
# <a href="https://colab.research.google.com/github/pepperamy/tenK_phase2/blob/main/104_of_10k_featureselection_cnnlstm_fl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pickle
import re
from matplotlib import pyplot as plt
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from scipy.optimize import linear_sum_assignment
import time

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import statsmodels.api as sm
import statsmodels.formula.api as smf

import warnings
warnings.filterwarnings('ignore')

from scipy.stats import mstats
import math

from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.model_selection import KFold,StratifiedKFold

# %%
from keras import regularizers

# %%
from keras import backend as K

# %%
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, precision_recall_curve, classification_report,accuracy_score, auc, roc_curve, roc_auc_score, average_precision_score

# %%
from keras.models import Sequential
from sklearn.metrics import mean_squared_error
from keras.layers import Embedding, Dense, Conv2D, MaxPooling2D, Reshape, Conv1D, MaxPooling1D,\
Dropout, Activation, Input, Flatten, Concatenate, BatchNormalization, Lambda, LSTM, GRU, Bidirectional,\
ZeroPadding2D
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from keras import regularizers
from keras.models import Model
from keras import optimizers
from keras import metrics
from keras import models
from keras import layers

# %%
from sklearn.utils import class_weight

# %%
from sklearn import utils

# %%
import random

# %%
from sklearn.svm import LinearSVC,SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score
#from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # data prepare

# %%
df = pd.read_csv('data_performance_words_win1_comb_20210301.csv')

# %%
df.shape
# Out:
# (53635, 212)

# %%
sum(df.label)
# Out:
# 487.0

# %%
df.head()
# Out:
#     cik      y1      y2  ...  Discrep_down  Reward_up  Reward_down
# 0  20.0  1995.0  1996.0  ...      0.248916   0.190476     0.193121
# 1  20.0  1996.0  1997.0  ...      0.070482   0.200000     0.207947
# 2  20.0  1997.0  1998.0  ...      0.202532   0.002960     0.268170
# 3  20.0  1998.0  1999.0  ...      0.144520   0.053633     0.003575
# 4  20.0  1999.0  2000.0  ...      0.253588   0.176471     0.007639
#
# [5 rows x 212 columns]

# %%
df_fl = df[(df.y2 <= 2012) & (df.y2 >= 1995 ) ]

# %%
df_fl.label.value_counts()
# Out:
# 0.0    53148
# 1.0      487
# Name: label, dtype: int64

# %%
df_fl.shape
# Out:
# (53635, 212)

# %%
selected_new = ['WeakModal','Negative', 'Compare', 'Discrep','Positive',\
         'Achieve',  'Reward', 'StrongModal','Uncertainty', 'Litigious']#[::-1]

v_perf = ['aqi',
 'asset_turnover',
 'depi',
 'gmi',
 #'ig',
 'opm',
 'rg',
 'sg',
 'sgee',
 'ch_rec',
 'ch_inv',
 'soft_asset',
 'ch_cs',
 'ch_roa',
 'issue']

v_1 = ['s1']
v_2 = ['pastavg3','cr3']

# %%
# selected_comb = []
# for s in selected_new:
#   selected_comb.append(s+'_up')
#   selected_comb.append(s+'_down')

# %%
selected_new_all = []
temp = []
for s in selected_new:
    wrd = s.split('_')[0]
    if wrd not in temp:
        #print(s,'\n',temp)
        #selected_new_all.append(wrd+'_3_avg')
        selected_new_all.append(wrd+'_3_p')
        selected_new_all.append(wrd+'_3_n')
        #selected_new_all.append(wrd+'_3_u')
        selected_new_all.append(wrd+'_3_new')
        selected_new_all.append(wrd+'_3_dis')
        temp.append(wrd)
    else: 
        pass

# %%
selected_new_all

# %%
selected_new_all_sorted = []
selected_new_all_p = []
selected_new_all_n = []
selected_new_all_new = []
selected_new_all_dis = []
for s in selected_new_all:
  if 'new' in s.split('_'):
    selected_new_all_new.append(s)
  elif 'p' in s.split('_'):
    selected_new_all_p.append(s)
  elif 'n' in s.split('_'):
    selected_new_all_n.append(s)
  elif 'dis' in s.split('_'):
    selected_new_all_dis.append(s)

for i, w in enumerate(selected_new_all_p):
  selected_new_all_sorted.append(selected_new_all_p[i])
  selected_new_all_sorted.append(selected_new_all_new[i])
  selected_new_all_sorted.append(selected_new_all_n[i])
  
  selected_new_all_sorted.append(selected_new_all_dis[i])

# %%
selected_new_all_sorted

# %% [markdown]
# # SVM

# %%
def svm( data, vs, label = 'label'):
    
    columns_fl = vs[1] #+ [ 'sic_class_x']
    
    data_target = data.loc[:,columns_fl + [label]]
    
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    
    class_report = []
    sum_pred_list = []

    kf = StratifiedKFold(n_splits = 4, shuffle = True)
    c = 0
    data_target = data[columns_fl + [label]]
    data_target = data_target.dropna()
    data_target = data_target.reset_index(drop = True)
    print('dataset: ', data_target.shape, '/n', sum(data_target.label))
     
    for train_index, test_index in kf.split(data_target[columns_fl],data_target[label]):
        
        c += 1

        train_x = data_target.loc[train_index,columns_fl]
        train_y = data_target.loc[train_index,label]
        test_x = data_target.loc[test_index,columns_fl]
        test_y = data_target.loc[test_index,label] 

        print('iterate_num: ', c, '\n','sum of test_y:', sum(test_y))
    
        svm = LinearSVC(class_weight = "balanced")
        svm.fit(train_x, train_y )
        pickle.dump(svm, open('svm_'+str(vs[0])+ '_'+str(c), 'wb'))
        

        pred = svm.predict(test_x)
        sum_pred_list.append(pred)
        print('sum of pred: ', sum(pred), '\n')
        # c_r = metrics.classification_report(test_y, pred, labels=[0,1], output_dict = True)
        # class_report.append(c_r)
        #print(metrics.classification_report(test_y, pred, labels=[0,1]))
        
        decision_values = svm.decision_function(test_x)
        auc_score = roc_auc_score(test_y, decision_values)
        print(auc_score)
        auc_list.append(auc_score)
        
        fpr, tpr, thresholds = roc_curve(test_y, decision_values)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        
#         mean_tpr = np.mean(tprs, axis=0)
#         mean_auc = auc(mean_fpr, mean_tpr)
        
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    frauds_prec = []
    fradus_recall = []
    for d in class_report:
        frauds_prec.append(d['1']['precision'])
        fradus_recall.append(d['1']['recall'])
    
#     coef_s = 0
#     for i in coef:
#         coef_s += abs(i)
#     coef_avg = coef_s / len(coef)
#     coef_top = pd.DataFrame(coef_avg, index = columns_fl,columns = ['importance'])
#     coef_top = coef_top.sort_values('importance',ascending=False)
#     print(coef_top.iloc[0:10,:])
        
    print('frauds_prec : ', np.mean(frauds_prec))
    print('fradus_recall : ', np.mean(fradus_recall))
    print('\n')
    return np.mean(auc_list),mean_tpr

# %%
v_2
# Out:
# ['pastavg3', 'cr3']

# %%
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
mean_tpr_dict_svm = dict()
for fl in vs_fl.items():
#    print(fl)
    svm_model = svm( df_fl, fl,label = 'label')
    print(fl)
    print(svm_model[0])
    mean_tpr_dict_svm[fl[0]] = svm_model[1]
    print('============================')
# Out:
# dataset:  (53635, 15) /n 487.0
# iterate_num:  1
#  sum of test_y: 122.0
# sum of pred:  2960.0
#
# 0.6313572862418215
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  2962.0
#
# 0.7022561187010106
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  2938.0
#
# 0.693073594675925
# iterate_num:  4
#  sum of test_y: 121.0
# sum of pred:  3034.0
#
# 0.6850323469096432
# avg_AUC :  0.6779298366321002
# avg_AUC_2 :  0.6779131239231496
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6779298366321002
# ============================
# dataset:  (53635, 16) /n 487.0
# iterate_num:  1
#  sum of test_y: 122.0
# sum of pred:  2511.0
#
# 0.7127637392397598
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  2856.0
#
# 0.6997175841787918
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  2506.0
#
# 0.6791866078886425
# iterate_num:  4
#  sum of test_y: 121.0
# sum of pred:  2887.0
#
# 0.6293705336789144
# avg_AUC :  0.6802596162465271
# avg_AUC_2 :  0.6803034066446882
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.6802596162465271
# ============================
# dataset:  (53635, 42) /n 487.0
# iterate_num:  1
#  sum of test_y: 122.0
# sum of pred:  4961.0
#
# 0.605014515605664
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  5008.0
#
# 0.606037332188371
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  4894.0
#
# 0.6188589364434853
# iterate_num:  4
#  sum of test_y: 121.0
# sum of pred:  5004.0
#
# 0.6378620250826166
# avg_AUC :  0.6169432023300342
# avg_AUC_2 :  0.616753327886643
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6169432023300342
# ============================
# dataset:  (53635, 56) /n 487.0
# iterate_num:  1
#  sum of test_y: 122.0
# sum of pred:  2639.0
#
# 0.7351694679996594
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  2781.0
#
# 0.6964326032964552
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  3027.0
#
# 0.7049501114734358
# iterate_num:  4
#  sum of test_y: 121.0
# sum of pred:  2998.0
#
# 0.6785517690503425
# avg_AUC :  0.7037759879549733
# avg_AUC_2 :  0.7037200688636809
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.7037759879549733
# ============================

# %%
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1+v_2, 'wrd+spc': selected_new_all +v_1 +v_2,'perf+spc+wrd': v_perf +v_1 +v_2 +selected_new_all}
mean_tpr_dict_svm = dict()
for fl in vs_fl.items():
#    print(fl)
    svm_model = svm( df_fl, fl,label = 'label')
    print(fl)
    print(svm_model[0])
    mean_tpr_dict_svm[fl[0]] = svm_model[1]
    print('============================')

# %% [markdown]
# # LR

# %%
def lg( data,vs, label = 'label'):
    
    
    columns_fl = vs[1]# + [ 'sic_class_x']
    data_target = data.loc[:,columns_fl + [label]]
    
        
#     train_x, test_x, train_y, test_y = train_test_split(data_x, data_y,test_size=0.2, random_state=19, 
#                                                                         stratify = data_y) 

    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    
    class_report = []
    sum_pred_list = []
    kf = StratifiedKFold(n_splits = 4, shuffle = True)
    c = 0
    data_target = data[columns_fl + [label]]
    data_target = data_target.dropna()
    data_target = data_target.reset_index(drop = True)
    for train_index, test_index in kf.split(data_target[columns_fl],data_target[label]):
        
        c += 1

        train_x = data_target.loc[train_index,columns_fl]
        train_y = data_target.loc[train_index,label]
        test_x = data_target.loc[test_index,columns_fl]
        test_y = data_target.loc[test_index,label] 

        print('iterate_num: ', c, '\n','sum of test_y:', sum(test_y))
    
        lg = LogisticRegression(class_weight = 'balanced')
        lg.fit(train_x, train_y )
        #pickle.dump(lg, open('lg_'+str(vs[0])+ '_'+str(c), 'wb'))

        pred = lg.predict(test_x)
        sum_pred_list.append(pred)
        print('sum of pred: ', sum(pred), '\n')
        # c_r = metrics.classification_report(test_y, pred, labels=[0,1], output_dict = True)
        # class_report.append(c_r)
        #print(metrics.classification_report(test_y, pred, labels=[0,1]))
        
        decision_values = lg.predict_proba(test_x)
        auc_score = roc_auc_score(test_y, decision_values[:,1])
        print(auc_score)
        auc_list.append(auc_score)
        fpr, tpr, thresholds = roc_curve(test_y, decision_values[:,1])
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        
        #print('AUC',auc_score)
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    frauds_prec = []
    fradus_recall = []
    for d in class_report:
        frauds_prec.append(d['1']['precision'])
        fradus_recall.append(d['1']['recall'])
        
    print('frauds_prec : ', np.mean(frauds_prec))
    print('fradus_recall : ', np.mean(fradus_recall))
    print('\n')
    return np.mean(auc_list),mean_tpr

# %%
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1,'perf+spc+wrd': v_perf+v_1+selected_new_all}
mean_tpr_dict_lg = dict()
for fl in vs_fl.items():
    lg_model = lg( df_fl, fl,label = 'label')
    print(fl)
    print(lg_model[0])
    mean_tpr_dict_lg[fl[0]] = lg_model[1]
    print('============================')
# Out:
# iterate_num:  1
#  sum of test_y: 122.0
# sum of pred:  5607.0
#
# 0.6999409011890089
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  5029.0
#
# 0.6429469455538324
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  5314.0
#
# 0.6876467445685233
# iterate_num:  4
#  sum of test_y: 121.0
# sum of pred:  5189.0
#
# 0.6862551913353448
# avg_AUC :  0.6791974456616774
# avg_AUC_2 :  0.6792197137340072
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6791974456616774
# ============================
# iterate_num:  1
#  sum of test_y: 122.0
# sum of pred:  5235.0
#
# 0.7177698650350954
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  5051.0
#
# 0.669646283128955
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  5237.0
#
# 0.6794512570526844
# iterate_num:  4
#  sum of test_y: 121.0
# sum of pred:  5174.0
#
# 0.6651471300786762
# avg_AUC :  0.6830036338238528
# avg_AUC_2 :  0.6828599639533116
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.6830036338238528
# ============================
# iterate_num:  1
#  sum of test_y: 122.0
# sum of pred:  5117.0
#
# 0.6142445407627571
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  5211.0
#
# 0.6317163207720601
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  5118.0
#
# 0.6373763582547716
# iterate_num:  4
#  sum of test_y: 121.0
# sum of pred:  4909.0
#
# 0.5643949501376788
# avg_AUC :  0.6119330424818169
# avg_AUC_2 :  0.6118639654915227
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('wrd+spc', ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1'])
# 0.6119330424818169
# ============================
# iterate_num:  1
#  sum of test_y: 122.0
# sum of pred:  4797.0
#
# 0.7142683530185426
# iterate_num:  2
#  sum of test_y: 122.0
# sum of pred:  4549.0
#
# 0.719702605899764
# iterate_num:  3
#  sum of test_y: 122.0
# sum of pred:  4472.0
#
# 0.6391869533514208
# iterate_num:  4
#  sum of test_y: 121.0
# sum of pred:  4881.0
#
# 0.7178065679061184
# avg_AUC :  0.6977411200439615
# avg_AUC_2 :  0.6976643894575069
# frauds_prec :  nan
# fradus_recall :  nan
#
#
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.6977411200439615
# ============================

# %% [markdown]
# # NN

# %%
def model_M1(n1,n2):
    model_m1 = None
    model_m1 = Sequential(name = 'M1')
    model_m1.add(BatchNormalization())
    model_m1.add(layers.Dense(n1,name = 'layer_1',activation='relu'))
    model_m1.add(layers.Dropout(0.3))
    #model_m1.add(layers.Dense(64,name = 'layer_2'))
    model_m1.add(BatchNormalization())
    model_m1.add(layers.Dense(n2,name = 'layer_2',activation='relu'))
    model_m1.add(layers.Dense(1,activation='sigmoid'))
    
    return model_m1

# %%
def performance_measure(pred_yp, y):
    '''
    Given lists of predicted y probability and x, y, return a dataframe of AR, AUC, Brier, Decile Table
    '''
    
    tenc_dat = pd.DataFrame({'y_true':y,'probability':pred_yp.flatten()})
    tenc_dat.sort_values('probability',axis = 0,ascending=False, inplace = True)
    tenc_dat.index = range(0,len(tenc_dat))
    y = tenc_dat['y_true']
    point = float(len(tenc_dat))/10
    point = int(round(point))
    tenc = []
    for i in range(0,10):
        tenc.append(y[(i*point):((i+1)*point)])
    tenc[9]=tenc[9].append(y[10*point:])
    total = sum(y)
    num_of_bkr = []
    for j in range(0,10):
        num_of_bkr.append(sum(tenc[j]))
    tencile_bkr = np.array(num_of_bkr)
    rate = tencile_bkr.astype(float)/total

    return rate

# %%
class AUCEvaluation(Callback):
    """ Show AUC after interval number of epoches """
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()
        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            logs['auc'] = score
            tencile=performance_measure(y_pred, self.y_val)
            logs['tencile'] = tencile
            print(" epoch:{:d} auc: {:.4f}".format(epoch, score))

# %%
def fit_model( model,x_train, y_train, x_val, y_val, x_test, y_test, model_name, verbose = 0):
    
    history = None
    result = None
    
    model_df = model
    
    #class weight for test 
    class_weights = class_weight.compute_class_weight('balanced',
                              np.unique(y_train),
                              y_train)
    class_weights = {l:c for l,c in zip(np.unique(y_train), class_weights)}
    print('class_weights',class_weights)
    # class weight for val
    val_class_weights = class_weight.compute_class_weight('balanced',
                                np.unique(y_val),
                                y_val)
    val_class_weights = {l:c for l,c in zip(np.unique(y_val), val_class_weights)}
    val_sample_weights = []
    for y in y_val:
        if y == 1:
          val_sample_weights.append(val_class_weights[1])
        else: val_sample_weights.append(val_class_weights[0])
    val_sample_weights = np.asarray(val_sample_weights)
    
    
    auc_eval = AUCEvaluation(validation_data=(x_val, y_val), interval=1)
    earlyStopping = EarlyStopping(monitor='val_my_auc',patience = 3, 
                      verbose =verbose, mode ='max')
    checkpoint = ModelCheckpoint(model_name,monitor='val_my_auc',verbose=verbose,
              save_best_only=True, save_weights_only=True, mode ='max')

    opt = optimizers.RMSprop(lr=0.0005)
    model_df.compile(optimizer= opt,
              loss='binary_crossentropy',
              metrics=['accuracy', metrics.AUC(name='my_auc')])
    
    history = model_df.fit(x_train,
                y_train,
                epochs=30,
                batch_size=512,
                callbacks=[auc_eval, earlyStopping,checkpoint], #checkpoint
                class_weight = class_weights, \
                validation_data=(x_val,y_val,val_sample_weights))
    model_df.summary()
    model_df.load_weights(model_name)
    y_pred = model_df.predict(x_test)
    y_pred_1=np.reshape(y_pred, -1)
    auc_score = roc_auc_score(y_test, y_pred_1)
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_1)
    print("AUC: " ,round(auc_score,4))
        
    return history, auc_score, fpr, tpr, thresholds, [y_test, y_pred_1]

# %%
def cross_val(n1, n2, data,label,columns_fl,model_name):
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    
    kf = StratifiedKFold(n_splits = 4, shuffle = True)
    c = 0
    data_1 = data[columns_fl + [label]]
    data_1 = data_1.dropna()
    data_target = data_1.reset_index(drop = True)
    
    predicted_res =[]
    print('dataset: ', data_target.shape, '/n', sum(data_target.label))
    
    
    for train_index, test_index in kf.split(data_target[columns_fl],data_target[label]):
        
        c += 1

        train_data = data_target.loc[train_index,columns_fl]
        train_label = data_target.loc[train_index,label]
        test_x = data_target.loc[test_index,columns_fl].to_numpy()
        test_y = data_target.loc[test_index,label] 

        print('iterate_num: ', c, '\n','sum of test_y:', sum(test_y))
        train_x, val_x, train_y, val_y = train_test_split(train_data.to_numpy(), train_label.to_numpy(),test_size=0.2, \
                                  random_state=42, stratify = train_label)
        print('train_x_shape',train_x.shape)
        model = model_M1(n1,n2)
        mod_res = fit_model(model, train_x, train_y, val_x, val_y, test_x, test_y, model_name+'_'+str(c)+'_NN_model')
        auc_list.append(mod_res[1])
        tprs.append(np.interp(mean_fpr, mod_res[2], mod_res[3]))
#         print(type(mod_res[-1]))
#         print(len(mod_res[-1]))
#         print(mod_res[-1])
        temp_pred_res = [mod_res[-1],test_index]
        #print(temp_pred_res)
        predicted_res.append(temp_pred_res)
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    
    return np.mean(auc_list),mean_tpr, predicted_res

# %%
label = 'label'
vs_fl = {'perf':v_perf, 'perf+spc': v_perf +v_1, 'wrd+spc': selected_new_all +v_1 ,'perf+spc+wrd': v_perf +v_1 +selected_new_all}
#
mean_tpr_dict_nn = dict()
pred_res_nn = dict()
for fl in vs_fl.items():
    print(fl[1])
    n1 = len(fl[1])*2
    n2 = len(fl[1])
    #M1 = model_M1(n1,n2)
    NN = cross_val(n1, n2, df_fl, label, fl[1], fl[0])
    print(fl)
    print(NN[0])
    mean_tpr_dict_nn[fl[0]] = NN[1]
    pred_res_nn[fl[0]] = NN[2]
# Out:
# ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue']
# dataset:  (53635, 15) /n 487.0
# iterate_num:  1
#  sum of test_y: 122.0
# train_x_shape (32180, 14)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 23ms/step - loss: 0.8369 - accuracy: 0.8020 - my_auc: 0.5571 - val_loss: 0.6769 - val_accuracy: 0.4998 - val_my_auc: 0.6139
#  epoch:0 auc: 0.6148
# Epoch 2/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.7265 - accuracy: 0.7375 - my_auc: 0.5931 - val_loss: 0.6765 - val_accuracy: 0.2964 - val_my_auc: 0.6382
#  epoch:1 auc: 0.6387
# Epoch 3/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.7119 - accuracy: 0.6922 - my_auc: 0.5843 - val_loss: 0.6728 - val_accuracy: 0.3271 - val_my_auc: 0.6478
#  epoch:2 auc: 0.6481
# Epoch 4/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.7050 - accuracy: 0.6466 - my_auc: 0.6080 - val_loss: 0.6647 - val_accuracy: 0.3727 - val_my_auc: 0.6576
#  epoch:3 auc: 0.6577
# Epoch 5/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.7067 - accuracy: 0.6115 - my_auc: 0.6184 - val_loss: 0.6587 - val_accuracy: 0.4280 - val_my_auc: 0.6630
#  epoch:4 auc: 0.6634
# Epoch 6/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6643 - accuracy: 0.6106 - my_auc: 0.6515 - val_loss: 0.6557 - val_accuracy: 0.4723 - val_my_auc: 0.6636
#  epoch:5 auc: 0.6630
# Epoch 7/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6536 - accuracy: 0.5963 - my_auc: 0.6459 - val_loss: 0.6564 - val_accuracy: 0.4911 - val_my_auc: 0.6637
#  epoch:6 auc: 0.6642
# Epoch 8/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6495 - accuracy: 0.5865 - my_auc: 0.6682 - val_loss: 0.6560 - val_accuracy: 0.5117 - val_my_auc: 0.6652
#  epoch:7 auc: 0.6647
# Epoch 9/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6449 - accuracy: 0.5879 - my_auc: 0.6304 - val_loss: 0.6545 - val_accuracy: 0.5225 - val_my_auc: 0.6666
#  epoch:8 auc: 0.6665
# Epoch 10/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6243 - accuracy: 0.5916 - my_auc: 0.6637 - val_loss: 0.6549 - val_accuracy: 0.5445 - val_my_auc: 0.6669
#  epoch:9 auc: 0.6668
# Epoch 11/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6312 - accuracy: 0.5913 - my_auc: 0.6792 - val_loss: 0.6559 - val_accuracy: 0.5503 - val_my_auc: 0.6664
#  epoch:10 auc: 0.6661
# Epoch 12/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6689 - accuracy: 0.5806 - my_auc: 0.6955 - val_loss: 0.6557 - val_accuracy: 0.5674 - val_my_auc: 0.6667
#  epoch:11 auc: 0.6672
# Epoch 13/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6554 - accuracy: 0.5995 - my_auc: 0.6698 - val_loss: 0.6553 - val_accuracy: 0.5641 - val_my_auc: 0.6682
#  epoch:12 auc: 0.6685
# Epoch 14/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6739 - accuracy: 0.5958 - my_auc: 0.6599 - val_loss: 0.6556 - val_accuracy: 0.5774 - val_my_auc: 0.6670
#  epoch:13 auc: 0.6668
# Epoch 15/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6496 - accuracy: 0.5947 - my_auc: 0.7020 - val_loss: 0.6551 - val_accuracy: 0.5744 - val_my_auc: 0.6682
#  epoch:14 auc: 0.6684
# Epoch 16/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6245 - accuracy: 0.5930 - my_auc: 0.6486 - val_loss: 0.6541 - val_accuracy: 0.5516 - val_my_auc: 0.6724
#  epoch:15 auc: 0.6723
# Epoch 17/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6693 - accuracy: 0.5693 - my_auc: 0.6754 - val_loss: 0.6555 - val_accuracy: 0.5477 - val_my_auc: 0.6707
#  epoch:16 auc: 0.6711
# Epoch 18/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6585 - accuracy: 0.5665 - my_auc: 0.6795 - val_loss: 0.6562 - val_accuracy: 0.5470 - val_my_auc: 0.6700
#  epoch:17 auc: 0.6699
# Epoch 19/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6435 - accuracy: 0.5720 - my_auc: 0.6713 - val_loss: 0.6561 - val_accuracy: 0.5506 - val_my_auc: 0.6697
#  epoch:18 auc: 0.6702
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_4 (Batch (None, 14)                56
# _________________________________________________________________
# layer_1 (Dense)              (None, 28)                420
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28)                0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 28)                112
# _________________________________________________________________
# layer_2 (Dense)              (None, 14)                406
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 1,009
# Trainable params: 925
# Non-trainable params: 84
# _________________________________________________________________
# AUC:  0.6595
# iterate_num:  2
#  sum of test_y: 122.0
# train_x_shape (32180, 14)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 22ms/step - loss: 0.7846 - accuracy: 0.2237 - my_auc: 0.4807 - val_loss: 0.6925 - val_accuracy: 0.7578 - val_my_auc: 0.5377
#  epoch:0 auc: 0.5361
# Epoch 2/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7130 - accuracy: 0.3024 - my_auc: 0.5347 - val_loss: 0.6885 - val_accuracy: 0.6034 - val_my_auc: 0.5476
#  epoch:1 auc: 0.5466
# Epoch 3/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6775 - accuracy: 0.3808 - my_auc: 0.5685 - val_loss: 0.6813 - val_accuracy: 0.4144 - val_my_auc: 0.5842
#  epoch:2 auc: 0.5849
# Epoch 4/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6951 - accuracy: 0.4050 - my_auc: 0.5960 - val_loss: 0.6755 - val_accuracy: 0.3889 - val_my_auc: 0.6018
#  epoch:3 auc: 0.6013
# Epoch 5/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6453 - accuracy: 0.4485 - my_auc: 0.6328 - val_loss: 0.6696 - val_accuracy: 0.4366 - val_my_auc: 0.6176
#  epoch:4 auc: 0.6168
# Epoch 6/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6476 - accuracy: 0.4823 - my_auc: 0.6488 - val_loss: 0.6656 - val_accuracy: 0.4876 - val_my_auc: 0.6282
#  epoch:5 auc: 0.6279
# Epoch 7/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6262 - accuracy: 0.4976 - my_auc: 0.6602 - val_loss: 0.6642 - val_accuracy: 0.5380 - val_my_auc: 0.6327
#  epoch:6 auc: 0.6322
# Epoch 8/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6697 - accuracy: 0.5031 - my_auc: 0.6577 - val_loss: 0.6636 - val_accuracy: 0.5619 - val_my_auc: 0.6355
#  epoch:7 auc: 0.6354
# Epoch 9/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6850 - accuracy: 0.5152 - my_auc: 0.6428 - val_loss: 0.6659 - val_accuracy: 0.5764 - val_my_auc: 0.6345
#  epoch:8 auc: 0.6345
# Epoch 10/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6027 - accuracy: 0.5365 - my_auc: 0.7065 - val_loss: 0.6684 - val_accuracy: 0.5825 - val_my_auc: 0.6350
#  epoch:9 auc: 0.6348
# Epoch 11/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6604 - accuracy: 0.5288 - my_auc: 0.6526 - val_loss: 0.6714 - val_accuracy: 0.5905 - val_my_auc: 0.6339
#  epoch:10 auc: 0.6337
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_6 (Batch (None, 14)                56
# _________________________________________________________________
# layer_1 (Dense)              (None, 28)                420
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 28)                0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 28)                112
# _________________________________________________________________
# layer_2 (Dense)              (None, 14)                406
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 1,009
# Trainable params: 925
# Non-trainable params: 84
# _________________________________________________________________
# AUC:  0.6798
# iterate_num:  3
#  sum of test_y: 122.0
# train_x_shape (32180, 14)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 22ms/step - loss: 0.9402 - accuracy: 0.5890 - my_auc: 0.4587 - val_loss: 0.6964 - val_accuracy: 0.7266 - val_my_auc: 0.5190
#  epoch:0 auc: 0.5201
# Epoch 2/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.8417 - accuracy: 0.5514 - my_auc: 0.4992 - val_loss: 0.6943 - val_accuracy: 0.3922 - val_my_auc: 0.5270
#  epoch:1 auc: 0.5263
# Epoch 3/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6989 - accuracy: 0.5328 - my_auc: 0.5927 - val_loss: 0.6879 - val_accuracy: 0.3178 - val_my_auc: 0.5656
#  epoch:2 auc: 0.5652
# Epoch 4/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6705 - accuracy: 0.5276 - my_auc: 0.6148 - val_loss: 0.6752 - val_accuracy: 0.3444 - val_my_auc: 0.6003
#  epoch:3 auc: 0.6003
# Epoch 5/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6630 - accuracy: 0.5334 - my_auc: 0.6405 - val_loss: 0.6646 - val_accuracy: 0.3930 - val_my_auc: 0.6215
#  epoch:4 auc: 0.6217
# Epoch 6/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.7327 - accuracy: 0.5217 - my_auc: 0.6198 - val_loss: 0.6566 - val_accuracy: 0.4328 - val_my_auc: 0.6363
#  epoch:5 auc: 0.6364
# Epoch 7/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7128 - accuracy: 0.5272 - my_auc: 0.6461 - val_loss: 0.6504 - val_accuracy: 0.4827 - val_my_auc: 0.6453
#  epoch:6 auc: 0.6457
# Epoch 8/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6846 - accuracy: 0.5452 - my_auc: 0.6375 - val_loss: 0.6480 - val_accuracy: 0.4932 - val_my_auc: 0.6513
#  epoch:7 auc: 0.6518
# Epoch 9/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6149 - accuracy: 0.5588 - my_auc: 0.6874 - val_loss: 0.6443 - val_accuracy: 0.5109 - val_my_auc: 0.6589
#  epoch:8 auc: 0.6591
# Epoch 10/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6552 - accuracy: 0.5568 - my_auc: 0.6297 - val_loss: 0.6415 - val_accuracy: 0.5164 - val_my_auc: 0.6640
#  epoch:9 auc: 0.6647
# Epoch 11/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6339 - accuracy: 0.5566 - my_auc: 0.6691 - val_loss: 0.6395 - val_accuracy: 0.5157 - val_my_auc: 0.6698
#  epoch:10 auc: 0.6692
# Epoch 12/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6614 - accuracy: 0.5437 - my_auc: 0.6578 - val_loss: 0.6360 - val_accuracy: 0.5382 - val_my_auc: 0.6728
#  epoch:11 auc: 0.6726
# Epoch 13/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6476 - accuracy: 0.5588 - my_auc: 0.6490 - val_loss: 0.6330 - val_accuracy: 0.5257 - val_my_auc: 0.6790
#  epoch:12 auc: 0.6788
# Epoch 14/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7021 - accuracy: 0.5378 - my_auc: 0.6784 - val_loss: 0.6305 - val_accuracy: 0.5445 - val_my_auc: 0.6834
#  epoch:13 auc: 0.6840
# Epoch 15/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6341 - accuracy: 0.5726 - my_auc: 0.6491 - val_loss: 0.6289 - val_accuracy: 0.5358 - val_my_auc: 0.6858
#  epoch:14 auc: 0.6856
# Epoch 16/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6276 - accuracy: 0.5549 - my_auc: 0.6885 - val_loss: 0.6289 - val_accuracy: 0.5445 - val_my_auc: 0.6872
#  epoch:15 auc: 0.6866
# Epoch 17/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6302 - accuracy: 0.5585 - my_auc: 0.7270 - val_loss: 0.6281 - val_accuracy: 0.5533 - val_my_auc: 0.6879
#  epoch:16 auc: 0.6880
# Epoch 18/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6340 - accuracy: 0.5623 - my_auc: 0.6824 - val_loss: 0.6280 - val_accuracy: 0.5513 - val_my_auc: 0.6902
#  epoch:17 auc: 0.6902
# Epoch 19/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6394 - accuracy: 0.5612 - my_auc: 0.6824 - val_loss: 0.6277 - val_accuracy: 0.5549 - val_my_auc: 0.6895
#  epoch:18 auc: 0.6900
# Epoch 20/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6801 - accuracy: 0.5622 - my_auc: 0.6691 - val_loss: 0.6257 - val_accuracy: 0.5544 - val_my_auc: 0.6927
#  epoch:19 auc: 0.6928
# Epoch 21/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6538 - accuracy: 0.5545 - my_auc: 0.6943 - val_loss: 0.6257 - val_accuracy: 0.5635 - val_my_auc: 0.6929
#  epoch:20 auc: 0.6932
# Epoch 22/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6258 - accuracy: 0.5730 - my_auc: 0.6917 - val_loss: 0.6247 - val_accuracy: 0.5564 - val_my_auc: 0.6943
#  epoch:21 auc: 0.6946
# Epoch 23/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.5626 - accuracy: 0.5800 - my_auc: 0.7117 - val_loss: 0.6234 - val_accuracy: 0.5470 - val_my_auc: 0.6978
#  epoch:22 auc: 0.6982
# Epoch 24/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6388 - accuracy: 0.5545 - my_auc: 0.7101 - val_loss: 0.6229 - val_accuracy: 0.5549 - val_my_auc: 0.7000
#  epoch:23 auc: 0.7003
# Epoch 25/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6658 - accuracy: 0.5597 - my_auc: 0.6890 - val_loss: 0.6211 - val_accuracy: 0.5517 - val_my_auc: 0.7017
#  epoch:24 auc: 0.7016
# Epoch 26/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.5990 - accuracy: 0.5654 - my_auc: 0.7054 - val_loss: 0.6201 - val_accuracy: 0.5538 - val_my_auc: 0.7025
#  epoch:25 auc: 0.7024
# Epoch 27/30
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6170 - accuracy: 0.5641 - my_auc: 0.6975 - val_loss: 0.6193 - val_accuracy: 0.5460 - val_my_auc: 0.7023
#  epoch:26 auc: 0.7030
# Epoch 28/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6039 - accuracy: 0.5544 - my_auc: 0.7228 - val_loss: 0.6176 - val_accuracy: 0.5604 - val_my_auc: 0.7061
#  epoch:27 auc: 0.7066
# Epoch 29/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6065 - accuracy: 0.5678 - my_auc: 0.7036 - val_loss: 0.6181 - val_accuracy: 0.5592 - val_my_auc: 0.7048
#  epoch:28 auc: 0.7052
# Epoch 30/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6386 - accuracy: 0.5623 - my_auc: 0.7053 - val_loss: 0.6182 - val_accuracy: 0.5725 - val_my_auc: 0.7051
#  epoch:29 auc: 0.7052
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_8 (Batch (None, 14)                56
# _________________________________________________________________
# layer_1 (Dense)              (None, 28)                420
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 28)                0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 28)                112
# _________________________________________________________________
# layer_2 (Dense)              (None, 14)                406
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 1,009
# Trainable params: 925
# Non-trainable params: 84
# _________________________________________________________________
# AUC:  0.662
# iterate_num:  4
#  sum of test_y: 121.0
# train_x_shape (32181, 14)
# class_weights {0.0: 0.5045942047165077, 1.0: 54.91638225255973}
# Epoch 1/30
# 63/63 [==============================] - 3s 22ms/step - loss: 0.7137 - accuracy: 0.6104 - my_auc: 0.5861 - val_loss: 0.7013 - val_accuracy: 0.3281 - val_my_auc: 0.4795
#  epoch:0 auc: 0.4805
# Epoch 2/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7143 - accuracy: 0.5797 - my_auc: 0.5816 - val_loss: 0.7068 - val_accuracy: 0.2808 - val_my_auc: 0.4826
#  epoch:1 auc: 0.4818
# Epoch 3/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6461 - accuracy: 0.5628 - my_auc: 0.5833 - val_loss: 0.7065 - val_accuracy: 0.2631 - val_my_auc: 0.5087
#  epoch:2 auc: 0.5080
# Epoch 4/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6774 - accuracy: 0.5386 - my_auc: 0.6303 - val_loss: 0.6996 - val_accuracy: 0.2892 - val_my_auc: 0.5493
#  epoch:3 auc: 0.5492
# Epoch 5/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6702 - accuracy: 0.5285 - my_auc: 0.6284 - val_loss: 0.6897 - val_accuracy: 0.3497 - val_my_auc: 0.5877
#  epoch:4 auc: 0.5881
# Epoch 6/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6465 - accuracy: 0.5375 - my_auc: 0.6807 - val_loss: 0.6784 - val_accuracy: 0.4090 - val_my_auc: 0.6188
#  epoch:5 auc: 0.6190
# Epoch 7/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6261 - accuracy: 0.5463 - my_auc: 0.6731 - val_loss: 0.6703 - val_accuracy: 0.4380 - val_my_auc: 0.6372
#  epoch:6 auc: 0.6385
# Epoch 8/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6749 - accuracy: 0.5229 - my_auc: 0.6702 - val_loss: 0.6650 - val_accuracy: 0.4913 - val_my_auc: 0.6504
#  epoch:7 auc: 0.6509
# Epoch 9/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6696 - accuracy: 0.5445 - my_auc: 0.6544 - val_loss: 0.6617 - val_accuracy: 0.5113 - val_my_auc: 0.6591
#  epoch:8 auc: 0.6594
# Epoch 10/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6469 - accuracy: 0.5480 - my_auc: 0.6922 - val_loss: 0.6615 - val_accuracy: 0.5260 - val_my_auc: 0.6610
#  epoch:9 auc: 0.6614
# Epoch 11/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6801 - accuracy: 0.5413 - my_auc: 0.6526 - val_loss: 0.6620 - val_accuracy: 0.5322 - val_my_auc: 0.6623
#  epoch:10 auc: 0.6622
# Epoch 12/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6628 - accuracy: 0.5398 - my_auc: 0.6872 - val_loss: 0.6628 - val_accuracy: 0.5447 - val_my_auc: 0.6608
#  epoch:11 auc: 0.6607
# Epoch 13/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6662 - accuracy: 0.5454 - my_auc: 0.6702 - val_loss: 0.6642 - val_accuracy: 0.5483 - val_my_auc: 0.6615
#  epoch:12 auc: 0.6614
# Epoch 14/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6346 - accuracy: 0.5514 - my_auc: 0.7117 - val_loss: 0.6636 - val_accuracy: 0.5608 - val_my_auc: 0.6618
#  epoch:13 auc: 0.6619
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_10 (Batc (None, 14)                56
# _________________________________________________________________
# layer_1 (Dense)              (None, 28)                420
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 28)                0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 28)                112
# _________________________________________________________________
# layer_2 (Dense)              (None, 14)                406
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 1,009
# Trainable params: 925
# Non-trainable params: 84
# _________________________________________________________________
# AUC:  0.6404
# avg_AUC :  0.6604254215810862
# avg_AUC_2 :  0.6604962030547995
# ('perf', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue'])
# 0.6604254215810862
# ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1']
# dataset:  (53635, 16) /n 487.0
# iterate_num:  1
#  sum of test_y: 122.0
# train_x_shape (32180, 15)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 22ms/step - loss: 0.7944 - accuracy: 0.5117 - my_auc: 0.5042 - val_loss: 0.6965 - val_accuracy: 0.6709 - val_my_auc: 0.4883
#  epoch:0 auc: 0.4881
# Epoch 2/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6908 - accuracy: 0.5093 - my_auc: 0.5721 - val_loss: 0.6948 - val_accuracy: 0.2420 - val_my_auc: 0.5143
#  epoch:1 auc: 0.5150
# Epoch 3/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7815 - accuracy: 0.4968 - my_auc: 0.5759 - val_loss: 0.6908 - val_accuracy: 0.2380 - val_my_auc: 0.5627
#  epoch:2 auc: 0.5630
# Epoch 4/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7721 - accuracy: 0.4986 - my_auc: 0.5704 - val_loss: 0.6834 - val_accuracy: 0.3270 - val_my_auc: 0.5953
#  epoch:3 auc: 0.5946
# Epoch 5/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6881 - accuracy: 0.5238 - my_auc: 0.5896 - val_loss: 0.6772 - val_accuracy: 0.4027 - val_my_auc: 0.6147
#  epoch:4 auc: 0.6146
# Epoch 6/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6675 - accuracy: 0.5306 - my_auc: 0.6327 - val_loss: 0.6715 - val_accuracy: 0.4591 - val_my_auc: 0.6252
#  epoch:5 auc: 0.6259
# Epoch 7/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6756 - accuracy: 0.5342 - my_auc: 0.6404 - val_loss: 0.6670 - val_accuracy: 0.5088 - val_my_auc: 0.6346
#  epoch:6 auc: 0.6351
# Epoch 8/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6801 - accuracy: 0.5409 - my_auc: 0.6643 - val_loss: 0.6630 - val_accuracy: 0.5342 - val_my_auc: 0.6436
#  epoch:7 auc: 0.6431
# Epoch 9/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6212 - accuracy: 0.5559 - my_auc: 0.6847 - val_loss: 0.6623 - val_accuracy: 0.5619 - val_my_auc: 0.6483
#  epoch:8 auc: 0.6486
# Epoch 10/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6639 - accuracy: 0.5559 - my_auc: 0.6687 - val_loss: 0.6593 - val_accuracy: 0.5756 - val_my_auc: 0.6518
#  epoch:9 auc: 0.6518
# Epoch 11/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6629 - accuracy: 0.5484 - my_auc: 0.6826 - val_loss: 0.6580 - val_accuracy: 0.5825 - val_my_auc: 0.6557
#  epoch:10 auc: 0.6560
# Epoch 12/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6250 - accuracy: 0.5643 - my_auc: 0.6744 - val_loss: 0.6571 - val_accuracy: 0.5872 - val_my_auc: 0.6593
#  epoch:11 auc: 0.6596
# Epoch 13/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6327 - accuracy: 0.5617 - my_auc: 0.6827 - val_loss: 0.6564 - val_accuracy: 0.5895 - val_my_auc: 0.6615
#  epoch:12 auc: 0.6617
# Epoch 14/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6517 - accuracy: 0.5575 - my_auc: 0.6990 - val_loss: 0.6566 - val_accuracy: 0.5998 - val_my_auc: 0.6628
#  epoch:13 auc: 0.6625
# Epoch 15/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6296 - accuracy: 0.5728 - my_auc: 0.7109 - val_loss: 0.6560 - val_accuracy: 0.6061 - val_my_auc: 0.6627
#  epoch:14 auc: 0.6633
# Epoch 16/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6284 - accuracy: 0.5742 - my_auc: 0.6935 - val_loss: 0.6566 - val_accuracy: 0.6114 - val_my_auc: 0.6623
#  epoch:15 auc: 0.6622
# Epoch 17/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6619 - accuracy: 0.5678 - my_auc: 0.6763 - val_loss: 0.6585 - val_accuracy: 0.6187 - val_my_auc: 0.6617
#  epoch:16 auc: 0.6614
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_12 (Batc (None, 15)                60
# _________________________________________________________________
# layer_1 (Dense)              (None, 30)                480
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30)                0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 30)                120
# _________________________________________________________________
# layer_2 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,141
# Trainable params: 1,051
# Non-trainable params: 90
# _________________________________________________________________
# AUC:  0.6832
# iterate_num:  2
#  sum of test_y: 122.0
# train_x_shape (32180, 15)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 27ms/step - loss: 0.8149 - accuracy: 0.6012 - my_auc: 0.5181 - val_loss: 0.6950 - val_accuracy: 0.0652 - val_my_auc: 0.5526
#  epoch:0 auc: 0.5552
# Epoch 2/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7355 - accuracy: 0.5400 - my_auc: 0.5960 - val_loss: 0.6929 - val_accuracy: 0.1059 - val_my_auc: 0.5928
#  epoch:1 auc: 0.5945
# Epoch 3/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6782 - accuracy: 0.5160 - my_auc: 0.5990 - val_loss: 0.6861 - val_accuracy: 0.1654 - val_my_auc: 0.6161
#  epoch:2 auc: 0.6169
# Epoch 4/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6533 - accuracy: 0.4994 - my_auc: 0.6086 - val_loss: 0.6775 - val_accuracy: 0.2253 - val_my_auc: 0.6220
#  epoch:3 auc: 0.6216
# Epoch 5/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6797 - accuracy: 0.4901 - my_auc: 0.6434 - val_loss: 0.6716 - val_accuracy: 0.2893 - val_my_auc: 0.6245
#  epoch:4 auc: 0.6250
# Epoch 6/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6546 - accuracy: 0.4924 - my_auc: 0.6439 - val_loss: 0.6679 - val_accuracy: 0.3589 - val_my_auc: 0.6287
#  epoch:5 auc: 0.6278
# Epoch 7/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6631 - accuracy: 0.5047 - my_auc: 0.6775 - val_loss: 0.6653 - val_accuracy: 0.4050 - val_my_auc: 0.6288
#  epoch:6 auc: 0.6295
# Epoch 8/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6548 - accuracy: 0.5053 - my_auc: 0.6681 - val_loss: 0.6638 - val_accuracy: 0.4348 - val_my_auc: 0.6327
#  epoch:7 auc: 0.6321
# Epoch 9/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6391 - accuracy: 0.5017 - my_auc: 0.6715 - val_loss: 0.6638 - val_accuracy: 0.4673 - val_my_auc: 0.6325
#  epoch:8 auc: 0.6321
# Epoch 10/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6460 - accuracy: 0.5196 - my_auc: 0.6768 - val_loss: 0.6642 - val_accuracy: 0.4773 - val_my_auc: 0.6322
#  epoch:9 auc: 0.6322
# Epoch 11/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6363 - accuracy: 0.5212 - my_auc: 0.6811 - val_loss: 0.6639 - val_accuracy: 0.4883 - val_my_auc: 0.6345
#  epoch:10 auc: 0.6349
# Epoch 12/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6494 - accuracy: 0.5254 - my_auc: 0.6835 - val_loss: 0.6628 - val_accuracy: 0.4930 - val_my_auc: 0.6390
#  epoch:11 auc: 0.6391
# Epoch 13/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6307 - accuracy: 0.5254 - my_auc: 0.7063 - val_loss: 0.6613 - val_accuracy: 0.4950 - val_my_auc: 0.6434
#  epoch:12 auc: 0.6429
# Epoch 14/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6105 - accuracy: 0.5276 - my_auc: 0.6929 - val_loss: 0.6601 - val_accuracy: 0.5019 - val_my_auc: 0.6434
#  epoch:13 auc: 0.6430
# Epoch 15/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6631 - accuracy: 0.5265 - my_auc: 0.6827 - val_loss: 0.6594 - val_accuracy: 0.5044 - val_my_auc: 0.6458
#  epoch:14 auc: 0.6453
# Epoch 16/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.5975 - accuracy: 0.5403 - my_auc: 0.7291 - val_loss: 0.6611 - val_accuracy: 0.5107 - val_my_auc: 0.6448
#  epoch:15 auc: 0.6452
# Epoch 17/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6233 - accuracy: 0.5325 - my_auc: 0.7009 - val_loss: 0.6617 - val_accuracy: 0.5149 - val_my_auc: 0.6460
#  epoch:16 auc: 0.6462
# Epoch 18/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6357 - accuracy: 0.5356 - my_auc: 0.6935 - val_loss: 0.6627 - val_accuracy: 0.5193 - val_my_auc: 0.6465
#  epoch:17 auc: 0.6464
# Epoch 19/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6526 - accuracy: 0.5399 - my_auc: 0.6951 - val_loss: 0.6631 - val_accuracy: 0.5193 - val_my_auc: 0.6477
#  epoch:18 auc: 0.6477
# Epoch 20/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6403 - accuracy: 0.5376 - my_auc: 0.6991 - val_loss: 0.6619 - val_accuracy: 0.5225 - val_my_auc: 0.6499
#  epoch:19 auc: 0.6498
# Epoch 21/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6327 - accuracy: 0.5452 - my_auc: 0.7354 - val_loss: 0.6607 - val_accuracy: 0.5257 - val_my_auc: 0.6519
#  epoch:20 auc: 0.6517
# Epoch 22/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6253 - accuracy: 0.5479 - my_auc: 0.6720 - val_loss: 0.6602 - val_accuracy: 0.5336 - val_my_auc: 0.6548
#  epoch:21 auc: 0.6548
# Epoch 23/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6533 - accuracy: 0.5535 - my_auc: 0.7096 - val_loss: 0.6599 - val_accuracy: 0.5419 - val_my_auc: 0.6598
#  epoch:22 auc: 0.6591
# Epoch 24/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6694 - accuracy: 0.5517 - my_auc: 0.6988 - val_loss: 0.6609 - val_accuracy: 0.5428 - val_my_auc: 0.6597
#  epoch:23 auc: 0.6595
# Epoch 25/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6265 - accuracy: 0.5502 - my_auc: 0.7113 - val_loss: 0.6613 - val_accuracy: 0.5444 - val_my_auc: 0.6611
#  epoch:24 auc: 0.6609
# Epoch 26/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6347 - accuracy: 0.5567 - my_auc: 0.7251 - val_loss: 0.6619 - val_accuracy: 0.5442 - val_my_auc: 0.6621
#  epoch:25 auc: 0.6618
# Epoch 27/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.5876 - accuracy: 0.5620 - my_auc: 0.7227 - val_loss: 0.6636 - val_accuracy: 0.5398 - val_my_auc: 0.6625
#  epoch:26 auc: 0.6620
# Epoch 28/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6087 - accuracy: 0.5522 - my_auc: 0.7099 - val_loss: 0.6645 - val_accuracy: 0.5515 - val_my_auc: 0.6636
#  epoch:27 auc: 0.6637
# Epoch 29/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.5921 - accuracy: 0.5642 - my_auc: 0.7067 - val_loss: 0.6637 - val_accuracy: 0.5423 - val_my_auc: 0.6653
#  epoch:28 auc: 0.6654
# Epoch 30/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6305 - accuracy: 0.5483 - my_auc: 0.7196 - val_loss: 0.6633 - val_accuracy: 0.5552 - val_my_auc: 0.6662
#  epoch:29 auc: 0.6665
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_14 (Batc (None, 15)                60
# _________________________________________________________________
# layer_1 (Dense)              (None, 30)                480
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 30)                0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 30)                120
# _________________________________________________________________
# layer_2 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,141
# Trainable params: 1,051
# Non-trainable params: 90
# _________________________________________________________________
# AUC:  0.662
# iterate_num:  3
#  sum of test_y: 122.0
# train_x_shape (32180, 15)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 22ms/step - loss: 0.7397 - accuracy: 0.7076 - my_auc: 0.5583 - val_loss: 0.6903 - val_accuracy: 0.7491 - val_my_auc: 0.5294
#  epoch:0 auc: 0.5301
# Epoch 2/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7136 - accuracy: 0.6310 - my_auc: 0.5814 - val_loss: 0.6895 - val_accuracy: 0.2528 - val_my_auc: 0.5579
#  epoch:1 auc: 0.5562
# Epoch 3/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7001 - accuracy: 0.5843 - my_auc: 0.5983 - val_loss: 0.6869 - val_accuracy: 0.2742 - val_my_auc: 0.5792
#  epoch:2 auc: 0.5796
# Epoch 4/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6969 - accuracy: 0.5564 - my_auc: 0.6160 - val_loss: 0.6784 - val_accuracy: 0.3428 - val_my_auc: 0.6066
#  epoch:3 auc: 0.6086
# Epoch 5/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6749 - accuracy: 0.5565 - my_auc: 0.6392 - val_loss: 0.6711 - val_accuracy: 0.4065 - val_my_auc: 0.6267
#  epoch:4 auc: 0.6271
# Epoch 6/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6528 - accuracy: 0.5655 - my_auc: 0.6452 - val_loss: 0.6654 - val_accuracy: 0.4420 - val_my_auc: 0.6436
#  epoch:5 auc: 0.6439
# Epoch 7/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6356 - accuracy: 0.5599 - my_auc: 0.6731 - val_loss: 0.6612 - val_accuracy: 0.4797 - val_my_auc: 0.6565
#  epoch:6 auc: 0.6561
# Epoch 8/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6567 - accuracy: 0.5549 - my_auc: 0.6763 - val_loss: 0.6596 - val_accuracy: 0.5355 - val_my_auc: 0.6593
#  epoch:7 auc: 0.6607
# Epoch 9/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6625 - accuracy: 0.5749 - my_auc: 0.6845 - val_loss: 0.6567 - val_accuracy: 0.5561 - val_my_auc: 0.6684
#  epoch:8 auc: 0.6684
# Epoch 10/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6591 - accuracy: 0.5777 - my_auc: 0.6409 - val_loss: 0.6597 - val_accuracy: 0.5594 - val_my_auc: 0.6673
#  epoch:9 auc: 0.6682
# Epoch 11/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6400 - accuracy: 0.5766 - my_auc: 0.6645 - val_loss: 0.6609 - val_accuracy: 0.5644 - val_my_auc: 0.6678
#  epoch:10 auc: 0.6682
# Epoch 12/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6357 - accuracy: 0.5642 - my_auc: 0.6645 - val_loss: 0.6590 - val_accuracy: 0.5691 - val_my_auc: 0.6703
#  epoch:11 auc: 0.6696
# Epoch 13/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6731 - accuracy: 0.5655 - my_auc: 0.6440 - val_loss: 0.6599 - val_accuracy: 0.5781 - val_my_auc: 0.6678
#  epoch:12 auc: 0.6676
# Epoch 14/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6411 - accuracy: 0.5712 - my_auc: 0.6833 - val_loss: 0.6606 - val_accuracy: 0.5809 - val_my_auc: 0.6657
#  epoch:13 auc: 0.6663
# Epoch 15/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6381 - accuracy: 0.5744 - my_auc: 0.6783 - val_loss: 0.6598 - val_accuracy: 0.5921 - val_my_auc: 0.6698
#  epoch:14 auc: 0.6693
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_16 (Batc (None, 15)                60
# _________________________________________________________________
# layer_1 (Dense)              (None, 30)                480
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30)                0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 30)                120
# _________________________________________________________________
# layer_2 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,141
# Trainable params: 1,051
# Non-trainable params: 90
# _________________________________________________________________
# AUC:  0.7049
# iterate_num:  4
#  sum of test_y: 121.0
# train_x_shape (32181, 15)
# class_weights {0.0: 0.5045942047165077, 1.0: 54.91638225255973}
# Epoch 1/30
# 63/63 [==============================] - 3s 23ms/step - loss: 0.7374 - accuracy: 0.2874 - my_auc: 0.4901 - val_loss: 0.6958 - val_accuracy: 0.1989 - val_my_auc: 0.5206
#  epoch:0 auc: 0.5218
# Epoch 2/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.7031 - accuracy: 0.3866 - my_auc: 0.5268 - val_loss: 0.6926 - val_accuracy: 0.3474 - val_my_auc: 0.5443
#  epoch:1 auc: 0.5447
# Epoch 3/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7326 - accuracy: 0.4445 - my_auc: 0.5769 - val_loss: 0.6852 - val_accuracy: 0.4538 - val_my_auc: 0.5708
#  epoch:2 auc: 0.5713
# Epoch 4/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6884 - accuracy: 0.5000 - my_auc: 0.5953 - val_loss: 0.6788 - val_accuracy: 0.4741 - val_my_auc: 0.5822
#  epoch:3 auc: 0.5832
# Epoch 5/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6727 - accuracy: 0.5215 - my_auc: 0.6136 - val_loss: 0.6722 - val_accuracy: 0.4953 - val_my_auc: 0.6005
#  epoch:4 auc: 0.6018
# Epoch 6/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6798 - accuracy: 0.5287 - my_auc: 0.6554 - val_loss: 0.6696 - val_accuracy: 0.5389 - val_my_auc: 0.6114
#  epoch:5 auc: 0.6109
# Epoch 7/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6597 - accuracy: 0.5523 - my_auc: 0.6654 - val_loss: 0.6686 - val_accuracy: 0.5672 - val_my_auc: 0.6160
#  epoch:6 auc: 0.6167
# Epoch 8/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6246 - accuracy: 0.5702 - my_auc: 0.6299 - val_loss: 0.6678 - val_accuracy: 0.5746 - val_my_auc: 0.6222
#  epoch:7 auc: 0.6221
# Epoch 9/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6666 - accuracy: 0.5620 - my_auc: 0.6650 - val_loss: 0.6656 - val_accuracy: 0.6000 - val_my_auc: 0.6328
#  epoch:8 auc: 0.6327
# Epoch 10/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6515 - accuracy: 0.5769 - my_auc: 0.6645 - val_loss: 0.6653 - val_accuracy: 0.5982 - val_my_auc: 0.6389
#  epoch:9 auc: 0.6392
# Epoch 11/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6646 - accuracy: 0.5698 - my_auc: 0.6937 - val_loss: 0.6652 - val_accuracy: 0.6170 - val_my_auc: 0.6448
#  epoch:10 auc: 0.6450
# Epoch 12/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6459 - accuracy: 0.5857 - my_auc: 0.6739 - val_loss: 0.6663 - val_accuracy: 0.6153 - val_my_auc: 0.6469
#  epoch:11 auc: 0.6469
# Epoch 13/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6230 - accuracy: 0.5877 - my_auc: 0.6878 - val_loss: 0.6659 - val_accuracy: 0.6174 - val_my_auc: 0.6523
#  epoch:12 auc: 0.6520
# Epoch 14/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6492 - accuracy: 0.5711 - my_auc: 0.6911 - val_loss: 0.6654 - val_accuracy: 0.6253 - val_my_auc: 0.6535
#  epoch:13 auc: 0.6539
# Epoch 15/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5959 - accuracy: 0.5976 - my_auc: 0.7010 - val_loss: 0.6657 - val_accuracy: 0.6234 - val_my_auc: 0.6561
#  epoch:14 auc: 0.6560
# Epoch 16/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6225 - accuracy: 0.5917 - my_auc: 0.6878 - val_loss: 0.6673 - val_accuracy: 0.6194 - val_my_auc: 0.6565
#  epoch:15 auc: 0.6567
# Epoch 17/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6200 - accuracy: 0.5907 - my_auc: 0.6897 - val_loss: 0.6667 - val_accuracy: 0.6265 - val_my_auc: 0.6603
#  epoch:16 auc: 0.6602
# Epoch 18/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6388 - accuracy: 0.5911 - my_auc: 0.6836 - val_loss: 0.6657 - val_accuracy: 0.6325 - val_my_auc: 0.6630
#  epoch:17 auc: 0.6635
# Epoch 19/30
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6369 - accuracy: 0.5941 - my_auc: 0.7073 - val_loss: 0.6659 - val_accuracy: 0.6386 - val_my_auc: 0.6626
#  epoch:18 auc: 0.6630
# Epoch 20/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5739 - accuracy: 0.6157 - my_auc: 0.7445 - val_loss: 0.6677 - val_accuracy: 0.6396 - val_my_auc: 0.6618
#  epoch:19 auc: 0.6617
# Epoch 21/30
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5893 - accuracy: 0.6119 - my_auc: 0.7289 - val_loss: 0.6679 - val_accuracy: 0.6434 - val_my_auc: 0.6606
#  epoch:20 auc: 0.6610
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_18 (Batc (None, 15)                60
# _________________________________________________________________
# layer_1 (Dense)              (None, 30)                480
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 30)                0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 30)                120
# _________________________________________________________________
# layer_2 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,141
# Trainable params: 1,051
# Non-trainable params: 90
# _________________________________________________________________
# AUC:  0.6893
# avg_AUC :  0.684874222870621
# avg_AUC_2 :  0.6847938468823173
# ('perf+spc', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1'])
# 0.684874222870621
# ['WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis', 's1']
# dataset:  (53635, 42) /n 487.0
# iterate_num:  1
#  sum of test_y: 122.0
# train_x_shape (32180, 41)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 25ms/step - loss: 0.7437 - accuracy: 0.4726 - my_auc: 0.5267 - val_loss: 0.6919 - val_accuracy: 0.1619 - val_my_auc: 0.5665
#  epoch:0 auc: 0.5702
# Epoch 2/30
# 63/63 [==============================] - 0s 8ms/step - loss: 0.6847 - accuracy: 0.5315 - my_auc: 0.5743 - val_loss: 0.6907 - val_accuracy: 0.0271 - val_my_auc: 0.6008
#  epoch:1 auc: 0.6059
# Epoch 3/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6974 - accuracy: 0.5249 - my_auc: 0.5734 - val_loss: 0.6890 - val_accuracy: 0.0625 - val_my_auc: 0.6203
#  epoch:2 auc: 0.6228
# Epoch 4/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6907 - accuracy: 0.5415 - my_auc: 0.5835 - val_loss: 0.6865 - val_accuracy: 0.1230 - val_my_auc: 0.6251
#  epoch:3 auc: 0.6251
# Epoch 5/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6859 - accuracy: 0.5494 - my_auc: 0.6326 - val_loss: 0.6840 - val_accuracy: 0.1741 - val_my_auc: 0.6230
#  epoch:4 auc: 0.6232
# Epoch 6/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6703 - accuracy: 0.5674 - my_auc: 0.6516 - val_loss: 0.6721 - val_accuracy: 0.3167 - val_my_auc: 0.6323
#  epoch:5 auc: 0.6321
# Epoch 7/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6232 - accuracy: 0.6039 - my_auc: 0.6970 - val_loss: 0.6681 - val_accuracy: 0.3706 - val_my_auc: 0.6345
#  epoch:6 auc: 0.6345
# Epoch 8/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6468 - accuracy: 0.5860 - my_auc: 0.6621 - val_loss: 0.6673 - val_accuracy: 0.4533 - val_my_auc: 0.6320
#  epoch:7 auc: 0.6321
# Epoch 9/30
# 63/63 [==============================] - 0s 8ms/step - loss: 0.6395 - accuracy: 0.5905 - my_auc: 0.6922 - val_loss: 0.6727 - val_accuracy: 0.5394 - val_my_auc: 0.6223
#  epoch:8 auc: 0.6222
# Epoch 10/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.5982 - accuracy: 0.6197 - my_auc: 0.7020 - val_loss: 0.6777 - val_accuracy: 0.5896 - val_my_auc: 0.6217
#  epoch:9 auc: 0.6214
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_20 (Batc (None, 41)                164
# _________________________________________________________________
# layer_1 (Dense)              (None, 82)                3444
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 82)                0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 82)                328
# _________________________________________________________________
# layer_2 (Dense)              (None, 41)                3403
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 42
# =================================================================
# Total params: 7,381
# Trainable params: 7,135
# Non-trainable params: 246
# _________________________________________________________________
# AUC:  0.5718
# iterate_num:  2
#  sum of test_y: 122.0
# train_x_shape (32180, 41)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 25ms/step - loss: 0.8399 - accuracy: 0.7912 - my_auc: 0.4968 - val_loss: 0.6959 - val_accuracy: 0.0103 - val_my_auc: 0.5903
#  epoch:0 auc: 0.5840
# Epoch 2/30
# 63/63 [==============================] - 0s 8ms/step - loss: 0.6704 - accuracy: 0.6481 - my_auc: 0.6275 - val_loss: 0.7036 - val_accuracy: 0.0132 - val_my_auc: 0.5939
#  epoch:1 auc: 0.5920
# Epoch 3/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6908 - accuracy: 0.5807 - my_auc: 0.5818 - val_loss: 0.7055 - val_accuracy: 0.0244 - val_my_auc: 0.6058
#  epoch:2 auc: 0.6063
# Epoch 4/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6935 - accuracy: 0.5441 - my_auc: 0.6205 - val_loss: 0.7051 - val_accuracy: 0.0447 - val_my_auc: 0.6158
#  epoch:3 auc: 0.6166
# Epoch 5/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6391 - accuracy: 0.5807 - my_auc: 0.6561 - val_loss: 0.6997 - val_accuracy: 0.0788 - val_my_auc: 0.6314
#  epoch:4 auc: 0.6303
# Epoch 6/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6944 - accuracy: 0.5559 - my_auc: 0.6346 - val_loss: 0.6893 - val_accuracy: 0.1750 - val_my_auc: 0.6387
#  epoch:5 auc: 0.6388
# Epoch 7/30
# 63/63 [==============================] - 1s 8ms/step - loss: 0.7102 - accuracy: 0.5628 - my_auc: 0.6314 - val_loss: 0.6795 - val_accuracy: 0.2550 - val_my_auc: 0.6455
#  epoch:6 auc: 0.6453
# Epoch 8/30
# ...
#  epoch:1 auc: 0.6386
# Epoch 3/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6090 - accuracy: 0.5871 - my_auc: 0.7279 - val_loss: 0.6809 - val_accuracy: 0.1971 - val_my_auc: 0.6434
#  epoch:2 auc: 0.6434
# Epoch 4/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5819 - accuracy: 0.6121 - my_auc: 0.7415 - val_loss: 0.6778 - val_accuracy: 0.2416 - val_my_auc: 0.6491
#  epoch:3 auc: 0.6487
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_28 (Batc (None, 55)                220
# _________________________________________________________________
# layer_1 (Dense)              (None, 110)               6160
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 110)               0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 110)               440
# _________________________________________________________________
# layer_2 (Dense)              (None, 55)                6105
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 56
# =================================================================
# Total params: 12,981
# Trainable params: 12,651
# Non-trainable params: 330
# _________________________________________________________________
# AUC:  0.6397
# iterate_num:  2
#  sum of test_y: 122.0
# train_x_shape (32180, 55)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 26ms/step - loss: 0.6935 - accuracy: 0.6349 - my_auc: 0.5776 - val_loss: 0.6955 - val_accuracy: 0.0286 - val_my_auc: 0.5868
#  epoch:0 auc: 0.5877
# Epoch 2/30
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6662 - accuracy: 0.5906 - my_auc: 0.6645 - val_loss: 0.6942 - val_accuracy: 0.0420 - val_my_auc: 0.6413
#  epoch:1 auc: 0.6396
# Epoch 3/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6237 - accuracy: 0.6112 - my_auc: 0.7104 - val_loss: 0.6910 - val_accuracy: 0.0825 - val_my_auc: 0.6687
#  epoch:2 auc: 0.6678
# Epoch 4/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5945 - accuracy: 0.6170 - my_auc: 0.7692 - val_loss: 0.6785 - val_accuracy: 0.1757 - val_my_auc: 0.6743
#  epoch:3 auc: 0.6737
# Epoch 5/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5941 - accuracy: 0.6245 - my_auc: 0.7476 - val_loss: 0.6536 - val_accuracy: 0.3033 - val_my_auc: 0.7013
#  epoch:4 auc: 0.7019
# Epoch 6/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5616 - accuracy: 0.6599 - my_auc: 0.7675 - val_loss: 0.6319 - val_accuracy: 0.4121 - val_my_auc: 0.7172
#  epoch:5 auc: 0.7168
# Epoch 7/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5219 - accuracy: 0.6831 - my_auc: 0.7774 - val_loss: 0.6210 - val_accuracy: 0.4650 - val_my_auc: 0.7177
#  epoch:6 auc: 0.7178
# Epoch 8/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5265 - accuracy: 0.6767 - my_auc: 0.8027 - val_loss: 0.6071 - val_accuracy: 0.5492 - val_my_auc: 0.7282
#  epoch:7 auc: 0.7282
# Epoch 9/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5477 - accuracy: 0.6614 - my_auc: 0.8077 - val_loss: 0.6044 - val_accuracy: 0.6332 - val_my_auc: 0.7261
#  epoch:8 auc: 0.7259
# Epoch 10/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4959 - accuracy: 0.7036 - my_auc: 0.8260 - val_loss: 0.6141 - val_accuracy: 0.6651 - val_my_auc: 0.7130
#  epoch:9 auc: 0.7128
# Epoch 11/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5249 - accuracy: 0.6900 - my_auc: 0.8203 - val_loss: 0.6163 - val_accuracy: 0.6918 - val_my_auc: 0.7118
#  epoch:10 auc: 0.7117
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_30 (Batc (None, 55)                220
# _________________________________________________________________
# layer_1 (Dense)              (None, 110)               6160
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 110)               0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 110)               440
# _________________________________________________________________
# layer_2 (Dense)              (None, 55)                6105
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 56
# =================================================================
# Total params: 12,981
# Trainable params: 12,651
# Non-trainable params: 330
# _________________________________________________________________
# AUC:  0.7158
# iterate_num:  3
#  sum of test_y: 122.0
# train_x_shape (32180, 55)
# class_weights {0.0: 0.5045785248369292, 1.0: 55.102739726027394}
# Epoch 1/30
# 63/63 [==============================] - 3s 27ms/step - loss: 0.8045 - accuracy: 0.3163 - my_auc: 0.5271 - val_loss: 0.6837 - val_accuracy: 0.5235 - val_my_auc: 0.6068
#  epoch:0 auc: 0.6068
# Epoch 2/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6733 - accuracy: 0.5280 - my_auc: 0.6386 - val_loss: 0.6785 - val_accuracy: 0.2765 - val_my_auc: 0.6212
#  epoch:1 auc: 0.6222
# Epoch 3/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6108 - accuracy: 0.5830 - my_auc: 0.7031 - val_loss: 0.6722 - val_accuracy: 0.2430 - val_my_auc: 0.6499
#  epoch:2 auc: 0.6499
# Epoch 4/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6100 - accuracy: 0.6016 - my_auc: 0.7211 - val_loss: 0.6637 - val_accuracy: 0.3023 - val_my_auc: 0.6653
#  epoch:3 auc: 0.6658
# Epoch 5/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6020 - accuracy: 0.6232 - my_auc: 0.7340 - val_loss: 0.6581 - val_accuracy: 0.3745 - val_my_auc: 0.6660
#  epoch:4 auc: 0.6661
# Epoch 6/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5873 - accuracy: 0.6330 - my_auc: 0.7444 - val_loss: 0.6539 - val_accuracy: 0.4447 - val_my_auc: 0.6670
#  epoch:5 auc: 0.6670
# Epoch 7/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6226 - accuracy: 0.6141 - my_auc: 0.7574 - val_loss: 0.6470 - val_accuracy: 0.5610 - val_my_auc: 0.6717
#  epoch:6 auc: 0.6715
# Epoch 8/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5756 - accuracy: 0.6605 - my_auc: 0.7584 - val_loss: 0.6471 - val_accuracy: 0.6071 - val_my_auc: 0.6758
#  epoch:7 auc: 0.6753
# Epoch 9/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5374 - accuracy: 0.6765 - my_auc: 0.7861 - val_loss: 0.6563 - val_accuracy: 0.6171 - val_my_auc: 0.6701
#  epoch:8 auc: 0.6701
# Epoch 10/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5754 - accuracy: 0.6568 - my_auc: 0.7941 - val_loss: 0.6685 - val_accuracy: 0.6754 - val_my_auc: 0.6748
#  epoch:9 auc: 0.6745
# Epoch 11/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4915 - accuracy: 0.6888 - my_auc: 0.8030 - val_loss: 0.6680 - val_accuracy: 0.6766 - val_my_auc: 0.6817
#  epoch:10 auc: 0.6819
# Epoch 12/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5334 - accuracy: 0.6662 - my_auc: 0.8112 - val_loss: 0.6738 - val_accuracy: 0.7018 - val_my_auc: 0.6806
#  epoch:11 auc: 0.6807
# Epoch 13/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5229 - accuracy: 0.6833 - my_auc: 0.8243 - val_loss: 0.6885 - val_accuracy: 0.7359 - val_my_auc: 0.6806
#  epoch:12 auc: 0.6808
# Epoch 14/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4945 - accuracy: 0.7032 - my_auc: 0.8083 - val_loss: 0.6870 - val_accuracy: 0.7202 - val_my_auc: 0.6882
#  epoch:13 auc: 0.6883
# Epoch 15/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4847 - accuracy: 0.6943 - my_auc: 0.8373 - val_loss: 0.7036 - val_accuracy: 0.7407 - val_my_auc: 0.6845
#  epoch:14 auc: 0.6845
# Epoch 16/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5016 - accuracy: 0.6994 - my_auc: 0.8237 - val_loss: 0.7043 - val_accuracy: 0.7405 - val_my_auc: 0.6881
#  epoch:15 auc: 0.6882
# Epoch 17/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4952 - accuracy: 0.7035 - my_auc: 0.8325 - val_loss: 0.7036 - val_accuracy: 0.7527 - val_my_auc: 0.6936
#  epoch:16 auc: 0.6934
# Epoch 18/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5063 - accuracy: 0.7061 - my_auc: 0.8410 - val_loss: 0.7075 - val_accuracy: 0.7646 - val_my_auc: 0.6976
#  epoch:17 auc: 0.6973
# Epoch 19/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4499 - accuracy: 0.7249 - my_auc: 0.8686 - val_loss: 0.7284 - val_accuracy: 0.7795 - val_my_auc: 0.6934
#  epoch:18 auc: 0.6931
# Epoch 20/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4463 - accuracy: 0.7362 - my_auc: 0.8744 - val_loss: 0.7371 - val_accuracy: 0.7928 - val_my_auc: 0.7033
#  epoch:19 auc: 0.7035
# Epoch 21/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4375 - accuracy: 0.7438 - my_auc: 0.8685 - val_loss: 0.7415 - val_accuracy: 0.7819 - val_my_auc: 0.6976
#  epoch:20 auc: 0.6981
# Epoch 22/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4382 - accuracy: 0.7406 - my_auc: 0.8613 - val_loss: 0.7411 - val_accuracy: 0.7745 - val_my_auc: 0.7000
#  epoch:21 auc: 0.7006
# Epoch 23/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4624 - accuracy: 0.7361 - my_auc: 0.8737 - val_loss: 0.7424 - val_accuracy: 0.7708 - val_my_auc: 0.7003
#  epoch:22 auc: 0.7005
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_32 (Batc (None, 55)                220
# _________________________________________________________________
# layer_1 (Dense)              (None, 110)               6160
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 110)               0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 110)               440
# _________________________________________________________________
# layer_2 (Dense)              (None, 55)                6105
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 56
# =================================================================
# Total params: 12,981
# Trainable params: 12,651
# Non-trainable params: 330
# _________________________________________________________________
# AUC:  0.7203
# iterate_num:  4
#  sum of test_y: 121.0
# train_x_shape (32181, 55)
# class_weights {0.0: 0.5045942047165077, 1.0: 54.91638225255973}
# Epoch 1/30
# 63/63 [==============================] - 3s 26ms/step - loss: 0.6865 - accuracy: 0.4781 - my_auc: 0.5799 - val_loss: 0.6881 - val_accuracy: 0.0656 - val_my_auc: 0.6455
#  epoch:0 auc: 0.6424
# Epoch 2/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6629 - accuracy: 0.5284 - my_auc: 0.6661 - val_loss: 0.6892 - val_accuracy: 0.1155 - val_my_auc: 0.6156
#  epoch:1 auc: 0.6163
# Epoch 3/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6322 - accuracy: 0.5850 - my_auc: 0.6881 - val_loss: 0.6854 - val_accuracy: 0.1735 - val_my_auc: 0.6372
#  epoch:2 auc: 0.6353
# Epoch 4/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6156 - accuracy: 0.6160 - my_auc: 0.7176 - val_loss: 0.6739 - val_accuracy: 0.2554 - val_my_auc: 0.6497
#  epoch:3 auc: 0.6488
# Epoch 5/30
# 63/63 [==============================] - 1s 11ms/step - loss: 0.5676 - accuracy: 0.6241 - my_auc: 0.7662 - val_loss: 0.6584 - val_accuracy: 0.3502 - val_my_auc: 0.6629
#  epoch:4 auc: 0.6629
# Epoch 6/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5805 - accuracy: 0.6427 - my_auc: 0.7764 - val_loss: 0.6496 - val_accuracy: 0.4551 - val_my_auc: 0.6646
#  epoch:5 auc: 0.6652
# Epoch 7/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5472 - accuracy: 0.6811 - my_auc: 0.7676 - val_loss: 0.6443 - val_accuracy: 0.5086 - val_my_auc: 0.6745
#  epoch:6 auc: 0.6749
# Epoch 8/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5165 - accuracy: 0.6748 - my_auc: 0.7877 - val_loss: 0.6398 - val_accuracy: 0.5462 - val_my_auc: 0.6827
#  epoch:7 auc: 0.6828
# Epoch 9/30
# 63/63 [==============================] - 1s 11ms/step - loss: 0.5422 - accuracy: 0.6599 - my_auc: 0.7901 - val_loss: 0.6395 - val_accuracy: 0.6208 - val_my_auc: 0.6848
#  epoch:8 auc: 0.6855
# Epoch 10/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5538 - accuracy: 0.6740 - my_auc: 0.7896 - val_loss: 0.6505 - val_accuracy: 0.6643 - val_my_auc: 0.6817
#  epoch:9 auc: 0.6820
# Epoch 11/30
# 63/63 [==============================] - 1s 11ms/step - loss: 0.5410 - accuracy: 0.6791 - my_auc: 0.7886 - val_loss: 0.6536 - val_accuracy: 0.6994 - val_my_auc: 0.6920
#  epoch:10 auc: 0.6922
# Epoch 12/30
# 63/63 [==============================] - 1s 11ms/step - loss: 0.5269 - accuracy: 0.6953 - my_auc: 0.8063 - val_loss: 0.6704 - val_accuracy: 0.7072 - val_my_auc: 0.6838
#  epoch:11 auc: 0.6839
# Epoch 13/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5215 - accuracy: 0.6889 - my_auc: 0.8106 - val_loss: 0.6766 - val_accuracy: 0.7131 - val_my_auc: 0.6854
#  epoch:12 auc: 0.6854
# Epoch 14/30
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4986 - accuracy: 0.6974 - my_auc: 0.8439 - val_loss: 0.6904 - val_accuracy: 0.7202 - val_my_auc: 0.6765
#  epoch:13 auc: 0.6765
# Model: "M1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_34 (Batc (None, 55)                220
# _________________________________________________________________
# layer_1 (Dense)              (None, 110)               6160
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 110)               0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 110)               440
# _________________________________________________________________
# layer_2 (Dense)              (None, 55)                6105
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 56
# =================================================================
# Total params: 12,981
# Trainable params: 12,651
# Non-trainable params: 330
# _________________________________________________________________
# AUC:  0.6979
# avg_AUC :  0.693440269052285
# avg_AUC_2 :  0.6935980178427001
# ('perf+spc+wrd', ['aqi', 'asset_turnover', 'depi', 'gmi', 'opm', 'rg', 'sg', 'sgee', 'ch_rec', 'ch_inv', 'soft_asset', 'ch_cs', 'ch_roa', 'issue', 's1', 'WeakModal_3_p', 'WeakModal_3_n', 'WeakModal_3_new', 'WeakModal_3_dis', 'Negative_3_p', 'Negative_3_n', 'Negative_3_new', 'Negative_3_dis', 'Compare_3_p', 'Compare_3_n', 'Compare_3_new', 'Compare_3_dis', 'Discrep_3_p', 'Discrep_3_n', 'Discrep_3_new', 'Discrep_3_dis', 'Positive_3_p', 'Positive_3_n', 'Positive_3_new', 'Positive_3_dis', 'Achieve_3_p', 'Achieve_3_n', 'Achieve_3_new', 'Achieve_3_dis', 'Reward_3_p', 'Reward_3_n', 'Reward_3_new', 'Reward_3_dis', 'StrongModal_3_p', 'StrongModal_3_n', 'StrongModal_3_new', 'StrongModal_3_dis', 'Uncertainty_3_p', 'Uncertainty_3_n', 'Uncertainty_3_new', 'Uncertainty_3_dis', 'Litigious_3_p', 'Litigious_3_n', 'Litigious_3_new', 'Litigious_3_dis'])
# 0.693440269052285

# %% [markdown]
# ---

# %% [markdown]
# # LSTM

# %%
def model_lstm(n1,n2,n,w,l):
    model = None
    
    input_all = Input(shape=(w,l), \
               dtype='float32', name='input')
    nor = BatchNormalization()(input_all)
    LSTM_w_1 = Bidirectional(LSTM(n1, dropout = 0.3, recurrent_dropout = 0.3, \
              name = 'layer_lstm_1', return_sequences=True))(nor)
    LSTM_w_2 = LSTM(n2, activation='relu', dropout = 0.3, recurrent_dropout = 0.3,
                   name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)

    dense = Dense(n, activation='relu', name='dense')(LSTM_w_2)
    preds = Dense(1, activation='sigmoid', name='output')(dense)
    model = Model(inputs=input_all, outputs=preds)
    model._name = "model_lstm"
    model.summary()
    
    return model

# %%
def performance_measure(pred_yp, y):
    '''
    Given lists of predicted y probability and x, y, return a dataframe of AR, AUC, Brier, Decile Table
    '''
    
    tenc_dat = pd.DataFrame({'y_true':y,'probability':pred_yp.flatten()})
    tenc_dat.sort_values('probability',axis = 0,ascending=False, inplace = True)
    tenc_dat.index = range(0,len(tenc_dat))
    y = tenc_dat['y_true']
    point = float(len(tenc_dat))/10
    point = int(round(point))
    tenc = []
    for i in range(0,10):
        tenc.append(y[(i*point):((i+1)*point)])
    tenc[9]=tenc[9].append(y[10*point:])
    total = sum(y)
    num_of_bkr = []
    for j in range(0,10):
        num_of_bkr.append(sum(tenc[j]))
    tencile_bkr = np.array(num_of_bkr)
    rate = tencile_bkr.astype(float)/total

    return rate

# %%
class AUCEvaluation(Callback):
    """ Show AUC after interval number of epoches """
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()
        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            logs['auc'] = score
            tencile=performance_measure(y_pred, self.y_val)
            logs['tencile'] = tencile
            print(" epoch:{:d} auc: {:.4f}".format(epoch, score))

# %%
def fit_model( model,x_train, y_train, x_val, y_val, x_test, y_test, model_name, verbose = 0):
    
    history = None
    result = None
    
    model_df = model
    
    #class weight for test 
    class_weights = class_weight.compute_class_weight('balanced',
                              np.unique(y_train),
                              y_train)
    class_weights = {l:c for l,c in zip(np.unique(y_train), class_weights)}
    print(class_weights)
    # class weight for val
    val_class_weights = class_weight.compute_class_weight('balanced',
                                np.unique(y_val),
                                y_val)
    val_class_weights = {l:c for l,c in zip(np.unique(y_val), val_class_weights)}
    val_sample_weights = []
    for y in y_val:
        if y == 1:
          val_sample_weights.append(val_class_weights[1])
        else: val_sample_weights.append(val_class_weights[0])
    val_sample_weights = np.asarray(val_sample_weights)
    
    
    auc_eval = AUCEvaluation(validation_data=(x_val, y_val), interval=1)
    earlyStopping = EarlyStopping(monitor='val_my_auc',patience = 3, 
                      verbose =verbose, mode ='max')
    checkpoint = ModelCheckpoint(model_name,monitor='val_my_auc',verbose=verbose,
              save_best_only=True, save_weights_only=True, mode ='max')

    opt = optimizers.RMSprop(lr=0.0005)
    model_df.compile(optimizer= opt,
              loss='binary_crossentropy',
              metrics=['accuracy', metrics.AUC(name='my_auc')])
    
    history = model_df.fit(x_train,
                y_train,
                epochs=30,
                batch_size=512,
                callbacks=[auc_eval, earlyStopping,checkpoint], #checkpoint
                class_weight = class_weights, \
                validation_data=(x_val,y_val,val_sample_weights)) 
    model_df.load_weights(model_name)
    y_pred = model_df.predict(x_test)
    y_pred_1=np.reshape(y_pred, -1)
    auc_score = roc_auc_score(y_test, y_pred_1)
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_1)
    print("AUC: " ,round(auc_score,4))
        
    return history, auc_score, fpr, tpr, thresholds, [y_test, y_pred_1]

# %%
def cross_val(data, label, perf_cols, name, w):
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    predicted_res =[]
    his_auc = []
    
    kf = StratifiedKFold(n_splits = 4, shuffle = True, random_state = 42)
    c = 0

    X_perf,  Y = shift_data(df_fl, w, \
                    perf_cols, \
                    'label')
    
    for train_index, test_index in kf.split(range(len(X_perf)),Y):
        
        c += 1
        
        l1 = X_perf.shape[-1] + 16
        
        model = model_lstm(l1,l1,32,\
                    X_perf.shape[1],X_perf.shape[2])
    
        #model = model_lstm(n1,n2,n,w)
        # train_x, train_val = train_test_split(train_index,test_size=0.2, \
        #             random_state=42, stratify = Y[train_index])
        train_perf_data = X_perf[train_index]
        #train_word_data = X_word[train_x]
        #train_perf_val = X_perf[train_val]
        #train_word_val = X_word[train_val]

        train_label = Y[train_index]
        #val_label = Y[train_val]

        test_perf_x = X_perf[test_index]
        #test_word_x = X_word[test_index]
        test_y = Y[test_index] 
        
        # train_data = [train_perf_data, train_word_data]
        # val_data = [train_perf_val,train_word_val]       
        # test_x = [test_perf_x, test_word_x]

        mod_res = fit_model(model, train_perf_data, train_label, test_perf_x, test_y, test_perf_x, test_y,\
                  name+'_'+str(c))
        his_auc.append(mod_res[0].history['val_my_auc'])
        
        
        
        
        auc_list.append(mod_res[1])
        tprs.append(np.interp(mean_fpr, mod_res[2], mod_res[3]))
        temp_pred_res = [mod_res[-1],test_index]
        print(len(test_index))
        predicted_res.append(temp_pred_res)
        
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    print(pd.DataFrame(his_auc))
    print(pd.DataFrame(his_auc).mean())
    
    return np.average(auc_list), mean_tpr, predicted_res

# %%
def shift_data(data, step, perf_cols, label):
    A = []
    
    cols = perf_cols #+ words_cols
    A.append(data[cols].values)
    
    for t in range(1, step):
        d = data.groupby("cik")[cols].shift(t)
        A.append(d.values)
    A = A[::-1]
    A = np.concatenate(A, axis = 1)  # flatten shifted columns
    A = np.concatenate([data[label].values[:,None], A], axis = 1)  # add target
    #np.random.shuffle(A)
    #print(A[3])
    print('init A shape: ',A.shape)
    #print(A[3,:])
    #print(data[cols].iloc[4,:])


    
    A = A[~np.isnan(A).any(axis=1)]  # drop nan
    

    Y = A[:,0]  # get target
    #A = np.reshape(A[:,1:], (len(A), step, len(cols))) # reshape

    A = np.reshape(A[:,1:], (len(A), step, len(perf_cols) + len(words_cols)))
    
    A_perf = A[:, :, 0:len(perf_cols)]
    # # CNN_LSTM must be None x T x words x 4
    # A_words = A[:, :, len(perf_cols):]
    # #convert the shape to [[_p,_new][_dis,_n]]
    # A_words = A_words.reshape((len(A), step, int(len(words_cols)/2), 2), order = 'C')
    
    print(A_perf.shape, Y.sum())
    return A_perf, Y

# %%
# financial performance + overall change timestep = 3
cross_val(df_fl, 'label', v_perf + v_1, 'lstm_perf', 3)
# Out:
# init A shape:  (53635, 46)
# (39123, 3, 15) 341.0
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 15)]           0
# _________________________________________________________________
# batch_normalization_68 (Batc (None, 3, 15)             60
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 3, 31)             5828
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 31)                7812
# _________________________________________________________________
# dense (Dense)                (None, 32)                1024
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 14,757
# Trainable params: 14,727
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/30
# 58/58 [==============================] - 9s 56ms/step - loss: 0.7106 - accuracy: 0.3629 - my_auc: 0.5765 - val_loss: 0.6906 - val_accuracy: 0.1111 - val_my_auc: 0.6377
#  epoch:0 auc: 0.6560
# Epoch 2/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6921 - accuracy: 0.6229 - my_auc: 0.6712 - val_loss: 0.6830 - val_accuracy: 0.2577 - val_my_auc: 0.7038
#  epoch:1 auc: 0.7005
# Epoch 3/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6524 - accuracy: 0.6463 - my_auc: 0.6869 - val_loss: 0.6672 - val_accuracy: 0.3270 - val_my_auc: 0.7189
#  epoch:2 auc: 0.7201
# Epoch 4/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6464 - accuracy: 0.6003 - my_auc: 0.6950 - val_loss: 0.6447 - val_accuracy: 0.4195 - val_my_auc: 0.7255
#  epoch:3 auc: 0.7253
# Epoch 5/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6457 - accuracy: 0.5777 - my_auc: 0.6729 - val_loss: 0.6267 - val_accuracy: 0.4858 - val_my_auc: 0.7282
#  epoch:4 auc: 0.7281
# Epoch 6/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6303 - accuracy: 0.5804 - my_auc: 0.6926 - val_loss: 0.6152 - val_accuracy: 0.5085 - val_my_auc: 0.7291
#  epoch:5 auc: 0.7291
# Epoch 7/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6100 - accuracy: 0.5730 - my_auc: 0.6843 - val_loss: 0.6083 - val_accuracy: 0.5294 - val_my_auc: 0.7325
#  epoch:6 auc: 0.7327
# Epoch 8/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6006 - accuracy: 0.5743 - my_auc: 0.7186 - val_loss: 0.6038 - val_accuracy: 0.5377 - val_my_auc: 0.7363
#  epoch:7 auc: 0.7362
# Epoch 9/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6260 - accuracy: 0.5639 - my_auc: 0.7073 - val_loss: 0.5989 - val_accuracy: 0.5511 - val_my_auc: 0.7393
#  epoch:8 auc: 0.7392
# Epoch 10/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5768 - accuracy: 0.5818 - my_auc: 0.7046 - val_loss: 0.5969 - val_accuracy: 0.5391 - val_my_auc: 0.7413
#  epoch:9 auc: 0.7414
# Epoch 11/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6197 - accuracy: 0.5555 - my_auc: 0.7128 - val_loss: 0.5930 - val_accuracy: 0.5681 - val_my_auc: 0.7416
#  epoch:10 auc: 0.7416
# Epoch 12/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6018 - accuracy: 0.5853 - my_auc: 0.6963 - val_loss: 0.5885 - val_accuracy: 0.5740 - val_my_auc: 0.7453
#  epoch:11 auc: 0.7454
# Epoch 13/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6604 - accuracy: 0.5653 - my_auc: 0.6948 - val_loss: 0.5860 - val_accuracy: 0.5832 - val_my_auc: 0.7492
#  epoch:12 auc: 0.7490
# Epoch 14/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6342 - accuracy: 0.5842 - my_auc: 0.7279 - val_loss: 0.5854 - val_accuracy: 0.6398 - val_my_auc: 0.7462
#  epoch:13 auc: 0.7463
# Epoch 15/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6178 - accuracy: 0.6205 - my_auc: 0.6837 - val_loss: 0.5827 - val_accuracy: 0.6165 - val_my_auc: 0.7495
#  epoch:14 auc: 0.7493
# Epoch 16/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6294 - accuracy: 0.6045 - my_auc: 0.7359 - val_loss: 0.5820 - val_accuracy: 0.6270 - val_my_auc: 0.7515
#  epoch:15 auc: 0.7518
# Epoch 17/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5807 - accuracy: 0.6378 - my_auc: 0.7418 - val_loss: 0.5812 - val_accuracy: 0.6010 - val_my_auc: 0.7523
#  epoch:16 auc: 0.7521
# Epoch 18/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5830 - accuracy: 0.6110 - my_auc: 0.7441 - val_loss: 0.5818 - val_accuracy: 0.6176 - val_my_auc: 0.7519
#  epoch:17 auc: 0.7516
# Epoch 19/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5795 - accuracy: 0.6329 - my_auc: 0.7319 - val_loss: 0.5794 - val_accuracy: 0.6117 - val_my_auc: 0.7538
#  epoch:18 auc: 0.7537
# Epoch 20/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5950 - accuracy: 0.6048 - my_auc: 0.7425 - val_loss: 0.5787 - val_accuracy: 0.6240 - val_my_auc: 0.7545
#  epoch:19 auc: 0.7550
# Epoch 21/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6169 - accuracy: 0.6198 - my_auc: 0.7076 - val_loss: 0.5758 - val_accuracy: 0.6103 - val_my_auc: 0.7577
#  epoch:20 auc: 0.7577
# Epoch 22/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.5880 - accuracy: 0.6137 - my_auc: 0.7378 - val_loss: 0.5770 - val_accuracy: 0.6194 - val_my_auc: 0.7569
#  epoch:21 auc: 0.7570
# Epoch 23/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6072 - accuracy: 0.6145 - my_auc: 0.7486 - val_loss: 0.5770 - val_accuracy: 0.6190 - val_my_auc: 0.7568
#  epoch:22 auc: 0.7566
# Epoch 24/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6082 - accuracy: 0.6199 - my_auc: 0.7259 - val_loss: 0.5756 - val_accuracy: 0.6487 - val_my_auc: 0.7578
#  epoch:23 auc: 0.7583
# Epoch 25/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6164 - accuracy: 0.6493 - my_auc: 0.7109 - val_loss: 0.5726 - val_accuracy: 0.6359 - val_my_auc: 0.7615
#  epoch:24 auc: 0.7612
# Epoch 26/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5945 - accuracy: 0.6382 - my_auc: 0.7535 - val_loss: 0.5709 - val_accuracy: 0.6441 - val_my_auc: 0.7625
#  epoch:25 auc: 0.7624
# Epoch 27/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5779 - accuracy: 0.6496 - my_auc: 0.7774 - val_loss: 0.5740 - val_accuracy: 0.6431 - val_my_auc: 0.7601
#  epoch:26 auc: 0.7599
# Epoch 28/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6198 - accuracy: 0.6471 - my_auc: 0.7147 - val_loss: 0.5742 - val_accuracy: 0.6543 - val_my_auc: 0.7604
#  epoch:27 auc: 0.7604
# Epoch 29/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6163 - accuracy: 0.6368 - my_auc: 0.7393 - val_loss: 0.5707 - val_accuracy: 0.6698 - val_my_auc: 0.7625
#  epoch:28 auc: 0.7625
# AUC:  0.7624
# 9781
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 15)]           0
# _________________________________________________________________
# batch_normalization_69 (Batc (None, 3, 15)             60
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 3, 31)             5828
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 31)                7812
# _________________________________________________________________
# dense (Dense)                (None, 32)                1024
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 14,757
# Trainable params: 14,727
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/30
# 58/58 [==============================] - 9s 58ms/step - loss: 0.6669 - accuracy: 0.6994 - my_auc: 0.5898 - val_loss: 0.6916 - val_accuracy: 0.5266 - val_my_auc: 0.5969
#  epoch:0 auc: 0.6049
# Epoch 2/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6642 - accuracy: 0.6585 - my_auc: 0.6205 - val_loss: 0.6857 - val_accuracy: 0.3809 - val_my_auc: 0.6555
#  epoch:1 auc: 0.6556
# Epoch 3/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6671 - accuracy: 0.6246 - my_auc: 0.6700 - val_loss: 0.6704 - val_accuracy: 0.4490 - val_my_auc: 0.6735
#  epoch:2 auc: 0.6731
# Epoch 4/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6621 - accuracy: 0.6134 - my_auc: 0.7074 - val_loss: 0.6526 - val_accuracy: 0.5341 - val_my_auc: 0.6803
#  epoch:3 auc: 0.6798
# Epoch 5/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6282 - accuracy: 0.6320 - my_auc: 0.7111 - val_loss: 0.6387 - val_accuracy: 0.5287 - val_my_auc: 0.6883
#  epoch:4 auc: 0.6884
# Epoch 6/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5960 - accuracy: 0.6090 - my_auc: 0.7216 - val_loss: 0.6283 - val_accuracy: 0.5638 - val_my_auc: 0.6964
#  epoch:5 auc: 0.6963
# Epoch 7/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.5946 - accuracy: 0.6124 - my_auc: 0.7200 - val_loss: 0.6216 - val_accuracy: 0.5695 - val_my_auc: 0.7028
#  epoch:6 auc: 0.7029
# Epoch 8/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5885 - accuracy: 0.6169 - my_auc: 0.7366 - val_loss: 0.6162 - val_accuracy: 0.5999 - val_my_auc: 0.7076
#  epoch:7 auc: 0.7076
# Epoch 9/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6249 - accuracy: 0.6168 - my_auc: 0.6993 - val_loss: 0.6113 - val_accuracy: 0.6135 - val_my_auc: 0.7100
#  epoch:8 auc: 0.7102
# Epoch 10/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6034 - accuracy: 0.6334 - my_auc: 0.6995 - val_loss: 0.6079 - val_accuracy: 0.6329 - val_my_auc: 0.7144
#  epoch:9 auc: 0.7143
# Epoch 11/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6347 - accuracy: 0.6294 - my_auc: 0.7240 - val_loss: 0.6063 - val_accuracy: 0.6612 - val_my_auc: 0.7188
#  epoch:10 auc: 0.7185
# Epoch 12/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5800 - accuracy: 0.6695 - my_auc: 0.7489 - val_loss: 0.6044 - val_accuracy: 0.6126 - val_my_auc: 0.7183
#  epoch:11 auc: 0.7183
# Epoch 13/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5808 - accuracy: 0.6316 - my_auc: 0.7254 - val_loss: 0.6027 - val_accuracy: 0.6228 - val_my_auc: 0.7198
#  epoch:12 auc: 0.7196
# Epoch 14/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6299 - accuracy: 0.6194 - my_auc: 0.7012 - val_loss: 0.6015 - val_accuracy: 0.6447 - val_my_auc: 0.7198
#  epoch:13 auc: 0.7195
# Epoch 15/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6248 - accuracy: 0.6324 - my_auc: 0.7281 - val_loss: 0.6008 - val_accuracy: 0.6729 - val_my_auc: 0.7204
#  epoch:14 auc: 0.7202
# Epoch 16/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.5599 - accuracy: 0.6828 - my_auc: 0.7388 - val_loss: 0.5982 - val_accuracy: 0.6269 - val_my_auc: 0.7214
#  epoch:15 auc: 0.7215
# Epoch 17/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6075 - accuracy: 0.6293 - my_auc: 0.7290 - val_loss: 0.5951 - val_accuracy: 0.6625 - val_my_auc: 0.7246
#  epoch:16 auc: 0.7247
# Epoch 18/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6012 - accuracy: 0.6581 - my_auc: 0.7423 - val_loss: 0.5933 - val_accuracy: 0.6606 - val_my_auc: 0.7262
#  epoch:17 auc: 0.7260
# Epoch 19/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5989 - accuracy: 0.6611 - my_auc: 0.7476 - val_loss: 0.5923 - val_accuracy: 0.6473 - val_my_auc: 0.7278
#  epoch:18 auc: 0.7276
# Epoch 20/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6212 - accuracy: 0.6371 - my_auc: 0.7290 - val_loss: 0.5917 - val_accuracy: 0.6876 - val_my_auc: 0.7278
#  epoch:19 auc: 0.7273
# Epoch 21/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5734 - accuracy: 0.6819 - my_auc: 0.7430 - val_loss: 0.5914 - val_accuracy: 0.6476 - val_my_auc: 0.7282
#  epoch:20 auc: 0.7285
# Epoch 22/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6031 - accuracy: 0.6502 - my_auc: 0.7177 - val_loss: 0.5897 - val_accuracy: 0.6753 - val_my_auc: 0.7290
#  epoch:21 auc: 0.7292
# Epoch 23/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6072 - accuracy: 0.6692 - my_auc: 0.7295 - val_loss: 0.5909 - val_accuracy: 0.6583 - val_my_auc: 0.7281
#  epoch:22 auc: 0.7285
# Epoch 24/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6081 - accuracy: 0.6569 - my_auc: 0.7205 - val_loss: 0.5910 - val_accuracy: 0.6909 - val_my_auc: 0.7282
#  epoch:23 auc: 0.7280
# Epoch 25/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5628 - accuracy: 0.6981 - my_auc: 0.7523 - val_loss: 0.5905 - val_accuracy: 0.6517 - val_my_auc: 0.7286
#  epoch:24 auc: 0.7289
# AUC:  0.7292
# 9781
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 15)]           0
# _________________________________________________________________
# batch_normalization_70 (Batc (None, 3, 15)             60
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 3, 31)             5828
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 31)                7812
# _________________________________________________________________
# dense (Dense)                (None, 32)                1024
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 14,757
# Trainable params: 14,727
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/30
# 58/58 [==============================] - 10s 56ms/step - loss: 0.7104 - accuracy: 0.6252 - my_auc: 0.5145 - val_loss: 0.6904 - val_accuracy: 0.4149 - val_my_auc: 0.6239
#  epoch:0 auc: 0.6340
# Epoch 2/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6885 - accuracy: 0.7205 - my_auc: 0.6487 - val_loss: 0.6835 - val_accuracy: 0.2243 - val_my_auc: 0.6656
#  epoch:1 auc: 0.6708
# Epoch 3/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6607 - accuracy: 0.6709 - my_auc: 0.6641 - val_loss: 0.6664 - val_accuracy: 0.3412 - val_my_auc: 0.6803
#  epoch:2 auc: 0.6816
# Epoch 4/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6798 - accuracy: 0.6459 - my_auc: 0.6797 - val_loss: 0.6485 - val_accuracy: 0.4169 - val_my_auc: 0.6849
#  epoch:3 auc: 0.6860
# Epoch 5/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6526 - accuracy: 0.6208 - my_auc: 0.7004 - val_loss: 0.6357 - val_accuracy: 0.5001 - val_my_auc: 0.6903
#  epoch:4 auc: 0.6904
# Epoch 6/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6467 - accuracy: 0.6263 - my_auc: 0.6822 - val_loss: 0.6286 - val_accuracy: 0.5306 - val_my_auc: 0.6932
#  epoch:5 auc: 0.6933
# Epoch 7/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6159 - accuracy: 0.6191 - my_auc: 0.7159 - val_loss: 0.6230 - val_accuracy: 0.5932 - val_my_auc: 0.6967
#  epoch:6 auc: 0.6966
# Epoch 8/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6383 - accuracy: 0.6474 - my_auc: 0.6807 - val_loss: 0.6215 - val_accuracy: 0.5866 - val_my_auc: 0.6984
#  epoch:7 auc: 0.6988
# Epoch 9/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6282 - accuracy: 0.6308 - my_auc: 0.7052 - val_loss: 0.6193 - val_accuracy: 0.6201 - val_my_auc: 0.7004
#  epoch:8 auc: 0.7002
# Epoch 10/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6223 - accuracy: 0.6513 - my_auc: 0.7121 - val_loss: 0.6180 - val_accuracy: 0.6290 - val_my_auc: 0.7011
#  epoch:9 auc: 0.7012
# Epoch 11/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6373 - accuracy: 0.6602 - my_auc: 0.7126 - val_loss: 0.6157 - val_accuracy: 0.6215 - val_my_auc: 0.7045
#  epoch:10 auc: 0.7049
# Epoch 12/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6249 - accuracy: 0.6374 - my_auc: 0.7323 - val_loss: 0.6172 - val_accuracy: 0.6652 - val_my_auc: 0.7067
#  epoch:11 auc: 0.7064
# Epoch 13/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6449 - accuracy: 0.6701 - my_auc: 0.7155 - val_loss: 0.6156 - val_accuracy: 0.6345 - val_my_auc: 0.7081
#  epoch:12 auc: 0.7083
# Epoch 14/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6116 - accuracy: 0.6526 - my_auc: 0.7218 - val_loss: 0.6179 - val_accuracy: 0.6701 - val_my_auc: 0.7098
#  epoch:13 auc: 0.7098
# Epoch 15/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6122 - accuracy: 0.6871 - my_auc: 0.7180 - val_loss: 0.6177 - val_accuracy: 0.6256 - val_my_auc: 0.7093
#  epoch:14 auc: 0.7094
# Epoch 16/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5926 - accuracy: 0.6596 - my_auc: 0.7482 - val_loss: 0.6176 - val_accuracy: 0.6420 - val_my_auc: 0.7127
#  epoch:15 auc: 0.7125
# Epoch 17/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6100 - accuracy: 0.6534 - my_auc: 0.7410 - val_loss: 0.6189 - val_accuracy: 0.6528 - val_my_auc: 0.7145
#  epoch:16 auc: 0.7143
# Epoch 18/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5825 - accuracy: 0.6791 - my_auc: 0.7301 - val_loss: 0.6188 - val_accuracy: 0.6417 - val_my_auc: 0.7146
#  epoch:17 auc: 0.7145
# Epoch 19/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.5665 - accuracy: 0.6714 - my_auc: 0.7326 - val_loss: 0.6241 - val_accuracy: 0.6502 - val_my_auc: 0.7151
#  epoch:18 auc: 0.7154
# Epoch 20/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6354 - accuracy: 0.6512 - my_auc: 0.7220 - val_loss: 0.6281 - val_accuracy: 0.6765 - val_my_auc: 0.7174
#  epoch:19 auc: 0.7174
# Epoch 21/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6066 - accuracy: 0.6787 - my_auc: 0.7416 - val_loss: 0.6267 - val_accuracy: 0.6668 - val_my_auc: 0.7180
#  epoch:20 auc: 0.7181
# Epoch 22/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5516 - accuracy: 0.6945 - my_auc: 0.7625 - val_loss: 0.6271 - val_accuracy: 0.6348 - val_my_auc: 0.7196
#  epoch:21 auc: 0.7196
# Epoch 23/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6298 - accuracy: 0.6408 - my_auc: 0.7102 - val_loss: 0.6232 - val_accuracy: 0.6613 - val_my_auc: 0.7206
#  epoch:22 auc: 0.7206
# Epoch 24/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5958 - accuracy: 0.6594 - my_auc: 0.7624 - val_loss: 0.6211 - val_accuracy: 0.6573 - val_my_auc: 0.7213
#  epoch:23 auc: 0.7208
# Epoch 25/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.5490 - accuracy: 0.6784 - my_auc: 0.7821 - val_loss: 0.6239 - val_accuracy: 0.6599 - val_my_auc: 0.7222
#  epoch:24 auc: 0.7220
# Epoch 26/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.5560 - accuracy: 0.6863 - my_auc: 0.7673 - val_loss: 0.6260 - val_accuracy: 0.6508 - val_my_auc: 0.7220
#  epoch:25 auc: 0.7223
# Epoch 27/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5805 - accuracy: 0.6742 - my_auc: 0.7553 - val_loss: 0.6274 - val_accuracy: 0.6573 - val_my_auc: 0.7221
#  epoch:26 auc: 0.7221
# Epoch 28/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.5581 - accuracy: 0.6833 - my_auc: 0.7614 - val_loss: 0.6382 - val_accuracy: 0.6737 - val_my_auc: 0.7204
#  epoch:27 auc: 0.7207
# AUC:  0.722
# 9781
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 15)]           0
# _________________________________________________________________
# batch_normalization_71 (Batc (None, 3, 15)             60
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 3, 31)             5828
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 31)                7812
# _________________________________________________________________
# dense (Dense)                (None, 32)                1024
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 14,757
# Trainable params: 14,727
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/30
# 58/58 [==============================] - 10s 60ms/step - loss: 0.6901 - accuracy: 0.7904 - my_auc: 0.5711 - val_loss: 0.6916 - val_accuracy: 0.0257 - val_my_auc: 0.6038
#  epoch:0 auc: 0.6755
# Epoch 2/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6810 - accuracy: 0.7330 - my_auc: 0.6559 - val_loss: 0.6868 - val_accuracy: 0.1439 - val_my_auc: 0.6658
#  epoch:1 auc: 0.6855
# Epoch 3/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6579 - accuracy: 0.6836 - my_auc: 0.6626 - val_loss: 0.6758 - val_accuracy: 0.2522 - val_my_auc: 0.6848
#  epoch:2 auc: 0.6849
# Epoch 4/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6655 - accuracy: 0.6198 - my_auc: 0.6748 - val_loss: 0.6553 - val_accuracy: 0.3789 - val_my_auc: 0.6859
#  epoch:3 auc: 0.6866
# Epoch 5/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6012 - accuracy: 0.6198 - my_auc: 0.7159 - val_loss: 0.6439 - val_accuracy: 0.4229 - val_my_auc: 0.6911
#  epoch:4 auc: 0.6905
# Epoch 6/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6497 - accuracy: 0.5494 - my_auc: 0.6917 - val_loss: 0.6348 - val_accuracy: 0.4790 - val_my_auc: 0.6950
#  epoch:5 auc: 0.6952
# Epoch 7/30
# 58/58 [==============================] - 2s 31ms/step - loss: 0.6214 - accuracy: 0.5686 - my_auc: 0.6984 - val_loss: 0.6297 - val_accuracy: 0.5001 - val_my_auc: 0.6992
#  epoch:6 auc: 0.6982
# Epoch 8/30
# 58/58 [==============================] - 2s 32ms/step - loss: 0.5978 - accuracy: 0.5645 - my_auc: 0.6929 - val_loss: 0.6253 - val_accuracy: 0.5365 - val_my_auc: 0.7030
#  epoch:7 auc: 0.7030
# Epoch 9/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6096 - accuracy: 0.5730 - my_auc: 0.7229 - val_loss: 0.6246 - val_accuracy: 0.5717 - val_my_auc: 0.7047
#  epoch:8 auc: 0.7049
# Epoch 10/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6104 - accuracy: 0.5997 - my_auc: 0.7025 - val_loss: 0.6223 - val_accuracy: 0.5715 - val_my_auc: 0.7053
#  epoch:9 auc: 0.7051
# Epoch 11/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6259 - accuracy: 0.5820 - my_auc: 0.6897 - val_loss: 0.6248 - val_accuracy: 0.5760 - val_my_auc: 0.7056
#  epoch:10 auc: 0.7054
# Epoch 12/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6195 - accuracy: 0.5828 - my_auc: 0.7173 - val_loss: 0.6309 - val_accuracy: 0.6086 - val_my_auc: 0.7049
#  epoch:11 auc: 0.7049
# Epoch 13/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6040 - accuracy: 0.6130 - my_auc: 0.7194 - val_loss: 0.6299 - val_accuracy: 0.6267 - val_my_auc: 0.7064
#  epoch:12 auc: 0.7062
# Epoch 14/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6153 - accuracy: 0.6192 - my_auc: 0.7056 - val_loss: 0.6342 - val_accuracy: 0.6319 - val_my_auc: 0.7051
#  epoch:13 auc: 0.7052
# Epoch 15/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6326 - accuracy: 0.6168 - my_auc: 0.7190 - val_loss: 0.6267 - val_accuracy: 0.6323 - val_my_auc: 0.7112
#  epoch:14 auc: 0.7112
# Epoch 16/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6186 - accuracy: 0.6221 - my_auc: 0.7114 - val_loss: 0.6262 - val_accuracy: 0.6238 - val_my_auc: 0.7113
#  epoch:15 auc: 0.7114
# Epoch 17/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6231 - accuracy: 0.6043 - my_auc: 0.7216 - val_loss: 0.6350 - val_accuracy: 0.6489 - val_my_auc: 0.7109
#  epoch:16 auc: 0.7112
# Epoch 18/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.5789 - accuracy: 0.6469 - my_auc: 0.7509 - val_loss: 0.6302 - val_accuracy: 0.6268 - val_my_auc: 0.7175
#  epoch:17 auc: 0.7175
# Epoch 19/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5864 - accuracy: 0.6287 - my_auc: 0.7356 - val_loss: 0.6285 - val_accuracy: 0.6291 - val_my_auc: 0.7201
#  epoch:18 auc: 0.7200
# Epoch 20/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6185 - accuracy: 0.6151 - my_auc: 0.7283 - val_loss: 0.6290 - val_accuracy: 0.6403 - val_my_auc: 0.7220
#  epoch:19 auc: 0.7219
# Epoch 21/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.5824 - accuracy: 0.6343 - my_auc: 0.7382 - val_loss: 0.6269 - val_accuracy: 0.6293 - val_my_auc: 0.7244
#  epoch:20 auc: 0.7245
# Epoch 22/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5483 - accuracy: 0.6458 - my_auc: 0.7507 - val_loss: 0.6275 - val_accuracy: 0.6160 - val_my_auc: 0.7261
#  epoch:21 auc: 0.7261
# Epoch 23/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5924 - accuracy: 0.6140 - my_auc: 0.7476 - val_loss: 0.6230 - val_accuracy: 0.6224 - val_my_auc: 0.7295
#  epoch:22 auc: 0.7296
# Epoch 24/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5709 - accuracy: 0.6212 - my_auc: 0.7705 - val_loss: 0.6260 - val_accuracy: 0.6286 - val_my_auc: 0.7308
#  epoch:23 auc: 0.7309
# Epoch 25/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5936 - accuracy: 0.6155 - my_auc: 0.7298 - val_loss: 0.6334 - val_accuracy: 0.6381 - val_my_auc: 0.7288
#  epoch:24 auc: 0.7290
# Epoch 26/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.5810 - accuracy: 0.6249 - my_auc: 0.7279 - val_loss: 0.6396 - val_accuracy: 0.6480 - val_my_auc: 0.7286
#  epoch:25 auc: 0.7286
# Epoch 27/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.5728 - accuracy: 0.6441 - my_auc: 0.7653 - val_loss: 0.6477 - val_accuracy: 0.6447 - val_my_auc: 0.7261
#  epoch:26 auc: 0.7260
# AUC:  0.7309
# 9780
# avg_AUC :  0.7361061647450375
# avg_AUC_2 :  0.7359940029570673
#          0         1         2   ...        26        27        28
# 0  0.637706  0.703770  0.718885  ...  0.760127  0.760369  0.762488
# 1  0.596893  0.655523  0.673527  ...       NaN       NaN       NaN
# 2  0.623929  0.665597  0.680264  ...  0.722130  0.720376       NaN
# 3  0.603823  0.665841  0.684807  ...  0.726055       NaN       NaN
#
# [4 rows x 29 columns]
# 0     0.615588
# 1     0.672683
# 2     0.689371
# 3     0.694167
# 4     0.699498
# 5     0.703418
# 6     0.707794
# 7     0.711334
# 8     0.713608
# 9     0.715529
# 10    0.717634
# 11    0.718803
# 12    0.720874
# 13    0.720227
# 14    0.722611
# 15    0.724225
# 16    0.725571
# 17    0.727540
# 18    0.729200
# 19    0.730402
# 20    0.732058
# 21    0.732878
# 22    0.733737
# 23    0.734540
# 24    0.735277
# 25    0.737722
# 26    0.736104
# 27    0.740372
# 28    0.762488
# dtype: float64
# (0.7361061647450375,
#  array([0.00294118, 0.06751026, 0.11145691, 0.149658  , 0.19069767,
#         0.22294802, 0.25813953, 0.28156635, 0.30800274, 0.32852257,
#         0.35492476, 0.38426813, 0.40772914, 0.42828317, 0.4370383 ,
#         0.45167579, 0.46340629, 0.4751026 , 0.50153899, 0.51614227,
#         0.5249316 , 0.53666211, 0.54839261, 0.55427497, 0.56894665,
#         0.57770178, 0.59534884, 0.60707934, 0.6129275 , 0.6246238 ,
#         0.63932969, 0.64815321, 0.65694254, 0.66863885, 0.68040356,
#         0.69213406, 0.70092339, 0.70974692, 0.7126881 , 0.72151163,
#         0.73614911, 0.73909029, 0.74787962, 0.75666895, 0.76545828,
#         0.77718878, 0.78601231, 0.79480164, 0.80355677, 0.8123461 ,
#         0.81528728, 0.81528728, 0.82407661, 0.82992476, 0.83871409,
#         0.84162107, 0.84746922, 0.84746922, 0.8504104 , 0.8504104 ,
#         0.85625855, 0.85625855, 0.86802326, 0.87390561, 0.88272914,
#         0.89445964, 0.90328317, 0.92089603, 0.92383721, 0.92383721,
#         0.93266074, 0.93556772, 0.94145007, 0.95321477, 0.95615595,
#         0.9620041 , 0.96785226, 0.97366621, 0.97366621, 0.97657319,
#         0.98826949, 0.99121067, 0.99121067, 0.99121067, 0.99121067,
#         0.99121067, 0.99415185, 0.99415185, 0.99415185, 0.99415185,
#         0.99415185, 0.99415185, 0.99415185, 0.99415185, 0.99415185,
#         0.99415185, 1.        , 1.        , 1.        , 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5613756 , 0.5589938 , 0.23280266, ..., 0.09382552, 0.41997403,
#            0.4547148 ], dtype=float32)],
#    array([    6,    10,    12, ..., 39113, 39118, 39121])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.43964124, 0.46301618, 0.56452525, ..., 0.30372855, 0.46984226,
#            0.48313117], dtype=float32)],
#    array([    0,     5,     9, ..., 39117, 39119, 39122])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.543832  , 0.49685127, 0.40532136, ..., 0.7876654 , 0.8054595 ,
#            0.4108003 ], dtype=float32)],
#    array([    1,     2,     4, ..., 39106, 39107, 39115])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.41336298, 0.5621213 , 0.516376  , ..., 0.00134799, 0.06136245,
#            0.46417785], dtype=float32)],
#    array([    3,     8,    11, ..., 39109, 39116, 39120])]])

# %%
# financial performance + overall change timestep = 2
cross_val(df_fl, 'label', v_perf + v_1, 'lstm_perf', 2)
# Out:
# init A shape:  (53635, 31)
# (45945, 2, 15) 408.0
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 15)]           0
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 2, 15)             60
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 2, 31)             5828
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 31)                7812
# _________________________________________________________________
# dense (Dense)                (None, 32)                1024
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 14,757
# Trainable params: 14,727
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/30
# 68/68 [==============================] - 9s 49ms/step - loss: 0.6850 - accuracy: 0.4367 - my_auc: 0.5236 - val_loss: 0.6908 - val_accuracy: 0.0614 - val_my_auc: 0.6617
#  epoch:0 auc: 0.6951
# Epoch 2/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6775 - accuracy: 0.5394 - my_auc: 0.6906 - val_loss: 0.6834 - val_accuracy: 0.2359 - val_my_auc: 0.6995
#  epoch:1 auc: 0.6987
# Epoch 3/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6368 - accuracy: 0.6149 - my_auc: 0.6883 - val_loss: 0.6702 - val_accuracy: 0.3550 - val_my_auc: 0.7009
#  epoch:2 auc: 0.7000
# Epoch 4/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6717 - accuracy: 0.5650 - my_auc: 0.6695 - val_loss: 0.6514 - val_accuracy: 0.5118 - val_my_auc: 0.7009
#  epoch:3 auc: 0.7016
# Epoch 5/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6496 - accuracy: 0.6037 - my_auc: 0.6837 - val_loss: 0.6368 - val_accuracy: 0.5719 - val_my_auc: 0.7020
#  epoch:4 auc: 0.7020
# Epoch 6/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6513 - accuracy: 0.6064 - my_auc: 0.6720 - val_loss: 0.6286 - val_accuracy: 0.6112 - val_my_auc: 0.7026
#  epoch:5 auc: 0.7025
# Epoch 7/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6437 - accuracy: 0.6192 - my_auc: 0.6811 - val_loss: 0.6241 - val_accuracy: 0.5912 - val_my_auc: 0.7036
#  epoch:6 auc: 0.7034
# Epoch 8/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6186 - accuracy: 0.6141 - my_auc: 0.7155 - val_loss: 0.6239 - val_accuracy: 0.6278 - val_my_auc: 0.7026
#  epoch:7 auc: 0.7027
# Epoch 9/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6287 - accuracy: 0.6276 - my_auc: 0.6827 - val_loss: 0.6220 - val_accuracy: 0.6258 - val_my_auc: 0.7034
#  epoch:8 auc: 0.7037
# Epoch 10/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6444 - accuracy: 0.6246 - my_auc: 0.6806 - val_loss: 0.6200 - val_accuracy: 0.6217 - val_my_auc: 0.7054
#  epoch:9 auc: 0.7050
# Epoch 11/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6442 - accuracy: 0.6176 - my_auc: 0.6803 - val_loss: 0.6191 - val_accuracy: 0.6152 - val_my_auc: 0.7062
#  epoch:10 auc: 0.7064
# Epoch 12/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6398 - accuracy: 0.6159 - my_auc: 0.6828 - val_loss: 0.6191 - val_accuracy: 0.6224 - val_my_auc: 0.7056
#  epoch:11 auc: 0.7057
# Epoch 13/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6295 - accuracy: 0.6253 - my_auc: 0.6973 - val_loss: 0.6181 - val_accuracy: 0.6262 - val_my_auc: 0.7068
#  epoch:12 auc: 0.7070
# Epoch 14/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6260 - accuracy: 0.6254 - my_auc: 0.6939 - val_loss: 0.6174 - val_accuracy: 0.6426 - val_my_auc: 0.7087
#  epoch:13 auc: 0.7087
# Epoch 15/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6068 - accuracy: 0.6447 - my_auc: 0.7109 - val_loss: 0.6169 - val_accuracy: 0.6466 - val_my_auc: 0.7089
#  epoch:14 auc: 0.7091
# Epoch 16/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6572 - accuracy: 0.6291 - my_auc: 0.6969 - val_loss: 0.6174 - val_accuracy: 0.6498 - val_my_auc: 0.7089
#  epoch:15 auc: 0.7088
# Epoch 17/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6078 - accuracy: 0.6483 - my_auc: 0.7181 - val_loss: 0.6175 - val_accuracy: 0.6431 - val_my_auc: 0.7083
#  epoch:16 auc: 0.7087
# Epoch 18/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6071 - accuracy: 0.6515 - my_auc: 0.6880 - val_loss: 0.6149 - val_accuracy: 0.6077 - val_my_auc: 0.7108
#  epoch:17 auc: 0.7110
# Epoch 19/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6033 - accuracy: 0.6254 - my_auc: 0.7086 - val_loss: 0.6152 - val_accuracy: 0.6241 - val_my_auc: 0.7111
#  epoch:18 auc: 0.7115
# Epoch 20/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6295 - accuracy: 0.6295 - my_auc: 0.7094 - val_loss: 0.6163 - val_accuracy: 0.6215 - val_my_auc: 0.7105
#  epoch:19 auc: 0.7105
# Epoch 21/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6432 - accuracy: 0.6239 - my_auc: 0.6938 - val_loss: 0.6175 - val_accuracy: 0.6407 - val_my_auc: 0.7110
#  epoch:20 auc: 0.7108
# Epoch 22/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6488 - accuracy: 0.6350 - my_auc: 0.6919 - val_loss: 0.6182 - val_accuracy: 0.6379 - val_my_auc: 0.7110
#  epoch:21 auc: 0.7106
# AUC:  0.7115
# 11487
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 15)]           0
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 2, 15)             60
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 2, 31)             5828
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 31)                7812
# _________________________________________________________________
# dense (Dense)                (None, 32)                1024
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 14,757
# Trainable params: 14,727
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/30
# 68/68 [==============================] - 9s 48ms/step - loss: 0.7152 - accuracy: 0.1600 - my_auc: 0.5172 - val_loss: 0.6912 - val_accuracy: 0.3636 - val_my_auc: 0.6279
#  epoch:0 auc: 0.6451
# Epoch 2/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6622 - accuracy: 0.6818 - my_auc: 0.6180 - val_loss: 0.6851 - val_accuracy: 0.3099 - val_my_auc: 0.6622
#  epoch:1 auc: 0.6658
# Epoch 3/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6991 - accuracy: 0.5777 - my_auc: 0.6659 - val_loss: 0.6724 - val_accuracy: 0.4781 - val_my_auc: 0.6670
#  epoch:2 auc: 0.6664
# Epoch 4/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6548 - accuracy: 0.6220 - my_auc: 0.6932 - val_loss: 0.6591 - val_accuracy: 0.5247 - val_my_auc: 0.6682
#  epoch:3 auc: 0.6684
# Epoch 5/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6287 - accuracy: 0.6193 - my_auc: 0.6715 - val_loss: 0.6481 - val_accuracy: 0.5607 - val_my_auc: 0.6744
#  epoch:4 auc: 0.6743
# Epoch 6/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6396 - accuracy: 0.6067 - my_auc: 0.7125 - val_loss: 0.6406 - val_accuracy: 0.6275 - val_my_auc: 0.6806
#  epoch:5 auc: 0.6806
# Epoch 7/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6255 - accuracy: 0.6471 - my_auc: 0.6820 - val_loss: 0.6367 - val_accuracy: 0.6051 - val_my_auc: 0.6851
#  epoch:6 auc: 0.6851
# Epoch 8/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6691 - accuracy: 0.6039 - my_auc: 0.6915 - val_loss: 0.6347 - val_accuracy: 0.6530 - val_my_auc: 0.6895
#  epoch:7 auc: 0.6891
# Epoch 9/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6212 - accuracy: 0.6487 - my_auc: 0.7074 - val_loss: 0.6323 - val_accuracy: 0.6299 - val_my_auc: 0.6921
#  epoch:8 auc: 0.6918
# Epoch 10/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6213 - accuracy: 0.6275 - my_auc: 0.6971 - val_loss: 0.6320 - val_accuracy: 0.6171 - val_my_auc: 0.6932
#  epoch:9 auc: 0.6931
# Epoch 11/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6006 - accuracy: 0.6282 - my_auc: 0.7104 - val_loss: 0.6317 - val_accuracy: 0.6114 - val_my_auc: 0.6946
#  epoch:10 auc: 0.6945
# Epoch 12/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6226 - accuracy: 0.6238 - my_auc: 0.6774 - val_loss: 0.6318 - val_accuracy: 0.5955 - val_my_auc: 0.6952
#  epoch:11 auc: 0.6954
# Epoch 13/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6272 - accuracy: 0.6040 - my_auc: 0.6802 - val_loss: 0.6315 - val_accuracy: 0.6007 - val_my_auc: 0.6958
#  epoch:12 auc: 0.6955
# Epoch 14/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6346 - accuracy: 0.5998 - my_auc: 0.6866 - val_loss: 0.6307 - val_accuracy: 0.6124 - val_my_auc: 0.6970
#  epoch:13 auc: 0.6969
# Epoch 15/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.5825 - accuracy: 0.6198 - my_auc: 0.7314 - val_loss: 0.6307 - val_accuracy: 0.5950 - val_my_auc: 0.6965
#  epoch:14 auc: 0.6972
# Epoch 16/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.5933 - accuracy: 0.6023 - my_auc: 0.7218 - val_loss: 0.6270 - val_accuracy: 0.5998 - val_my_auc: 0.7014
#  epoch:15 auc: 0.7012
# Epoch 17/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.5915 - accuracy: 0.6052 - my_auc: 0.7157 - val_loss: 0.6280 - val_accuracy: 0.5664 - val_my_auc: 0.7014
#  epoch:16 auc: 0.7012
# Epoch 18/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6043 - accuracy: 0.5782 - my_auc: 0.6941 - val_loss: 0.6302 - val_accuracy: 0.5798 - val_my_auc: 0.7004
#  epoch:17 auc: 0.7002
# Epoch 19/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6071 - accuracy: 0.5830 - my_auc: 0.7229 - val_loss: 0.6276 - val_accuracy: 0.6075 - val_my_auc: 0.7017
#  epoch:18 auc: 0.7017
# Epoch 20/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.5930 - accuracy: 0.6103 - my_auc: 0.7047 - val_loss: 0.6266 - val_accuracy: 0.5952 - val_my_auc: 0.7022
#  epoch:19 auc: 0.7024
# Epoch 21/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6167 - accuracy: 0.5926 - my_auc: 0.7008 - val_loss: 0.6252 - val_accuracy: 0.6023 - val_my_auc: 0.7033
#  epoch:20 auc: 0.7033
# Epoch 22/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6135 - accuracy: 0.5988 - my_auc: 0.7316 - val_loss: 0.6237 - val_accuracy: 0.6205 - val_my_auc: 0.7044
#  epoch:21 auc: 0.7043
# Epoch 23/30
# 68/68 [==============================] - 2s 22ms/step - loss: 0.6201 - accuracy: 0.6111 - my_auc: 0.6987 - val_loss: 0.6263 - val_accuracy: 0.6273 - val_my_auc: 0.7042
#  epoch:22 auc: 0.7041
# Epoch 24/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.5674 - accuracy: 0.6444 - my_auc: 0.7437 - val_loss: 0.6245 - val_accuracy: 0.6207 - val_my_auc: 0.7076
#  epoch:23 auc: 0.7072
# Epoch 25/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6128 - accuracy: 0.6098 - my_auc: 0.7141 - val_loss: 0.6226 - val_accuracy: 0.6029 - val_my_auc: 0.7078
#  epoch:24 auc: 0.7078
# Epoch 26/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.5852 - accuracy: 0.6124 - my_auc: 0.7283 - val_loss: 0.6225 - val_accuracy: 0.6208 - val_my_auc: 0.7082
#  epoch:25 auc: 0.7082
# Epoch 27/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6149 - accuracy: 0.6094 - my_auc: 0.7331 - val_loss: 0.6235 - val_accuracy: 0.6131 - val_my_auc: 0.7083
#  epoch:26 auc: 0.7086
# Epoch 28/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6187 - accuracy: 0.5966 - my_auc: 0.7256 - val_loss: 0.6232 - val_accuracy: 0.6507 - val_my_auc: 0.7100
#  epoch:27 auc: 0.7106
# Epoch 29/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.5876 - accuracy: 0.6457 - my_auc: 0.7316 - val_loss: 0.6226 - val_accuracy: 0.6417 - val_my_auc: 0.7117
#  epoch:28 auc: 0.7115
# Epoch 30/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.5919 - accuracy: 0.6358 - my_auc: 0.7393 - val_loss: 0.6239 - val_accuracy: 0.6358 - val_my_auc: 0.7112
#  epoch:29 auc: 0.7112
# AUC:  0.7115
# 11486
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 15)]           0
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 2, 15)             60
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 2, 31)             5828
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 31)                7812
# _________________________________________________________________
# dense (Dense)                (None, 32)                1024
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 14,757
# Trainable params: 14,727
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/30
# 68/68 [==============================] - 10s 49ms/step - loss: 0.6705 - accuracy: 0.9868 - my_auc: 0.5316 - val_loss: 0.6918 - val_accuracy: 0.9160 - val_my_auc: 0.6170
#  epoch:0 auc: 0.6526
# Epoch 2/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6679 - accuracy: 0.9460 - my_auc: 0.6363 - val_loss: 0.6866 - val_accuracy: 0.5691 - val_my_auc: 0.6603
#  epoch:1 auc: 0.6784
# Epoch 3/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6987 - accuracy: 0.7687 - my_auc: 0.6512 - val_loss: 0.6746 - val_accuracy: 0.5439 - val_my_auc: 0.6836
#  epoch:2 auc: 0.6852
# Epoch 4/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6660 - accuracy: 0.6939 - my_auc: 0.6683 - val_loss: 0.6621 - val_accuracy: 0.5156 - val_my_auc: 0.6881
#  epoch:3 auc: 0.6889
# Epoch 5/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6389 - accuracy: 0.6412 - my_auc: 0.7023 - val_loss: 0.6525 - val_accuracy: 0.5164 - val_my_auc: 0.6916
#  epoch:4 auc: 0.6917
# Epoch 6/30
# 68/68 [==============================] - 2s 22ms/step - loss: 0.6235 - accuracy: 0.5981 - my_auc: 0.6876 - val_loss: 0.6440 - val_accuracy: 0.5389 - val_my_auc: 0.6927
#  epoch:5 auc: 0.6931
# Epoch 7/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6430 - accuracy: 0.5720 - my_auc: 0.6875 - val_loss: 0.6392 - val_accuracy: 0.5619 - val_my_auc: 0.6938
#  epoch:6 auc: 0.6946
# Epoch 8/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6264 - accuracy: 0.5834 - my_auc: 0.6691 - val_loss: 0.6358 - val_accuracy: 0.5445 - val_my_auc: 0.6957
#  epoch:7 auc: 0.6962
# Epoch 9/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6477 - accuracy: 0.5477 - my_auc: 0.6726 - val_loss: 0.6331 - val_accuracy: 0.5606 - val_my_auc: 0.6978
#  epoch:8 auc: 0.6974
# Epoch 10/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6443 - accuracy: 0.5583 - my_auc: 0.6927 - val_loss: 0.6331 - val_accuracy: 0.5740 - val_my_auc: 0.6961
#  epoch:9 auc: 0.6966
# Epoch 11/30
# 68/68 [==============================] - 2s 22ms/step - loss: 0.6092 - accuracy: 0.5858 - my_auc: 0.7158 - val_loss: 0.6332 - val_accuracy: 0.5670 - val_my_auc: 0.6967
#  epoch:10 auc: 0.6971
# Epoch 12/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6459 - accuracy: 0.5708 - my_auc: 0.6911 - val_loss: 0.6321 - val_accuracy: 0.5862 - val_my_auc: 0.6968
#  epoch:11 auc: 0.6968
# AUC:  0.6974
# 11486
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 15)]           0
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 2, 15)             60
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 2, 31)             5828
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 31)                7812
# _________________________________________________________________
# dense (Dense)                (None, 32)                1024
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 14,757
# Trainable params: 14,727
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/30
# 68/68 [==============================] - 10s 48ms/step - loss: 0.6746 - accuracy: 0.9427 - my_auc: 0.5594 - val_loss: 0.6915 - val_accuracy: 0.9765 - val_my_auc: 0.6155
#  epoch:0 auc: 0.6206
# Epoch 2/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6720 - accuracy: 0.8818 - my_auc: 0.6427 - val_loss: 0.6852 - val_accuracy: 0.5972 - val_my_auc: 0.6444
#  epoch:1 auc: 0.6450
# Epoch 3/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6811 - accuracy: 0.6874 - my_auc: 0.6814 - val_loss: 0.6689 - val_accuracy: 0.5513 - val_my_auc: 0.6626
#  epoch:2 auc: 0.6635
# Epoch 4/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6253 - accuracy: 0.6564 - my_auc: 0.6901 - val_loss: 0.6555 - val_accuracy: 0.5083 - val_my_auc: 0.6718
#  epoch:3 auc: 0.6711
# Epoch 5/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6354 - accuracy: 0.5984 - my_auc: 0.7173 - val_loss: 0.6442 - val_accuracy: 0.5158 - val_my_auc: 0.6779
#  epoch:4 auc: 0.6783
# Epoch 6/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6205 - accuracy: 0.5761 - my_auc: 0.7142 - val_loss: 0.6396 - val_accuracy: 0.5094 - val_my_auc: 0.6821
#  epoch:5 auc: 0.6827
# Epoch 7/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6446 - accuracy: 0.5538 - my_auc: 0.7038 - val_loss: 0.6357 - val_accuracy: 0.5419 - val_my_auc: 0.6874
#  epoch:6 auc: 0.6875
# Epoch 8/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6371 - accuracy: 0.5614 - my_auc: 0.6751 - val_loss: 0.6326 - val_accuracy: 0.5243 - val_my_auc: 0.6924
#  epoch:7 auc: 0.6920
# Epoch 9/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6421 - accuracy: 0.5439 - my_auc: 0.6886 - val_loss: 0.6292 - val_accuracy: 0.5508 - val_my_auc: 0.6961
#  epoch:8 auc: 0.6962
# Epoch 10/30
# 68/68 [==============================] - 2s 22ms/step - loss: 0.5954 - accuracy: 0.5871 - my_auc: 0.7119 - val_loss: 0.6268 - val_accuracy: 0.5427 - val_my_auc: 0.6993
#  epoch:9 auc: 0.6991
# Epoch 11/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6273 - accuracy: 0.5653 - my_auc: 0.6951 - val_loss: 0.6249 - val_accuracy: 0.5470 - val_my_auc: 0.7011
#  epoch:10 auc: 0.7008
# Epoch 12/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6000 - accuracy: 0.5748 - my_auc: 0.7141 - val_loss: 0.6252 - val_accuracy: 0.5433 - val_my_auc: 0.7010
#  epoch:11 auc: 0.7010
# Epoch 13/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6381 - accuracy: 0.5575 - my_auc: 0.7128 - val_loss: 0.6231 - val_accuracy: 0.5772 - val_my_auc: 0.7032
#  epoch:12 auc: 0.7031
# Epoch 14/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6029 - accuracy: 0.6027 - my_auc: 0.7195 - val_loss: 0.6223 - val_accuracy: 0.5593 - val_my_auc: 0.7046
#  epoch:13 auc: 0.7043
# Epoch 15/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6287 - accuracy: 0.5735 - my_auc: 0.6897 - val_loss: 0.6213 - val_accuracy: 0.5809 - val_my_auc: 0.7064
#  epoch:14 auc: 0.7061
# Epoch 16/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6414 - accuracy: 0.5970 - my_auc: 0.6983 - val_loss: 0.6193 - val_accuracy: 0.5660 - val_my_auc: 0.7085
#  epoch:15 auc: 0.7082
# Epoch 17/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6494 - accuracy: 0.5725 - my_auc: 0.6638 - val_loss: 0.6188 - val_accuracy: 0.5972 - val_my_auc: 0.7095
#  epoch:16 auc: 0.7095
# Epoch 18/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6332 - accuracy: 0.6128 - my_auc: 0.7119 - val_loss: 0.6174 - val_accuracy: 0.5958 - val_my_auc: 0.7113
#  epoch:17 auc: 0.7114
# Epoch 19/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6004 - accuracy: 0.6207 - my_auc: 0.7133 - val_loss: 0.6149 - val_accuracy: 0.6094 - val_my_auc: 0.7152
#  epoch:18 auc: 0.7153
# Epoch 20/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6103 - accuracy: 0.6333 - my_auc: 0.7315 - val_loss: 0.6163 - val_accuracy: 0.5994 - val_my_auc: 0.7128
#  epoch:19 auc: 0.7129
# Epoch 21/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6359 - accuracy: 0.6141 - my_auc: 0.7161 - val_loss: 0.6153 - val_accuracy: 0.5938 - val_my_auc: 0.7154
#  epoch:20 auc: 0.7151
# Epoch 22/30
# 68/68 [==============================] - 2s 22ms/step - loss: 0.6030 - accuracy: 0.6346 - my_auc: 0.7113 - val_loss: 0.6147 - val_accuracy: 0.6040 - val_my_auc: 0.7136
#  epoch:21 auc: 0.7141
# Epoch 23/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6220 - accuracy: 0.6235 - my_auc: 0.7277 - val_loss: 0.6126 - val_accuracy: 0.6360 - val_my_auc: 0.7204
#  epoch:22 auc: 0.7203
# Epoch 24/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.5681 - accuracy: 0.6762 - my_auc: 0.7475 - val_loss: 0.6109 - val_accuracy: 0.6265 - val_my_auc: 0.7210
#  epoch:23 auc: 0.7210
# Epoch 25/30
# 68/68 [==============================] - 2s 22ms/step - loss: 0.5980 - accuracy: 0.6512 - my_auc: 0.7218 - val_loss: 0.6121 - val_accuracy: 0.6154 - val_my_auc: 0.7171
#  epoch:24 auc: 0.7171
# Epoch 26/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6277 - accuracy: 0.6406 - my_auc: 0.7109 - val_loss: 0.6101 - val_accuracy: 0.6473 - val_my_auc: 0.7184
#  epoch:25 auc: 0.7182
# Epoch 27/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6064 - accuracy: 0.6601 - my_auc: 0.7340 - val_loss: 0.6097 - val_accuracy: 0.6293 - val_my_auc: 0.7170
#  epoch:26 auc: 0.7171
# AUC:  0.721
# 11486
# avg_AUC :  0.7103611252950334
# avg_AUC_2 :  0.7101901366607248
#          0         1         2   ...        27        28       29
# 0  0.661650  0.699515  0.700945  ...       NaN       NaN      NaN
# 1  0.627895  0.662185  0.667020  ...  0.710029  0.711716  0.71115
# 2  0.617049  0.660260  0.683586  ...       NaN       NaN      NaN
# 3  0.615459  0.644429  0.662586  ...       NaN       NaN      NaN
#
# [4 rows x 30 columns]
# 0     0.630513
# 1     0.666598
# 2     0.678534
# 3     0.682257
# 4     0.686478
# 5     0.689480
# 6     0.692480
# 7     0.695032
# 8     0.697385
# 9     0.698524
# 10    0.699652
# 11    0.699650
# 12    0.701955
# 13    0.703409
# 14    0.703952
# 15    0.706267
# 16    0.706415
# 17    0.707488
# 18    0.709344
# 19    0.708509
# 20    0.709884
# 21    0.709660
# 22    0.712309
# 23    0.714264
# 24    0.712453
# 25    0.713312
# 26    0.712676
# 27    0.710029
# 28    0.711716
# 29    0.711150
# dtype: float64
# (0.7103611252950334,
#  array([0.        , 0.06127451, 0.09558824, 0.12254902, 0.15441176,
#         0.18872549, 0.22303922, 0.24019608, 0.26715686, 0.29166667,
#         0.31617647, 0.33333333, 0.35539216, 0.35784314, 0.37990196,
#         0.39215686, 0.41176471, 0.43137255, 0.45098039, 0.46568627,
#         0.47794118, 0.48039216, 0.50245098, 0.51470588, 0.5245098 ,
#         0.53921569, 0.55147059, 0.57598039, 0.58578431, 0.59803922,
#         0.60539216, 0.6127451 , 0.62745098, 0.62990196, 0.64705882,
#         0.66176471, 0.66421569, 0.66666667, 0.67647059, 0.68382353,
#         0.69852941, 0.70343137, 0.72303922, 0.73284314, 0.7377451 ,
#         0.75245098, 0.7622549 , 0.76960784, 0.7745098 , 0.78186275,
#         0.78431373, 0.79166667, 0.80147059, 0.80637255, 0.81127451,
#         0.82107843, 0.82598039, 0.83088235, 0.83088235, 0.83578431,
#         0.83823529, 0.85294118, 0.85784314, 0.86519608, 0.87254902,
#         0.87745098, 0.88970588, 0.89460784, 0.8995098 , 0.90196078,
#         0.90931373, 0.91421569, 0.91911765, 0.92892157, 0.93382353,
#         0.93627451, 0.94117647, 0.95098039, 0.95588235, 0.96078431,
#         0.96323529, 0.97303922, 0.9754902 , 0.9754902 , 0.98039216,
#         0.98284314, 0.98529412, 0.9877451 , 0.9877451 , 0.9877451 ,
#         0.9877451 , 0.99019608, 0.99509804, 0.99754902, 0.99754902,
#         1.        , 1.        , 1.        , 1.        , 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.21381113, 0.6130022 , 0.47159338, ..., 0.5258506 , 0.4387024 ,
#            0.6715356 ], dtype=float32)],
#    array([    0,    11,    12, ..., 45939, 45940, 45943])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.403045  , 0.5094106 , 0.63376176, ..., 0.47078416, 0.6924894 ,
#            0.2759515 ], dtype=float32)],
#    array([    4,     8,    10, ..., 45936, 45938, 45944])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5015114 , 0.59619534, 0.4409119 , ..., 0.68626124, 0.57782936,
#            0.425609  ], dtype=float32)],
#    array([    1,     2,     5, ..., 45920, 45922, 45924])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.44524217, 0.67424536, 0.48315954, ..., 0.3825953 , 0.5377977 ,
#            0.6067833 ], dtype=float32)],
#    array([    3,    17,    20, ..., 45937, 45941, 45942])]])

# %%
# financial performance timestep = 3
cross_val(df_fl, 'label', v_perf, 'lstm_perf', 3)
# Out:
# init A shape:  (53635, 43)
# (39123, 3, 14) 341.0
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 14)]           0
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 3, 14)             56
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 3, 30)             5400
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 32)                992
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 13,801
# Trainable params: 13,773
# Non-trainable params: 28
# _________________________________________________________________
# Epoch 1/30
# 58/58 [==============================] - 10s 54ms/step - loss: 0.7101 - accuracy: 0.1147 - my_auc: 0.5619 - val_loss: 0.6898 - val_accuracy: 0.0094 - val_my_auc: 0.6945
#  epoch:0 auc: 0.6942
# Epoch 2/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6936 - accuracy: 0.4336 - my_auc: 0.6473 - val_loss: 0.6821 - val_accuracy: 0.0973 - val_my_auc: 0.7126
#  epoch:1 auc: 0.7072
# Epoch 3/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6570 - accuracy: 0.5389 - my_auc: 0.6854 - val_loss: 0.6703 - val_accuracy: 0.2241 - val_my_auc: 0.7126
#  epoch:2 auc: 0.7131
# Epoch 4/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6605 - accuracy: 0.5467 - my_auc: 0.6808 - val_loss: 0.6522 - val_accuracy: 0.3788 - val_my_auc: 0.7151
#  epoch:3 auc: 0.7151
# Epoch 5/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6444 - accuracy: 0.5751 - my_auc: 0.6837 - val_loss: 0.6351 - val_accuracy: 0.4833 - val_my_auc: 0.7178
#  epoch:4 auc: 0.7183
# Epoch 6/30
# 58/58 [==============================] - 1s 26ms/step - loss: 0.6285 - accuracy: 0.5791 - my_auc: 0.6969 - val_loss: 0.6259 - val_accuracy: 0.4917 - val_my_auc: 0.7209
#  epoch:5 auc: 0.7206
# Epoch 7/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6139 - accuracy: 0.5658 - my_auc: 0.6602 - val_loss: 0.6200 - val_accuracy: 0.5104 - val_my_auc: 0.7204
#  epoch:6 auc: 0.7203
# Epoch 8/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6108 - accuracy: 0.5558 - my_auc: 0.6906 - val_loss: 0.6169 - val_accuracy: 0.5122 - val_my_auc: 0.7237
#  epoch:7 auc: 0.7242
# Epoch 9/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6312 - accuracy: 0.5464 - my_auc: 0.7045 - val_loss: 0.6134 - val_accuracy: 0.5180 - val_my_auc: 0.7259
#  epoch:8 auc: 0.7263
# Epoch 10/30
# 58/58 [==============================] - 2s 26ms/step - loss: 0.5795 - accuracy: 0.5554 - my_auc: 0.6991 - val_loss: 0.6107 - val_accuracy: 0.5273 - val_my_auc: 0.7269
#  epoch:9 auc: 0.7270
# Epoch 11/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6217 - accuracy: 0.5455 - my_auc: 0.6942 - val_loss: 0.6075 - val_accuracy: 0.5505 - val_my_auc: 0.7298
#  epoch:10 auc: 0.7299
# Epoch 12/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6148 - accuracy: 0.5659 - my_auc: 0.6593 - val_loss: 0.6062 - val_accuracy: 0.5381 - val_my_auc: 0.7322
#  epoch:11 auc: 0.7317
# Epoch 13/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6578 - accuracy: 0.5379 - my_auc: 0.6890 - val_loss: 0.6052 - val_accuracy: 0.5577 - val_my_auc: 0.7319
#  epoch:12 auc: 0.7322
# Epoch 14/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6498 - accuracy: 0.5491 - my_auc: 0.7030 - val_loss: 0.6100 - val_accuracy: 0.5832 - val_my_auc: 0.7291
#  epoch:13 auc: 0.7292
# Epoch 15/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6286 - accuracy: 0.5744 - my_auc: 0.6813 - val_loss: 0.6041 - val_accuracy: 0.5697 - val_my_auc: 0.7362
#  epoch:14 auc: 0.7360
# Epoch 16/30
# 58/58 [==============================] - 2s 26ms/step - loss: 0.6390 - accuracy: 0.5621 - my_auc: 0.7058 - val_loss: 0.6023 - val_accuracy: 0.5706 - val_my_auc: 0.7389
#  epoch:15 auc: 0.7394
# Epoch 17/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.5878 - accuracy: 0.5890 - my_auc: 0.7284 - val_loss: 0.5974 - val_accuracy: 0.5541 - val_my_auc: 0.7426
#  epoch:16 auc: 0.7431
# Epoch 18/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6004 - accuracy: 0.5626 - my_auc: 0.7209 - val_loss: 0.5959 - val_accuracy: 0.5577 - val_my_auc: 0.7443
#  epoch:17 auc: 0.7446
# Epoch 19/30
# 58/58 [==============================] - 2s 26ms/step - loss: 0.5761 - accuracy: 0.5721 - my_auc: 0.7263 - val_loss: 0.5945 - val_accuracy: 0.5493 - val_my_auc: 0.7455
#  epoch:18 auc: 0.7455
# Epoch 20/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6051 - accuracy: 0.5547 - my_auc: 0.7146 - val_loss: 0.5929 - val_accuracy: 0.5604 - val_my_auc: 0.7476
#  epoch:19 auc: 0.7473
# Epoch 21/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6378 - accuracy: 0.5543 - my_auc: 0.6992 - val_loss: 0.5903 - val_accuracy: 0.5462 - val_my_auc: 0.7480
#  epoch:20 auc: 0.7487
# Epoch 22/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.5919 - accuracy: 0.5580 - my_auc: 0.7308 - val_loss: 0.5891 - val_accuracy: 0.5467 - val_my_auc: 0.7491
#  epoch:21 auc: 0.7486
# Epoch 23/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6299 - accuracy: 0.5465 - my_auc: 0.6970 - val_loss: 0.5872 - val_accuracy: 0.5515 - val_my_auc: 0.7501
#  epoch:22 auc: 0.7502
# Epoch 24/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6171 - accuracy: 0.5584 - my_auc: 0.7147 - val_loss: 0.5863 - val_accuracy: 0.5725 - val_my_auc: 0.7518
#  epoch:23 auc: 0.7517
# Epoch 25/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6107 - accuracy: 0.5723 - my_auc: 0.6946 - val_loss: 0.5853 - val_accuracy: 0.5583 - val_my_auc: 0.7506
#  epoch:24 auc: 0.7508
# Epoch 26/30
# 58/58 [==============================] - 2s 26ms/step - loss: 0.5953 - accuracy: 0.5699 - my_auc: 0.7253 - val_loss: 0.5848 - val_accuracy: 0.5555 - val_my_auc: 0.7522
#  epoch:25 auc: 0.7526
# Epoch 27/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.5980 - accuracy: 0.5697 - my_auc: 0.7362 - val_loss: 0.5850 - val_accuracy: 0.5593 - val_my_auc: 0.7531
#  epoch:26 auc: 0.7531
# Epoch 28/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6127 - accuracy: 0.5730 - my_auc: 0.6962 - val_loss: 0.5885 - val_accuracy: 0.5827 - val_my_auc: 0.7554
#  epoch:27 auc: 0.7555
# Epoch 29/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6196 - accuracy: 0.5711 - my_auc: 0.7241 - val_loss: 0.5884 - val_accuracy: 0.5749 - val_my_auc: 0.7557
#  epoch:28 auc: 0.7556
# Epoch 30/30
# 58/58 [==============================] - 2s 26ms/step - loss: 0.6281 - accuracy: 0.5750 - my_auc: 0.7090 - val_loss: 0.5827 - val_accuracy: 0.5474 - val_my_auc: 0.7568
#  epoch:29 auc: 0.7566
# AUC:  0.7566
# 9781
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 14)]           0
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 3, 14)             56
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 3, 30)             5400
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 32)                992
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 13,801
# Trainable params: 13,773
# Non-trainable params: 28
# _________________________________________________________________
# Epoch 1/30
# 58/58 [==============================] - 9s 55ms/step - loss: 0.6700 - accuracy: 0.5154 - my_auc: 0.4473 - val_loss: 0.6915 - val_accuracy: 0.1037 - val_my_auc: 0.6058
#  epoch:0 auc: 0.6350
# Epoch 2/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6658 - accuracy: 0.6113 - my_auc: 0.6279 - val_loss: 0.6856 - val_accuracy: 0.1785 - val_my_auc: 0.6807
#  epoch:1 auc: 0.6797
# Epoch 3/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6747 - accuracy: 0.5973 - my_auc: 0.6479 - val_loss: 0.6750 - val_accuracy: 0.3289 - val_my_auc: 0.6923
#  epoch:2 auc: 0.6917
# Epoch 4/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6802 - accuracy: 0.5910 - my_auc: 0.6727 - val_loss: 0.6596 - val_accuracy: 0.4849 - val_my_auc: 0.6973
#  epoch:3 auc: 0.6975
# Epoch 5/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6519 - accuracy: 0.6216 - my_auc: 0.6720 - val_loss: 0.6452 - val_accuracy: 0.4991 - val_my_auc: 0.7005
#  epoch:4 auc: 0.7000
# Epoch 6/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6077 - accuracy: 0.6054 - my_auc: 0.7110 - val_loss: 0.6318 - val_accuracy: 0.5409 - val_my_auc: 0.7047
#  epoch:5 auc: 0.7044
# Epoch 7/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6118 - accuracy: 0.6030 - my_auc: 0.6948 - val_loss: 0.6239 - val_accuracy: 0.5475 - val_my_auc: 0.7090
#  epoch:6 auc: 0.7093
# Epoch 8/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6068 - accuracy: 0.5968 - my_auc: 0.7146 - val_loss: 0.6181 - val_accuracy: 0.5546 - val_my_auc: 0.7118
#  epoch:7 auc: 0.7118
# Epoch 9/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6342 - accuracy: 0.5806 - my_auc: 0.6838 - val_loss: 0.6111 - val_accuracy: 0.5743 - val_my_auc: 0.7128
#  epoch:8 auc: 0.7128
# Epoch 10/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6129 - accuracy: 0.5963 - my_auc: 0.6789 - val_loss: 0.6074 - val_accuracy: 0.5705 - val_my_auc: 0.7140
#  epoch:9 auc: 0.7146
# Epoch 11/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6435 - accuracy: 0.5742 - my_auc: 0.7061 - val_loss: 0.6058 - val_accuracy: 0.5906 - val_my_auc: 0.7152
#  epoch:10 auc: 0.7154
# Epoch 12/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5893 - accuracy: 0.6105 - my_auc: 0.7240 - val_loss: 0.6041 - val_accuracy: 0.5500 - val_my_auc: 0.7172
#  epoch:11 auc: 0.7174
# Epoch 13/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6005 - accuracy: 0.5730 - my_auc: 0.6959 - val_loss: 0.6019 - val_accuracy: 0.5749 - val_my_auc: 0.7170
#  epoch:12 auc: 0.7171
# Epoch 14/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6288 - accuracy: 0.5806 - my_auc: 0.7048 - val_loss: 0.6012 - val_accuracy: 0.5886 - val_my_auc: 0.7166
#  epoch:13 auc: 0.7166
# Epoch 15/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6515 - accuracy: 0.5763 - my_auc: 0.6969 - val_loss: 0.6001 - val_accuracy: 0.5918 - val_my_auc: 0.7180
#  epoch:14 auc: 0.7181
# Epoch 16/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5740 - accuracy: 0.6099 - my_auc: 0.7281 - val_loss: 0.5976 - val_accuracy: 0.5675 - val_my_auc: 0.7217
#  epoch:15 auc: 0.7212
# Epoch 17/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6158 - accuracy: 0.5705 - my_auc: 0.7031 - val_loss: 0.5958 - val_accuracy: 0.5946 - val_my_auc: 0.7225
#  epoch:16 auc: 0.7221
# Epoch 18/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6439 - accuracy: 0.5881 - my_auc: 0.7045 - val_loss: 0.5937 - val_accuracy: 0.5771 - val_my_auc: 0.7251
#  epoch:17 auc: 0.7252
# Epoch 19/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6186 - accuracy: 0.5860 - my_auc: 0.7261 - val_loss: 0.5926 - val_accuracy: 0.5806 - val_my_auc: 0.7258
#  epoch:18 auc: 0.7255
# Epoch 20/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6326 - accuracy: 0.5750 - my_auc: 0.7214 - val_loss: 0.5927 - val_accuracy: 0.6048 - val_my_auc: 0.7261
#  epoch:19 auc: 0.7258
# Epoch 21/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.5822 - accuracy: 0.6072 - my_auc: 0.7218 - val_loss: 0.5906 - val_accuracy: 0.5866 - val_my_auc: 0.7270
#  epoch:20 auc: 0.7274
# Epoch 22/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6311 - accuracy: 0.5795 - my_auc: 0.6796 - val_loss: 0.5898 - val_accuracy: 0.5854 - val_my_auc: 0.7271
#  epoch:21 auc: 0.7271
# Epoch 23/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6047 - accuracy: 0.5797 - my_auc: 0.7165 - val_loss: 0.5891 - val_accuracy: 0.5538 - val_my_auc: 0.7294
#  epoch:22 auc: 0.7299
# Epoch 24/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.5993 - accuracy: 0.5696 - my_auc: 0.7308 - val_loss: 0.5882 - val_accuracy: 0.5919 - val_my_auc: 0.7323
#  epoch:23 auc: 0.7322
# Epoch 25/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5801 - accuracy: 0.6000 - my_auc: 0.7340 - val_loss: 0.5881 - val_accuracy: 0.5506 - val_my_auc: 0.7329
#  epoch:24 auc: 0.7327
# Epoch 26/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6154 - accuracy: 0.5601 - my_auc: 0.7511 - val_loss: 0.5881 - val_accuracy: 0.6244 - val_my_auc: 0.7306
#  epoch:25 auc: 0.7309
# Epoch 27/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5816 - accuracy: 0.6298 - my_auc: 0.7061 - val_loss: 0.5861 - val_accuracy: 0.6006 - val_my_auc: 0.7363
#  epoch:26 auc: 0.7363
# Epoch 28/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6864 - accuracy: 0.5745 - my_auc: 0.7215 - val_loss: 0.5872 - val_accuracy: 0.6433 - val_my_auc: 0.7345
#  epoch:27 auc: 0.7343
# Epoch 29/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6331 - accuracy: 0.6187 - my_auc: 0.7262 - val_loss: 0.5862 - val_accuracy: 0.6445 - val_my_auc: 0.7342
#  epoch:28 auc: 0.7339
# Epoch 30/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6176 - accuracy: 0.6200 - my_auc: 0.7224 - val_loss: 0.5845 - val_accuracy: 0.6171 - val_my_auc: 0.7366
#  epoch:29 auc: 0.7367
# AUC:  0.7367
# 9781
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 14)]           0
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 3, 14)             56
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 3, 30)             5400
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 32)                992
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 13,801
# Trainable params: 13,773
# Non-trainable params: 28
# _________________________________________________________________
# Epoch 1/30
# 58/58 [==============================] - 10s 55ms/step - loss: 0.7083 - accuracy: 0.5261 - my_auc: 0.5979 - val_loss: 0.6911 - val_accuracy: 0.0302 - val_my_auc: 0.6365
#  epoch:0 auc: 0.6508
# Epoch 2/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6850 - accuracy: 0.6246 - my_auc: 0.6589 - val_loss: 0.6843 - val_accuracy: 0.1171 - val_my_auc: 0.6675
#  epoch:1 auc: 0.6679
# Epoch 3/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6600 - accuracy: 0.6173 - my_auc: 0.6477 - val_loss: 0.6693 - val_accuracy: 0.2616 - val_my_auc: 0.6665
#  epoch:2 auc: 0.6664
# Epoch 4/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6918 - accuracy: 0.6090 - my_auc: 0.6517 - val_loss: 0.6547 - val_accuracy: 0.3693 - val_my_auc: 0.6712
#  epoch:3 auc: 0.6709
# Epoch 5/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6689 - accuracy: 0.6011 - my_auc: 0.6718 - val_loss: 0.6441 - val_accuracy: 0.4483 - val_my_auc: 0.6741
#  epoch:4 auc: 0.6743
# Epoch 6/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6468 - accuracy: 0.5937 - my_auc: 0.6745 - val_loss: 0.6369 - val_accuracy: 0.4950 - val_my_auc: 0.6763
#  epoch:5 auc: 0.6767
# Epoch 7/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6290 - accuracy: 0.5838 - my_auc: 0.7009 - val_loss: 0.6333 - val_accuracy: 0.5549 - val_my_auc: 0.6789
#  epoch:6 auc: 0.6786
# Epoch 8/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6330 - accuracy: 0.6121 - my_auc: 0.6884 - val_loss: 0.6307 - val_accuracy: 0.5629 - val_my_auc: 0.6817
#  epoch:7 auc: 0.6816
# Epoch 9/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.6435 - accuracy: 0.5989 - my_auc: 0.6771 - val_loss: 0.6287 - val_accuracy: 0.5761 - val_my_auc: 0.6829
#  epoch:8 auc: 0.6836
# Epoch 10/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6410 - accuracy: 0.6035 - my_auc: 0.6875 - val_loss: 0.6271 - val_accuracy: 0.5882 - val_my_auc: 0.6858
#  epoch:9 auc: 0.6861
# Epoch 11/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6317 - accuracy: 0.6090 - my_auc: 0.7016 - val_loss: 0.6264 - val_accuracy: 0.5787 - val_my_auc: 0.6873
#  epoch:10 auc: 0.6873
# Epoch 12/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6555 - accuracy: 0.5867 - my_auc: 0.6914 - val_loss: 0.6267 - val_accuracy: 0.6074 - val_my_auc: 0.6890
#  epoch:11 auc: 0.6894
# Epoch 13/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6555 - accuracy: 0.6116 - my_auc: 0.6881 - val_loss: 0.6256 - val_accuracy: 0.5757 - val_my_auc: 0.6901
#  epoch:12 auc: 0.6904
# Epoch 14/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6199 - accuracy: 0.5836 - my_auc: 0.7041 - val_loss: 0.6280 - val_accuracy: 0.5925 - val_my_auc: 0.6919
#  epoch:13 auc: 0.6919
# Epoch 15/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6288 - accuracy: 0.6053 - my_auc: 0.6897 - val_loss: 0.6283 - val_accuracy: 0.5676 - val_my_auc: 0.6906
#  epoch:14 auc: 0.6905
# Epoch 16/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6113 - accuracy: 0.6054 - my_auc: 0.7370 - val_loss: 0.6292 - val_accuracy: 0.5702 - val_my_auc: 0.6896
#  epoch:15 auc: 0.6897
# Epoch 17/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6351 - accuracy: 0.5848 - my_auc: 0.7118 - val_loss: 0.6302 - val_accuracy: 0.5768 - val_my_auc: 0.6917
#  epoch:16 auc: 0.6922
# AUC:  0.6919
# 9781
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3, 14)]           0
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 3, 14)             56
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 3, 30)             5400
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 32)                992
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 13,801
# Trainable params: 13,773
# Non-trainable params: 28
# _________________________________________________________________
# Epoch 1/30
# 58/58 [==============================] - 10s 58ms/step - loss: 0.6918 - accuracy: 0.8370 - my_auc: 0.4985 - val_loss: 0.6919 - val_accuracy: 0.7770 - val_my_auc: 0.6034
#  epoch:0 auc: 0.6176
# Epoch 2/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6837 - accuracy: 0.8231 - my_auc: 0.6648 - val_loss: 0.6875 - val_accuracy: 0.6009 - val_my_auc: 0.6393
#  epoch:1 auc: 0.6396
# Epoch 3/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6653 - accuracy: 0.7440 - my_auc: 0.6645 - val_loss: 0.6781 - val_accuracy: 0.5228 - val_my_auc: 0.6504
#  epoch:2 auc: 0.6545
# Epoch 4/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6772 - accuracy: 0.6732 - my_auc: 0.6712 - val_loss: 0.6648 - val_accuracy: 0.5385 - val_my_auc: 0.6588
#  epoch:3 auc: 0.6588
# Epoch 5/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6235 - accuracy: 0.6559 - my_auc: 0.6980 - val_loss: 0.6559 - val_accuracy: 0.5257 - val_my_auc: 0.6625
#  epoch:4 auc: 0.6623
# Epoch 6/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6654 - accuracy: 0.5864 - my_auc: 0.6831 - val_loss: 0.6510 - val_accuracy: 0.5600 - val_my_auc: 0.6643
#  epoch:5 auc: 0.6652
# Epoch 7/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6192 - accuracy: 0.6080 - my_auc: 0.7044 - val_loss: 0.6492 - val_accuracy: 0.5702 - val_my_auc: 0.6686
#  epoch:6 auc: 0.6683
# Epoch 8/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.6024 - accuracy: 0.6032 - my_auc: 0.6869 - val_loss: 0.6465 - val_accuracy: 0.5712 - val_my_auc: 0.6725
#  epoch:7 auc: 0.6723
# Epoch 9/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6323 - accuracy: 0.5860 - my_auc: 0.6854 - val_loss: 0.6441 - val_accuracy: 0.5810 - val_my_auc: 0.6769
#  epoch:8 auc: 0.6767
# Epoch 10/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6066 - accuracy: 0.6023 - my_auc: 0.6930 - val_loss: 0.6445 - val_accuracy: 0.5788 - val_my_auc: 0.6784
#  epoch:9 auc: 0.6788
# Epoch 11/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6336 - accuracy: 0.5787 - my_auc: 0.6584 - val_loss: 0.6464 - val_accuracy: 0.5820 - val_my_auc: 0.6802
#  epoch:10 auc: 0.6804
# Epoch 12/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6209 - accuracy: 0.5874 - my_auc: 0.7144 - val_loss: 0.6454 - val_accuracy: 0.5880 - val_my_auc: 0.6833
#  epoch:11 auc: 0.6829
# Epoch 13/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.6162 - accuracy: 0.5911 - my_auc: 0.7017 - val_loss: 0.6496 - val_accuracy: 0.5960 - val_my_auc: 0.6840
#  epoch:12 auc: 0.6842
# Epoch 14/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6218 - accuracy: 0.5911 - my_auc: 0.6902 - val_loss: 0.6480 - val_accuracy: 0.5933 - val_my_auc: 0.6852
#  epoch:13 auc: 0.6856
# Epoch 15/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6222 - accuracy: 0.5957 - my_auc: 0.7100 - val_loss: 0.6442 - val_accuracy: 0.5901 - val_my_auc: 0.6884
#  epoch:14 auc: 0.6885
# Epoch 16/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6172 - accuracy: 0.5907 - my_auc: 0.7109 - val_loss: 0.6431 - val_accuracy: 0.5696 - val_my_auc: 0.6881
#  epoch:15 auc: 0.6880
# Epoch 17/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6328 - accuracy: 0.5593 - my_auc: 0.7193 - val_loss: 0.6483 - val_accuracy: 0.6097 - val_my_auc: 0.6895
#  epoch:16 auc: 0.6900
# Epoch 18/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6099 - accuracy: 0.5964 - my_auc: 0.7130 - val_loss: 0.6387 - val_accuracy: 0.5800 - val_my_auc: 0.6908
#  epoch:17 auc: 0.6906
# Epoch 19/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.5960 - accuracy: 0.5813 - my_auc: 0.7178 - val_loss: 0.6333 - val_accuracy: 0.5728 - val_my_auc: 0.6928
#  epoch:18 auc: 0.6930
# Epoch 20/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.6417 - accuracy: 0.5651 - my_auc: 0.7095 - val_loss: 0.6391 - val_accuracy: 0.5918 - val_my_auc: 0.6945
#  epoch:19 auc: 0.6943
# Epoch 21/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5957 - accuracy: 0.5864 - my_auc: 0.7103 - val_loss: 0.6409 - val_accuracy: 0.5922 - val_my_auc: 0.6949
#  epoch:20 auc: 0.6947
# Epoch 22/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5647 - accuracy: 0.6011 - my_auc: 0.7214 - val_loss: 0.6352 - val_accuracy: 0.5507 - val_my_auc: 0.6927
#  epoch:21 auc: 0.6929
# Epoch 23/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.5942 - accuracy: 0.5613 - my_auc: 0.7388 - val_loss: 0.6383 - val_accuracy: 0.5797 - val_my_auc: 0.6934
#  epoch:22 auc: 0.6933
# Epoch 24/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.5769 - accuracy: 0.5839 - my_auc: 0.7479 - val_loss: 0.6326 - val_accuracy: 0.5751 - val_my_auc: 0.6943
#  epoch:23 auc: 0.6942
# AUC:  0.6947
# 9780
# avg_AUC :  0.7199705384336382
# avg_AUC_2 :  0.7200085672041896
#          0         1         2   ...        27        28        29
# 0  0.694479  0.712592  0.712555  ...  0.755364  0.755689  0.756800
# 1  0.605837  0.680680  0.692281  ...  0.734549  0.734226  0.736612
# 2  0.636456  0.667510  0.666461  ...       NaN       NaN       NaN
# 3  0.603447  0.639303  0.650440  ...       NaN       NaN       NaN
#
# [4 rows x 30 columns]
# 0     0.635055
# 1     0.675022
# 2     0.680434
# 3     0.685610
# 4     0.688714
# 5     0.691547
# 6     0.694219
# 7     0.697428
# 8     0.699617
# 9     0.701276
# 10    0.703144
# 11    0.705435
# 12    0.705743
# 13    0.705706
# 14    0.708301
# 15    0.709585
# 16    0.711611
# 17    0.720089
# 18    0.721368
# 19    0.722719
# 20    0.723342
# 21    0.722936
# 22    0.724311
# 23    0.726162
# 24    0.741771
# 25    0.741386
# 26    0.744667
# 27    0.744956
# 28    0.744957
# 29    0.746706
# dtype: float64
# (0.7199705384336382,
#  array([0.00294118, 0.07041724, 0.10560876, 0.12609439, 0.16138851,
#         0.20246238, 0.21716826, 0.2377223 , 0.25831053, 0.29353625,
#         0.32582079, 0.34640903, 0.36699726, 0.37869357, 0.3874829 ,
#         0.39921341, 0.40509576, 0.41976744, 0.44018468, 0.45188098,
#         0.46942544, 0.48112175, 0.48984268, 0.51036252, 0.51918605,
#         0.52797538, 0.53679891, 0.55735294, 0.56316689, 0.574829  ,
#         0.59247606, 0.60417237, 0.6246238 , 0.64514364, 0.65102599,
#         0.67746238, 0.69794802, 0.70383037, 0.70677155, 0.71556088,
#         0.71846785, 0.73023256, 0.73611491, 0.74493844, 0.75666895,
#         0.75961012, 0.76839945, 0.77428181, 0.78604651, 0.79189466,
#         0.80068399, 0.80068399, 0.80950752, 0.82407661, 0.83290014,
#         0.83874829, 0.83874829, 0.84459644, 0.85632695, 0.85923393,
#         0.8621751 , 0.87387141, 0.87975376, 0.88563611, 0.89736662,
#         0.89736662, 0.90913133, 0.9120383 , 0.91788646, 0.92376881,
#         0.93255814, 0.93549932, 0.95307798, 0.9619015 , 0.9619015 ,
#         0.9619015 , 0.96484268, 0.97069083, 0.97363201, 0.98536252,
#         0.99124487, 0.99124487, 0.99124487, 0.99124487, 0.99124487,
#         0.99124487, 0.99124487, 0.99124487, 0.99415185, 0.99705882,
#         0.99705882, 0.99705882, 0.99705882, 0.99705882, 0.99705882,
#         0.99705882, 1.        , 1.        , 1.        , 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.5903009 , 0.6746893 , 0.29193097, ..., 0.05000496, 0.5225965 ,
#            0.48077667], dtype=float32)],
#    array([    6,    10,    12, ..., 39113, 39118, 39121])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.33004653, 0.5396575 , 0.6320083 , ..., 0.31081545, 0.3778099 ,
#            0.73899513], dtype=float32)],
#    array([    0,     5,     9, ..., 39117, 39119, 39122])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.49678373, 0.52337164, 0.4388396 , ..., 0.6982635 , 0.74602824,
#            0.5116808 ], dtype=float32)],
#    array([    1,     2,     4, ..., 39106, 39107, 39115])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.4384101 , 0.61293876, 0.6000879 , ..., 0.0162946 , 0.05389673,
#            0.4377035 ], dtype=float32)],
#    array([    3,     8,    11, ..., 39109, 39116, 39120])]])

# %%
# financial performance timestep = 2
cross_val(df_fl, 'label', v_perf, 'lstm_perf', 2)
# Out:
# init A shape:  (53635, 29)
# (45945, 2, 14) 408.0
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 14)]           0
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 2, 14)             56
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 2, 30)             5400
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 32)                992
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 13,801
# Trainable params: 13,773
# Non-trainable params: 28
# _________________________________________________________________
# Epoch 1/30
# 68/68 [==============================] - 9s 47ms/step - loss: 0.6844 - accuracy: 0.7277 - my_auc: 0.5498 - val_loss: 0.6904 - val_accuracy: 0.7448 - val_my_auc: 0.6375
#  epoch:0 auc: 0.6636
# Epoch 2/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6786 - accuracy: 0.6716 - my_auc: 0.6558 - val_loss: 0.6834 - val_accuracy: 0.4718 - val_my_auc: 0.6739
#  epoch:1 auc: 0.6821
# Epoch 3/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6335 - accuracy: 0.6692 - my_auc: 0.6952 - val_loss: 0.6693 - val_accuracy: 0.4340 - val_my_auc: 0.6940
#  epoch:2 auc: 0.6940
# Epoch 4/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6726 - accuracy: 0.5922 - my_auc: 0.6576 - val_loss: 0.6525 - val_accuracy: 0.5276 - val_my_auc: 0.6978
#  epoch:3 auc: 0.6978
# Epoch 5/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6454 - accuracy: 0.6092 - my_auc: 0.6899 - val_loss: 0.6361 - val_accuracy: 0.5627 - val_my_auc: 0.7024
#  epoch:4 auc: 0.7017
# Epoch 6/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6460 - accuracy: 0.6064 - my_auc: 0.6819 - val_loss: 0.6298 - val_accuracy: 0.5869 - val_my_auc: 0.7026
#  epoch:5 auc: 0.7024
# Epoch 7/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6529 - accuracy: 0.6109 - my_auc: 0.6698 - val_loss: 0.6268 - val_accuracy: 0.5810 - val_my_auc: 0.7021
#  epoch:6 auc: 0.7024
# Epoch 8/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6290 - accuracy: 0.6015 - my_auc: 0.7011 - val_loss: 0.6257 - val_accuracy: 0.6186 - val_my_auc: 0.7009
#  epoch:7 auc: 0.7006
# Epoch 9/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6366 - accuracy: 0.6152 - my_auc: 0.6718 - val_loss: 0.6248 - val_accuracy: 0.6277 - val_my_auc: 0.6993
#  epoch:8 auc: 0.6995
# AUC:  0.7024
# 11487
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 14)]           0
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 2, 14)             56
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 2, 30)             5400
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 32)                992
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 13,801
# Trainable params: 13,773
# Non-trainable params: 28
# _________________________________________________________________
# Epoch 1/30
# 68/68 [==============================] - 11s 47ms/step - loss: 0.7152 - accuracy: 0.2328 - my_auc: 0.5244 - val_loss: 0.6914 - val_accuracy: 0.1542 - val_my_auc: 0.6368
#  epoch:0 auc: 0.6640
# Epoch 2/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6612 - accuracy: 0.7232 - my_auc: 0.6565 - val_loss: 0.6865 - val_accuracy: 0.2063 - val_my_auc: 0.6640
#  epoch:1 auc: 0.6692
# Epoch 3/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.7019 - accuracy: 0.5857 - my_auc: 0.6634 - val_loss: 0.6736 - val_accuracy: 0.3919 - val_my_auc: 0.6703
#  epoch:2 auc: 0.6713
# Epoch 4/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6553 - accuracy: 0.6118 - my_auc: 0.6945 - val_loss: 0.6595 - val_accuracy: 0.4706 - val_my_auc: 0.6722
#  epoch:3 auc: 0.6722
# Epoch 5/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6236 - accuracy: 0.5997 - my_auc: 0.6835 - val_loss: 0.6483 - val_accuracy: 0.5013 - val_my_auc: 0.6759
#  epoch:4 auc: 0.6758
# Epoch 6/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6508 - accuracy: 0.5588 - my_auc: 0.6889 - val_loss: 0.6441 - val_accuracy: 0.5238 - val_my_auc: 0.6781
#  epoch:5 auc: 0.6779
# Epoch 7/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6102 - accuracy: 0.5630 - my_auc: 0.6979 - val_loss: 0.6424 - val_accuracy: 0.5171 - val_my_auc: 0.6795
#  epoch:6 auc: 0.6793
# Epoch 8/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6584 - accuracy: 0.5350 - my_auc: 0.7027 - val_loss: 0.6413 - val_accuracy: 0.5606 - val_my_auc: 0.6804
#  epoch:7 auc: 0.6805
# Epoch 9/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6227 - accuracy: 0.5772 - my_auc: 0.6982 - val_loss: 0.6394 - val_accuracy: 0.5622 - val_my_auc: 0.6818
#  epoch:8 auc: 0.6821
# Epoch 10/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6356 - accuracy: 0.5568 - my_auc: 0.6785 - val_loss: 0.6403 - val_accuracy: 0.5570 - val_my_auc: 0.6822
#  epoch:9 auc: 0.6818
# Epoch 11/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6068 - accuracy: 0.5693 - my_auc: 0.6979 - val_loss: 0.6389 - val_accuracy: 0.5554 - val_my_auc: 0.6829
#  epoch:10 auc: 0.6831
# Epoch 12/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6124 - accuracy: 0.5593 - my_auc: 0.6773 - val_loss: 0.6402 - val_accuracy: 0.5465 - val_my_auc: 0.6825
#  epoch:11 auc: 0.6827
# Epoch 13/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6095 - accuracy: 0.5602 - my_auc: 0.6989 - val_loss: 0.6418 - val_accuracy: 0.5549 - val_my_auc: 0.6825
#  epoch:12 auc: 0.6830
# Epoch 14/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6294 - accuracy: 0.5533 - my_auc: 0.6966 - val_loss: 0.6391 - val_accuracy: 0.5607 - val_my_auc: 0.6854
#  epoch:13 auc: 0.6850
# Epoch 15/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.5941 - accuracy: 0.5694 - my_auc: 0.7163 - val_loss: 0.6387 - val_accuracy: 0.5555 - val_my_auc: 0.6846
#  epoch:14 auc: 0.6848
# Epoch 16/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6011 - accuracy: 0.5722 - my_auc: 0.7147 - val_loss: 0.6356 - val_accuracy: 0.5624 - val_my_auc: 0.6870
#  epoch:15 auc: 0.6867
# Epoch 17/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.5923 - accuracy: 0.5732 - my_auc: 0.7098 - val_loss: 0.6360 - val_accuracy: 0.5615 - val_my_auc: 0.6888
#  epoch:16 auc: 0.6886
# Epoch 18/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6088 - accuracy: 0.5718 - my_auc: 0.6911 - val_loss: 0.6355 - val_accuracy: 0.5737 - val_my_auc: 0.6897
#  epoch:17 auc: 0.6899
# Epoch 19/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6049 - accuracy: 0.5751 - my_auc: 0.7180 - val_loss: 0.6346 - val_accuracy: 0.5737 - val_my_auc: 0.6910
#  epoch:18 auc: 0.6911
# Epoch 20/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.5940 - accuracy: 0.5805 - my_auc: 0.6958 - val_loss: 0.6345 - val_accuracy: 0.5622 - val_my_auc: 0.6912
#  epoch:19 auc: 0.6912
# Epoch 21/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6131 - accuracy: 0.5653 - my_auc: 0.6958 - val_loss: 0.6344 - val_accuracy: 0.5600 - val_my_auc: 0.6897
#  epoch:20 auc: 0.6899
# Epoch 22/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6033 - accuracy: 0.5666 - my_auc: 0.7263 - val_loss: 0.6370 - val_accuracy: 0.5635 - val_my_auc: 0.6910
#  epoch:21 auc: 0.6909
# Epoch 23/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6311 - accuracy: 0.5617 - my_auc: 0.6924 - val_loss: 0.6343 - val_accuracy: 0.5892 - val_my_auc: 0.6946
#  epoch:22 auc: 0.6942
# Epoch 24/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.5868 - accuracy: 0.5992 - my_auc: 0.7202 - val_loss: 0.6325 - val_accuracy: 0.5751 - val_my_auc: 0.6944
#  epoch:23 auc: 0.6947
# Epoch 25/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6106 - accuracy: 0.5740 - my_auc: 0.7168 - val_loss: 0.6324 - val_accuracy: 0.5598 - val_my_auc: 0.6950
#  epoch:24 auc: 0.6954
# Epoch 26/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6066 - accuracy: 0.5634 - my_auc: 0.7077 - val_loss: 0.6319 - val_accuracy: 0.5774 - val_my_auc: 0.6966
#  epoch:25 auc: 0.6964
# Epoch 27/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6322 - accuracy: 0.5687 - my_auc: 0.7143 - val_loss: 0.6290 - val_accuracy: 0.5507 - val_my_auc: 0.6962
#  epoch:26 auc: 0.6964
# Epoch 28/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6161 - accuracy: 0.5532 - my_auc: 0.7286 - val_loss: 0.6312 - val_accuracy: 0.5990 - val_my_auc: 0.6990
#  epoch:27 auc: 0.6988
# Epoch 29/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6007 - accuracy: 0.5975 - my_auc: 0.7143 - val_loss: 0.6276 - val_accuracy: 0.5848 - val_my_auc: 0.6997
#  epoch:28 auc: 0.6994
# Epoch 30/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6000 - accuracy: 0.5842 - my_auc: 0.7324 - val_loss: 0.6261 - val_accuracy: 0.5927 - val_my_auc: 0.6995
#  epoch:29 auc: 0.6997
# AUC:  0.6994
# 11486
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 14)]           0
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 2, 14)             56
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 2, 30)             5400
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 32)                992
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 13,801
# Trainable params: 13,773
# Non-trainable params: 28
# _________________________________________________________________
# Epoch 1/30
# 68/68 [==============================] - 10s 48ms/step - loss: 0.6725 - accuracy: 0.9304 - my_auc: 0.4251 - val_loss: 0.6922 - val_accuracy: 0.3055 - val_my_auc: 0.6003
#  epoch:0 auc: 0.6558
# Epoch 2/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6718 - accuracy: 0.8400 - my_auc: 0.6494 - val_loss: 0.6891 - val_accuracy: 0.2590 - val_my_auc: 0.6637
#  epoch:1 auc: 0.6852
# Epoch 3/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.7059 - accuracy: 0.7003 - my_auc: 0.6531 - val_loss: 0.6814 - val_accuracy: 0.4197 - val_my_auc: 0.6921
#  epoch:2 auc: 0.6913
# Epoch 4/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6748 - accuracy: 0.6824 - my_auc: 0.6652 - val_loss: 0.6677 - val_accuracy: 0.5041 - val_my_auc: 0.6917
#  epoch:3 auc: 0.6926
# Epoch 5/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6466 - accuracy: 0.6548 - my_auc: 0.6987 - val_loss: 0.6550 - val_accuracy: 0.5164 - val_my_auc: 0.6929
#  epoch:4 auc: 0.6924
# Epoch 6/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6245 - accuracy: 0.6255 - my_auc: 0.6846 - val_loss: 0.6457 - val_accuracy: 0.5454 - val_my_auc: 0.6934
#  epoch:5 auc: 0.6931
# Epoch 7/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6335 - accuracy: 0.6047 - my_auc: 0.7100 - val_loss: 0.6391 - val_accuracy: 0.5811 - val_my_auc: 0.6930
#  epoch:6 auc: 0.6932
# Epoch 8/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6196 - accuracy: 0.6160 - my_auc: 0.6918 - val_loss: 0.6357 - val_accuracy: 0.5548 - val_my_auc: 0.6938
#  epoch:7 auc: 0.6941
# Epoch 9/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6473 - accuracy: 0.5804 - my_auc: 0.6783 - val_loss: 0.6320 - val_accuracy: 0.5893 - val_my_auc: 0.6973
#  epoch:8 auc: 0.6968
# Epoch 10/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6440 - accuracy: 0.5893 - my_auc: 0.6920 - val_loss: 0.6317 - val_accuracy: 0.5898 - val_my_auc: 0.6969
#  epoch:9 auc: 0.6971
# Epoch 11/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6174 - accuracy: 0.5966 - my_auc: 0.6970 - val_loss: 0.6298 - val_accuracy: 0.5760 - val_my_auc: 0.7004
#  epoch:10 auc: 0.7001
# Epoch 12/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6593 - accuracy: 0.5765 - my_auc: 0.6809 - val_loss: 0.6298 - val_accuracy: 0.6035 - val_my_auc: 0.6987
#  epoch:11 auc: 0.6986
# Epoch 13/30
# 68/68 [==============================] - 1s 20ms/step - loss: 0.6591 - accuracy: 0.5873 - my_auc: 0.6721 - val_loss: 0.6291 - val_accuracy: 0.5886 - val_my_auc: 0.6979
#  epoch:12 auc: 0.6980
# Epoch 14/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6653 - accuracy: 0.5908 - my_auc: 0.6814 - val_loss: 0.6279 - val_accuracy: 0.5881 - val_my_auc: 0.7001
#  epoch:13 auc: 0.7001
# AUC:  0.7001
# 11486
# Model: "model_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2, 14)]           0
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 2, 14)             56
# _________________________________________________________________
# layer_lstm_1 (LSTM)          (None, 2, 30)             5400
# _________________________________________________________________
# layer_lstm_2 (LSTM)          (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 32)                992
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 13,801
# Trainable params: 13,773
# Non-trainable params: 28
# _________________________________________________________________
# Epoch 1/30
# 68/68 [==============================] - 10s 47ms/step - loss: 0.6739 - accuracy: 0.6786 - my_auc: 0.5741 - val_loss: 0.6908 - val_accuracy: 0.0259 - val_my_auc: 0.6558
#  epoch:0 auc: 0.6522
# Epoch 2/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6718 - accuracy: 0.6256 - my_auc: 0.6373 - val_loss: 0.6845 - val_accuracy: 0.1383 - val_my_auc: 0.6559
#  epoch:1 auc: 0.6586
# Epoch 3/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6863 - accuracy: 0.5655 - my_auc: 0.6584 - val_loss: 0.6711 - val_accuracy: 0.3630 - val_my_auc: 0.6625
#  epoch:2 auc: 0.6635
# Epoch 4/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6333 - accuracy: 0.6293 - my_auc: 0.6749 - val_loss: 0.6574 - val_accuracy: 0.4583 - val_my_auc: 0.6671
#  epoch:3 auc: 0.6671
# Epoch 5/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6394 - accuracy: 0.6005 - my_auc: 0.7022 - val_loss: 0.6474 - val_accuracy: 0.5132 - val_my_auc: 0.6726
#  epoch:4 auc: 0.6723
# Epoch 6/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6225 - accuracy: 0.6039 - my_auc: 0.7099 - val_loss: 0.6405 - val_accuracy: 0.5542 - val_my_auc: 0.6775
#  epoch:5 auc: 0.6775
# Epoch 7/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6378 - accuracy: 0.6049 - my_auc: 0.6994 - val_loss: 0.6356 - val_accuracy: 0.5748 - val_my_auc: 0.6838
#  epoch:6 auc: 0.6836
# Epoch 8/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6338 - accuracy: 0.6056 - my_auc: 0.6907 - val_loss: 0.6339 - val_accuracy: 0.5590 - val_my_auc: 0.6862
#  epoch:7 auc: 0.6866
# Epoch 9/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6367 - accuracy: 0.5858 - my_auc: 0.6893 - val_loss: 0.6303 - val_accuracy: 0.5908 - val_my_auc: 0.6909
#  epoch:8 auc: 0.6908
# Epoch 10/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.5881 - accuracy: 0.6237 - my_auc: 0.7164 - val_loss: 0.6274 - val_accuracy: 0.5728 - val_my_auc: 0.6946
#  epoch:9 auc: 0.6944
# Epoch 11/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6210 - accuracy: 0.6046 - my_auc: 0.7071 - val_loss: 0.6256 - val_accuracy: 0.5712 - val_my_auc: 0.6972
#  epoch:10 auc: 0.6969
# Epoch 12/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6085 - accuracy: 0.6007 - my_auc: 0.6921 - val_loss: 0.6257 - val_accuracy: 0.5491 - val_my_auc: 0.6974
#  epoch:11 auc: 0.6974
# Epoch 13/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6646 - accuracy: 0.5693 - my_auc: 0.6946 - val_loss: 0.6236 - val_accuracy: 0.5865 - val_my_auc: 0.7012
#  epoch:12 auc: 0.7013
# Epoch 14/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6112 - accuracy: 0.6078 - my_auc: 0.7104 - val_loss: 0.6242 - val_accuracy: 0.5596 - val_my_auc: 0.7005
#  epoch:13 auc: 0.7003
# Epoch 15/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6251 - accuracy: 0.5822 - my_auc: 0.6939 - val_loss: 0.6212 - val_accuracy: 0.5880 - val_my_auc: 0.7041
#  epoch:14 auc: 0.7038
# Epoch 16/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6456 - accuracy: 0.6030 - my_auc: 0.6964 - val_loss: 0.6211 - val_accuracy: 0.5699 - val_my_auc: 0.7044
#  epoch:15 auc: 0.7039
# Epoch 17/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6381 - accuracy: 0.5864 - my_auc: 0.6791 - val_loss: 0.6198 - val_accuracy: 0.5746 - val_my_auc: 0.7060
#  epoch:16 auc: 0.7059
# Epoch 18/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6347 - accuracy: 0.5941 - my_auc: 0.7064 - val_loss: 0.6188 - val_accuracy: 0.5892 - val_my_auc: 0.7077
#  epoch:17 auc: 0.7074
# Epoch 19/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6167 - accuracy: 0.6122 - my_auc: 0.6825 - val_loss: 0.6178 - val_accuracy: 0.5710 - val_my_auc: 0.7080
#  epoch:18 auc: 0.7082
# Epoch 20/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6199 - accuracy: 0.5945 - my_auc: 0.7112 - val_loss: 0.6190 - val_accuracy: 0.5564 - val_my_auc: 0.7081
#  epoch:19 auc: 0.7076
# Epoch 21/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6550 - accuracy: 0.5750 - my_auc: 0.6941 - val_loss: 0.6190 - val_accuracy: 0.5523 - val_my_auc: 0.7083
#  epoch:20 auc: 0.7083
# Epoch 22/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.5990 - accuracy: 0.5878 - my_auc: 0.7058 - val_loss: 0.6200 - val_accuracy: 0.5548 - val_my_auc: 0.7074
#  epoch:21 auc: 0.7071
# Epoch 23/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6220 - accuracy: 0.5797 - my_auc: 0.7212 - val_loss: 0.6177 - val_accuracy: 0.5784 - val_my_auc: 0.7114
#  epoch:22 auc: 0.7114
# Epoch 24/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.5693 - accuracy: 0.6166 - my_auc: 0.7342 - val_loss: 0.6179 - val_accuracy: 0.5687 - val_my_auc: 0.7113
#  epoch:23 auc: 0.7112
# Epoch 25/30
# 68/68 [==============================] - 1s 21ms/step - loss: 0.6198 - accuracy: 0.5922 - my_auc: 0.7185 - val_loss: 0.6179 - val_accuracy: 0.5608 - val_my_auc: 0.7126
#  epoch:24 auc: 0.7125
# Epoch 26/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6443 - accuracy: 0.5896 - my_auc: 0.7047 - val_loss: 0.6171 - val_accuracy: 0.5929 - val_my_auc: 0.7128
#  epoch:25 auc: 0.7129
# Epoch 27/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6072 - accuracy: 0.6135 - my_auc: 0.7320 - val_loss: 0.6174 - val_accuracy: 0.5604 - val_my_auc: 0.7125
#  epoch:26 auc: 0.7124
# Epoch 28/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.6277 - accuracy: 0.5790 - my_auc: 0.7138 - val_loss: 0.6167 - val_accuracy: 0.5773 - val_my_auc: 0.7138
#  epoch:27 auc: 0.7137
# Epoch 29/30
# 68/68 [==============================] - 1s 22ms/step - loss: 0.5814 - accuracy: 0.6128 - my_auc: 0.7414 - val_loss: 0.6175 - val_accuracy: 0.5699 - val_my_auc: 0.7101
#  epoch:28 auc: 0.7102
# Epoch 30/30
# 68/68 [==============================] - 2s 22ms/step - loss: 0.5863 - accuracy: 0.6054 - my_auc: 0.7172 - val_loss: 0.6166 - val_accuracy: 0.5689 - val_my_auc: 0.7125
#  epoch:29 auc: 0.7127
# AUC:  0.7137
# 11486
# avg_AUC :  0.7039040328260695
# avg_AUC_2 :  0.7038646266587443
#          0         1         2   ...        27        28        29
# 0  0.637482  0.673948  0.693951  ...       NaN       NaN       NaN
# 1  0.636801  0.663993  0.670267  ...  0.699019  0.699723  0.699535
# 2  0.600267  0.663698  0.692129  ...       NaN       NaN       NaN
# 3  0.655799  0.655907  0.662526  ...  0.713808  0.710119  0.712507
#
# [4 rows x 30 columns]
# 0     0.632587
# 1     0.664386
# 2     0.679718
# 3     0.682217
# 4     0.685936
# 5     0.687918
# 6     0.689591
# 7     0.690321
# 8     0.692344
# 9     0.691225
# 10    0.693508
# 11    0.692872
# 12    0.693850
# 13    0.695302
# 14    0.694336
# 15    0.695663
# 16    0.697407
# 17    0.698690
# 18    0.699533
# 19    0.699636
# 20    0.699017
# 21    0.699190
# 22    0.702992
# 23    0.702838
# 24    0.703800
# 25    0.704714
# 26    0.704348
# 27    0.706414
# 28    0.704921
# 29    0.706021
# dtype: float64
# (0.7039040328260695,
#  array([0.00245098, 0.05882353, 0.09803922, 0.12745098, 0.16666667,
#         0.17892157, 0.20588235, 0.22303922, 0.2622549 , 0.29166667,
#         0.29656863, 0.31372549, 0.33823529, 0.3504902 , 0.36029412,
#         0.36519608, 0.37990196, 0.39705882, 0.40686275, 0.42892157,
#         0.44607843, 0.47303922, 0.47794118, 0.49019608, 0.5       ,
#         0.50980392, 0.5245098 , 0.54411765, 0.56372549, 0.57843137,
#         0.58578431, 0.59313725, 0.60784314, 0.6127451 , 0.62745098,
#         0.64215686, 0.65196078, 0.65441176, 0.66666667, 0.68382353,
#         0.70833333, 0.71813725, 0.7254902 , 0.73284314, 0.74264706,
#         0.75245098, 0.75735294, 0.75980392, 0.77696078, 0.78676471,
#         0.78921569, 0.79656863, 0.80392157, 0.80637255, 0.80882353,
#         0.81372549, 0.82598039, 0.82598039, 0.83088235, 0.84313725,
#         0.8504902 , 0.8627451 , 0.86519608, 0.87009804, 0.87254902,
#         0.88480392, 0.89215686, 0.89460784, 0.90196078, 0.90196078,
#         0.90196078, 0.90931373, 0.91176471, 0.92156863, 0.92892157,
#         0.93627451, 0.94362745, 0.95343137, 0.95343137, 0.96078431,
#         0.96813725, 0.97303922, 0.97794118, 0.97794118, 0.98284314,
#         0.98529412, 0.98529412, 0.98529412, 0.9877451 , 0.9877451 ,
#         0.9877451 , 0.99019608, 0.99509804, 0.99509804, 0.99754902,
#         0.99754902, 1.        , 1.        , 1.        , 1.        ]),
#  [[[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.33499786, 0.64066297, 0.5241118 , ..., 0.6259867 , 0.49027315,
#            0.6520592 ], dtype=float32)],
#    array([    0,    11,    12, ..., 45939, 45940, 45943])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.43917713, 0.52758425, 0.70324165, ..., 0.54399246, 0.80846334,
#            0.27304435], dtype=float32)],
#    array([    4,     8,    10, ..., 45936, 45938, 45944])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.4391513 , 0.5396592 , 0.3589238 , ..., 0.7339598 , 0.5912581 ,
#            0.46326712], dtype=float32)],
#    array([    1,     2,     5, ..., 45920, 45922, 45924])],
#   [[array([0., 0., 0., ..., 0., 0., 0.]),
#     array([0.47811422, 0.70148546, 0.5472333 , ..., 0.36513   , 0.56760126,
#            0.56641597], dtype=float32)],
#    array([    3,    17,    20, ..., 45937, 45941, 45942])]])

# %% [markdown]
# # LSTM+TCN

# %%
# def model_cnn(w, num_wrds, num_depth):
#   model = None
#   input_wds = Input(shape=(w, num_wrds, 1),dtype='float32', name='input_words')

#   cov = Conv2D(4, (2,2), activation='relu')(input_wds)
#   maxpool = MaxPooling2D((1,1))(cov)
#   #reshp = Reshape((1,64))(maxpool)
#   #flt = Flatten()(maxpool)
#   model = Model(inputs=input_wds, outputs= maxpool)
#   model._name = 'cnn'          
#   model.summary()
#   return model

# %%
# def model_lstm(n1, n2, n3, w, num_wrds, num_perf, num_depth):
#     model = None
    
#     input_perf = Input(shape=(1,num_perf),dtype='float32', name='input_financial')
#     input_wds = Input(shape=(w,num_wrds),dtype='float32', name='input_words')

#     cnnmodel = model_cnn(w, num_wrds, num_depth)
#     cnn_wrds = cnnmodel(input_wds)

#     reshp_perf = Reshape((1,num_perf))(input_perf)

#     concate = Concatenate(axis=-1)([cnn_wrds,input_perf])

#     #nor = BatchNormalization()(concate)
#     drop1 = Dropout(0.3)(concate)
#     #nor = BatchNormalization()(drop1)
#     # LSTM_w_1 = Bidirectional(LSTM(81,recurrent_dropout = 0.2, name = 'layer_lstm_1',\
#     #                   return_sequences=True, \
#     #                #kernel_regularizer=regularizers.l2(0.01),\
#     #                #bias_regularizer=regularizers.l2(0.01),
#     #               activity_regularizer=regularizers.l2(0.01)))(drop1)
#     LSTM_w_2 = LSTM(81,recurrent_dropout = 0.2, name = 'layer_lstm_2', \
#                 return_sequences=False )(drop1)        
#     #nor = BatchNormalization()(LSTM_w_2)
#     dense1 = Dense(81, activation='relu', name='dense1')(LSTM_w_2)
#     dense2 = Dense(n3, activation='relu', name='dense2')(dense1)
#     nor = BatchNormalization()(dense2)
#     drop2 = Dropout(0.3)(nor)
    
#     preds = Dense(1, activation='sigmoid', name='output')(drop2)
#     model = Model(inputs=[input_perf, input_wds], outputs=preds)
#     model._name = "lstm"
#     model.summary()
    
#     return model

# %%
#LR
# def model_cnn_lstm(n1, n2, n3, T, perf, words, channel, filters = 24):
#     model = None
    
#     input_perf = Input(shape=(T,perf), \
#                       dtype='float32', name='input_perf')
    
#     input_words = Input(shape=(T, words, channel), \
#                       dtype='float32', name='input_words') 
    
#     word_norm = BatchNormalization()(input_words)
    
    
#     conv = Conv2D(filters = filters,\
#                   kernel_size = 1,\
#                   use_bias = False,\
#                   activation = None)(word_norm)  # Shape None x T x words x filters
#     print("conv shape:", K.int_shape(conv))
#     conv = BatchNormalization()(conv)
#     conv = Activation("relu") (conv)
    
#     pool = MaxPooling2D(pool_size=(1, words), \
#                         strides=(1,1))(conv) # None x T x filters
#     pool = Reshape((T, filters))(conv)
#     print("pool shape:", K.int_shape(pool))
    
#     #drop = Dropout(0.3)(input_all)
#     # Now concatenate
#     perf_norm = BatchNormalization()(input_perf)
#     all_input = Concatenate(axis = -1)([perf_norm, pool])
#     #nor = BatchNormalization()(all_input)
    
#     LSTM_w_1 = Bidirectional(LSTM(n1, dropout= 0.3, recurrent_dropout = 0.3,\
#                     name = 'layer_lstm_1', return_sequences=True))(all_input)
#     LSTM_w_2 = LSTM(n2, dropout= 0.3, recurrent_dropout = 0.3,
#                    name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)
    
#     dense = Dense(n3, activation='relu', name='dense')(LSTM_w_2)
#     drop = Dropout(0.3)(dense)
    
#     preds = Dense(1, activation='sigmoid', name='output')(drop)
#     model = Model(inputs=[input_perf, input_words], outputs=preds)
#     model._name = "model_cnnlstm"
#     model.summary()
    
#     return model

# %%
def model_cnn_lstm_1(n1,n2,n3,T, perf, words, types ,filters = 32): #channel,
    model = None
    filters = 32
    
    input_perf = Input(shape=(T,perf), \
                      dtype='float32', name='input_perf')
    
    input_words = Input(shape=(T,words,types), \
                      dtype='float32', name='input_words')
    

    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(input_words)  # Shape None x T x words x filters
    print("conv shape 1:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    pool_1 = MaxPooling2D(pool_size= (1,17), \
                        strides=1)(conv)
    pool_1 = Reshape((T, filters))(pool_1)

    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(conv)  # Shape None x T x words x filters
    print("conv shape 2:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    pool_2 = MaxPooling2D(pool_size= (1,14), \
                        strides=1)(conv)
    pool_2 = Reshape((T, filters))(pool_2)


    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(conv)  # Shape None x T x words x filters
    print("conv shape 3:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    pool_3 = MaxPooling2D(pool_size= (1,11), \
                        strides=1)(conv)
    pool_3 = Reshape((T, filters))(pool_3)
    
    # conv = Conv2D(filters = filters,\
    #               kernel_size = (1,4),\
    #               activation = 'relu')(conv)  # Shape None x T x words x filters
    # print("conv shape 4:", K.int_shape(conv))
    # conv = BatchNormalization()(conv)
    # conv = Activation("relu") (conv)
    # pool_4 = MaxPooling2D(pool_size= (1,8), \
    #                     strides=1)(conv)
    # pool_4 = Reshape((T, filters))(pool_4)
    
    # pool = MaxPooling2D(pool_size= (1,8), \
    #                     strides=1)(conv) # None x T x filters
    
    # print("pool_init shape:", K.int_shape(pool))
    # pool = Reshape((T, filters))(pool)
    # print("pool shape:", K.int_shape(pool))
    
    #drop = Dropout(0.3)(input_all)
    # Now concatenate
    perf_norm = BatchNormalization()(input_perf)
    all_input = Concatenate(axis = -1)([perf_norm, pool_3, pool_2, pool_1 ])
    nor = BatchNormalization()(all_input)
    #drop = Dropout(0.3)(nor)
    
    LSTM_w_1 =Bidirectional(LSTM(120,  recurrent_dropout = 0.2,
                    name = 'layer_lstm_1', return_sequences=True,
                    kernel_regularizer = regularizers.l2(0.01),
                    activity_regularizer = regularizers.l2(0.01),
                    bias_regularizer = regularizers.l2(0.01)
                    ))(nor)
    LSTM_w_2 = LSTM(120, recurrent_dropout = 0.2, 
                   name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)

    dense = Dense(32, activation='relu', name='dense')(LSTM_w_2)
    nor = BatchNormalization()(dense)
    drop = Dropout(0.3)(nor)
    preds = Dense(1, activation='sigmoid', name='output')(drop)
    model = Model(inputs=[input_perf, input_words], outputs=preds)
    model._name = "model_cnnlstm_1"
    model.summary()
    
    return model

# %%
def model_cnn_lstm_2(n1,n2,n3,T, perf, words, types ,filters = 32): #channel,
    model = None
    filters = 32
    
    input_perf = Input(shape=(T,perf), \
                      dtype='float32', name='input_perf')
    
    input_words = Input(shape=(T,words,types), \
                      dtype='float32', name='input_words')
    

    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(input_words)  # Shape None x T x words x filters
    print("conv shape 1:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)

    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(conv)  # Shape None x T x words x filters
    print("conv shape 2:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)


    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(conv)  # Shape None x T x words x filters
    print("conv shape 3:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    
    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(conv)  # Shape None x T x words x filters
    print("conv shape 4:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    
    pool = MaxPooling2D(pool_size= (1,8), \
                        strides=1)(conv) # None x T x filters
    
    print("pool_init shape:", K.int_shape(pool))
    pool = Reshape((T, filters))(pool)
    print("pool shape:", K.int_shape(pool))
    
    #drop = Dropout(0.3)(input_all)
    # Now concatenate
    perf_norm = BatchNormalization()(input_perf)
    all_input = Concatenate(axis = -1)([perf_norm, pool ])
    nor = BatchNormalization()(all_input)
    #drop = Dropout(0.3)(nor)
    
    LSTM_w_1 =Bidirectional(LSTM(n1,  recurrent_dropout = 0.2,
                    name = 'layer_lstm_1', return_sequences=True,
                    kernel_regularizer = regularizers.l2(0.01),
                    activity_regularizer = regularizers.l2(0.01),
                    bias_regularizer = regularizers.l2(0.01)
                    ))(nor)
    LSTM_w_2 = LSTM(n2, recurrent_dropout = 0.2, 
                   name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)

    dense = Dense(32, activation='relu', name='dense')(LSTM_w_2)
    nor = BatchNormalization()(dense)
    drop = Dropout(0.3)(nor)
    preds = Dense(1, activation='sigmoid', name='output')(drop)
    model = Model(inputs=[input_perf, input_words], outputs=preds)
    model._name = "model_cnnlstm_2"
    model.summary()
    
    return model

# %%
def model_cnn_lstm_3(n1,n2,n3,T, perf, words, types ,filters = 32): #channel,
    model = None
    filters = 32
    
    input_perf = Input(shape=(T,perf), \
                      dtype='float32', name='input_perf')
    
    input_words = Input(shape=(T,words,types), \
                      dtype='float32', name='input_words')
    

    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(input_words)  # Shape None x T x words x filters
    print("conv shape 1:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    pool = MaxPooling2D(pool_size= (1,4), \
                        strides=1)(conv)

    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(pool)  # Shape None x T x words x filters
    print("conv shape 2:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    pool = MaxPooling2D(pool_size= (1,4), \
                        strides=1)(conv)

    conv = Conv2D(filters = filters,\
                  kernel_size = (1,4),\
                  activation = 'relu')(pool)  # Shape None x T x words x filters
    print("conv shape 3:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    
    # conv = Conv2D(filters = filters,\
    #               kernel_size = (1,4),\
    #               activation = 'relu')(conv)  # Shape None x T x words x filters
    # print("conv shape 4:", K.int_shape(conv))
    # conv = BatchNormalization()(conv)
    # conv = Activation("relu") (conv)
    
    pool = MaxPooling2D(pool_size= (1,5), \
                        strides=1)(conv) # None x T x filters
    
    print("pool_init shape:", K.int_shape(pool))
    pool = Reshape((T, filters))(pool)
    print("pool shape:", K.int_shape(pool))
    
    #drop = Dropout(0.3)(input_all)
    # Now concatenate
    perf_norm = BatchNormalization()(input_perf)
    all_input = Concatenate(axis = -1)([perf_norm, pool ])
    nor = BatchNormalization()(all_input)
    #drop = Dropout(0.3)(nor)
    
    LSTM_w_1 =Bidirectional(LSTM(n1,  recurrent_dropout = 0.2,
                    name = 'layer_lstm_1', return_sequences=True,
                    kernel_regularizer = regularizers.l2(0.01),
                    activity_regularizer = regularizers.l2(0.01),
                    bias_regularizer = regularizers.l2(0.01)
                    ))(nor)
    LSTM_w_2 = LSTM(n2, recurrent_dropout = 0.2, 
                   name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)

    dense = Dense(32, activation='relu', name='dense')(LSTM_w_2)
    nor = BatchNormalization()(dense)
    drop = Dropout(0.3)(nor)
    preds = Dense(1, activation='sigmoid', name='output')(drop)
    model = Model(inputs=[input_perf, input_words], outputs=preds)
    model._name = "model_cnnlstm_3"
    model.summary()
    
    return model

# %%
#TCN for timestep = 1
def model_tcn(n1,n2,n3,T, perf, words, channel, filters = 24, dropout = 0):
    model = None
    
    input_perf = Input(shape=(T,perf), \
                      dtype='float32', name='input_perf')
    
    input_words = Input(shape=(T,words,channel), \
                      dtype='float32', name='input_words') 
    
    word_norm = BatchNormalization()(input_words)
    padding = ZeroPadding2D(padding=((0,0),(words-1,0)))(word_norm)
    
    print("shape after padding:", K.int_shape(padding))
    
    conv = Conv2D(filters = filters,\
                  kernel_size = (1,words),\
                  use_bias = False,\
                  activation = None)(padding)  # Shape None x T x words x filters
    print("conv shape:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    
    pool = MaxPooling2D(pool_size=(1, words), \
                        strides=(1,1))(conv) # None x T x filters
    
    pool = Reshape((T, filters))(pool)
    print("pool shape:", K.int_shape(pool))
    pool = Dropout(0.3)(pool)

    #drop = Dropout(0.3)(input_all)
    # Now concatenate
    perf_norm = BatchNormalization()(input_perf)
    all_input = Concatenate(axis = -1)([perf_norm, pool])
    all_rsp = Reshape((filters+ input_perf.shape[2],))(all_input)
    #nor = BatchNormalization()(all_rsp)
    
    # LSTM_w_1 =Bidirectional(LSTM(n1,  recurrent_dropout = 0.2,
    #                 name = 'layer_lstm_1', return_sequences=True,
    #                 # kernel_regularizer = regularizers.l2(0.01),
    #                 # activity_regularizer = regularizers.l2(0.01),
    #                 # bias_regularizer = regularizers.l2(0.01)
    #                 ))(all_input)
    # LSTM_w_2 = LSTM(n2, dropout= 0.3, recurrent_dropout = 0.3,
    #                name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)
    
    dense = Dense(120, activation='relu', name='dense0')(all_rsp)
    drop = Dropout(0.3)(dense)
    dense = Dense(60, activation='relu', name='dense')(drop)
    #nor = BatchNormalization()(dense)
    #dense = Dense(24, activation='relu', name='dense2')(drop)
    preds = Dense(1, activation='sigmoid', name='output')(dense)
    model = Model(inputs=[input_perf, input_words], outputs=preds)
    model._name = "model_tcn"
    model.summary()
    
    return model

# %%
#TCN for timestep > 1
def model_tcn_1(n1,n2,n3,T, perf, words, channel, filters = 24, dropout = 0):
    model = None
    
    input_perf = Input(shape=(T,perf), \
                      dtype='float32', name='input_perf')
    
    input_words = Input(shape=(T,words,channel), \
                      dtype='float32', name='input_words') 
    
    word_norm = BatchNormalization()(input_words)
    padding = ZeroPadding2D(padding=((0,0),(words-1,0)))(word_norm)
    
    print("shape after padding:", K.int_shape(padding))
    
    conv = Conv2D(filters = filters,\
                  kernel_size = (1,words),\
                  use_bias = False,\
                  activation = None)(padding)  # Shape None x T x words x filters
    print("conv shape:", K.int_shape(conv))
    conv = BatchNormalization()(conv)
    conv = Activation("relu") (conv)
    
    pool = MaxPooling2D(pool_size=(1, words), \
                        strides=(1,1))(conv) # None x T x filters
    pool = Reshape((T, filters))(pool)
    print("pool shape:", K.int_shape(pool))

    #drop = Dropout(0.3)(input_all)
    # Now concatenate
    perf_norm = BatchNormalization()(input_perf)
    all_input = Concatenate(axis = -1)([perf_norm, pool])
    #all_rsp = Reshape((filters+15,))(all_input)
    #nor = BatchNormalization()(all_input)
    
    LSTM_w_1 =Bidirectional(LSTM(n1,  recurrent_dropout = 0.2,
                    name = 'layer_lstm_1', return_sequences=True,
                    # kernel_regularizer = regularizers.l2(0.01),
                    # activity_regularizer = regularizers.l2(0.01),
                    # bias_regularizer = regularizers.l2(0.01)
                    ))(all_input)
    LSTM_w_2 = LSTM(n2, dropout= 0.3, recurrent_dropout = 0.3,
                   name = 'layer_lstm_2', return_sequences=False)(LSTM_w_1)
    
    dense = Dense(n3, activation='relu', name='dense')(LSTM_w_2)
    drop = Dropout(0.3)(dense)
    
    preds = Dense(1, activation='sigmoid', name='output')(drop)
    model = Model(inputs=[input_perf, input_words], outputs=preds)
    model._name = "model_tcn"
    model.summary()
    
    return model

# %%
def performance_measure(pred_yp, y):
    '''
    Given lists of predicted y probability and x, y, return a dataframe of AR, AUC, Brier, Decile Table
    '''
    
    tenc_dat = pd.DataFrame({'y_true':y,'probability':pred_yp.flatten()})
    tenc_dat.sort_values('probability',axis = 0,ascending=False, inplace = True)
    tenc_dat.index = range(0,len(tenc_dat))
    y = tenc_dat['y_true']
    point = float(len(tenc_dat))/10
    point = int(round(point))
    tenc = []
    for i in range(0,10):
        tenc.append(y[(i*point):((i+1)*point)])
    tenc[9]=tenc[9].append(y[10*point:])
    total = sum(y)
    num_of_bkr = []
    for j in range(0,10):
        num_of_bkr.append(sum(tenc[j]))
    tencile_bkr = np.array(num_of_bkr)
    rate = tencile_bkr.astype(float)/total

    return rate

# %%
class AUCEvaluation(Callback):
    """ Show AUC after interval number of epoches """
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()
        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            logs['auc'] = score
            tencile=performance_measure(y_pred, self.y_val)
            logs['tencile'] = tencile
            print(" epoch:{:d} auc: {:.4f}".format(epoch, score))

# %%
def fit_model( model,x_train, y_train, x_val, y_val, x_test, y_test, model_name, verbose = 0):
    
    history = None
    result = None
    
    model_df = model
    print('in fit, val_y: ', sum(y_val), 'test_y',sum(y_test), 'train_y',sum(y_train))

    #class weight for test 
    class_weights = class_weight.compute_class_weight('balanced',
                              np.unique(y_train),
                              y_train)
    class_weights = {l:c for l,c in zip(np.unique(y_train), class_weights)}
    # class weight for val
    val_class_weights = class_weight.compute_class_weight('balanced',
                                np.unique(y_val),
                                y_val)
    val_class_weights = {l:c for l,c in zip(np.unique(y_val), val_class_weights)}
    val_sample_weights = []
    for y in y_val:
        if y == 1:
          val_sample_weights.append(val_class_weights[1])
        else: val_sample_weights.append(val_class_weights[0])
    val_sample_weights = np.asarray(val_sample_weights)
    #print('in fit val weights', val_sample_weights.shape)
    
    auc_eval = AUCEvaluation(validation_data=(x_val, y_val), interval=1)
    # earlyStopping = EarlyStopping(monitor='val_loss',patience = 3, 
    #                   verbose =verbose, mode ='min')
    # checkpoint = ModelCheckpoint(model_name,monitor='val_my_auc',verbose=verbose,
    #           save_best_only=True, save_weights_only=True, mode ='max')

    opt = optimizers.RMSprop(lr=0.0005)
    model_df.compile(optimizer= opt,
              loss='binary_crossentropy',
              metrics=['accuracy', metrics.AUC(name='my_auc')])

    history = model_df.fit(x_train,
                y_train,
                epochs=12,
                batch_size=128,
                verbose =verbose,
                callbacks=[auc_eval],\
                #callbacks=[auc_eval, earlyStopping, checkpoint], #checkpoint
                class_weight = class_weights, \
                validation_data=(x_val, y_val, val_sample_weights)) 
    model_df.save(model_name+".h5")
    #model_df.load_weights(model_name)
    y_pred = model_df.predict(x_test)
    y_pred_1=np.reshape(y_pred, -1)
    auc_score = roc_auc_score(y_test, y_pred_1)
    #auc_score = roc_auc_score(y_test, y_pred_1)
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_1)
    print("AUC: " ,round(auc_score,4))
    print([ round(h,4) for h in history.history['val_loss']])    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

        
    return history, auc_score, fpr, tpr, thresholds, [y_test, y_pred_1]

# %%
def cross_val(data, label, perf_cols, words_cols, name, w, filters = 24):
    tprs = []
    auc_list = []
    mean_fpr = np.linspace(0,1,100)
    predicted_res =[]
    his_auc = []
    
    kf = StratifiedKFold(n_splits = 4, shuffle = True, random_state = 42)
    c = 0

    X_perf, X_word, Y = shift_data(df_fl, w, \
                    perf_cols, \
                    words_cols, \
                    'label')
    
    for train_index, test_index in kf.split(range(len(X_perf)),Y):
        
        c += 1
        
        l1 = X_perf.shape[-1]+ filters + 16
        
        model = model_tcn(l1,l1,32,\
                    X_perf.shape[1],\
                    X_perf.shape[2],
                    X_word.shape[2], \
                    X_word.shape[3], \
                    filters = filters)
    
        #model = model_lstm(n1,n2,n,w)
        # train_x, train_val = train_test_split(train_index,test_size=0.2, \
        #             random_state=42, stratify = Y[train_index])
        train_perf_data = X_perf[train_index]
        train_word_data = X_word[train_index]
        # train_perf_val = X_perf[train_val]
        # train_word_val = X_word[train_val]

        train_label = Y[train_index]
        #val_label = Y[train_val]

        test_perf_x = X_perf[test_index]
        test_word_x = X_word[test_index]
        test_y = Y[test_index] 
        
        train_data = [train_perf_data, train_word_data]
        #val_data = [train_perf_val,train_word_val]
        test_x = [test_perf_x, test_word_x]

        mod_res = fit_model(model, train_data, train_label, test_x, test_y, test_x, test_y,\
                  name+'_'+str(c))
        his_auc.append(mod_res[0].history['val_my_auc'])
        
        
        
        
        auc_list.append(mod_res[1])
        tprs.append(np.interp(mean_fpr, mod_res[2], mod_res[3]))
        temp_pred_res = [mod_res[-1],test_index]
        print(len(test_index))
        predicted_res.append(temp_pred_res)
        
        
    mean_tpr = np.mean(tprs, axis=0)
    print('avg_AUC : ', np.mean(auc_list))
    print('avg_AUC_2 : ', auc(mean_fpr, mean_tpr))
    print(pd.DataFrame(his_auc))
    print(pd.DataFrame(his_auc).mean())
    
    return np.average(auc_list), mean_tpr, predicted_res

# %%
#a = np.arange(16).reshape((2,8#))

# %%
#a

# %%
#a.reshape((2,8), order = '')

# %%
#a.reshape((2,4,2), order = 'C')

# %%
def shift_data(data, step, perf_cols, words_cols, label):
    A = []
    
    cols = perf_cols + words_cols
    A.append(data[cols].values)
    
    for t in range(1, step):
        d = data.groupby("cik")[cols].shift(t)
        A.append(d.values)
    A = A[::-1]
    A = np.concatenate(A, axis = 1)  # flatten shifted columns
    A = np.concatenate([data[label].values[:,None], A], axis = 1)  # add target
    #np.random.shuffle(A)
    #print(A[3])
    print('init A shape: ',A.shape)
    #print(A[3,:])
    #print(data[cols].iloc[4,:])


    
    A = A[~np.isnan(A).any(axis=1)]  # drop nan
    

    Y = A[:,0]  # get target
    #A = np.reshape(A[:,1:], (len(A), step, len(cols))) # reshape

    A = np.reshape(A[:,1:], (len(A), step, len(perf_cols) + len(words_cols)))
    
    A_perf = A[:, :, 0:len(perf_cols)]
    # CNN_LSTM must be None x T x words x 4
    A_words = A[:, :, len(perf_cols):]
    #convert the shape to [[_p,_new][_dis,_n]]
    A_words = A_words.reshape((len(A), step, int(len(words_cols)/4), 4), order = 'C')
    
    print(A_perf.shape, A_words.shape, Y.sum())
    return A_perf, A_words, Y

# %%
#shift_perf,shit_wrd, _y = shift_data(df_fl, 3, v_perf + v_1+ v_2, selected_new_all_sorted, label='label')

# %%
#shit_wrd[2]

# %%
# for k , fr in df_fl.groupby("cik"):
#   print(fr[selected_new_all_sorted])
#   break

# %%
import os, random

seed_value = 43
os.environ['PYTHONASHSEED'] = str(seed_value)

random.seed(seed_value)

from numpy.random import seed
seed(seed_value)

import tensorflow
tensorflow.random.set_seed(seed_value)

# %%
print("\n ======= v_1 and word changes =========")

#filter = [24,28,32,36,46,56]
filter = [32,36,46,56,66,76]
for f in filter:
  w = 1
  perf_cols =  v_1 #+ v_perf
  words_cols = selected_new_all_sorted
  label = 'label'
  h = cross_val( df_fl, 'label', \
            perf_cols,\
            words_cols, \
            'model_tcn_w1_v1words',w, \
            filters = f)
# Out:
#  ======= v_1 and word changes =========
# init A shape:  (53635, 42)
# (53635, 1, 1) (53635, 1, 10, 4) 487.0
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 32)
# pool shape: (None, 1, 32)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 1, 19, 4)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 1, 10, 32)    1280        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 1, 10, 32)    128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 10, 32)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 1, 1, 32)     0           activation[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 32)        0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1, 32)        0           reshape[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 33)        0           batch_normalization_2[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 33)           0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          4080        reshape_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 12,829
# Trainable params: 12,755
# Non-trainable params: 74
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5835
#  epoch:1 auc: 0.4978
#  epoch:2 auc: 0.5623
#  epoch:3 auc: 0.5855
#  epoch:4 auc: 0.5890
#  epoch:5 auc: 0.6032
#  epoch:6 auc: 0.5727
#  epoch:7 auc: 0.5899
#  epoch:8 auc: 0.5813
#  epoch:9 auc: 0.5824
#  epoch:10 auc: 0.5782
#  epoch:11 auc: 0.5747
# AUC:  0.5747
# [0.6885, 0.7113, 0.7359, 0.6903, 0.721, 0.6808, 0.6987, 0.6849, 0.6871, 0.6845, 0.6866, 0.6844]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 32)
# pool shape: (None, 1, 32)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 1, 10, 32)    1280        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1, 10, 32)    128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 10, 32)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 1, 32)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 32)        0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1, 32)        0           reshape_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1, 33)        0           batch_normalization_5[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 33)           0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          4080        reshape_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_3[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 12,829
# Trainable params: 12,755
# Non-trainable params: 74
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5678
#  epoch:1 auc: 0.5619
#  epoch:2 auc: 0.5733
#  epoch:3 auc: 0.5627
#  epoch:4 auc: 0.5739
#  epoch:5 auc: 0.5619
#  epoch:6 auc: 0.5727
#  epoch:7 auc: 0.5749
#  epoch:8 auc: 0.5771
#  epoch:9 auc: 0.5658
#  epoch:10 auc: 0.5708
#  epoch:11 auc: 0.5869
# AUC:  0.5869
# [0.6891, 0.7475, 0.7162, 0.7064, 0.6954, 0.6926, 0.7009, 0.7014, 0.7039, 0.7154, 0.6903, 0.7026]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 32)
# pool shape: (None, 1, 32)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 10, 32)    1280        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 1, 10, 32)    128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 10, 32)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 1, 32)     0           activation_2[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 32)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1, 32)        0           reshape_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 33)        0           batch_normalization_8[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 33)           0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          4080        reshape_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_5[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 12,829
# Trainable params: 12,755
# Non-trainable params: 74
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5591
#  epoch:1 auc: 0.5278
#  epoch:2 auc: 0.5472
#  epoch:3 auc: 0.5472
#  epoch:4 auc: 0.5574
#  epoch:5 auc: 0.5486
#  epoch:6 auc: 0.5643
#  epoch:7 auc: 0.5438
#  epoch:8 auc: 0.5686
#  epoch:9 auc: 0.5832
#  epoch:10 auc: 0.5582
#  epoch:11 auc: 0.5692
# AUC:  0.5692
# [0.691, 0.7049, 0.7019, 0.7054, 0.712, 0.7239, 0.707, 0.7348, 0.7108, 0.7047, 0.7063, 0.7088]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 32)
# pool shape: (None, 1, 32)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 10, 32)    1280        zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 1, 10, 32)    128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 10, 32)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 32)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 32)        0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1, 32)        0           reshape_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1, 33)        0           batch_normalization_11[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 33)           0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          4080        reshape_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_7[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 12,829
# Trainable params: 12,755
# Non-trainable params: 74
# __________________________________________________________________________________________________
# in fit, val_y:  121.0 test_y 121.0 train_y 366.0
#  epoch:0 auc: 0.5450
#  epoch:1 auc: 0.5585
#  epoch:2 auc: 0.5459
#  epoch:3 auc: 0.5611
#  epoch:4 auc: 0.5711
#  epoch:5 auc: 0.5514
#  epoch:6 auc: 0.5767
#  epoch:7 auc: 0.5894
#  epoch:8 auc: 0.5913
#  epoch:9 auc: 0.5778
#  epoch:10 auc: 0.5864
#  epoch:11 auc: 0.5964
# AUC:  0.5964
# [0.69, 0.6952, 0.6967, 0.6964, 0.7024, 0.7277, 0.6967, 0.6858, 0.683, 0.6934, 0.6827, 0.6831]
# 13408
# avg_AUC :  0.5818118504582179
# avg_AUC_2 :  0.5821442647584092
#          0         1         2   ...        9         10        11
# 0  0.583386  0.498163  0.561767  ...  0.582626  0.578548  0.573861
# 1  0.567131  0.562337  0.573742  ...  0.565509  0.570636  0.586176
# 2  0.558926  0.527779  0.547665  ...  0.583203  0.557342  0.569016
# 3  0.544403  0.558598  0.545133  ...  0.578160  0.586807  0.595781
#
# [4 rows x 12 columns]
# 0     0.563462
# 1     0.536719
# 2     0.557077
# 3     0.563906
# 4     0.572125
# 5     0.566072
# 6     0.571537
# 7     0.574679
# 8     0.578967
# 9     0.577375
# 10    0.573333
# 11    0.581208
# dtype: float64
# init A shape:  (53635, 42)
# (53635, 1, 1) (53635, 1, 10, 4) 487.0
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 36)
# pool shape: (None, 1, 36)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 10, 36)    1440        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 1, 10, 36)    144         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 10, 36)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 36)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 36)        0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 1, 36)        0           reshape_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 1, 37)        0           batch_normalization_14[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 37)           0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          4560        reshape_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_9[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 13,485
# Trainable params: 13,403
# Non-trainable params: 82
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.6008
#  epoch:1 auc: 0.5651
#  epoch:2 auc: 0.6052
#  epoch:3 auc: 0.6105
#  epoch:4 auc: 0.5902
#  epoch:5 auc: 0.5907
#  epoch:6 auc: 0.5779
#  epoch:7 auc: 0.6067
#  epoch:8 auc: 0.6095
#  epoch:9 auc: 0.6231
#  epoch:10 auc: 0.6232
#  epoch:11 auc: 0.6104
# AUC:  0.6104
# [0.6901, 0.7263, 0.7559, 0.6868, 0.7498, 0.7025, 0.7239, 0.6996, 0.6846, 0.6791, 0.6838, 0.6892]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 36)
# pool shape: (None, 1, 36)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 10, 36)    1440        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1, 10, 36)    144         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 10, 36)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 1, 1, 36)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 36)        0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 1, 36)        0           reshape_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 1, 37)        0           batch_normalization_17[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 37)           0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          4560        reshape_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_11[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 13,485
# Trainable params: 13,403
# Non-trainable params: 82
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5643
#  epoch:1 auc: 0.5490
#  epoch:2 auc: 0.5627
#  epoch:3 auc: 0.5753
#  epoch:4 auc: 0.5815
#  epoch:5 auc: 0.5950
#  epoch:6 auc: 0.5909
#  epoch:7 auc: 0.5999
#  epoch:8 auc: 0.5882
#  epoch:9 auc: 0.6107
#  epoch:10 auc: 0.5964
#  epoch:11 auc: 0.5859
# AUC:  0.5859
# [0.6886, 0.7498, 0.7154, 0.7021, 0.7178, 0.6937, 0.7424, 0.6891, 0.6843, 0.6829, 0.6821, 0.6879]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 36)
# pool shape: (None, 1, 36)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 10, 36)    1440        zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 1, 10, 36)    144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 10, 36)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 1, 1, 36)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 1, 36)        0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 1, 36)        0           reshape_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 1, 37)        0           batch_normalization_20[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 37)           0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          4560        reshape_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_13[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 13,485
# Trainable params: 13,403
# Non-trainable params: 82
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5512
#  epoch:1 auc: 0.5399
#  epoch:2 auc: 0.5570
#  epoch:3 auc: 0.5556
#  epoch:4 auc: 0.5738
#  epoch:5 auc: 0.5899
#  epoch:6 auc: 0.5775
#  epoch:7 auc: 0.5677
#  epoch:8 auc: 0.5708
#  epoch:9 auc: 0.5768
#  epoch:10 auc: 0.5739
#  epoch:11 auc: 0.5819
# AUC:  0.5819
# [0.6937, 0.738, 0.7208, 0.7204, 0.7166, 0.7162, 0.6949, 0.7166, 0.697, 0.7082, 0.707, 0.7056]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 36)
# pool shape: (None, 1, 36)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 10, 36)    1440        zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 1, 10, 36)    144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1, 10, 36)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 1, 1, 36)     0           activation_7[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 1, 36)        0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 1, 36)        0           reshape_14[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1, 37)        0           batch_normalization_23[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 37)           0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          4560        reshape_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_15[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 13,485
# Trainable params: 13,403
# Non-trainable params: 82
# __________________________________________________________________________________________________
# in fit, val_y:  121.0 test_y 121.0 train_y 366.0
#  epoch:0 auc: 0.5497
#  epoch:1 auc: 0.5799
#  epoch:2 auc: 0.5553
#  epoch:3 auc: 0.5793
#  epoch:4 auc: 0.5788
#  epoch:5 auc: 0.5813
#  epoch:6 auc: 0.5891
#  epoch:7 auc: 0.6021
#  epoch:8 auc: 0.6069
#  epoch:9 auc: 0.6116
#  epoch:10 auc: 0.6194
#  epoch:11 auc: 0.6018
# AUC:  0.6018
# [0.6937, 0.6966, 0.7411, 0.6954, 0.704, 0.755, 0.7147, 0.685, 0.6879, 0.7002, 0.6767, 0.6847]
# 13408
# avg_AUC :  0.5950139245308826
# avg_AUC_2 :  0.5950707453891304
#          0         1         2   ...        9         10        11
# 0  0.599098  0.566404  0.604972  ...  0.622629  0.622438  0.611151
# 1  0.564415  0.547948  0.562143  ...  0.608826  0.593986  0.585142
# 2  0.550300  0.540392  0.555805  ...  0.574226  0.574522  0.580737
# 3  0.548850  0.580251  0.554377  ...  0.610175  0.618776  0.602123
#
# [4 rows x 12 columns]
# 0     0.565666
# 1     0.558749
# 2     0.569324
# 3     0.580139
# 4     0.581393
# 5     0.589599
# 6     0.584472
# 7     0.593756
# 8     0.593604
# 9     0.603964
# 10    0.602430
# 11    0.594788
# dtype: float64
# init A shape:  (53635, 42)
# (53635, 1, 1) (53635, 1, 10, 4) 487.0
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 46)
# pool shape: (None, 1, 46)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 10, 46)    1840        zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 1, 10, 46)    184         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1, 10, 46)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 1, 1, 46)     0           activation_8[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 1, 46)        0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 1, 46)        0           reshape_16[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 1, 47)        0           batch_normalization_26[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 47)           0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          5760        reshape_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_17[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 15,125
# Trainable params: 15,023
# Non-trainable params: 102
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5936
#  epoch:1 auc: 0.5832
#  epoch:2 auc: 0.6009
#  epoch:3 auc: 0.6166
#  epoch:4 auc: 0.6138
#  epoch:5 auc: 0.5913
#  epoch:6 auc: 0.5977
#  epoch:7 auc: 0.5951
#  epoch:8 auc: 0.5959
#  epoch:9 auc: 0.6357
#  epoch:10 auc: 0.6335
#  epoch:11 auc: 0.6222
# AUC:  0.6222
# [0.6908, 0.7074, 0.7247, 0.6997, 0.7404, 0.6947, 0.6929, 0.6976, 0.6928, 0.6793, 0.6921, 0.6818]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 46)
# pool shape: (None, 1, 46)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 1, 19, 4)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 10, 46)    1840        zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 1, 10, 46)    184         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1, 10, 46)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 1, 1, 46)     0           activation_9[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 1, 46)        0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 1, 46)        0           reshape_18[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 1, 47)        0           batch_normalization_29[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 47)           0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          5760        reshape_19[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_19[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 15,125
# Trainable params: 15,023
# Non-trainable params: 102
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5491
#  epoch:1 auc: 0.5387
#  epoch:2 auc: 0.5723
#  epoch:3 auc: 0.5788
#  epoch:4 auc: 0.5721
#  epoch:5 auc: 0.5899
#  epoch:6 auc: 0.5870
#  epoch:7 auc: 0.5665
#  epoch:8 auc: 0.5463
#  epoch:9 auc: 0.5453
#  epoch:10 auc: 0.5529
#  epoch:11 auc: 0.5360
# AUC:  0.536
# [0.6904, 0.7155, 0.705, 0.6973, 0.6931, 0.7101, 0.6958, 0.6893, 0.692, 0.7124, 0.6999, 0.7024]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 46)
# pool shape: (None, 1, 46)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 1, 19, 4)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 1, 10, 46)    1840        zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 1, 10, 46)    184         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 10, 46)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 1, 1, 46)     0           activation_10[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# ...
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 1, 77)        0           batch_normalization_62[0][0]
#                                                                  dropout_40[0][0]
# __________________________________________________________________________________________________
# reshape_41 (Reshape)            (None, 77)           0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          9360        reshape_41[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_41[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 20,045
# Trainable params: 19,883
# Non-trainable params: 162
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5870
#  epoch:1 auc: 0.4551
#  epoch:2 auc: 0.6076
#  epoch:3 auc: 0.6224
#  epoch:4 auc: 0.5894
#  epoch:5 auc: 0.5759
#  epoch:6 auc: 0.6006
#  epoch:7 auc: 0.6013
#  epoch:8 auc: 0.5917
#  epoch:9 auc: 0.6292
#  epoch:10 auc: 0.6060
#  epoch:11 auc: 0.5970
# AUC:  0.597
# [0.691, 0.7131, 0.7356, 0.7291, 0.7761, 0.7341, 0.732, 0.7306, 0.693, 0.685, 0.6847, 0.6889]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 76)
# pool shape: (None, 1, 76)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 1, 19, 4)     0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 1, 10, 76)    3040        zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 1, 10, 76)    304         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 1, 10, 76)    0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 1, 1, 76)     0           activation_21[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_42 (Reshape)            (None, 1, 76)        0           max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 1, 76)        0           reshape_42[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 1, 77)        0           batch_normalization_65[0][0]
#                                                                  dropout_42[0][0]
# __________________________________________________________________________________________________
# reshape_43 (Reshape)            (None, 77)           0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          9360        reshape_43[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_43[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 20,045
# Trainable params: 19,883
# Non-trainable params: 162
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5838
#  epoch:1 auc: 0.5644
#  epoch:2 auc: 0.5721
#  epoch:3 auc: 0.5736
#  epoch:4 auc: 0.5782
#  epoch:5 auc: 0.5923
#  epoch:6 auc: 0.5867
#  epoch:7 auc: 0.5886
#  epoch:8 auc: 0.5921
#  epoch:9 auc: 0.5948
#  epoch:10 auc: 0.5855
#  epoch:11 auc: 0.5931
# AUC:  0.5931
# [0.6871, 0.7074, 0.7141, 0.6893, 0.6854, 0.7028, 0.7033, 0.6907, 0.7043, 0.7005, 0.7011, 0.6938]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 76)
# pool shape: (None, 1, 76)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 1, 19, 4)     0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 1, 10, 76)    3040        zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 1, 10, 76)    304         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 1, 10, 76)    0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 1, 1, 76)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_44 (Reshape)            (None, 1, 76)        0           max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 1, 76)        0           reshape_44[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 1, 77)        0           batch_normalization_68[0][0]
#                                                                  dropout_44[0][0]
# __________________________________________________________________________________________________
# reshape_45 (Reshape)            (None, 77)           0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          9360        reshape_45[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_45[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 20,045
# Trainable params: 19,883
# Non-trainable params: 162
# __________________________________________________________________________________________________
# in fit, val_y:  122.0 test_y 122.0 train_y 365.0
#  epoch:0 auc: 0.5503
#  epoch:1 auc: 0.5341
#  epoch:2 auc: 0.5499
#  epoch:3 auc: 0.5720
#  epoch:4 auc: 0.5765
#  epoch:5 auc: 0.5664
#  epoch:6 auc: 0.5815
#  epoch:7 auc: 0.5599
#  epoch:8 auc: 0.5661
#  epoch:9 auc: 0.5768
#  epoch:10 auc: 0.5806
#  epoch:11 auc: 0.5959
# AUC:  0.5959
# [0.6941, 0.7498, 0.741, 0.7184, 0.7447, 0.7133, 0.7354, 0.74, 0.7371, 0.7432, 0.7206, 0.7397]
# 13409
# shape after padding: (None, 1, 19, 4)
# conv shape: (None, 1, 10, 76)
# pool shape: (None, 1, 76)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 1, 10, 4)]   0
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 1, 10, 4)     16          input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 1, 19, 4)     0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 1, 10, 76)    3040        zero_padding2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 1, 10, 76)    304         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 1, 10, 76)    0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 1, 1, 76)     0           activation_23[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 1, 1)]       0
# __________________________________________________________________________________________________
# reshape_46 (Reshape)            (None, 1, 76)        0           max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 1, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 1, 76)        0           reshape_46[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 1, 77)        0           batch_normalization_71[0][0]
#                                                                  dropout_46[0][0]
# __________________________________________________________________________________________________
# reshape_47 (Reshape)            (None, 77)           0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# dense0 (Dense)                  (None, 120)          9360        reshape_47[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 120)          0           dense0[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 60)           7260        dropout_47[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            61          dense[0][0]
# ==================================================================================================
# Total params: 20,045
# Trainable params: 19,883
# Non-trainable params: 162
# __________________________________________________________________________________________________
# in fit, val_y:  121.0 test_y 121.0 train_y 366.0
#  epoch:0 auc: 0.5741
#  epoch:1 auc: 0.5913
#  epoch:2 auc: 0.5754
#  epoch:3 auc: 0.6001
#  epoch:4 auc: 0.6001
#  epoch:5 auc: 0.5812
#  epoch:6 auc: 0.5994
#  epoch:7 auc: 0.6325
#  epoch:8 auc: 0.6263
#  epoch:9 auc: 0.5962
#  epoch:10 auc: 0.6222
#  epoch:11 auc: 0.6442
# AUC:  0.6442
# [0.6896, 0.689, 0.7234, 0.6833, 0.6928, 0.7277, 0.6841, 0.6669, 0.6688, 0.6935, 0.6703, 0.6654]
# 13408
# avg_AUC :  0.6075499643642093
# avg_AUC_2 :  0.6075360364243982
#          0         1         2   ...        9         10        11
# 0  0.585746  0.454684  0.606646  ...  0.629311  0.605035  0.595625
# 1  0.585738  0.565544  0.572258  ...  0.595673  0.585601  0.592184
# 2  0.548938  0.533416  0.549036  ...  0.577281  0.580696  0.594822
# 3  0.571538  0.590466  0.575400  ...  0.596659  0.622019  0.643680
#
# [4 rows x 12 columns]
# 0     0.572990
# 1     0.536027
# 2     0.575835
# 3     0.591136
# 4     0.586314
# 5     0.578768
# 6     0.592314
# 7     0.596021
# 8     0.592850
# 9     0.599731
# 10    0.598338
# 11    0.606578
# dtype: float64

# %%
filter = [24,28,32,36,46,56]
for f in filter:
  w = 1
  perf_cols = v_perf + v_1
  words_cols = selected_new_all_sorted
  label = 'label'
  h = cross_val( df_fl, 'label', \
            perf_cols,\
            words_cols, \
            'model_tcn_w1',w, \
            filters = f)
# Out:
#  ======= v_1 and word changes =========
# init A shape:  (53635, 83)
# (45945, 2, 1) (45945, 2, 20, 2) 408.0
# shape after padding: (None, 2, 39, 2)
# conv shape: (None, 2, 20, 24)
# pool shape: (None, 2, 24)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 20, 2)]   0
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 2, 20, 2)     8           input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 2, 39, 2)     0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 20, 24)    960         zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 2, 20, 24)    96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 2, 20, 24)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 2, 1, 24)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 2, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 2, 24)        0           max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 2, 25)        0           batch_normalization_80[0][0]
#                                                                  reshape_19[0][0]
# __________________________________________________________________________________________________
# bidirectional_19 (Bidirectional (None, 2, 82)        21976       concatenate_19[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 41)           20336       bidirectional_19[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           1344        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_19[0][0]
# ==================================================================================================
# Total params: 44,757
# Trainable params: 44,703
# Non-trainable params: 54
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.6110
#  epoch:1 auc: 0.6185
#  epoch:2 auc: 0.6463
#  epoch:3 auc: 0.6452
#  epoch:4 auc: 0.6597
#  epoch:5 auc: 0.6737
#  epoch:6 auc: 0.6729
#  epoch:7 auc: 0.6700
#  epoch:8 auc: 0.6771
#  epoch:9 auc: 0.6801
# AUC:  0.6801
# [0.6905, 0.6791, 0.6681, 0.6651, 0.6574, 0.6795, 0.682, 0.7173, 0.6523, 0.7366]
# 11487
# shape after padding: (None, 2, 39, 2)
# conv shape: (None, 2, 20, 24)
# pool shape: (None, 2, 24)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 20, 2)]   0
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 2, 20, 2)     8           input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 2, 39, 2)     0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 20, 24)    960         zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 2, 20, 24)    96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 2, 20, 24)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 2, 1, 24)     0           activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 2, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 2, 24)        0           max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 2, 25)        0           batch_normalization_83[0][0]
#                                                                  reshape_20[0][0]
# __________________________________________________________________________________________________
# bidirectional_20 (Bidirectional (None, 2, 82)        21976       concatenate_20[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 41)           20336       bidirectional_20[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           1344        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_20[0][0]
# ==================================================================================================
# Total params: 44,757
# Trainable params: 44,703
# Non-trainable params: 54
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.5555
#  epoch:1 auc: 0.5584
#  epoch:2 auc: 0.5801
#  epoch:3 auc: 0.5983
#  epoch:4 auc: 0.6043
#  epoch:5 auc: 0.6133
#  epoch:6 auc: 0.6255
#  epoch:7 auc: 0.6268
#  epoch:8 auc: 0.6357
#  epoch:9 auc: 0.6421
# AUC:  0.6421
# [0.6925, 0.6907, 0.6853, 0.694, 0.6978, 0.7028, 0.6962, 0.8626, 0.7401, 0.7794]
# 11486
# shape after padding: (None, 2, 39, 2)
# conv shape: (None, 2, 20, 24)
# pool shape: (None, 2, 24)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 20, 2)]   0
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 2, 20, 2)     8           input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 2, 39, 2)     0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 20, 24)    960         zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 2, 20, 24)    96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 2, 20, 24)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 2, 1, 24)     0           activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 2, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 2, 24)        0           max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 2, 25)        0           batch_normalization_86[0][0]
#                                                                  reshape_21[0][0]
# __________________________________________________________________________________________________
# bidirectional_21 (Bidirectional (None, 2, 82)        21976       concatenate_21[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 41)           20336       bidirectional_21[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           1344        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_21[0][0]
# ==================================================================================================
# Total params: 44,757
# Trainable params: 44,703
# Non-trainable params: 54
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.5896
#  epoch:1 auc: 0.5963
#  epoch:2 auc: 0.6235
#  epoch:3 auc: 0.6427
#  epoch:4 auc: 0.6518
#  epoch:5 auc: 0.6654
#  epoch:6 auc: 0.6705
#  epoch:7 auc: 0.6877
#  epoch:8 auc: 0.6867
#  epoch:9 auc: 0.6985
# AUC:  0.6985
# [0.6909, 0.6814, 0.6763, 0.6639, 0.6597, 0.6469, 0.7013, 0.6714, 0.7369, 0.798]
# 11486
# shape after padding: (None, 2, 39, 2)
# conv shape: (None, 2, 20, 24)
# pool shape: (None, 2, 24)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 2, 20, 2)]   0
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 2, 20, 2)     8           input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 2, 39, 2)     0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 20, 24)    960         zero_padding2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 2, 20, 24)    96          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 2, 20, 24)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 2, 1)]       0
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 2, 1, 24)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 2, 1)         4           input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 2, 24)        0           max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 2, 25)        0           batch_normalization_89[0][0]
#                                                                  reshape_22[0][0]
# __________________________________________________________________________________________________
# bidirectional_22 (Bidirectional (None, 2, 82)        21976       concatenate_22[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 41)           20336       bidirectional_22[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           1344        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_22[0][0]
# ==================================================================================================
# Total params: 44,757
# Trainable params: 44,703
# Non-trainable params: 54
# __________________________________________________________________________________________________
# in fit, val_y:  102.0 test_y 102.0 train_y 306.0
#  epoch:0 auc: 0.5751
#  epoch:1 auc: 0.6243
#  epoch:2 auc: 0.6455
#  epoch:3 auc: 0.6593
#  epoch:4 auc: 0.6554
#  epoch:5 auc: 0.6551
#  epoch:6 auc: 0.6527
#  epoch:7 auc: 0.6665
#  epoch:8 auc: 0.6888
#  epoch:9 auc: 0.6923
# AUC:  0.6923
# [0.6922, 0.6784, 0.6663, 0.6502, 0.6622, 0.6541, 0.7802, 0.6509, 0.6563, 0.6658]
# 11486
# avg_AUC :  0.6782565329677348
# avg_AUC_2 :  0.6781417112299465
#           0         1         2  ...         7         8         9
# 0  0.596460  0.619182  0.645461  ...  0.669859  0.676715  0.679949
# 1  0.552030  0.558218  0.581191  ...  0.626367  0.635713  0.642428
# 2  0.574998  0.596124  0.622779  ...  0.687667  0.686478  0.698155
# 3  0.569429  0.623111  0.646964  ...  0.666409  0.688852  0.691964
#
# [4 rows x 10 columns]
# 0    0.573229
# 1    0.599159
# 2    0.624099
# 3    0.636544
# 4    0.642360
# 5    0.651814
# 6    0.655250
# 7    0.662576
# 8    0.671939
# 9    0.678124
# dtype: float64

# %%
print("\n ======= Select columns for LSTM ALL OBS.=========")

result = []

# First choose all varaibles
#cols = v_perf + v_1+ v_2 + selected_new_all #must order like this
w = 3
perf_cols = v_perf + v_1
words_cols = selected_new_all_sorted
label = 'label'
h = cross_val( df_fl, 'label', \
          perf_cols,\
          words_cols, \
          'model_tcn_w3',w, \
          filters = 32)
    
#best_auc = h[0]

# Next, remove one from the list each time
# Out:
#  ======= Select columns for LSTM ALL OBS.=========
# init A shape:  (53635, 166)
# (39123, 3, 15) (39123, 3, 20, 2) 341.0
# shape after padding: (None, 3, 39, 2)
# conv shape: (None, 3, 20, 32)
# pool shape: (None, 3, 32)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 20, 2)]   0
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 3, 20, 2)     8           input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 3, 39, 2)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 3, 20, 32)    1280        zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 3, 20, 32)    128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 3, 20, 32)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 3, 1, 32)     0           activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 3, 32)        0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 3, 47)        0           batch_normalization_35[0][0]
#                                                                  reshape_15[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 3, 126)       55944       concatenate_11[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 63)           47880       bidirectional_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           2048        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_15[0][0]
# ==================================================================================================
# Total params: 107,381
# Trainable params: 107,283
# Non-trainable params: 98
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7162
#  epoch:1 auc: 0.7321
#  epoch:2 auc: 0.7564
#  epoch:3 auc: 0.7616
#  epoch:4 auc: 0.7730
#  epoch:5 auc: 0.7694
#  epoch:6 auc: 0.7759
#  epoch:7 auc: 0.7777
#  epoch:8 auc: 0.7869
#  epoch:9 auc: 0.7879
#  epoch:10 auc: 0.7968
#  epoch:11 auc: 0.8175
#  epoch:12 auc: 0.8005
#  epoch:13 auc: 0.7761
#  epoch:14 auc: 0.8009
#  epoch:15 auc: 0.7736
#  epoch:16 auc: 0.7961
#  epoch:17 auc: 0.7998
#  epoch:18 auc: 0.8004
#  epoch:19 auc: 0.7949
#  epoch:20 auc: 0.8135
#  epoch:21 auc: 0.8096
#  epoch:22 auc: 0.7965
#  epoch:23 auc: 0.8051
#  epoch:24 auc: 0.8045
# AUC:  0.8045
# [0.6721, 0.6428, 0.6007, 0.5854, 0.5673, 0.5727, 0.6192, 0.6244, 0.5428, 0.7229, 0.5731, 0.5447, 0.7105, 0.6944, 0.7127, 1.6605, 0.912, 0.8419, 0.8675, 1.0061, 0.6992, 0.8038, 0.8641, 0.7572, 1.2314]
# 9781
# shape after padding: (None, 3, 39, 2)
# conv shape: (None, 3, 20, 32)
# pool shape: (None, 3, 32)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 20, 2)]   0
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 3, 20, 2)     8           input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 3, 39, 2)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 3, 20, 32)    1280        zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 3, 20, 32)    128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 3, 20, 32)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 3, 1, 32)     0           activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 3, 32)        0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 3, 47)        0           batch_normalization_38[0][0]
#                                                                  reshape_16[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 3, 126)       55944       concatenate_12[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 63)           47880       bidirectional_8[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           2048        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_16[0][0]
# ==================================================================================================
# Total params: 107,381
# Trainable params: 107,283
# Non-trainable params: 98
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7040
#  epoch:1 auc: 0.7175
#  epoch:2 auc: 0.7454
#  epoch:3 auc: 0.7502
#  epoch:4 auc: 0.7856
#  epoch:5 auc: 0.8052
#  epoch:6 auc: 0.8081
#  epoch:7 auc: 0.8094
#  epoch:8 auc: 0.8106
#  epoch:9 auc: 0.8253
#  epoch:10 auc: 0.8136
#  epoch:11 auc: 0.8222
#  epoch:12 auc: 0.8312
#  epoch:13 auc: 0.8165
#  epoch:14 auc: 0.7892
#  epoch:15 auc: 0.8411
#  epoch:16 auc: 0.8170
#  epoch:17 auc: 0.8167
#  epoch:18 auc: 0.7912
#  epoch:19 auc: 0.8182
#  epoch:20 auc: 0.8245
#  epoch:21 auc: 0.8255
#  epoch:22 auc: 0.8239
#  epoch:23 auc: 0.8001
#  epoch:24 auc: 0.8102
# AUC:  0.8102
# [0.662, 0.6299, 0.7085, 0.6947, 0.5621, 0.5782, 0.5344, 0.6196, 0.6009, 0.5466, 0.9948, 0.5496, 0.6449, 0.8239, 1.2295, 0.5872, 0.8564, 1.1343, 1.8464, 1.0976, 0.6703, 1.1923, 0.7453, 0.979, 0.8796]
# 9781
# shape after padding: (None, 3, 39, 2)
# conv shape: (None, 3, 20, 32)
# pool shape: (None, 3, 32)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 20, 2)]   0
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 3, 20, 2)     8           input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 3, 39, 2)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 3, 20, 32)    1280        zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 3, 20, 32)    128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 3, 20, 32)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 3, 1, 32)     0           activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 3, 32)        0           max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 3, 47)        0           batch_normalization_41[0][0]
#                                                                  reshape_17[0][0]
# __________________________________________________________________________________________________
# bidirectional_9 (Bidirectional) (None, 3, 126)       55944       concatenate_13[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 63)           47880       bidirectional_9[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           2048        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_17[0][0]
# ==================================================================================================
# Total params: 107,381
# Trainable params: 107,283
# Non-trainable params: 98
# __________________________________________________________________________________________________
# in fit, val_y:  86.0 test_y 86.0 train_y 255.0
#  epoch:0 auc: 0.6778
#  epoch:1 auc: 0.7086
#  epoch:2 auc: 0.7116
#  epoch:3 auc: 0.7408
#  epoch:4 auc: 0.7490
#  epoch:5 auc: 0.7678
#  epoch:6 auc: 0.7620
#  epoch:7 auc: 0.7724
#  epoch:8 auc: 0.7805
#  epoch:9 auc: 0.7718
#  epoch:10 auc: 0.7961
#  epoch:11 auc: 0.7858
#  epoch:12 auc: 0.7754
#  epoch:13 auc: 0.7830
#  epoch:14 auc: 0.8113
#  epoch:15 auc: 0.7927
#  epoch:16 auc: 0.7979
#  epoch:17 auc: 0.7938
#  epoch:18 auc: 0.7960
#  epoch:19 auc: 0.7392
#  epoch:20 auc: 0.7836
#  epoch:21 auc: 0.7991
#  epoch:22 auc: 0.7949
#  epoch:23 auc: 0.7906
#  epoch:24 auc: 0.7984
# AUC:  0.7984
# [0.6733, 0.6231, 0.6987, 0.6052, 0.6762, 0.6379, 0.7215, 0.8327, 0.7138, 0.6904, 0.6558, 0.7891, 1.029, 1.2143, 0.6782, 0.7388, 0.9002, 1.0707, 1.1398, 3.0835, 1.053, 0.8535, 1.0722, 1.433, 1.4503]
# 9781
# shape after padding: (None, 3, 39, 2)
# conv shape: (None, 3, 20, 32)
# pool shape: (None, 3, 32)
# Model: "model_tcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_words (InputLayer)        [(None, 3, 20, 2)]   0
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 3, 20, 2)     8           input_words[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 3, 39, 2)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 3, 20, 32)    1280        zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 3, 20, 32)    128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 3, 20, 32)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# input_perf (InputLayer)         [(None, 3, 15)]      0
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 3, 1, 32)     0           activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 3, 15)        60          input_perf[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 3, 32)        0           max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 3, 47)        0           batch_normalization_44[0][0]
#                                                                  reshape_18[0][0]
# __________________________________________________________________________________________________
# bidirectional_10 (Bidirectional (None, 3, 126)       55944       concatenate_14[0][0]
# __________________________________________________________________________________________________
# layer_lstm_2 (LSTM)             (None, 63)           47880       bidirectional_10[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           2048        layer_lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_18[0][0]
# ==================================================================================================
# Total params: 107,381
# Trainable params: 107,283
# Non-trainable params: 98
# __________________________________________________________________________________________________
# in fit, val_y:  85.0 test_y 85.0 train_y 256.0
#  epoch:0 auc: 0.7063
#  epoch:1 auc: 0.6881
#  epoch:2 auc: 0.7410
#  epoch:3 auc: 0.7594
#  epoch:4 auc: 0.6961
#  epoch:5 auc: 0.7546
#  epoch:6 auc: 0.7656
#  epoch:7 auc: 0.7631
#  epoch:8 auc: 0.7215
#  epoch:9 auc: 0.7595
#  epoch:10 auc: 0.7547
#  epoch:11 auc: 0.7600
#  epoch:12 auc: 0.7467
#  epoch:13 auc: 0.7316
#  epoch:14 auc: 0.7468
#  epoch:15 auc: 0.7574

# %%
#best_auc
# Out:
# 0.752735165519567

# %%
#all_cols = selected_new_all

# selected_cols = selected_new_all + v_1 + v_2
# random.shuffle(selected_cols)

# for col in selected_cols:
    
#     print("\n ===========Test {}============\n".format(col))
    
#     test_cols = [item for item in selected_cols if item !=col]
#     #test_cols = v_perf + v_1+ v_2 + [col]
    
#     # n1 = 2*len(test_cols)
#     # n2 = len(test_cols)
#     label = 'label'
#     h = cross_val( df_fl, label, test_cols + v_perf, 'lstm_wds', 2)

#     gap = h[0] - best_auc
#     print('****** gap: {0:.4f}'.format(gap))
    
#     result.append([col, h[0], best_auc, gap]) #gap
    
#     if h[0]>= best_auc:  # better to drop col
        
#         selected_cols = test_cols
        
#         best_auc = h[0]
        
#         print("*** {} removed ***".format(col))
    
#     print("current auc: {0:.4f}\tbest_auc: {1:.4f}\tcolumn: {2}".format(h[0], best_auc, col))
#     print("selected columns: ", selected_cols)


# pd.DataFrame(result, columns = ["column", "auc", "prev_auc","gap"]).to_csv("var_selection_lstm_bi_2.csv")

# %%
print(random.shuffle(selected_new_all))

# %%
'Litigious_3_dis' in list(df_fl.columns)
# Out:
# True
